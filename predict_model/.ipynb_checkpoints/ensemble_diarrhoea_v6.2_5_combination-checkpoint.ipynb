# %% [markdown]
# # Matrix of metrics of Cross validation  for 5 top Simple Combination
# Date: 09/12/2022
# Description: Create cross validation metrics
# Use 5 combinations only regarding to the ranking from simple combination result.
# This file creates cross validation metrics for next steps
# Modificaiton 02/01/2023
# Sử dụng 5 combination mới

# %%
# !nvidia-smi
# Out:
# Sat Feb  4 07:53:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.13    Driver Version: 525.60.13    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 6000     On   | 00000000:21:00.0 Off |                  Off |
# | 41%   61C    P2   110W / 260W |   2059MiB / 24576MiB |     82%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     27440      C   ..._diseases_py39/bin/python     1040MiB |
# |    0   N/A  N/A     27963      C   ..._diseases_py39/bin/python     1016MiB |
# +-----------------------------------------------------------------------------+

# %%
# Install packages
# !pip install -U scikit-learn
# !pip install ftfy
# !pip install xlsxwriter 
# !pip install xlwt
# Out:
# Requirement already satisfied: scikit-learn in /home/mlworker/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.8.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ftfy in /home/mlworker/lib/python3.10/site-packages (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/mlworker/lib/python3.10/site-packages (from ftfy) (0.2.5)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
import tensorflow as tf 
# from google.colab import drive
import os

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense

import traceback
import sys
import copy
import numpy as np
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# lib for LSTM of Meta model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

from ftfy import fix_text
import warnings
warnings.simplefilter("ignore", UserWarning)

plt.rcParams['figure.figsize'] = [7, 3]
import math

# %% [markdown]
# # Global param and project path
# All mix data 1997-2018

# %%
# Attach Google Drive for reading and saving files
# drive.mount('/content/drive')
prj_path = '/home/mlworker/Quang/HealthCare/Source_14012023_v4/'

path_all_mix_data =             prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/'
path_all_mix_data_cnn =         path_all_mix_data+ '/cnn/'
path_all_mix_data_lstm =        path_all_mix_data+ '/lstm/'
path_all_mix_data_lstm_att =    path_all_mix_data+ '/lstm_att/'
path_all_mix_data_tf =          path_all_mix_data+ '/transformer/'

prj_path_opt= prj_path + '/optimize_hyperparam/opt_results/optimize_1997_2018/'

prj_path_result_ensemble =      prj_path+ '/results/ensemble/'
com_path_validation_metrics =   prj_path_result_ensemble+ '/result/weighted_combination/cv_metrics/'

com_eval_path_validation_metrics = prj_path + '/eval_result/21_12_2022_weighted_combination-5-cities/'


# loockback_window for meta model
meta_lookback_window = 3

# %%
com_path_validation_metrics
# Out:
# '/home/mlworker/Quang/HealthCare/Source_14012023_v4//results/ensemble//result/weighted_combination/cv_metrics/'

# %% [markdown]
# # Xây dựng Meta Data Set

# %%
##########################
# Xây Dựng Meta Data Set
meta_test_set_city = {}
meta_train_set_city = {}
meta_data_set_city = {}
# cities = ['An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
#         'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
#         'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
#         'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
#         'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
#         'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
#          'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp']
cities = [
 #     'An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau','Đà Nẵng',
        
#     'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
        
#     'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng', 'Đắk Nông',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
        
#     'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Đắk Lắk',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
        
#     'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
#         'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên','Đồng Tháp'
         ]

for city in cities:  
  meta_test_set = pd.DataFrame()
  meta_train_set = pd.DataFrame() 
  #Note: mỗi bộ all_mix_data sẽ có lenght = 251 (10997 -01/01/2018  và vì 1 dòng đầu bị bỏ đi do quá trình statitionary và remove NAN lúc train)
  lenght_whole_data_city = 251
  ######################################
  # Xử lý data của CNN ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_cnn+'mix_train_test_data_'+city+'_cnn.xlsx')
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index() 
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_cnn = result_test.reset_index(drop=True)  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_cnn = result_train.reset_index(drop=True)
  
  ######################################
  # Xử lý data của LSTM  ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm+'mix_train_test_data_'+city+'_lstm.xlsx')  
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm = result_test.reset_index(drop=True)
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm = result_train.reset_index(drop=True)

  ###########################################
  # Xử lý data của LSTM ATT ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm_att+'mix_train_test_data_'+city+'_lstm_att.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm_att = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36]
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm_att = result_train.reset_index(drop=True)


  #############################################
  # Xử lý data của Transformer ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_tf+'mix_train_test_data_'+city+'_tf.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
  meta_test_tf = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36] # Lấy từ meta_lookback_window cho đến -36 (3 năm cuối)
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_tf = result_train.reset_index(drop=True)

  
  meta_test_set['cnn_pred'] = meta_test_cnn
  meta_test_set['lstm_pred'] = meta_test_lstm
  meta_test_set['lstm_att_pred'] = meta_test_lstm_att
  meta_test_set['tf_pred'] = meta_test_tf
  meta_test_set['Observed'] = meta_test_observed
   
  meta_train_set['cnn_pred'] = meta_train_cnn
  meta_train_set['lstm_pred'] = meta_train_lstm
  meta_train_set['lstm_att_pred'] = meta_train_lstm_att 
  meta_train_set['tf_pred'] = meta_train_tf  
  meta_train_set['Observed'] = meta_train_observed

  meta_test_set_city[city] = meta_test_set # test set có chiều dài 39
  meta_train_set_city[city] = meta_train_set # train set có chiều dài 212 = 252 -36 (train) - 1 (station) - 3 (meta_lookback_window)

  # Đoạn này làm thêm. Nối dài meta_test_set_city và meta_train_set_city
  # lưu ý đoạn này sẽ tạo ra data có chiều dài = 252 - 1 (bỏ đi 1 tháng đầu do xử lý stationary) - meta_lookback_window
  df = meta_train_set.append(meta_test_set[3:])
  df = df.reset_index(drop=True)
  # range date từ 1 + lookback_window tháng đầu tiên
  
  df['year_month'] = pd.Series(pd.date_range("1997-05-01", periods=248, freq="M"))  
  meta_data_set_city[city] = df
  df.to_excel(prj_path_result_ensemble+'/meta_data/meta_data_'+city+'.xlsx')
# Out:
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-6-194a236b233b>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-6-194a236b233b>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-6-194a236b233b>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])

# %% [markdown]
# # Danh sách các based Model và các Combination có thể của nó

# %%
# Danh sách các based Model và các Combination có thể của nó
list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

combs_features = list(combinations(list_based_model[0:], 2)) + list(combinations(list_based_model[0:], 3)) + list(combinations(list_based_model[0:], 4))

# list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

# combs_features = list(combinations(list_based_model[0:], 3)) 
combs_features
# Out:
# [('cnn_pred', 'lstm_att_pred'),
#  ('cnn_pred', 'lstm_pred'),
#  ('cnn_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred'),
#  ('lstm_att_pred', 'tf_pred'),
#  ('lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred', 'tf_pred')]

# %% [markdown]
# # Selected 5 Combination

# %%
selected_combs = ['LSTM*cnn_pred-lstm_pred-Observed']
def is_in_Selected_combination(comb_string = ''):
    return any(comb_string in x for x in selected_combs)

# %% [markdown]
# # Support Functions and Train class

# %%
import requests

def send_to_telegram(message):

    apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
    chatID = '@ptn_announcement'
    apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

    try:
        response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
        print(response.text)
    except Exception as e:
        print(e)


def seed_everything(seed: int):
    import random, os    
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything(42)

# Set hyperparameters as args using the Configuration class
class Configuration():
    def __init__(self):
      # lấy bộ test dài 36 tháng = 3 năm
        self.test_size = 36
        # là nhìn vào dữ liệu trước 3 tháng và dự phóng        
        self.look_back = 3
        # dự phóng 3 tháng
        self.n_predicted_month = 3
        self.n_features = 3
        self.seed = 42
        # mỗi phần tử x trong tập suppervise có độ lớn là 16 = 16 tháng
        self.batch_size = 16
        # self.device = torch.device("cuda")
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.epochs = 300
     

# Biến args lưu giá trị Global.
args = Configuration()


# Lưu ý sau khi stationnary thì dòng đầu tiên trừ cho dòng trước nữa là ko có cho nên về cơ bản sẽ thành NaN
# Cần remove dòng đầu tiên ra khỏi data để train và test. Cho nên cơ bản là data sau khi in ra sẽ thiếu 1 đơn vị đầu tiên
def convert_to_stationary(city_data):
    """Subtracts previous value for all cols except disease rates"""
    for col_name in city_data.columns:
        if col_name != 'Diarrhoea_rates':
            try:
                city_data[col_name] = city_data[col_name] - city_data[col_name].shift()
            except:
                print(col_name)
    return city_data

def impute_missing_value(city_data):
    """
    Cơ bản dữ liệu bị thiếu sót rất nhiều: Như Điện Biên 1997 -2003 là thiếu dữ liệu về bệnh
    Hàm này sẽ tự sinh ra dữ liệu bị thiếu. Nếu tháng nào không có số liệu thì tính như sau:
    12 tháng đầu không có số liệu thì gán = 0
    tháng 13-24 không có số liệu, sẽ lấy giá trị của tháng cùng kỳ năm trước
    tháng từ 24 trở đi sẽ lấy giá trị nhỏ nhất của 2 tháng cùng kỳ trong 2 năm gần nhất.
    Do Điện Biên bằng 0 nên sau khi xử lý từ 1997 -2003 là đều = 0.  
    """
    for col in city_data.columns:
        for index in range(len(city_data[col])):
            if np.isnan(city_data[col].iloc[index]):
                if index < 12:
                    city_data[col].iloc[index] = 0
                elif index >= 12 and index <= 24:
                    city_data[col].iloc[index] = city_data[col].iloc[index - 12]
                else:
                    city_data[col].iloc[index] = min(city_data[col].iloc[index - 12], city_data[col].iloc[index - 24])
    return city_data

def split_data(data, look_back ):
    """Splits data into train and test sets based on args (Configuration class)"""
    train = data[: -args.test_size]    
    test = data[-args.test_size - look_back: ]
    return train, test

def to_supervised(data, d_in=args.look_back, d_out=args.n_predicted_month, features_list=[]):
    """
    Frames time-series as supervised learning dataset.
    
    Args:
      d_in: lookback window
      d_out: number of predicted months
      features_list: list of all features **where last col is the disease incidence**

    Returns:
      Numpy arrays of disease incidence (y) and other predictors (X)
    """
    X, y = list(), list()
    for index, _ in enumerate(data):
        in_end = index + d_in
        out_end = in_end + d_out
        if out_end <= len(data):
            if len(features_list) == 0 :
                X.append(data[index: in_end, :])
            else:
                X.append(data[index: in_end, features_list])
            y.append(data[in_end: out_end, -1])
    return np.array(X), np.array(y)


def get_data(train_np, test_np, batch_size, list_selected_features, origin_city_meta_data):
    """
    Returns important feature list and data formatted for input into Pytorch 
    models
    """ 
    # origin_city_meta_data chứa data mẫu để lấy index 
    # important_features = arrary index nên ta phải truyền indexex của columns
    important_features = [origin_city_meta_data.columns.get_loc(c) for c in list_selected_features if c in origin_city_meta_data]  

    train_X, train_y = to_supervised(train_np, features_list=important_features)
    test_X, test_y = to_supervised(test_np, features_list=important_features)
    train_tensor = TensorDataset(torch.from_numpy(train_X), torch.from_numpy(train_y))
    test_tensor = (torch.from_numpy(test_X), torch.from_numpy(test_y))

    train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

    return important_features, train_loader, test_tensor

#Define Pytorch LSTM model
class MultiVariateLSTM(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = output[:, -1, :]
        y_predicted = self.linear(last_hidden_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            #return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

#Define Pytorch LSTM-ATT model
class MultiVariateLSTM_Attention(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.attention_linear = nn.Linear(hidden_size, hidden_size)
        # self.linear = nn.Linear(hidden_size*2, args.n_predicted_month)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = last_hidden[-1]
        remain_hidden_vector = output
        e_t = remain_hidden_vector.bmm(self.attention_linear(last_hidden_vector).unsqueeze(2)).squeeze(-1)
        alpha_t = F.softmax(e_t, dim=1)
        attenion_vector = remain_hidden_vector.transpose(2, 1).bmm(alpha_t.unsqueeze(2)).squeeze(-1)
        # combine_vector = torch.cat((last_hidden_vector, attenion_vector), dim=1)
        # combine_vector = last_hidden_vector + attenion_vector
        y_predicted = self.linear(attenion_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Define Pytorch CNN model
class MultivariateCNN(nn.Module):
    def __init__(self, num_filters=[100, 100, 100], dropout=0.01):
        super(MultivariateCNN, self).__init__()
        self.loss_fn = loss = nn.MSELoss()
        self.filter_sizes = [1, 2, 3]
        self.conv1d_list = nn.ModuleList([nn.Conv1d(args.n_features, num_filters[i], self.filter_sizes[i]) for i in range(len(self.filter_sizes))])
        self.linear = nn.Linear(np.sum(num_filters), args.n_predicted_month)
        self.dropout = nn.Dropout(dropout)
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))

    def forward(self, X_batch, y_batch=None):
        X_batch = X_batch.permute(0, 2, 1)  #(batch_size, n_features, n_look_back)
        X_conv_list = [F.relu(conv1d(X_batch)) for conv1d in self.conv1d_list]
        X_pool_list = [F.max_pool1d(x_conv, kernel_size=x_conv.shape[2]) for x_conv in X_conv_list]
        X_fc = torch.cat([x_pool.squeeze(dim=2) for x_pool in X_pool_list], dim=1)
        y_predicted = self.linear(self.dropout(X_fc))
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted

    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Transformer Model
# Transformer Model
class PositionalEncoder(nn.Module):
    def __init__(self, n_feature=3, dropout=0.1, max_length=24):
        super().__init__()
        
        self.hidden_dim = n_feature
        self.max_length = max_length
        self.dropout = nn.Dropout(dropout)
        
        pe = torch.zeros(max_length, self.hidden_dim)
        for pos in range(max_length):
            for i in range(0, self.hidden_dim, 2):
                pe[pos, i] = math.sin(pos/(10000**(2*i/self.hidden_dim)))
                if i + 1 < self.hidden_dim:
                    pe[pos, i+1] = math.cos(pos/(10000**((2*i+1)/self.hidden_dim)))
        pe = pe.unsqueeze(0)        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x*math.sqrt(self.hidden_dim)
        length = x.size(1)
        pe = Variable(self.pe[:, :length], requires_grad=False)
        if x.is_cuda:
            pe.cuda()
        x = x + pe
        x = self.dropout(x)
        
        return x

class TransformerModel(nn.Module):
    def __init__(self, d_input, n_look_back, hidden_size, n_layers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.hidden_size = hidden_size

        self.pe = PositionalEncoder(n_feature=args.n_features, dropout=dropout)

        encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dim_feedforward=hidden_size, dropout=dropout, activation='gelu')
        # encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)
        self.decoder = nn.Linear(d_input*n_look_back, args.n_predicted_month)

        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
        
        self.loss_fn = nn.MSELoss()
        
    
    def forward(self, X_batch, y_batch=None):
        X_batch = self.pe(X_batch)
        X_batch = self.transformer_encoder(X_batch)
        X_batch = X_batch.view(X_batch.size(0), -1)
        
        y_predicted = self.decoder(X_batch)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
        else:
            return y_predicted
        return X_batch
    
    def predict(self, X):
        with torch.no_grad():
            X = torch.tensor(X, device=args.device)
        return self.forward(X).squeeze()

# Create class to train and evaluate models
class Trainer():
    def __init__(self, city, model_type, learning_rate, important_features, train_loader, test_tensor, n_layers=2, hidden_size=128, num_filters=[100, 100, 100], dropout=0.01):
        """
        Initialise trainer, allowing input of LSTM, LSTM-ATT, or CNN 
        hyperparameters. Adam optimiser used for all models.
        """
        self.model_type = model_type    
        self.city = city    
        self.model = self.init_model(model_type, n_layers, hidden_size, num_filters, dropout, city)
        self.model.double().to(args.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.important_features, self.train_loader, self.test_tensor = important_features, train_loader, test_tensor
    
    def init_model(self, model_type, n_layers, hidden_size, num_filters, dropout, city):        
        #Get hyper param by name and set for n_layers, hidden_size, num_filters, dropout and overwrite the input param  
        # n_layers, hidden_size,num_filters, dropout= get_opt_param_by_name( algo = model_type, city = city)
    
        """Initialise a model based on whether LSTM, LSTM-ATT, or CNN is chosen."""
        if model_type.lower() == 'lstm':
            model = MultiVariateLSTM(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'lstm_attention':
            model = MultiVariateLSTM_Attention(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'cnn':
            model = MultivariateCNN(num_filters, dropout)
        elif model_type.lower() == 'transformers':
            model = TransformerModel(d_input=args.n_features, n_look_back=args.look_back, hidden_size=hidden_size, n_layers=n_layers, dropout=dropout)
        return model

    def step(self, batch):
        self.model.train()
        X_batch, y_batch = tuple(t.to(args.device) for t in batch)
        self.optimizer.zero_grad()
        y_pred, loss = self.model.forward(X_batch, y_batch)
        loss.backward()
        self.optimizer.step()
        return loss.mean().item()

    def validation(self):
        self.model.eval()
        eval_loss = 0.0

        result = {}

        y_true = np.array([])
        y_pred = np.array([])

        X_batch, y_batch = tuple(t.to(args.device) for t in self.test_tensor)
        with torch.no_grad():
            outputs, loss = self.model.forward(X_batch, y_batch)
            eval_loss = loss.mean().item()

        return eval_loss

    def train(self, epochs=20):
        # print('param of model')
        # print('hidensize',self.model.hidden_size)
        # print('nlayer',self.model.n_layers)  
        best_lost = float("inf")
        best_model = None
        for epoch in range(epochs):
            total_loss = 0.0
            for batch in self.train_loader:
                loss = self.step(batch)
                total_loss += loss
            train_loss = total_loss/len(self.train_loader)
            eval_loss = self.validation()
            if eval_loss < best_lost:
                best_lost = eval_loss
                best_model = copy.deepcopy(self.model)
            if (epoch + 1) == epochs or (epoch + 1) in [c + 1 for c in range(epochs) if c % int(epochs/4) == 0]:
                print(f"Epoch: {epoch:2}/{epochs:2} - train_loss: {train_loss:.4f} - test_loss: {eval_loss:4f}")
        self.model = best_model
        self.model.eval()
        return None



    # Lưu model vào trong thư mục models
    def save_model_to(self, path = '', city =''):       
        torch.save(self.model, path)

    def load_model_to(self, path = ''):       
        return torch.load(path)

    def evaluate_model(self, np_data=None, plot=True, scaled=True, city=None, k_steps=None, y_scaler =None):
        assert scaled, "data must be scaled"
        self.model.eval()
        tensor_data = torch.from_numpy(np_data)
        rmse_list = []
        mae_list = [] 
        mape_list = []

        y_predicted_list = []
        y_true_list = []

        for k_steps in range(1, args.n_predicted_month + 1):
            y_predicted = []
            y_true = []
            for index in range(tensor_data.size(0) - args.look_back):
                X = tensor_data[index: index + args.look_back, self.important_features]
                # yhat = self.model.predict(X.unsqueeze(0)).squeeze()

                yhat = self.model.predict(X.unsqueeze(0))
                yhat = yhat.squeeze()

                y_predicted.append(yhat.detach().cpu().numpy()[k_steps - 1])
                y_true.append(tensor_data[index + args.look_back, -1].detach().cpu().numpy())

            y_predicted = y_scaler.inverse_transform(np.array(y_predicted).reshape(-1, 1)).reshape(-1, )
            y_true = y_scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).reshape(-1, )

            

            rmse = mean_squared_error(y_true, y_predicted, squared=False)
            mae = mean_absolute_error(y_true, y_predicted)
            mape = mean_absolute_percentage_error(y_true, y_predicted)

            rmse_list.append(rmse)
            mae_list.append(mae)
            mape_list.append(mape)

            print('City: '+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))          
            if plot==True:
              plt.grid(True)
              plt.plot(y_predicted, label='predicted')
              plt.plot(y_true, label='actual')
              plt.title(f"k-steps = {k_steps} - city: "+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))
              plt.legend()
              plt.show()

              plt.show()
            y_predicted_list.append(y_predicted)
            y_true_list.append(y_true)

        return y_true_list, y_predicted_list, rmse_list, mae_list, mape_list

# %% [markdown]
# # Get optimized Hyper param

# %%
def convert_str_num_filter_array(str_filter = ''):  
  arr_filter = str_filter.split(',')  
  int_arr_filter= [int(x) for x in arr_filter]
  return int_arr_filter


opt_param_cnn = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_cnn.xlsx', index_col = 'City')
opt_param_lstm = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm.xlsx', index_col = 'City')
opt_param_lstm_att = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm_att.xlsx', index_col = 'City')
opt_param_transformer = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_transformer.xlsx', index_col = 'City')

def get_opt_param_by_name(algo = 'transformers', city = None):
  if algo == 'cnn':
    city_param = opt_param_cnn.loc[city]
    #load  param
    n_layers = ''
    hidden_size = ''
    num_filters = convert_str_num_filter_array(city_param['Num. filters'])
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm':
    city_param = opt_param_lstm.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm_attention':
    city_param = opt_param_lstm_att.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'transformers':
    city_param = opt_param_transformer.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hidden Size'])
    num_filters = ''
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  return n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window


# Manual Check param before train
n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window= get_opt_param_by_name(algo='transformers', city='Cao Bằng')
lookback_window,epoch, hidden_size, n_layers,learning_rate, num_filters, dropout
# Out:
# (3, 270, 36, 6, 0.001205121044593835, '', 0.4761287407623291)

# %% [markdown]
# # Create Cross validation Train/Test set

# %%
# tạo l_train_indices\l_test_indices
data = list(range(212))
min_train_size = 72 # Chiều dài ban đầu train size = 6 năm = 72
test_size = 36 # chiều dài test size 36 tháng
l_train_indices= []
l_test_indices = []
for i in range(min_train_size, len(data)-test_size+1):
    train = np.array(data[0:i])
    test = np.array(data[i:i+test_size])    
    l_train_indices.append(train)
    l_test_indices.append(test)

len(l_test_indices)
# Out:
# 105

# %% [markdown]
# # Function Tạo và Predict. Important (epoch = 1 for test)

# %%
def do_train_predict(city ='', algo = '', list_selected_features = '', origin_city_meta_test_set= '', y_scaler = '', s_selected_features= '', train ='', test ='', sample_idx ='', combination_idx= ''):
    
    metric_reslt = pd.DataFrame()
    n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = algo, city = city)
    # Get data to run model
    important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   

#     epoch = 1 # comment when do experiment
    
    if( algo =='cnn'): 
        algo = 'CNN'    # upper case only
        trainer = Trainer(
                            model_type='cnn',  
                            city = city,                    
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            num_filters= num_filters, 
                            dropout=dropout )

    if( algo =='lstm'):
        algo = 'LSTM'    # upper case only        
        trainer = Trainer(
                            model_type='lstm', 
                            city = city,
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size)

    if( algo =='lstm_attention'): 
        algo = 'LSTM ATT'    # upper case only       
        trainer = Trainer(
                            model_type= 'lstm_attention',
                            city = city,
                            learning_rate= learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers= n_layers,
                            hidden_size=hidden_size )

    if( algo =='transformers'): 
        algo = 'TF'    # upper case only       
        trainer = Trainer(
                            model_type='transformers',
                            city = city, 
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size,
                            dropout=dropout)

    
    # Train model with province-specific epochs
    trainer.train(epochs=epoch)  
    # Evaluate test set   
    y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
        
    metric_reslt = pd.DataFrame({
                                'City': city,
                                'Meta_Model_Name': algo, 
                                'sample_index':sample_idx,
                                'Based_Models': s_selected_features,                                                      
                                # algo+'_'+str(combination_idx)+'_rmse': rmse_list[0],
                                # algo+'_'+str(combination_idx)+'_mae': mae_list[0]
                                algo+'*'+s_selected_features+'_rmse': rmse_list[0],
                                algo+'*'+s_selected_features+'_mae': mae_list[0]
                                }, index=[0]) # do có 1 dòng nên pandas cần index = 0    
  

        
    return metric_reslt

# %% [markdown]
# # Main Cross Validation Metrics Creation
# Tạo ra 105 bộ validation. Xuất ra Metrics (RMSE và MAE) cho 5 bộ giải thuật chọn lựa. (10 cột cho 1 dòng validation )

# %%
dt_started = datetime.now()

l_errCity = {} # có lỗi sẽ lưu vào đây, kiểm tra ngay cell sau

for city in cities:
  pd_all_rows_new_meta_data = pd.DataFrame()

  for sample_index in  range(0,len(l_train_indices)):

    pd_one_row_new_meta_data = pd.DataFrame()
    combination_idx = 0
    for combination_features in combs_features:            
      list_selected_features = [x for x in combination_features] +['Observed'] # Lấy danh sách tên các features + cột Observed 
      s_selected_features = '-'.join([str(elem) for elem in list_selected_features])      

      # Có trong danh sách chọn lựa thì thực hiện dự đoán
      if((is_in_Selected_combination('CNN*'+s_selected_features)==True) or (is_in_Selected_combination('LSTM*'+s_selected_features) == True)):        
        args.n_features = len(list_selected_features) 
        args.look_back = meta_lookback_window  
        cnn_metrics = pd.DataFrame()
        lstm_metrics = pd.DataFrame()

        try:
          # Lấy data từ train set và chia ra theo valiation
          origin_city_meta_train_set = meta_train_set_city[city]
          origin_city_meta_test_set = meta_test_set_city[city]
          
          train = origin_city_meta_train_set.iloc[l_train_indices[sample_index]]
          test = origin_city_meta_train_set.iloc[l_test_indices[sample_index]]        

          # Data train/test processing for all Meta model
          train = train.astype(float)
          test = test.astype(float)

          train = train.replace((np.inf, -np.inf, np.nan), 0)
          test = test.replace((np.inf, -np.inf, np.nan), 0) 
        
          # Đoạn này impute các trường hợp rỗng
          train = impute_missing_value(train)
          test = impute_missing_value(test)

          # Fit data scaler to training data
          full_scaler = MinMaxScaler().fit(train)
          y_scaler = MinMaxScaler().fit(train.values[:, -1].reshape(-1, 1))

          # Scale train and test data
          train = full_scaler.transform(train)
          test = full_scaler.transform(test)

          if(is_in_Selected_combination('CNN*'+s_selected_features)==True):
            ########################################
            ########## CNN 
            ########################################
            cnn_metrics = do_train_predict(city =city, algo='cnn', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)

          if(is_in_Selected_combination('LSTM*'+s_selected_features)==True):
            ########################################
            ########## LSTM 
            ########################################
            lstm_metrics = do_train_predict(city =city, algo='lstm', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)
          

          
          
          ###############################   
          ## Khúc này rất thủ công
          if(cnn_metrics.empty==False and lstm_metrics.empty ==False):              
            join_2_results = pd.concat([cnn_metrics.iloc[:, [4, 5]], lstm_metrics.iloc[:, [4, 5]]], axis=1)
          
          if(cnn_metrics.empty== False and lstm_metrics.empty ==True):
            join_2_results = cnn_metrics.iloc[:, [4, 5]]
          
          if(cnn_metrics.empty== True and lstm_metrics.empty ==False):
            join_2_results = lstm_metrics.iloc[:, [4, 5]]

          if(pd_one_row_new_meta_data.empty):
            pd_one_row_new_meta_data = join_2_results
          else:
            pd_one_row_new_meta_data = pd.concat([join_2_results, pd_one_row_new_meta_data], axis=1)       

          combination_idx = combination_idx + 1
        except Exception as e:
          l_errCity[city] = e
          break    

        
    # Hết vòng lập pd_one_row_new_meta_data chứa 5 bộ kết quả của 1 sameple    
    # Qua sample kế tiếp   
    pd_all_rows_new_meta_data = pd.concat([pd_all_rows_new_meta_data, pd_one_row_new_meta_data], axis=0) 

  
  # Kết thúc hết tất cả validation -> Lưu kết quả cuối cùng ứng với từng thành phố
  pd_all_rows_new_meta_data.to_excel(com_path_validation_metrics+ city+'_5_comb_cv_metrics.xlsx')
  
  # send_to_telegram('Server Chạy city: '+ city)

dt_ended = datetime.now()
run_time = round((dt_ended - dt_started).total_seconds()/60)
print('kết thúc train trong:', run_time)
print ('danh sách error city: ')
print(l_errCity)
# Telegram vào
# Out:
# Epoch:  0/130 - train_loss: 0.8964 - test_loss: 0.681154
# Epoch: 32/130 - train_loss: 0.4292 - test_loss: 0.236684
# Epoch: 64/130 - train_loss: 0.3524 - test_loss: 0.241171
# Epoch: 96/130 - train_loss: 0.4059 - test_loss: 0.247209
# Epoch: 128/130 - train_loss: 0.4472 - test_loss: 0.231105
# Epoch: 129/130 - train_loss: 0.3766 - test_loss: 0.237857
# City: An Giang  _algo:cnn  -RMSE: 44.10444990211916
# City: An Giang  _algo:cnn  -RMSE: 50.480138628069035
# City: An Giang  _algo:cnn  -RMSE: 39.751190379933675
# Epoch:  0/380 - train_loss: 0.8040 - test_loss: 0.800058
# Epoch: 95/380 - train_loss: 0.1944 - test_loss: 0.116406
# Epoch: 190/380 - train_loss: 0.1763 - test_loss: 0.117119
# Epoch: 285/380 - train_loss: 0.1202 - test_loss: 0.138967
# Epoch: 379/380 - train_loss: 0.1597 - test_loss: 0.224454
# City: An Giang  _algo:lstm  -RMSE: 41.05888059043328
# City: An Giang  _algo:lstm  -RMSE: 32.43449125053419
# City: An Giang  _algo:lstm  -RMSE: 34.3991483515056
# Epoch:  0/130 - train_loss: 0.9410 - test_loss: 0.700386
# Epoch: 32/130 - train_loss: 0.3591 - test_loss: 0.208145
# Epoch: 64/130 - train_loss: 0.3444 - test_loss: 0.244023
# Epoch: 96/130 - train_loss: 0.3744 - test_loss: 0.234837
# Epoch: 128/130 - train_loss: 0.3387 - test_loss: 0.249082
# Epoch: 129/130 - train_loss: 0.3898 - test_loss: 0.246936
# City: An Giang  _algo:cnn  -RMSE: 43.80330221578739
# City: An Giang  _algo:cnn  -RMSE: 63.851548608341915
# City: An Giang  _algo:cnn  -RMSE: 60.10020192728153
# Epoch:  0/380 - train_loss: 0.7785 - test_loss: 0.738927
# Epoch: 95/380 - train_loss: 0.2038 - test_loss: 0.131870
# Epoch: 190/380 - train_loss: 0.1512 - test_loss: 0.105599
# Epoch: 285/380 - train_loss: 0.1617 - test_loss: 0.118099
# Epoch: 379/380 - train_loss: 0.1717 - test_loss: 0.128687
# City: An Giang  _algo:lstm  -RMSE: 30.877030792753636
# City: An Giang  _algo:lstm  -RMSE: 29.164722322876262
# City: An Giang  _algo:lstm  -RMSE: 35.93590085270141
# Epoch:  0/130 - train_loss: 0.8838 - test_loss: 0.698684
# Epoch: 32/130 - train_loss: 0.4083 - test_loss: 0.229213
# Epoch: 64/130 - train_loss: 0.3586 - test_loss: 0.239055
# Epoch: 96/130 - train_loss: 0.3427 - test_loss: 0.213944
# Epoch: 128/130 - train_loss: 0.3687 - test_loss: 0.219163
# Epoch: 129/130 - train_loss: 0.3388 - test_loss: 0.218716
# City: An Giang  _algo:cnn  -RMSE: 48.07524343181343
# City: An Giang  _algo:cnn  -RMSE: 46.57984900164508
# City: An Giang  _algo:cnn  -RMSE: 54.21523750068694
# Epoch:  0/380 - train_loss: 0.8591 - test_loss: 0.714518
# Epoch: 95/380 - train_loss: 0.2396 - test_loss: 0.166243
# Epoch: 190/380 - train_loss: 0.1796 - test_loss: 0.101231
# Epoch: 285/380 - train_loss: 0.1376 - test_loss: 0.120580
# Epoch: 379/380 - train_loss: 0.1204 - test_loss: 0.108190
# City: An Giang  _algo:lstm  -RMSE: 32.76374095849853
# City: An Giang  _algo:lstm  -RMSE: 30.381374012994268
# City: An Giang  _algo:lstm  -RMSE: 27.0149607223456
# Epoch:  0/130 - train_loss: 1.0103 - test_loss: 0.673239
# Epoch: 32/130 - train_loss: 0.3752 - test_loss: 0.222377
# Epoch: 64/130 - train_loss: 0.3219 - test_loss: 0.237319
# Epoch: 96/130 - train_loss: 0.3300 - test_loss: 0.245636
# Epoch: 128/130 - train_loss: 0.3264 - test_loss: 0.203400
# Epoch: 129/130 - train_loss: 0.3885 - test_loss: 0.201633
# City: An Giang  _algo:cnn  -RMSE: 50.86033413399474
# City: An Giang  _algo:cnn  -RMSE: 60.30629496430134
# City: An Giang  _algo:cnn  -RMSE: 64.6045150294254
# Epoch:  0/380 - train_loss: 0.7940 - test_loss: 0.733180
# Epoch: 95/380 - train_loss: 0.1996 - test_loss: 0.234240
# Epoch: 190/380 - train_loss: 0.1589 - test_loss: 0.121984
# Epoch: 285/380 - train_loss: 0.0934 - test_loss: 0.142132
# Epoch: 379/380 - train_loss: 0.0957 - test_loss: 0.163137
# City: An Giang  _algo:lstm  -RMSE: 32.51071143784243
# City: An Giang  _algo:lstm  -RMSE: 32.73516663179812
# City: An Giang  _algo:lstm  -RMSE: 27.57043982430328
# Epoch:  0/130 - train_loss: 0.9540 - test_loss: 0.670147
# Epoch: 32/130 - train_loss: 0.3403 - test_loss: 0.226419
# Epoch: 64/130 - train_loss: 0.3833 - test_loss: 0.227794
# Epoch: 96/130 - train_loss: 0.3101 - test_loss: 0.229216
# Epoch: 128/130 - train_loss: 0.3222 - test_loss: 0.247264
# Epoch: 129/130 - train_loss: 0.3144 - test_loss: 0.257981
# City: An Giang  _algo:cnn  -RMSE: 40.852010976274514
# City: An Giang  _algo:cnn  -RMSE: 55.16945071407667
# City: An Giang  _algo:cnn  -RMSE: 59.58383884252567
# Epoch:  0/380 - train_loss: 0.8290 - test_loss: 0.699000
# Epoch: 95/380 - train_loss: 0.1882 - test_loss: 0.154428
# Epoch: 190/380 - train_loss: 0.1539 - test_loss: 0.112861
# Epoch: 285/380 - train_loss: 0.0924 - test_loss: 0.151130
# Epoch: 379/380 - train_loss: 0.0360 - test_loss: 0.167407
# City: An Giang  _algo:lstm  -RMSE: 31.760785747627427
# City: An Giang  _algo:lstm  -RMSE: 27.125111644439876
# City: An Giang  _algo:lstm  -RMSE: 34.41909931050239
# Epoch:  0/130 - train_loss: 0.8867 - test_loss: 0.682877
# Epoch: 32/130 - train_loss: 0.3634 - test_loss: 0.231311
# Epoch: 64/130 - train_loss: 0.3367 - test_loss: 0.240098
# Epoch: 96/130 - train_loss: 0.3582 - test_loss: 0.236757
# Epoch: 128/130 - train_loss: 0.3179 - test_loss: 0.250487
# Epoch: 129/130 - train_loss: 0.3324 - test_loss: 0.249380
# City: An Giang  _algo:cnn  -RMSE: 35.66338387031759
# City: An Giang  _algo:cnn  -RMSE: 58.87981068410086
# City: An Giang  _algo:cnn  -RMSE: 67.94450395810574
# Epoch:  0/380 - train_loss: 0.7879 - test_loss: 0.732604
# Epoch: 95/380 - train_loss: 0.1843 - test_loss: 0.110914
# Epoch: 190/380 - train_loss: 0.1143 - test_loss: 0.112170
# Epoch: 285/380 - train_loss: 0.0689 - test_loss: 0.151590
# Epoch: 379/380 - train_loss: 0.0252 - test_loss: 0.449302
# City: An Giang  _algo:lstm  -RMSE: 37.13138716548009
# City: An Giang  _algo:lstm  -RMSE: 27.667818773977967
# City: An Giang  _algo:lstm  -RMSE: 31.81945496107444
# Epoch:  0/130 - train_loss: 0.9067 - test_loss: 0.663464
# Epoch: 32/130 - train_loss: 0.3453 - test_loss: 0.228923
# Epoch: 64/130 - train_loss: 0.3253 - test_loss: 0.208076
# Epoch: 96/130 - train_loss: 0.3258 - test_loss: 0.221300
# Epoch: 128/130 - train_loss: 0.3398 - test_loss: 0.237432
# Epoch: 129/130 - train_loss: 0.3394 - test_loss: 0.237814
# City: An Giang  _algo:cnn  -RMSE: 38.26080449208882
# City: An Giang  _algo:cnn  -RMSE: 52.959893370202536
# City: An Giang  _algo:cnn  -RMSE: 59.4661318151047
# Epoch:  0/380 - train_loss: 0.7982 - test_loss: 0.729004
# Epoch: 95/380 - train_loss: 0.1977 - test_loss: 0.211944
# Epoch: 190/380 - train_loss: 0.1226 - test_loss: 0.162886
# Epoch: 285/380 - train_loss: 0.1162 - test_loss: 0.335850
# Epoch: 379/380 - train_loss: 0.0251 - test_loss: 0.707898
# City: An Giang  _algo:lstm  -RMSE: 32.56697261558068
# City: An Giang  _algo:lstm  -RMSE: 31.801674936439337
# City: An Giang  _algo:lstm  -RMSE: 32.98239376460296
# Epoch:  0/130 - train_loss: 0.8652 - test_loss: 0.664310
# Epoch: 32/130 - train_loss: 0.3476 - test_loss: 0.237892
# Epoch: 64/130 - train_loss: 0.3451 - test_loss: 0.253686
# Epoch: 96/130 - train_loss: 0.3302 - test_loss: 0.226190
# Epoch: 128/130 - train_loss: 0.3305 - test_loss: 0.256192
# Epoch: 129/130 - train_loss: 0.3160 - test_loss: 0.243996
# City: An Giang  _algo:cnn  -RMSE: 43.66241165595265
# City: An Giang  _algo:cnn  -RMSE: 53.47898826064405
# City: An Giang  _algo:cnn  -RMSE: 65.81927471899837
# Epoch:  0/380 - train_loss: 0.7559 - test_loss: 0.752923
# Epoch: 95/380 - train_loss: 0.1933 - test_loss: 0.247416
# Epoch: 190/380 - train_loss: 0.1209 - test_loss: 0.136221
# Epoch: 285/380 - train_loss: 0.1235 - test_loss: 0.179921
# Epoch: 379/380 - train_loss: 0.0455 - test_loss: 0.518790
# City: An Giang  _algo:lstm  -RMSE: 38.46250140985628
# City: An Giang  _algo:lstm  -RMSE: 29.6239959593343
# City: An Giang  _algo:lstm  -RMSE: 36.26002808309816
# Epoch:  0/130 - train_loss: 0.9066 - test_loss: 0.681705
# Epoch: 32/130 - train_loss: 0.3518 - test_loss: 0.250544
# Epoch: 64/130 - train_loss: 0.3452 - test_loss: 0.251630
# Epoch: 96/130 - train_loss: 0.3293 - test_loss: 0.224944
# Epoch: 128/130 - train_loss: 0.3304 - test_loss: 0.249373
# Epoch: 129/130 - train_loss: 0.3294 - test_loss: 0.251369
# City: An Giang  _algo:cnn  -RMSE: 48.98582180982104
# City: An Giang  _algo:cnn  -RMSE: 59.00696760296097
# City: An Giang  _algo:cnn  -RMSE: 63.27034304677427
# Epoch:  0/380 - train_loss: 0.8474 - test_loss: 0.782227
# Epoch: 95/380 - train_loss: 0.2125 - test_loss: 0.109651
# Epoch: 190/380 - train_loss: 0.1294 - test_loss: 0.117745
# Epoch: 285/380 - train_loss: 0.1877 - test_loss: 0.165467
# Epoch: 379/380 - train_loss: 0.0664 - test_loss: 0.208814
# City: An Giang  _algo:lstm  -RMSE: 33.19402322489422
# City: An Giang  _algo:lstm  -RMSE: 30.238522175173223
# City: An Giang  _algo:lstm  -RMSE: 33.208321259408656
# Epoch:  0/130 - train_loss: 0.9084 - test_loss: 0.686105
# Epoch: 32/130 - train_loss: 0.3399 - test_loss: 0.280359
# Epoch: 64/130 - train_loss: 0.3609 - test_loss: 0.263572
# Epoch: 96/130 - train_loss: 0.3522 - test_loss: 0.272818
# Epoch: 128/130 - train_loss: 0.3147 - test_loss: 0.258794
# Epoch: 129/130 - train_loss: 0.3322 - test_loss: 0.263772
# City: An Giang  _algo:cnn  -RMSE: 51.764181373771564
# City: An Giang  _algo:cnn  -RMSE: 70.55072946654512
# City: An Giang  _algo:cnn  -RMSE: 75.12149164383287
# Epoch:  0/380 - train_loss: 0.7777 - test_loss: 0.798982
# Epoch: 95/380 - train_loss: 0.2043 - test_loss: 0.124603
# Epoch: 190/380 - train_loss: 0.1239 - test_loss: 0.115529
# Epoch: 285/380 - train_loss: 0.0965 - test_loss: 0.179219
# Epoch: 379/380 - train_loss: 0.0439 - test_loss: 0.470694
# City: An Giang  _algo:lstm  -RMSE: 35.32727886128056
# City: An Giang  _algo:lstm  -RMSE: 28.719354753576173
# City: An Giang  _algo:lstm  -RMSE: 30.108362692457273
# Epoch:  0/130 - train_loss: 0.9081 - test_loss: 0.676164
# Epoch: 32/130 - train_loss: 0.3549 - test_loss: 0.245705
# Epoch: 64/130 - train_loss: 0.3226 - test_loss: 0.228705
# Epoch: 96/130 - train_loss: 0.3184 - test_loss: 0.228607
# Epoch: 128/130 - train_loss: 0.3169 - test_loss: 0.226967
# Epoch: 129/130 - train_loss: 0.3490 - test_loss: 0.225773
# City: An Giang  _algo:cnn  -RMSE: 53.1171886703755
# City: An Giang  _algo:cnn  -RMSE: 59.839939590257984
# City: An Giang  _algo:cnn  -RMSE: 63.97838967684363
# Epoch:  0/380 - train_loss: 0.8412 - test_loss: 0.735327
# Epoch: 95/380 - train_loss: 0.1947 - test_loss: 0.294484
# Epoch: 190/380 - train_loss: 0.1714 - test_loss: 0.291722
# Epoch: 285/380 - train_loss: 0.1371 - test_loss: 0.178308
# Epoch: 379/380 - train_loss: 0.0547 - test_loss: 0.402951
# City: An Giang  _algo:lstm  -RMSE: 57.74806301337397
# City: An Giang  _algo:lstm  -RMSE: 30.528171600035886
# City: An Giang  _algo:lstm  -RMSE: 30.946555636396916
# Epoch:  0/130 - train_loss: 0.8830 - test_loss: 0.669718
# Epoch: 32/130 - train_loss: 0.3357 - test_loss: 0.264396
# Epoch: 64/130 - train_loss: 0.3262 - test_loss: 0.282707
# Epoch: 96/130 - train_loss: 0.3392 - test_loss: 0.251310
# Epoch: 128/130 - train_loss: 0.3247 - test_loss: 0.275514
# Epoch: 129/130 - train_loss: 0.3275 - test_loss: 0.268016
# City: An Giang  _algo:cnn  -RMSE: 59.536678448584084
# City: An Giang  _algo:cnn  -RMSE: 69.86847264481808
# City: An Giang  _algo:cnn  -RMSE: 79.53733582167916
# Epoch:  0/380 - train_loss: 0.7498 - test_loss: 0.710490
# Epoch: 95/380 - train_loss: 0.1854 - test_loss: 0.125263
# Epoch: 190/380 - train_loss: 0.1284 - test_loss: 0.135919
# Epoch: 285/380 - train_loss: 0.0197 - test_loss: 0.813537
# Epoch: 379/380 - train_loss: 0.0271 - test_loss: 0.932421
# City: An Giang  _algo:lstm  -RMSE: 32.06565859408423
# City: An Giang  _algo:lstm  -RMSE: 30.800293288527243
# City: An Giang  _algo:lstm  -RMSE: 38.58880887782817
# Epoch:  0/130 - train_loss: 0.8612 - test_loss: 0.662351
# Epoch: 32/130 - train_loss: 0.3331 - test_loss: 0.263529
# Epoch: 64/130 - train_loss: 0.3417 - test_loss: 0.243547
# Epoch: 96/130 - train_loss: 0.3209 - test_loss: 0.216856
# Epoch: 128/130 - train_loss: 0.3251 - test_loss: 0.231621
# Epoch: 129/130 - train_loss: 0.3290 - test_loss: 0.225766
# City: An Giang  _algo:cnn  -RMSE: 58.500988470981795
# City: An Giang  _algo:cnn  -RMSE: 59.609104375781186
# City: An Giang  _algo:cnn  -RMSE: 66.76231119562135
# Epoch:  0/380 - train_loss: 0.7640 - test_loss: 0.736101
# Epoch: 95/380 - train_loss: 0.1794 - test_loss: 0.189958
# Epoch: 190/380 - train_loss: 0.1243 - test_loss: 0.117999
# Epoch: 285/380 - train_loss: 0.0760 - test_loss: 0.282536
# Epoch: 379/380 - train_loss: 0.0143 - test_loss: 1.272042
# City: An Giang  _algo:lstm  -RMSE: 28.47144373675035
# City: An Giang  _algo:lstm  -RMSE: 23.62569411820988
# City: An Giang  _algo:lstm  -RMSE: 35.25232201475728
# Epoch:  0/130 - train_loss: 0.9600 - test_loss: 0.703942
# Epoch: 32/130 - train_loss: 0.3497 - test_loss: 0.244507
# Epoch: 64/130 - train_loss: 0.3437 - test_loss: 0.235018
# Epoch: 96/130 - train_loss: 0.3236 - test_loss: 0.227956
# Epoch: 128/130 - train_loss: 0.3103 - test_loss: 0.238391
# Epoch: 129/130 - train_loss: 0.3075 - test_loss: 0.239190
# City: An Giang  _algo:cnn  -RMSE: 32.55774878777819
# City: An Giang  _algo:cnn  -RMSE: 44.49813643097963
# City: An Giang  _algo:cnn  -RMSE: 47.945010670816416
# Epoch:  0/380 - train_loss: 0.7866 - test_loss: 0.743977
# Epoch: 95/380 - train_loss: 0.1783 - test_loss: 0.190190
# Epoch: 190/380 - train_loss: 0.1226 - test_loss: 0.181260
# Epoch: 285/380 - train_loss: 0.1067 - test_loss: 0.181498
# Epoch: 379/380 - train_loss: 0.0513 - test_loss: 0.342585
# City: An Giang  _algo:lstm  -RMSE: 44.28094224448226
# City: An Giang  _algo:lstm  -RMSE: 29.013440885345105
# City: An Giang  _algo:lstm  -RMSE: 54.50294563213499
# Epoch:  0/130 - train_loss: 0.8545 - test_loss: 0.678293
# Epoch: 32/130 - train_loss: 0.3028 - test_loss: 0.257670
# Epoch: 64/130 - train_loss: 0.3470 - test_loss: 0.289540
# Epoch: 96/130 - train_loss: 0.3042 - test_loss: 0.230510
# Epoch: 128/130 - train_loss: 0.3042 - test_loss: 0.244464
# Epoch: 129/130 - train_loss: 0.3050 - test_loss: 0.244768
# City: An Giang  _algo:cnn  -RMSE: 57.887529988407294
# City: An Giang  _algo:cnn  -RMSE: 58.975026298703725
# City: An Giang  _algo:cnn  -RMSE: 79.6889210998183
# Epoch:  0/380 - train_loss: 0.7736 - test_loss: 0.719978
# Epoch: 95/380 - train_loss: 0.2537 - test_loss: 0.295962
# Epoch: 190/380 - train_loss: 0.1674 - test_loss: 0.140607
# Epoch: 285/380 - train_loss: 0.1635 - test_loss: 0.129115
# Epoch: 379/380 - train_loss: 0.1484 - test_loss: 0.118961
# City: An Giang  _algo:lstm  -RMSE: 28.14291148029972
# City: An Giang  _algo:lstm  -RMSE: 31.140829356763327
# City: An Giang  _algo:lstm  -RMSE: 29.781327557315098
# Epoch:  0/130 - train_loss: 0.8942 - test_loss: 0.660305
# Epoch: 32/130 - train_loss: 0.3115 - test_loss: 0.235138
# Epoch: 64/130 - train_loss: 0.3271 - test_loss: 0.282037
# Epoch: 96/130 - train_loss: 0.4076 - test_loss: 0.260798
# Epoch: 128/130 - train_loss: 0.2850 - test_loss: 0.222467
# Epoch: 129/130 - train_loss: 0.3074 - test_loss: 0.225889
# City: An Giang  _algo:cnn  -RMSE: 49.558115873179005
# City: An Giang  _algo:cnn  -RMSE: 67.64160249342582
# City: An Giang  _algo:cnn  -RMSE: 74.78952392362893
# Epoch:  0/380 - train_loss: 0.7848 - test_loss: 0.798785
# Epoch: 95/380 - train_loss: 0.2105 - test_loss: 0.112570
# Epoch: 190/380 - train_loss: 0.1843 - test_loss: 0.151345
# Epoch: 285/380 - train_loss: 0.1606 - test_loss: 0.095865
# Epoch: 379/380 - train_loss: 0.1535 - test_loss: 0.140593
# City: An Giang  _algo:lstm  -RMSE: 23.30494990707456
# City: An Giang  _algo:lstm  -RMSE: 21.699444597549014
# City: An Giang  _algo:lstm  -RMSE: 23.355576932414156
# Epoch:  0/130 - train_loss: 0.8670 - test_loss: 0.648663
# Epoch: 32/130 - train_loss: 0.3218 - test_loss: 0.256811
# Epoch: 64/130 - train_loss: 0.3401 - test_loss: 0.246022
# Epoch: 96/130 - train_loss: 0.3349 - test_loss: 0.219575
# Epoch: 128/130 - train_loss: 0.3098 - test_loss: 0.195560
# Epoch: 129/130 - train_loss: 0.3088 - test_loss: 0.209067
# City: An Giang  _algo:cnn  -RMSE: 48.027793731050885
# City: An Giang  _algo:cnn  -RMSE: 62.020264696417954
# City: An Giang  _algo:cnn  -RMSE: 51.52300284007296
# Epoch:  0/380 - train_loss: 0.7914 - test_loss: 0.732320
# Epoch: 95/380 - train_loss: 0.1912 - test_loss: 0.134316
# Epoch: 190/380 - train_loss: 0.1275 - test_loss: 0.116424
# Epoch: 285/380 - train_loss: 0.1308 - test_loss: 0.141158
# Epoch: 379/380 - train_loss: 0.1179 - test_loss: 0.243877
# City: An Giang  _algo:lstm  -RMSE: 26.68659829066969
# City: An Giang  _algo:lstm  -RMSE: 25.396149871927843
# City: An Giang  _algo:lstm  -RMSE: 33.13911569840323
# Epoch:  0/130 - train_loss: 0.8740 - test_loss: 0.690849
# Epoch: 32/130 - train_loss: 0.3724 - test_loss: 0.215421
# Epoch: 64/130 - train_loss: 0.3109 - test_loss: 0.243961
# Epoch: 96/130 - train_loss: 0.3101 - test_loss: 0.216362
# Epoch: 128/130 - train_loss: 0.3146 - test_loss: 0.204793
# Epoch: 129/130 - train_loss: 0.3062 - test_loss: 0.215040
# City: An Giang  _algo:cnn  -RMSE: 45.79687536408963
# City: An Giang  _algo:cnn  -RMSE: 55.155359297346095
# City: An Giang  _algo:cnn  -RMSE: 61.14636813281078
# Epoch:  0/380 - train_loss: 0.7465 - test_loss: 0.698157
# Epoch: 95/380 - train_loss: 0.1724 - test_loss: 0.180648
# Epoch: 190/380 - train_loss: 0.1790 - test_loss: 0.087543
# Epoch: 285/380 - train_loss: 0.0979 - test_loss: 0.089794
# Epoch: 379/380 - train_loss: 0.1034 - test_loss: 0.124332
# City: An Giang  _algo:lstm  -RMSE: 24.149566978555793
# City: An Giang  _algo:lstm  -RMSE: 16.993934028916208
# City: An Giang  _algo:lstm  -RMSE: 26.083893148025737
# Epoch:  0/130 - train_loss: 0.8360 - test_loss: 0.674161
# Epoch: 32/130 - train_loss: 0.3439 - test_loss: 0.210973
# Epoch: 64/130 - train_loss: 0.3302 - test_loss: 0.228472
# Epoch: 96/130 - train_loss: 0.2988 - test_loss: 0.224579
# Epoch: 128/130 - train_loss: 0.3022 - test_loss: 0.210571
# Epoch: 129/130 - train_loss: 0.3126 - test_loss: 0.205753
# City: An Giang  _algo:cnn  -RMSE: 42.6182639991222
# City: An Giang  _algo:cnn  -RMSE: 49.60165686339869
# City: An Giang  _algo:cnn  -RMSE: 50.99054082088435
# Epoch:  0/380 - train_loss: 0.7430 - test_loss: 0.711240
# Epoch: 95/380 - train_loss: 0.1745 - test_loss: 0.093967
# Epoch: 190/380 - train_loss: 0.1163 - test_loss: 0.094227
# Epoch: 285/380 - train_loss: 0.1318 - test_loss: 0.120974
# Epoch: 379/380 - train_loss: 0.1054 - test_loss: 0.090663
# City: An Giang  _algo:lstm  -RMSE: 22.090931325185043
# City: An Giang  _algo:lstm  -RMSE: 30.76336044396052
# City: An Giang  _algo:lstm  -RMSE: 18.55872997094879
# Epoch:  0/130 - train_loss: 0.7983 - test_loss: 0.642106
# Epoch: 32/130 - train_loss: 0.3257 - test_loss: 0.250847
# Epoch: 64/130 - train_loss: 0.3356 - test_loss: 0.231674
# Epoch: 96/130 - train_loss: 0.3274 - test_loss: 0.231269
# Epoch: 128/130 - train_loss: 0.3136 - test_loss: 0.215527
# Epoch: 129/130 - train_loss: 0.3087 - test_loss: 0.209309
# City: An Giang  _algo:cnn  -RMSE: 42.53243246808226
# City: An Giang  _algo:cnn  -RMSE: 52.47234708469828
# City: An Giang  _algo:cnn  -RMSE: 64.13720254211582
# Epoch:  0/380 - train_loss: 0.8156 - test_loss: 0.732979
# Epoch: 95/380 - train_loss: 0.1720 - test_loss: 0.085198
# Epoch: 190/380 - train_loss: 0.2046 - test_loss: 0.091820
# Epoch: 285/380 - train_loss: 0.0709 - test_loss: 0.074716
# Epoch: 379/380 - train_loss: 0.0340 - test_loss: 0.224323
# City: An Giang  _algo:lstm  -RMSE: 16.590883616018576
# City: An Giang  _algo:lstm  -RMSE: 21.240242552336767
# City: An Giang  _algo:lstm  -RMSE: 28.95536343992447
# Epoch:  0/130 - train_loss: 0.8177 - test_loss: 0.667800
# Epoch: 32/130 - train_loss: 0.3226 - test_loss: 0.196915
# Epoch: 64/130 - train_loss: 0.3347 - test_loss: 0.195474
# Epoch: 96/130 - train_loss: 0.3290 - test_loss: 0.201169
# Epoch: 128/130 - train_loss: 0.3242 - test_loss: 0.211814
# Epoch: 129/130 - train_loss: 0.3087 - test_loss: 0.208889
# City: An Giang  _algo:cnn  -RMSE: 46.68313453508587
# City: An Giang  _algo:cnn  -RMSE: 52.94681204884673
# City: An Giang  _algo:cnn  -RMSE: 57.13445399716095
# Epoch:  0/380 - train_loss: 0.7675 - test_loss: 0.693498
# Epoch: 95/380 - train_loss: 0.1680 - test_loss: 0.154584
# Epoch: 190/380 - train_loss: 0.1222 - test_loss: 0.083521
# Epoch: 285/380 - train_loss: 0.1063 - test_loss: 0.081875
# Epoch: 379/380 - train_loss: 0.0185 - test_loss: 0.272433
# City: An Giang  _algo:lstm  -RMSE: 15.85751205254883
# City: An Giang  _algo:lstm  -RMSE: 19.545556064248544
# City: An Giang  _algo:lstm  -RMSE: 20.504947458130015
# Epoch:  0/130 - train_loss: 0.9414 - test_loss: 0.652097
# Epoch: 32/130 - train_loss: 0.3158 - test_loss: 0.217410
# Epoch: 64/130 - train_loss: 0.3216 - test_loss: 0.209884
# Epoch: 96/130 - train_loss: 0.3194 - test_loss: 0.197367
# Epoch: 128/130 - train_loss: 0.3027 - test_loss: 0.172313
# Epoch: 129/130 - train_loss: 0.3298 - test_loss: 0.168024
# City: An Giang  _algo:cnn  -RMSE: 35.34924196004894
# City: An Giang  _algo:cnn  -RMSE: 42.99825937328489
# City: An Giang  _algo:cnn  -RMSE: 46.62986891512127
# Epoch:  0/380 - train_loss: 0.8333 - test_loss: 0.703192
# Epoch: 95/380 - train_loss: 0.1636 - test_loss: 0.086228
# Epoch: 190/380 - train_loss: 0.1311 - test_loss: 0.097948
# Epoch: 285/380 - train_loss: 0.1260 - test_loss: 0.105212
# Epoch: 379/380 - train_loss: 0.0746 - test_loss: 0.113632
# City: An Giang  _algo:lstm  -RMSE: 15.19089309608774
# City: An Giang  _algo:lstm  -RMSE: 20.862178207047343
# City: An Giang  _algo:lstm  -RMSE: 21.660476371877184
# Epoch:  0/130 - train_loss: 0.8391 - test_loss: 0.649915
# Epoch: 32/130 - train_loss: 0.3230 - test_loss: 0.192729
# Epoch: 64/130 - train_loss: 0.3265 - test_loss: 0.211461
# Epoch: 96/130 - train_loss: 0.3332 - test_loss: 0.176208
# Epoch: 128/130 - train_loss: 0.3098 - test_loss: 0.213366
# Epoch: 129/130 - train_loss: 0.3230 - test_loss: 0.205002
# City: An Giang  _algo:cnn  -RMSE: 43.9275340806549
# City: An Giang  _algo:cnn  -RMSE: 51.16528448881733
# City: An Giang  _algo:cnn  -RMSE: 59.71054842083764
# Epoch:  0/380 - train_loss: 0.7631 - test_loss: 0.734809
# Epoch: 95/380 - train_loss: 0.1887 - test_loss: 0.116613
# Epoch: 190/380 - train_loss: 0.1169 - test_loss: 0.141356
# Epoch: 285/380 - train_loss: 0.0931 - test_loss: 0.088618
# Epoch: 379/380 - train_loss: 0.0742 - test_loss: 0.174110
# City: An Giang  _algo:lstm  -RMSE: 18.693366519707013
# City: An Giang  _algo:lstm  -RMSE: 17.919739745114267
# City: An Giang  _algo:lstm  -RMSE: 19.82571441066323
# Epoch:  0/130 - train_loss: 0.9028 - test_loss: 0.674511
# Epoch: 32/130 - train_loss: 0.3077 - test_loss: 0.215695
# Epoch: 64/130 - train_loss: 0.3147 - test_loss: 0.229874
# Epoch: 96/130 - train_loss: 0.3140 - test_loss: 0.181376
# Epoch: 128/130 - train_loss: 0.3080 - test_loss: 0.203212
# Epoch: 129/130 - train_loss: 0.3089 - test_loss: 0.198916
# City: An Giang  _algo:cnn  -RMSE: 43.002671037320425
# City: An Giang  _algo:cnn  -RMSE: 52.84379181945997
# City: An Giang  _algo:cnn  -RMSE: 47.66581310179364
# Epoch:  0/380 - train_loss: 0.7569 - test_loss: 0.706528
# Epoch: 95/380 - train_loss: 0.1887 - test_loss: 0.142470
# Epoch: 190/380 - train_loss: 0.1106 - test_loss: 0.129250
# Epoch: 285/380 - train_loss: 0.1318 - test_loss: 0.081181
# Epoch: 379/380 - train_loss: 0.0772 - test_loss: 0.182609
# City: An Giang  _algo:lstm  -RMSE: 18.696438512871893
# City: An Giang  _algo:lstm  -RMSE: 25.585562803247655
# City: An Giang  _algo:lstm  -RMSE: 33.65245800282284
# Epoch:  0/130 - train_loss: 0.8482 - test_loss: 0.651067
# Epoch: 32/130 - train_loss: 0.3458 - test_loss: 0.179180
# Epoch: 64/130 - train_loss: 0.3128 - test_loss: 0.209431
# Epoch: 96/130 - train_loss: 0.3075 - test_loss: 0.224309
# Epoch: 128/130 - train_loss: 0.3341 - test_loss: 0.206887
# Epoch: 129/130 - train_loss: 0.3144 - test_loss: 0.203348
# City: An Giang  _algo:cnn  -RMSE: 40.32184101572523
# City: An Giang  _algo:cnn  -RMSE: 48.68128963767415
# City: An Giang  _algo:cnn  -RMSE: 59.40008502726271
# Epoch:  0/380 - train_loss: 0.7907 - test_loss: 0.708112
# Epoch: 95/380 - train_loss: 0.1912 - test_loss: 0.117105
# Epoch: 190/380 - train_loss: 0.1132 - test_loss: 0.079666
# Epoch: 285/380 - train_loss: 0.0671 - test_loss: 0.134331
# Epoch: 379/380 - train_loss: 0.0181 - test_loss: 0.439024
# City: An Giang  _algo:lstm  -RMSE: 15.439038417878054
# City: An Giang  _algo:lstm  -RMSE: 20.12183538971415
# City: An Giang  _algo:lstm  -RMSE: 24.601776118309672
# Epoch:  0/130 - train_loss: 0.8376 - test_loss: 0.663854
# Epoch: 32/130 - train_loss: 0.3125 - test_loss: 0.221340
# Epoch: 64/130 - train_loss: 0.3129 - test_loss: 0.203872
# Epoch: 96/130 - train_loss: 0.3105 - test_loss: 0.195685
# Epoch: 128/130 - train_loss: 0.2986 - test_loss: 0.180155
# Epoch: 129/130 - train_loss: 0.3223 - test_loss: 0.184289
# City: An Giang  _algo:cnn  -RMSE: 37.575636438557446
# City: An Giang  _algo:cnn  -RMSE: 51.98649726642091
# City: An Giang  _algo:cnn  -RMSE: 51.53320216108499
# Epoch:  0/380 - train_loss: 0.7652 - test_loss: 0.706661
# Epoch: 95/380 - train_loss: 0.1624 - test_loss: 0.136565
# Epoch: 190/380 - train_loss: 0.1169 - test_loss: 0.113131
# Epoch: 285/380 - train_loss: 0.1277 - test_loss: 0.198774
# Epoch: 379/380 - train_loss: 0.0516 - test_loss: 0.097089
# City: An Giang  _algo:lstm  -RMSE: 15.30292233513999
# City: An Giang  _algo:lstm  -RMSE: 38.670564989248334
# City: An Giang  _algo:lstm  -RMSE: 26.3326379503664
# Epoch:  0/130 - train_loss: 0.8460 - test_loss: 0.658118
# Epoch: 32/130 - train_loss: 0.3204 - test_loss: 0.202740
# Epoch: 64/130 - train_loss: 0.2915 - test_loss: 0.201409
# Epoch: 96/130 - train_loss: 0.3028 - test_loss: 0.197687
# Epoch: 128/130 - train_loss: 0.3056 - test_loss: 0.212889
# Epoch: 129/130 - train_loss: 0.3044 - test_loss: 0.199192
# City: An Giang  _algo:cnn  -RMSE: 36.83499230146866
# City: An Giang  _algo:cnn  -RMSE: 45.64707614033078
# City: An Giang  _algo:cnn  -RMSE: 58.29570645722272
# Epoch:  0/380 - train_loss: 0.7707 - test_loss: 0.750451
# Epoch: 95/380 - train_loss: 0.1735 - test_loss: 0.095817
# Epoch: 190/380 - train_loss: 0.1515 - test_loss: 0.200830
# Epoch: 285/380 - train_loss: 0.1456 - test_loss: 0.073634
# Epoch: 379/380 - train_loss: 0.0286 - test_loss: 0.128440
# City: An Giang  _algo:lstm  -RMSE: 18.49306263187153
# City: An Giang  _algo:lstm  -RMSE: 16.38062064110186
# City: An Giang  _algo:lstm  -RMSE: 18.414272721318735
# Epoch:  0/130 - train_loss: 0.8720 - test_loss: 0.673949
# Epoch: 32/130 - train_loss: 0.3235 - test_loss: 0.199065
# Epoch: 64/130 - train_loss: 0.2953 - test_loss: 0.203190
# Epoch: 96/130 - train_loss: 0.3010 - test_loss: 0.198108
# Epoch: 128/130 - train_loss: 0.2936 - test_loss: 0.194819
# Epoch: 129/130 - train_loss: 0.3284 - test_loss: 0.191041
# City: An Giang  _algo:cnn  -RMSE: 37.7844689631486
# City: An Giang  _algo:cnn  -RMSE: 52.11508702390111
# City: An Giang  _algo:cnn  -RMSE: 57.05295844371766
# Epoch:  0/380 - train_loss: 0.7479 - test_loss: 0.726412
# Epoch: 95/380 - train_loss: 0.1804 - test_loss: 0.380208
# Epoch: 190/380 - train_loss: 0.1200 - test_loss: 0.159700
# Epoch: 285/380 - train_loss: 0.0962 - test_loss: 0.076670
# Epoch: 379/380 - train_loss: 0.0387 - test_loss: 0.062663
# City: An Giang  _algo:lstm  -RMSE: 18.485642260154552
# City: An Giang  _algo:lstm  -RMSE: 14.776703907152715
# City: An Giang  _algo:lstm  -RMSE: 19.22025704508946
# Epoch:  0/130 - train_loss: 0.8743 - test_loss: 0.658328
# Epoch: 32/130 - train_loss: 0.3095 - test_loss: 0.184528
# Epoch: 64/130 - train_loss: 0.3117 - test_loss: 0.204689
# Epoch: 96/130 - train_loss: 0.3054 - test_loss: 0.186491
# Epoch: 128/130 - train_loss: 0.3079 - test_loss: 0.191277
# Epoch: 129/130 - train_loss: 0.2991 - test_loss: 0.180940
# City: An Giang  _algo:cnn  -RMSE: 38.24815985401663
# City: An Giang  _algo:cnn  -RMSE: 38.61464181744582
# City: An Giang  _algo:cnn  -RMSE: 50.196874458284576
# Epoch:  0/380 - train_loss: 0.7767 - test_loss: 0.710035
# Epoch: 95/380 - train_loss: 0.1690 - test_loss: 0.133536
# Epoch: 190/380 - train_loss: 0.1488 - test_loss: 0.157759
# Epoch: 285/380 - train_loss: 0.0520 - test_loss: 0.118580
# Epoch: 379/380 - train_loss: 0.0384 - test_loss: 0.254507
# City: An Giang  _algo:lstm  -RMSE: 26.15836971911566
# City: An Giang  _algo:lstm  -RMSE: 18.97697631959284
# City: An Giang  _algo:lstm  -RMSE: 18.581352903975834
# Epoch:  0/130 - train_loss: 0.8363 - test_loss: 0.656725
# Epoch: 32/130 - train_loss: 0.3087 - test_loss: 0.173854
# Epoch: 64/130 - train_loss: 0.3011 - test_loss: 0.176988
# Epoch: 96/130 - train_loss: 0.3181 - test_loss: 0.157828
# Epoch: 128/130 - train_loss: 0.2935 - test_loss: 0.155676
# Epoch: 129/130 - train_loss: 0.2923 - test_loss: 0.164048
# City: An Giang  _algo:cnn  -RMSE: 34.07011759057527
# City: An Giang  _algo:cnn  -RMSE: 37.34523280890197
# City: An Giang  _algo:cnn  -RMSE: 39.5294612084007
# Epoch:  0/380 - train_loss: 0.7531 - test_loss: 0.702829
# Epoch: 95/380 - train_loss: 0.1659 - test_loss: 0.214541
# Epoch: 190/380 - train_loss: 0.0978 - test_loss: 0.099951
# Epoch: 285/380 - train_loss: 0.0265 - test_loss: 0.276403
# Epoch: 379/380 - train_loss: 0.0193 - test_loss: 0.430207
# City: An Giang  _algo:lstm  -RMSE: 25.909150355145886
# City: An Giang  _algo:lstm  -RMSE: 23.63948726389582
# City: An Giang  _algo:lstm  -RMSE: 23.598093113383808
# Epoch:  0/130 - train_loss: 0.8194 - test_loss: 0.667756
# Epoch: 32/130 - train_loss: 0.2912 - test_loss: 0.178787
# Epoch: 64/130 - train_loss: 0.3043 - test_loss: 0.174785
# Epoch: 96/130 - train_loss: 0.3024 - test_loss: 0.227729
# Epoch: 128/130 - train_loss: 0.3317 - test_loss: 0.212424
# Epoch: 129/130 - train_loss: 0.2960 - test_loss: 0.223104
# City: An Giang  _algo:cnn  -RMSE: 45.87263815755351
# City: An Giang  _algo:cnn  -RMSE: 46.72108198653329
# City: An Giang  _algo:cnn  -RMSE: 45.40363807916317
# Epoch:  0/380 - train_loss: 0.7527 - test_loss: 0.688983
# Epoch: 95/380 - train_loss: 0.3785 - test_loss: 0.966670
# Epoch: 190/380 - train_loss: 0.1816 - test_loss: 0.119219
# Epoch: 285/380 - train_loss: 0.1673 - test_loss: 0.084827
# Epoch: 379/380 - train_loss: 0.2438 - test_loss: 0.170143
# City: An Giang  _algo:lstm  -RMSE: 13.774674325153477
# City: An Giang  _algo:lstm  -RMSE: 14.106449983669028
# City: An Giang  _algo:lstm  -RMSE: 17.171844817511253
# Epoch:  0/130 - train_loss: 0.8793 - test_loss: 0.645495
# Epoch: 32/130 - train_loss: 0.2953 - test_loss: 0.188605
# Epoch: 64/130 - train_loss: 0.2751 - test_loss: 0.196190
# Epoch: 96/130 - train_loss: 0.2898 - test_loss: 0.180052
# Epoch: 128/130 - train_loss: 0.3824 - test_loss: 0.187308
# Epoch: 129/130 - train_loss: 0.2904 - test_loss: 0.201764
# City: An Giang  _algo:cnn  -RMSE: 23.89891615549466
# City: An Giang  _algo:cnn  -RMSE: 50.83255731579326
# City: An Giang  _algo:cnn  -RMSE: 46.624027077961806
# Epoch:  0/380 - train_loss: 0.7556 - test_loss: 0.764790
# Epoch: 95/380 - train_loss: 0.1754 - test_loss: 0.194129
# Epoch: 190/380 - train_loss: 0.1502 - test_loss: 0.155390
# Epoch: 285/380 - train_loss: 0.1062 - test_loss: 0.125942
# Epoch: 379/380 - train_loss: 0.2426 - test_loss: 0.067854
# City: An Giang  _algo:lstm  -RMSE: 12.426052650849313
# City: An Giang  _algo:lstm  -RMSE: 13.020827773591767
# City: An Giang  _algo:lstm  -RMSE: 12.85047876238609
# Epoch:  0/130 - train_loss: 0.8380 - test_loss: 0.664646
# Epoch: 32/130 - train_loss: 0.3428 - test_loss: 0.189831
# Epoch: 64/130 - train_loss: 0.2678 - test_loss: 0.156700
# Epoch: 96/130 - train_loss: 0.3086 - test_loss: 0.168403
# Epoch: 128/130 - train_loss: 0.3010 - test_loss: 0.176306
# Epoch: 129/130 - train_loss: 0.3214 - test_loss: 0.174504
# City: An Giang  _algo:cnn  -RMSE: 32.92583608981223
# City: An Giang  _algo:cnn  -RMSE: 45.26191327311303
# City: An Giang  _algo:cnn  -RMSE: 43.306392008682025
# Epoch:  0/380 - train_loss: 0.7347 - test_loss: 0.684321
# Epoch: 95/380 - train_loss: 0.1553 - test_loss: 0.157582
# Epoch: 190/380 - train_loss: 0.2723 - test_loss: 0.104969
# Epoch: 285/380 - train_loss: 0.1271 - test_loss: 0.165899
# Epoch: 379/380 - train_loss: 0.0859 - test_loss: 0.098070
# City: An Giang  _algo:lstm  -RMSE: 22.779535426873707
# City: An Giang  _algo:lstm  -RMSE: 17.326674004655853
# City: An Giang  _algo:lstm  -RMSE: 21.925678253565106
# Epoch:  0/130 - train_loss: 0.9018 - test_loss: 0.655439
# Epoch: 32/130 - train_loss: 0.3168 - test_loss: 0.186460
# Epoch: 64/130 - train_loss: 0.3091 - test_loss: 0.155573
# Epoch: 96/130 - train_loss: 0.2675 - test_loss: 0.162785
# Epoch: 128/130 - train_loss: 0.3207 - test_loss: 0.170458
# Epoch: 129/130 - train_loss: 0.2741 - test_loss: 0.174931
# City: An Giang  _algo:cnn  -RMSE: 30.44390802943438
# City: An Giang  _algo:cnn  -RMSE: 25.587457728758107
# City: An Giang  _algo:cnn  -RMSE: 42.467606240066026
# Epoch:  0/380 - train_loss: 0.7483 - test_loss: 0.681163
# Epoch: 95/380 - train_loss: 0.1662 - test_loss: 0.177940
# Epoch: 190/380 - train_loss: 0.1493 - test_loss: 0.177105
# Epoch: 285/380 - train_loss: 0.1345 - test_loss: 0.202626
# Epoch: 379/380 - train_loss: 0.1103 - test_loss: 0.177829
# City: An Giang  _algo:lstm  -RMSE: 25.027286563666912
# City: An Giang  _algo:lstm  -RMSE: 12.05115268062611
# City: An Giang  _algo:lstm  -RMSE: 13.268269722360857
# Epoch:  0/130 - train_loss: 0.8925 - test_loss: 0.653613
# Epoch: 32/130 - train_loss: 0.3108 - test_loss: 0.187556
# Epoch: 64/130 - train_loss: 0.3007 - test_loss: 0.185854
# Epoch: 96/130 - train_loss: 0.2918 - test_loss: 0.209711
# Epoch: 128/130 - train_loss: 0.2926 - test_loss: 0.202179
# Epoch: 129/130 - train_loss: 0.3112 - test_loss: 0.183919
# City: An Giang  _algo:cnn  -RMSE: 29.505823605012846
# City: An Giang  _algo:cnn  -RMSE: 32.868230155792446
# City: An Giang  _algo:cnn  -RMSE: 42.719974488206596
# Epoch:  0/380 - train_loss: 0.7566 - test_loss: 0.666966
# Epoch: 95/380 - train_loss: 0.1597 - test_loss: 0.186364
# Epoch: 190/380 - train_loss: 0.1242 - test_loss: 0.077717
# Epoch: 285/380 - train_loss: 0.0991 - test_loss: 0.057401
# Epoch: 379/380 - train_loss: 0.0454 - test_loss: 0.079683
# City: An Giang  _algo:lstm  -RMSE: 17.494380250366618
# City: An Giang  _algo:lstm  -RMSE: 17.633661248268453
# City: An Giang  _algo:lstm  -RMSE: 18.051639542974097
# Epoch:  0/130 - train_loss: 0.8509 - test_loss: 0.646937
# Epoch: 32/130 - train_loss: 0.2967 - test_loss: 0.171549
# Epoch: 64/130 - train_loss: 0.2795 - test_loss: 0.152728
# Epoch: 96/130 - train_loss: 0.3108 - test_loss: 0.167115
# Epoch: 128/130 - train_loss: 0.2658 - test_loss: 0.157929
# Epoch: 129/130 - train_loss: 0.2837 - test_loss: 0.157078
# City: An Giang  _algo:cnn  -RMSE: 30.746522132035008
# City: An Giang  _algo:cnn  -RMSE: 35.22850703224549
# City: An Giang  _algo:cnn  -RMSE: 40.725072451387966
# Epoch:  0/380 - train_loss: 0.7646 - test_loss: 0.675850
# Epoch: 95/380 - train_loss: 0.1821 - test_loss: 0.142396
# Epoch: 190/380 - train_loss: 0.1469 - test_loss: 0.151083
# Epoch: 285/380 - train_loss: 0.0770 - test_loss: 0.064996
# Epoch: 379/380 - train_loss: 0.0646 - test_loss: 0.166051
# City: An Giang  _algo:lstm  -RMSE: 17.592341965575404
# City: An Giang  _algo:lstm  -RMSE: 19.03925435696752
# City: An Giang  _algo:lstm  -RMSE: 22.125153688483074
# Epoch:  0/130 - train_loss: 0.8021 - test_loss: 0.664204
# Epoch: 32/130 - train_loss: 0.2922 - test_loss: 0.166526
# Epoch: 64/130 - train_loss: 0.2971 - test_loss: 0.201251
# Epoch: 96/130 - train_loss: 0.3149 - test_loss: 0.187070
# Epoch: 128/130 - train_loss: 0.2755 - test_loss: 0.169493
# Epoch: 129/130 - train_loss: 0.2981 - test_loss: 0.170495
# City: An Giang  _algo:cnn  -RMSE: 37.20805322132611
# City: An Giang  _algo:cnn  -RMSE: 38.38696023657049
# City: An Giang  _algo:cnn  -RMSE: 44.20075073695633
# Epoch:  0/380 - train_loss: 0.7450 - test_loss: 0.657929
# Epoch: 95/380 - train_loss: 0.1605 - test_loss: 0.117808
# Epoch: 190/380 - train_loss: 0.1082 - test_loss: 0.087366
# Epoch: 285/380 - train_loss: 0.1078 - test_loss: 0.121380
# Epoch: 379/380 - train_loss: 0.0241 - test_loss: 0.378780
# City: An Giang  _algo:lstm  -RMSE: 17.284931650939523
# City: An Giang  _algo:lstm  -RMSE: 19.093750429572275
# City: An Giang  _algo:lstm  -RMSE: 18.929203074925873
# Epoch:  0/130 - train_loss: 0.8348 - test_loss: 0.636977
# Epoch: 32/130 - train_loss: 0.2995 - test_loss: 0.172485
# Epoch: 64/130 - train_loss: 0.2807 - test_loss: 0.174909
# Epoch: 96/130 - train_loss: 0.2852 - test_loss: 0.186218
# Epoch: 128/130 - train_loss: 0.2965 - test_loss: 0.178181
# Epoch: 129/130 - train_loss: 0.2808 - test_loss: 0.150378
# City: An Giang  _algo:cnn  -RMSE: 29.663137907922724
# City: An Giang  _algo:cnn  -RMSE: 39.39310132807482
# City: An Giang  _algo:cnn  -RMSE: 36.160432105463414
# Epoch:  0/380 - train_loss: 0.7403 - test_loss: 0.670806
# Epoch: 95/380 - train_loss: 0.1704 - test_loss: 0.088938
# Epoch: 190/380 - train_loss: 0.1099 - test_loss: 0.092508
# Epoch: 285/380 - train_loss: 0.0676 - test_loss: 0.052169
# Epoch: 379/380 - train_loss: 0.0304 - test_loss: 0.112495
# City: An Giang  _algo:lstm  -RMSE: 14.725040109811847
# City: An Giang  _algo:lstm  -RMSE: 15.954683827792818
# City: An Giang  _algo:lstm  -RMSE: 19.464476965912922
# Epoch:  0/130 - train_loss: 0.8148 - test_loss: 0.650459
# Epoch: 32/130 - train_loss: 0.2997 - test_loss: 0.163221
# Epoch: 64/130 - train_loss: 0.2928 - test_loss: 0.156377
# Epoch: 96/130 - train_loss: 0.3210 - test_loss: 0.150784
# Epoch: 128/130 - train_loss: 0.2912 - test_loss: 0.144645
# Epoch: 129/130 - train_loss: 0.2730 - test_loss: 0.153440
# City: An Giang  _algo:cnn  -RMSE: 24.815693656607518
# City: An Giang  _algo:cnn  -RMSE: 30.012381498635516
# City: An Giang  _algo:cnn  -RMSE: 40.54380316971829
# Epoch:  0/380 - train_loss: 0.7623 - test_loss: 0.671404
# Epoch: 95/380 - train_loss: 0.1682 - test_loss: 0.114088
# Epoch: 190/380 - train_loss: 0.1418 - test_loss: 0.161676
# Epoch: 285/380 - train_loss: 0.0823 - test_loss: 0.060775
# Epoch: 379/380 - train_loss: 0.0305 - test_loss: 0.075910
# City: An Giang  _algo:lstm  -RMSE: 20.14270514782061
# City: An Giang  _algo:lstm  -RMSE: 13.284998137302255
# City: An Giang  _algo:lstm  -RMSE: 18.35714055899751
# Epoch:  0/130 - train_loss: 0.8103 - test_loss: 0.632967
# Epoch: 32/130 - train_loss: 0.3011 - test_loss: 0.168844
# Epoch: 64/130 - train_loss: 0.2698 - test_loss: 0.155283
# Epoch: 96/130 - train_loss: 0.2735 - test_loss: 0.148802
# Epoch: 128/130 - train_loss: 0.2685 - test_loss: 0.146826
# Epoch: 129/130 - train_loss: 0.3034 - test_loss: 0.148379
# City: An Giang  _algo:cnn  -RMSE: 28.21920263525289
# City: An Giang  _algo:cnn  -RMSE: 35.36857985133404
# City: An Giang  _algo:cnn  -RMSE: 36.296243821390085
# Epoch:  0/380 - train_loss: 0.7641 - test_loss: 0.668385
# Epoch: 95/380 - train_loss: 0.1655 - test_loss: 0.099775
# Epoch: 190/380 - train_loss: 0.1353 - test_loss: 0.212294
# Epoch: 285/380 - train_loss: 0.0799 - test_loss: 0.055809
# Epoch: 379/380 - train_loss: 0.0465 - test_loss: 0.071865
# City: An Giang  _algo:lstm  -RMSE: 15.100545929415869
# City: An Giang  _algo:lstm  -RMSE: 13.381650432832286
# City: An Giang  _algo:lstm  -RMSE: 15.280660685277027
# Epoch:  0/130 - train_loss: 0.8863 - test_loss: 0.673346
# Epoch: 32/130 - train_loss: 0.2945 - test_loss: 0.184178
# Epoch: 64/130 - train_loss: 0.3026 - test_loss: 0.157948
# Epoch: 96/130 - train_loss: 0.2772 - test_loss: 0.153134
# Epoch: 128/130 - train_loss: 0.2697 - test_loss: 0.148423
# Epoch: 129/130 - train_loss: 0.2910 - test_loss: 0.164528
# City: An Giang  _algo:cnn  -RMSE: 25.5575072450297
# City: An Giang  _algo:cnn  -RMSE: 32.95569974632036
# City: An Giang  _algo:cnn  -RMSE: 34.635393054844805
# Epoch:  0/380 - train_loss: 0.7377 - test_loss: 0.667310
# Epoch: 95/380 - train_loss: 0.1627 - test_loss: 0.097052
# Epoch: 190/380 - train_loss: 0.1118 - test_loss: 0.050086
# Epoch: 285/380 - train_loss: 0.0518 - test_loss: 0.057651
# Epoch: 379/380 - train_loss: 0.0168 - test_loss: 0.111993
# City: An Giang  _algo:lstm  -RMSE: 17.139028920809217
# City: An Giang  _algo:lstm  -RMSE: 12.318970120646366
# City: An Giang  _algo:lstm  -RMSE: 15.283442156097497
# Epoch:  0/130 - train_loss: 0.8555 - test_loss: 0.636658
# Epoch: 32/130 - train_loss: 0.3018 - test_loss: 0.169109
# Epoch: 64/130 - train_loss: 0.2957 - test_loss: 0.151810
# Epoch: 96/130 - train_loss: 0.2879 - test_loss: 0.168466
# Epoch: 128/130 - train_loss: 0.2856 - test_loss: 0.171307
# Epoch: 129/130 - train_loss: 0.2955 - test_loss: 0.167901
# City: An Giang  _algo:cnn  -RMSE: 25.648748601789816
# City: An Giang  _algo:cnn  -RMSE: 31.69070348512911
# City: An Giang  _algo:cnn  -RMSE: 37.43265711253948
# Epoch:  0/380 - train_loss: 0.7487 - test_loss: 0.666449
# Epoch: 95/380 - train_loss: 0.1668 - test_loss: 0.076680
# Epoch: 190/380 - train_loss: 0.0961 - test_loss: 0.062294
# Epoch: 285/380 - train_loss: 0.0481 - test_loss: 0.104082
# Epoch: 379/380 - train_loss: 0.0120 - test_loss: 0.208962
# City: An Giang  _algo:lstm  -RMSE: 13.846168025644044
# City: An Giang  _algo:lstm  -RMSE: 17.82440684170898
# City: An Giang  _algo:lstm  -RMSE: 14.708438789150302
# Epoch:  0/130 - train_loss: 0.8458 - test_loss: 0.655127
# Epoch: 32/130 - train_loss: 0.2842 - test_loss: 0.165390
# Epoch: 64/130 - train_loss: 0.2816 - test_loss: 0.143691
# Epoch: 96/130 - train_loss: 0.2905 - test_loss: 0.144948
# Epoch: 128/130 - train_loss: 0.2966 - test_loss: 0.152835
# Epoch: 129/130 - train_loss: 0.2859 - test_loss: 0.147974
# City: An Giang  _algo:cnn  -RMSE: 28.23231695755653
# City: An Giang  _algo:cnn  -RMSE: 29.946104202073055
# City: An Giang  _algo:cnn  -RMSE: 30.863978335046426
# Epoch:  0/380 - train_loss: 0.7399 - test_loss: 0.679940
# Epoch: 95/380 - train_loss: 0.1616 - test_loss: 0.068659
# Epoch: 190/380 - train_loss: 0.1058 - test_loss: 0.052072
# Epoch: 285/380 - train_loss: 0.0886 - test_loss: 0.052214
# Epoch: 379/380 - train_loss: 0.0384 - test_loss: 0.044099
# City: An Giang  _algo:lstm  -RMSE: 14.080395401909808
# City: An Giang  _algo:lstm  -RMSE: 12.591687602005281
# City: An Giang  _algo:lstm  -RMSE: 16.14745062449756
# Epoch:  0/130 - train_loss: 0.8019 - test_loss: 0.656000
# Epoch: 32/130 - train_loss: 0.2836 - test_loss: 0.160388
# Epoch: 64/130 - train_loss: 0.2929 - test_loss: 0.136008
# Epoch: 96/130 - train_loss: 0.2708 - test_loss: 0.146348
# Epoch: 128/130 - train_loss: 0.2839 - test_loss: 0.154746
# Epoch: 129/130 - train_loss: 0.2906 - test_loss: 0.151017
# City: An Giang  _algo:cnn  -RMSE: 21.39588094076283
# City: An Giang  _algo:cnn  -RMSE: 26.652919032382307
# City: An Giang  _algo:cnn  -RMSE: 33.62129782611054
# Epoch:  0/380 - train_loss: 0.7695 - test_loss: 0.691821
# Epoch: 95/380 - train_loss: 0.1542 - test_loss: 0.103164
# Epoch: 190/380 - train_loss: 0.1093 - test_loss: 0.069828
# Epoch: 285/380 - train_loss: 0.0537 - test_loss: 0.038990
# Epoch: 379/380 - train_loss: 0.0238 - test_loss: 0.061901
# City: An Giang  _algo:lstm  -RMSE: 14.484276339467934
# City: An Giang  _algo:lstm  -RMSE: 14.338828398162219
# City: An Giang  _algo:lstm  -RMSE: 15.11099424482347
# Epoch:  0/130 - train_loss: 0.7907 - test_loss: 0.635686
# Epoch: 32/130 - train_loss: 0.3062 - test_loss: 0.166281
# Epoch: 64/130 - train_loss: 0.2967 - test_loss: 0.149553
# Epoch: 96/130 - train_loss: 0.2865 - test_loss: 0.146146
# Epoch: 128/130 - train_loss: 0.2795 - test_loss: 0.128425
# Epoch: 129/130 - train_loss: 0.2763 - test_loss: 0.126860
# City: An Giang  _algo:cnn  -RMSE: 19.411383700630594
# City: An Giang  _algo:cnn  -RMSE: 31.30951936552219
# City: An Giang  _algo:cnn  -RMSE: 31.065287135085267
# Epoch:  0/380 - train_loss: 0.7515 - test_loss: 0.677788
# Epoch: 95/380 - train_loss: 0.1700 - test_loss: 0.073516
# Epoch: 190/380 - train_loss: 0.1042 - test_loss: 0.059751
# Epoch: 285/380 - train_loss: 0.0341 - test_loss: 0.055597
# Epoch: 379/380 - train_loss: 0.0326 - test_loss: 0.053472
# City: An Giang  _algo:lstm  -RMSE: 14.406652691767814
# City: An Giang  _algo:lstm  -RMSE: 13.024377127883577
# City: An Giang  _algo:lstm  -RMSE: 13.581156126459542
# Epoch:  0/130 - train_loss: 0.8069 - test_loss: 0.648399
# Epoch: 32/130 - train_loss: 0.2876 - test_loss: 0.165325
# Epoch: 64/130 - train_loss: 0.2883 - test_loss: 0.152304
# Epoch: 96/130 - train_loss: 0.2739 - test_loss: 0.151474
# Epoch: 128/130 - train_loss: 0.2876 - test_loss: 0.140026
# Epoch: 129/130 - train_loss: 0.2886 - test_loss: 0.153471
# City: An Giang  _algo:cnn  -RMSE: 26.939646173064915
# City: An Giang  _algo:cnn  -RMSE: 26.453740700760477
# City: An Giang  _algo:cnn  -RMSE: 32.00791018475799
# Epoch:  0/380 - train_loss: 0.7364 - test_loss: 0.656247
# Epoch: 95/380 - train_loss: 0.1573 - test_loss: 0.106297
# Epoch: 190/380 - train_loss: 0.1031 - test_loss: 0.056753
# Epoch: 285/380 - train_loss: 0.0557 - test_loss: 0.051201
# Epoch: 379/380 - train_loss: 0.0188 - test_loss: 0.086775
# City: An Giang  _algo:lstm  -RMSE: 12.2943656776765
# City: An Giang  _algo:lstm  -RMSE: 12.557405977113042
# City: An Giang  _algo:lstm  -RMSE: 11.872751973520767
# Epoch:  0/130 - train_loss: 0.7543 - test_loss: 0.626549
# Epoch: 32/130 - train_loss: 0.2632 - test_loss: 0.144578
# Epoch: 64/130 - train_loss: 0.2882 - test_loss: 0.155811
# Epoch: 96/130 - train_loss: 0.2709 - test_loss: 0.161134
# Epoch: 128/130 - train_loss: 0.2846 - test_loss: 0.176412
# Epoch: 129/130 - train_loss: 0.2941 - test_loss: 0.159595
# City: An Giang  _algo:cnn  -RMSE: 27.398519448406805
# City: An Giang  _algo:cnn  -RMSE: 27.83371687392576
# City: An Giang  _algo:cnn  -RMSE: 32.80876917969888
# Epoch:  0/380 - train_loss: 0.7399 - test_loss: 0.662738
# Epoch: 95/380 - train_loss: 0.1957 - test_loss: 0.094603
# Epoch: 190/380 - train_loss: 0.1849 - test_loss: 0.111808
# Epoch: 285/380 - train_loss: 0.1893 - test_loss: 0.094302
# Epoch: 379/380 - train_loss: 0.1768 - test_loss: 0.100738
# City: An Giang  _algo:lstm  -RMSE: 12.641661424504887
# City: An Giang  _algo:lstm  -RMSE: 11.960515019669007
# City: An Giang  _algo:lstm  -RMSE: 14.479084064564962
# Epoch:  0/130 - train_loss: 0.8006 - test_loss: 0.632257
# Epoch: 32/130 - train_loss: 0.2846 - test_loss: 0.152344
# Epoch: 64/130 - train_loss: 0.2842 - test_loss: 0.148549
# Epoch: 96/130 - train_loss: 0.2631 - test_loss: 0.133860
# Epoch: 128/130 - train_loss: 0.2684 - test_loss: 0.175031
# Epoch: 129/130 - train_loss: 0.2721 - test_loss: 0.152612
# City: An Giang  _algo:cnn  -RMSE: 28.05030685204018
# City: An Giang  _algo:cnn  -RMSE: 23.743959270552846
# City: An Giang  _algo:cnn  -RMSE: 29.482072873526466
# Epoch:  0/380 - train_loss: 0.7886 - test_loss: 0.669042
# Epoch: 95/380 - train_loss: 0.1814 - test_loss: 0.098470
# Epoch: 190/380 - train_loss: 0.1397 - test_loss: 0.063881
# Epoch: 285/380 - train_loss: 0.2199 - test_loss: 0.056900
# Epoch: 379/380 - train_loss: 0.1391 - test_loss: 0.061567
# City: An Giang  _algo:lstm  -RMSE: 10.516885866326003
# City: An Giang  _algo:lstm  -RMSE: 11.093928976310382
# City: An Giang  _algo:lstm  -RMSE: 10.772426205685612
# Epoch:  0/130 - train_loss: 0.7858 - test_loss: 0.637724
# Epoch: 32/130 - train_loss: 0.2993 - test_loss: 0.145689
# Epoch: 64/130 - train_loss: 0.3216 - test_loss: 0.161117
# Epoch: 96/130 - train_loss: 0.2705 - test_loss: 0.141650
# Epoch: 128/130 - train_loss: 0.2594 - test_loss: 0.154957
# Epoch: 129/130 - train_loss: 0.2784 - test_loss: 0.148290
# City: An Giang  _algo:cnn  -RMSE: 24.926931719469607
# City: An Giang  _algo:cnn  -RMSE: 28.257246729433614
# City: An Giang  _algo:cnn  -RMSE: 31.36342282716105
# Epoch:  0/380 - train_loss: 0.7268 - test_loss: 0.627220
# Epoch: 95/380 - train_loss: 0.1710 - test_loss: 0.141498
# Epoch: 190/380 - train_loss: 0.2109 - test_loss: 0.094230
# Epoch: 285/380 - train_loss: 0.1024 - test_loss: 0.058669
# Epoch: 379/380 - train_loss: 0.1013 - test_loss: 0.052533
# City: An Giang  _algo:lstm  -RMSE: 12.506181964596262
# City: An Giang  _algo:lstm  -RMSE: 12.34845573748914
# City: An Giang  _algo:lstm  -RMSE: 15.718213757233713
# Epoch:  0/130 - train_loss: 0.8525 - test_loss: 0.631423
# Epoch: 32/130 - train_loss: 0.3283 - test_loss: 0.138840
# Epoch: 64/130 - train_loss: 0.2671 - test_loss: 0.144877
# Epoch: 96/130 - train_loss: 0.2595 - test_loss: 0.146409
# Epoch: 128/130 - train_loss: 0.2688 - test_loss: 0.159674
# Epoch: 129/130 - train_loss: 0.2604 - test_loss: 0.144234
# City: An Giang  _algo:cnn  -RMSE: 28.224660098562204
# City: An Giang  _algo:cnn  -RMSE: 24.157319734837255
# City: An Giang  _algo:cnn  -RMSE: 30.24498197603901
# Epoch:  0/380 - train_loss: 0.7741 - test_loss: 0.677178
# Epoch: 95/380 - train_loss: 0.1735 - test_loss: 0.082929
# Epoch: 190/380 - train_loss: 0.1510 - test_loss: 0.084893
# Epoch: 285/380 - train_loss: 0.1555 - test_loss: 0.112746
# Epoch: 379/380 - train_loss: 0.0759 - test_loss: 0.037267
# City: An Giang  _algo:lstm  -RMSE: 11.131967173357335
# City: An Giang  _algo:lstm  -RMSE: 13.608136114944866
# City: An Giang  _algo:lstm  -RMSE: 14.212442933703509
# Epoch:  0/130 - train_loss: 0.7832 - test_loss: 0.644371
# Epoch: 32/130 - train_loss: 0.3326 - test_loss: 0.135466
# Epoch: 64/130 - train_loss: 0.2605 - test_loss: 0.131734
# Epoch: 96/130 - train_loss: 0.2539 - test_loss: 0.126962
# Epoch: 128/130 - train_loss: 0.2615 - test_loss: 0.132172
# Epoch: 129/130 - train_loss: 0.2845 - test_loss: 0.140988
# City: An Giang  _algo:cnn  -RMSE: 14.10145240013063
# City: An Giang  _algo:cnn  -RMSE: 19.998013146065837
# City: An Giang  _algo:cnn  -RMSE: 21.5983607500818
# ...
# City: Bình Định  _algo:cnn  -RMSE: 5.816645847900248
# City: Bình Định  _algo:cnn  -RMSE: 6.534794828633763
# City: Bình Định  _algo:cnn  -RMSE: 6.611956488747616
# Epoch:  0/480 - train_loss: 0.7704 - test_loss: 0.686957
# Epoch: 120/480 - train_loss: 0.1003 - test_loss: 0.061881
# Epoch: 240/480 - train_loss: 0.0692 - test_loss: 0.055433
# Epoch: 360/480 - train_loss: 0.0535 - test_loss: 0.052576
# Epoch: 479/480 - train_loss: 0.0632 - test_loss: 0.053851
# City: Bình Định  _algo:lstm  -RMSE: 7.114641556489262
# City: Bình Định  _algo:lstm  -RMSE: 7.1803324011303085
# City: Bình Định  _algo:lstm  -RMSE: 7.000160821040081
# Epoch:  0/180 - train_loss: 0.7413 - test_loss: 0.641289
# Epoch: 45/180 - train_loss: 0.1251 - test_loss: 0.068625
# Epoch: 90/180 - train_loss: 0.1171 - test_loss: 0.075815
# Epoch: 135/180 - train_loss: 0.1144 - test_loss: 0.060302
# Epoch: 179/180 - train_loss: 0.1121 - test_loss: 0.065930
# City: Bình Định  _algo:cnn  -RMSE: 6.49765323987244
# City: Bình Định  _algo:cnn  -RMSE: 7.054071288300625
# City: Bình Định  _algo:cnn  -RMSE: 6.2574819581620815
# Epoch:  0/480 - train_loss: 0.7203 - test_loss: 0.665353
# Epoch: 120/480 - train_loss: 0.1330 - test_loss: 0.096678
# Epoch: 240/480 - train_loss: 0.0991 - test_loss: 0.073451
# Epoch: 360/480 - train_loss: 0.0578 - test_loss: 0.068441
# Epoch: 479/480 - train_loss: 0.0721 - test_loss: 0.054107
# City: Bình Định  _algo:lstm  -RMSE: 6.903146140015344
# City: Bình Định  _algo:lstm  -RMSE: 7.299964862946811
# City: Bình Định  _algo:lstm  -RMSE: 7.270550678629298
# Epoch:  0/180 - train_loss: 0.7175 - test_loss: 0.640177
# Epoch: 45/180 - train_loss: 0.1329 - test_loss: 0.064180
# Epoch: 90/180 - train_loss: 0.1170 - test_loss: 0.074061
# Epoch: 135/180 - train_loss: 0.1155 - test_loss: 0.064009
# Epoch: 179/180 - train_loss: 0.1197 - test_loss: 0.062858
# City: Bình Định  _algo:cnn  -RMSE: 6.358533773766933
# City: Bình Định  _algo:cnn  -RMSE: 6.8380130916214386
# City: Bình Định  _algo:cnn  -RMSE: 6.324090017951741
# Epoch:  0/480 - train_loss: 0.7215 - test_loss: 0.664924
# Epoch: 120/480 - train_loss: 0.1282 - test_loss: 0.078982
# Epoch: 240/480 - train_loss: 0.0858 - test_loss: 0.056858
# Epoch: 360/480 - train_loss: 0.1041 - test_loss: 0.059991
# Epoch: 479/480 - train_loss: 0.0951 - test_loss: 0.057816
# City: Bình Định  _algo:lstm  -RMSE: 6.512097673015368
# City: Bình Định  _algo:lstm  -RMSE: 6.526739493722247
# City: Bình Định  _algo:lstm  -RMSE: 6.616384232169706
# Epoch:  0/180 - train_loss: 0.7415 - test_loss: 0.647064
# Epoch: 45/180 - train_loss: 0.1277 - test_loss: 0.065831
# Epoch: 90/180 - train_loss: 0.1150 - test_loss: 0.065482
# Epoch: 135/180 - train_loss: 0.1141 - test_loss: 0.065888
# Epoch: 179/180 - train_loss: 0.1260 - test_loss: 0.062196
# City: Bình Định  _algo:cnn  -RMSE: 6.765486513324031
# City: Bình Định  _algo:cnn  -RMSE: 6.596719507601884
# City: Bình Định  _algo:cnn  -RMSE: 6.346852497059382
# Epoch:  0/480 - train_loss: 0.7141 - test_loss: 0.667927
# Epoch: 120/480 - train_loss: 0.0907 - test_loss: 0.057225
# Epoch: 240/480 - train_loss: 0.0650 - test_loss: 0.049453
# Epoch: 360/480 - train_loss: 0.0588 - test_loss: 0.049853
# Epoch: 479/480 - train_loss: 0.0556 - test_loss: 0.054609
# City: Bình Định  _algo:lstm  -RMSE: 6.811422890103906
# City: Bình Định  _algo:lstm  -RMSE: 6.664093263029552
# City: Bình Định  _algo:lstm  -RMSE: 6.307018504711278
# Epoch:  0/180 - train_loss: 0.7509 - test_loss: 0.646116
# Epoch: 45/180 - train_loss: 0.1149 - test_loss: 0.064686
# Epoch: 90/180 - train_loss: 0.1132 - test_loss: 0.066582
# Epoch: 135/180 - train_loss: 0.1139 - test_loss: 0.060809
# Epoch: 179/180 - train_loss: 0.1077 - test_loss: 0.065593
# City: Bình Định  _algo:cnn  -RMSE: 6.321448966403254
# City: Bình Định  _algo:cnn  -RMSE: 6.435133475031423
# City: Bình Định  _algo:cnn  -RMSE: 5.983351271706238
# Epoch:  0/480 - train_loss: 0.7513 - test_loss: 0.673509
# Epoch: 120/480 - train_loss: 0.1293 - test_loss: 0.066559
# Epoch: 240/480 - train_loss: 0.1244 - test_loss: 0.066969
# Epoch: 360/480 - train_loss: 0.0921 - test_loss: 0.055366
# Epoch: 479/480 - train_loss: 0.0763 - test_loss: 0.049540
# City: Bình Định  _algo:lstm  -RMSE: 6.008181359316461
# City: Bình Định  _algo:lstm  -RMSE: 6.153341654836613
# City: Bình Định  _algo:lstm  -RMSE: 6.303293064110915
# Epoch:  0/180 - train_loss: 0.7624 - test_loss: 0.650782
# Epoch: 45/180 - train_loss: 0.1218 - test_loss: 0.064821
# Epoch: 90/180 - train_loss: 0.1250 - test_loss: 0.061573
# Epoch: 135/180 - train_loss: 0.1122 - test_loss: 0.061458
# Epoch: 179/180 - train_loss: 0.1147 - test_loss: 0.062156
# City: Bình Định  _algo:cnn  -RMSE: 5.863833637178931
# City: Bình Định  _algo:cnn  -RMSE: 6.448585046741864
# City: Bình Định  _algo:cnn  -RMSE: 6.627826437354799
# Epoch:  0/480 - train_loss: 0.7358 - test_loss: 0.669204
# Epoch: 120/480 - train_loss: 0.1032 - test_loss: 0.068638
# Epoch: 240/480 - train_loss: 0.0910 - test_loss: 0.077899
# Epoch: 360/480 - train_loss: 0.0636 - test_loss: 0.107546
# Epoch: 479/480 - train_loss: 0.0471 - test_loss: 0.307969
# City: Bình Định  _algo:lstm  -RMSE: 7.578736285239996
# City: Bình Định  _algo:lstm  -RMSE: 7.337445505387543
# City: Bình Định  _algo:lstm  -RMSE: 7.447862277862918
# Epoch:  0/180 - train_loss: 0.7360 - test_loss: 0.642191
# Epoch: 45/180 - train_loss: 0.1226 - test_loss: 0.064925
# Epoch: 90/180 - train_loss: 0.1174 - test_loss: 0.065172
# Epoch: 135/180 - train_loss: 0.1122 - test_loss: 0.062321
# Epoch: 179/180 - train_loss: 0.1115 - test_loss: 0.061426
# City: Bình Định  _algo:cnn  -RMSE: 6.021904203118784
# City: Bình Định  _algo:cnn  -RMSE: 5.775207677977448
# City: Bình Định  _algo:cnn  -RMSE: 6.123439040545984
# Epoch:  0/480 - train_loss: 0.7121 - test_loss: 0.667584
# Epoch: 120/480 - train_loss: 0.1027 - test_loss: 0.077620
# Epoch: 240/480 - train_loss: 0.1024 - test_loss: 0.089145
# Epoch: 360/480 - train_loss: 0.0987 - test_loss: 0.069800
# Epoch: 479/480 - train_loss: 0.1272 - test_loss: 0.062706
# City: Bình Định  _algo:lstm  -RMSE: 7.132541782095833
# City: Bình Định  _algo:lstm  -RMSE: 7.721751246080765
# City: Bình Định  _algo:lstm  -RMSE: 7.748321699733898
# Epoch:  0/180 - train_loss: 0.7544 - test_loss: 0.647004
# Epoch: 45/180 - train_loss: 0.1191 - test_loss: 0.067107
# Epoch: 90/180 - train_loss: 0.1158 - test_loss: 0.058408
# Epoch: 135/180 - train_loss: 0.1111 - test_loss: 0.064372
# Epoch: 179/180 - train_loss: 0.1173 - test_loss: 0.059902
# City: Bình Định  _algo:cnn  -RMSE: 6.268471336803277
# City: Bình Định  _algo:cnn  -RMSE: 6.464808403026816
# City: Bình Định  _algo:cnn  -RMSE: 6.352331955074475
# Epoch:  0/480 - train_loss: 0.7377 - test_loss: 0.669367
# Epoch: 120/480 - train_loss: 0.0981 - test_loss: 0.062933
# Epoch: 240/480 - train_loss: 0.0719 - test_loss: 0.048863
# Epoch: 360/480 - train_loss: 0.0616 - test_loss: 0.049774
# Epoch: 479/480 - train_loss: 0.0603 - test_loss: 0.055756
# City: Bình Định  _algo:lstm  -RMSE: 5.949961391771635
# City: Bình Định  _algo:lstm  -RMSE: 6.128845776763469
# City: Bình Định  _algo:lstm  -RMSE: 5.780782073837817
# Epoch:  0/180 - train_loss: 0.7236 - test_loss: 0.632939
# Epoch: 45/180 - train_loss: 0.1223 - test_loss: 0.070108
# Epoch: 90/180 - train_loss: 0.1082 - test_loss: 0.061262
# Epoch: 135/180 - train_loss: 0.1074 - test_loss: 0.070980
# Epoch: 179/180 - train_loss: 0.1053 - test_loss: 0.067206
# City: Bình Định  _algo:cnn  -RMSE: 6.421398403865826
# City: Bình Định  _algo:cnn  -RMSE: 6.447477746997742
# City: Bình Định  _algo:cnn  -RMSE: 7.024379143312879
# Epoch:  0/480 - train_loss: 0.7244 - test_loss: 0.666417
# Epoch: 120/480 - train_loss: 0.1241 - test_loss: 0.065542
# Epoch: 240/480 - train_loss: 0.1015 - test_loss: 0.065646
# Epoch: 360/480 - train_loss: 0.1125 - test_loss: 0.070310
# Epoch: 479/480 - train_loss: 0.0810 - test_loss: 0.062215
# City: Bình Định  _algo:lstm  -RMSE: 6.000925347225495
# City: Bình Định  _algo:lstm  -RMSE: 6.130550084937862
# City: Bình Định  _algo:lstm  -RMSE: 6.14698347036512
# Epoch:  0/180 - train_loss: 0.7422 - test_loss: 0.638801
# Epoch: 45/180 - train_loss: 0.1162 - test_loss: 0.065538
# Epoch: 90/180 - train_loss: 0.1060 - test_loss: 0.059233
# Epoch: 135/180 - train_loss: 0.1053 - test_loss: 0.065085
# Epoch: 179/180 - train_loss: 0.1133 - test_loss: 0.068952
# City: Bình Định  _algo:cnn  -RMSE: 5.776984034137895
# City: Bình Định  _algo:cnn  -RMSE: 5.8539525615543315
# City: Bình Định  _algo:cnn  -RMSE: 6.1538037329584885
# Epoch:  0/480 - train_loss: 0.7325 - test_loss: 0.668850
# Epoch: 120/480 - train_loss: 0.1016 - test_loss: 0.067738
# Epoch: 240/480 - train_loss: 0.0787 - test_loss: 0.069564
# Epoch: 360/480 - train_loss: 0.0718 - test_loss: 0.054185
# Epoch: 479/480 - train_loss: 0.0637 - test_loss: 0.055939
# City: Bình Định  _algo:lstm  -RMSE: 6.347851478517789
# City: Bình Định  _algo:lstm  -RMSE: 6.15556031222341
# City: Bình Định  _algo:lstm  -RMSE: 6.617243074305059
# Epoch:  0/180 - train_loss: 0.7420 - test_loss: 0.642206
# Epoch: 45/180 - train_loss: 0.1222 - test_loss: 0.066700
# Epoch: 90/180 - train_loss: 0.1139 - test_loss: 0.059550
# Epoch: 135/180 - train_loss: 0.1073 - test_loss: 0.070752
# Epoch: 179/180 - train_loss: 0.1115 - test_loss: 0.064738
# City: Bình Định  _algo:cnn  -RMSE: 6.183337011234772
# City: Bình Định  _algo:cnn  -RMSE: 6.1168878391741295
# City: Bình Định  _algo:cnn  -RMSE: 6.428071842590062
# Epoch:  0/480 - train_loss: 0.7491 - test_loss: 0.676340
# Epoch: 120/480 - train_loss: 0.0921 - test_loss: 0.055340
# Epoch: 240/480 - train_loss: 0.0826 - test_loss: 0.057261
# Epoch: 360/480 - train_loss: 0.0762 - test_loss: 0.057694
# Epoch: 479/480 - train_loss: 0.0739 - test_loss: 0.060153
# City: Bình Định  _algo:lstm  -RMSE: 6.07242644034482
# City: Bình Định  _algo:lstm  -RMSE: 5.840290215859788
# City: Bình Định  _algo:lstm  -RMSE: 6.172219422112473
# Epoch:  0/180 - train_loss: 0.7340 - test_loss: 0.628091
# Epoch: 45/180 - train_loss: 0.1154 - test_loss: 0.064126
# Epoch: 90/180 - train_loss: 0.1458 - test_loss: 0.077034
# Epoch: 135/180 - train_loss: 0.1158 - test_loss: 0.065284
# Epoch: 179/180 - train_loss: 0.1321 - test_loss: 0.070593
# City: Bình Định  _algo:cnn  -RMSE: 5.611023349271103
# City: Bình Định  _algo:cnn  -RMSE: 6.265181619429326
# City: Bình Định  _algo:cnn  -RMSE: 6.084794337791272
# Epoch:  0/480 - train_loss: 0.7148 - test_loss: 0.664731
# Epoch: 120/480 - train_loss: 0.1024 - test_loss: 0.060037
# Epoch: 240/480 - train_loss: 0.0955 - test_loss: 0.051995
# Epoch: 360/480 - train_loss: 0.0769 - test_loss: 0.048642
# Epoch: 479/480 - train_loss: 0.0660 - test_loss: 0.043784
# City: Bình Định  _algo:lstm  -RMSE: 6.116511350552391
# City: Bình Định  _algo:lstm  -RMSE: 5.976277443683714
# City: Bình Định  _algo:lstm  -RMSE: 6.291565201892481
# Epoch:  0/180 - train_loss: 0.7228 - test_loss: 0.624224
# Epoch: 45/180 - train_loss: 0.1251 - test_loss: 0.069561
# Epoch: 90/180 - train_loss: 0.1204 - test_loss: 0.074400
# Epoch: 135/180 - train_loss: 0.1170 - test_loss: 0.065714
# Epoch: 179/180 - train_loss: 0.1046 - test_loss: 0.059892
# City: Bình Định  _algo:cnn  -RMSE: 5.66568718169476
# City: Bình Định  _algo:cnn  -RMSE: 5.491351449329211
# City: Bình Định  _algo:cnn  -RMSE: 5.594855470803718
# Epoch:  0/480 - train_loss: 0.7204 - test_loss: 0.670038
# Epoch: 120/480 - train_loss: 0.0983 - test_loss: 0.055321
# Epoch: 240/480 - train_loss: 0.0956 - test_loss: 0.050813
# Epoch: 360/480 - train_loss: 0.1249 - test_loss: 0.062074
# Epoch: 479/480 - train_loss: 0.1215 - test_loss: 0.066806
# City: Bình Định  _algo:lstm  -RMSE: 5.626627677385553
# City: Bình Định  _algo:lstm  -RMSE: 5.1208466914895086
# City: Bình Định  _algo:lstm  -RMSE: 5.466188328837303
# Epoch:  0/180 - train_loss: 0.7261 - test_loss: 0.629195
# Epoch: 45/180 - train_loss: 0.1248 - test_loss: 0.058879
# Epoch: 90/180 - train_loss: 0.1085 - test_loss: 0.061261
# Epoch: 135/180 - train_loss: 0.1215 - test_loss: 0.065836
# Epoch: 179/180 - train_loss: 0.1157 - test_loss: 0.071527
# City: Bình Định  _algo:cnn  -RMSE: 4.876165872164993
# City: Bình Định  _algo:cnn  -RMSE: 4.975484597079401
# City: Bình Định  _algo:cnn  -RMSE: 5.115825052506298
# Epoch:  0/480 - train_loss: 0.7445 - test_loss: 0.660896
# Epoch: 120/480 - train_loss: 0.0969 - test_loss: 0.071697
# Epoch: 240/480 - train_loss: 0.0786 - test_loss: 0.080136
# Epoch: 360/480 - train_loss: 0.0590 - test_loss: 0.049370
# Epoch: 479/480 - train_loss: 0.0661 - test_loss: 0.070968
# City: Bình Định  _algo:lstm  -RMSE: 6.460277379137701
# City: Bình Định  _algo:lstm  -RMSE: 6.413134700353786
# City: Bình Định  _algo:lstm  -RMSE: 6.765596541973804
# Epoch:  0/180 - train_loss: 0.7348 - test_loss: 0.643081
# Epoch: 45/180 - train_loss: 0.1120 - test_loss: 0.073444
# Epoch: 90/180 - train_loss: 0.1083 - test_loss: 0.087615
# Epoch: 135/180 - train_loss: 0.1007 - test_loss: 0.066077
# Epoch: 179/180 - train_loss: 0.1147 - test_loss: 0.064227
# City: Bình Định  _algo:cnn  -RMSE: 5.507575186424865
# City: Bình Định  _algo:cnn  -RMSE: 5.188804254209032
# City: Bình Định  _algo:cnn  -RMSE: 5.518396123114128
# Epoch:  0/480 - train_loss: 0.7316 - test_loss: 0.663624
# Epoch: 120/480 - train_loss: 0.1155 - test_loss: 0.074720
# Epoch: 240/480 - train_loss: 0.1041 - test_loss: 0.089020
# Epoch: 360/480 - train_loss: 0.0906 - test_loss: 0.056623
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 63
#      54   cnn_metrics = do_train_predict(city =city, algo='cnn', list_selected_features = list_selected_features,
#      55                                       origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler,
#      56                                       s_selected_features= s_selected_features, train = train, test = test,
#      57                                       sample_idx = sample_index,combination_idx= combination_idx)
#      59 if(is_in_Selected_combination('LSTM*'+s_selected_features)==True):
#      60   ########################################
#      61   ########## LSTM
#      62   ########################################
# ---> 63   lstm_metrics = do_train_predict(city =city, algo='lstm', list_selected_features = list_selected_features,
#      64                                       origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler,
#      65                                       s_selected_features= s_selected_features, train = train, test = test,
#      66                                       sample_idx = sample_index,combination_idx= combination_idx)
#      71 ###############################
#      72 ## Khúc này rất thủ công
#      73 if(cnn_metrics.empty==False and lstm_metrics.empty ==False):
#
# Cell In[12], line 61, in do_train_predict(city, algo, list_selected_features, origin_city_meta_test_set, y_scaler, s_selected_features, train, test, sample_idx, combination_idx)
#      48     trainer = Trainer(
#      49                         model_type='transformers',
#      50                         city = city,
#    (...)
#      56                         hidden_size=hidden_size,
#      57                         dropout=dropout)
#      60 # Train model with province-specific epochs
# ---> 61 trainer.train(epochs=epoch)
#      62 # Evaluate test set
#      63 y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
#
# Cell In[9], line 351, in Trainer.train(self, epochs)
#     349 total_loss = 0.0
#     350 for batch in self.train_loader:
# --> 351     loss = self.step(batch)
#     352     total_loss += loss
#     353 train_loss = total_loss/len(self.train_loader)
#
# Cell In[9], line 320, in Trainer.step(self, batch)
#     318 self.model.train()
#     319 X_batch, y_batch = tuple(t.to(args.device) for t in batch)
# --> 320 self.optimizer.zero_grad()
#     321 y_pred, loss = self.model.forward(X_batch, y_batch)
#     322 loss.backward()
#
# File ~/anaconda3/envs/climate_diseases_py39/lib/python3.9/site-packages/torch/optim/optimizer.py:249, in Optimizer.zero_grad(self, set_to_none)
#     247     p.grad.requires_grad_(False)
#     248 if (not foreach or p.grad.is_sparse):
# --> 249     p.grad.zero_()
#     250 else:
#     251     per_device_and_dtype_grads[p.grad.device][p.grad.dtype].append(p.grad)
#
# KeyboardInterrupt:

# %%
send_to_telegram("Server Chạy Xong ensemble weighted " )
