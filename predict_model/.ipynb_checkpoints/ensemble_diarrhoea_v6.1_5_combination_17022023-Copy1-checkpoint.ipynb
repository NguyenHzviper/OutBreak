# %% [markdown]
# # Matrix of metrics of Cross validation  for 5 top Simple Combination
# Date: 09/12/2022
# Description: Create cross validation metrics
# Use 5 combinations only regarding to the ranking from simple combination result.
# This file creates cross validation metrics for next steps
# Modificaiton 02/01/2023
# Sử dụng 5 combination mới

# %%
# !nvidia-smi

# %%
# Install packages
# !pip install -U scikit-learn
# !pip install ftfy
# !pip install xlsxwriter 
# !pip install xlwt

# %%
# Imports
import tensorflow as tf 
# from google.colab import drive
import os

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense

import traceback
import sys
import copy
import numpy as np
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# lib for LSTM of Meta model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

from ftfy import fix_text
import warnings
warnings.simplefilter("ignore", UserWarning)

plt.rcParams['figure.figsize'] = [7, 3]
import math

# %% [markdown]
# # Global param and project path
# All mix data 1997-2018

# %%
# Attach Google Drive for reading and saving files
# drive.mount('/content/drive')
prj_path = '/home/mlworker/Quang/HealthCare/Source_14012023_v4/'

# Lấy từ 1997 tới 01/01/2018. Bỏ 12 tháng cuối rồi
path_all_mix_data =             prj_path+ 'results/all_mix_data/all_mix_data_1997_2018_mae/'
path_all_mix_data_cnn =         prj_path+ 'results/all_mix_data/all_mix_data_1997_2018_mae/cnn/'
path_all_mix_data_lstm =        prj_path+ 'results/all_mix_data/all_mix_data_1997_2018_mae/lstm/'
path_all_mix_data_lstm_att =    prj_path+ 'results/all_mix_data/all_mix_data_1997_2018_mae/lstm_att/'
path_all_mix_data_tf =          prj_path+ 'results/all_mix_data/all_mix_data_1997_2018_mae/tf/'

prj_path_opt= prj_path+ 'optimize_hyperparam/opt_results/opt_results_1997_2018_mae/'


prj_path_result_ensemble =      prj_path+ 'results/ensemble_17022023/'
com_path_validation_metrics =   prj_path_result_ensemble+ 'result/weighted_combination/cv_metrics/'

# com_eval_path_validation_metrics = 'H:/Store/Research/UIT/PhD Research/Dev Environment/Tropical Diseases/running/eval_result/21_12_2022_weighted_combination-5-cities/'


# loockback_window for meta model
meta_lookback_window = 3

# %% [markdown]
# # Xây dựng Meta Data Set

# %%
##########################
# Xây Dựng Meta Data Set
meta_test_set_city = {}
meta_train_set_city = {}
meta_data_set_city = {}
cities = [
    'An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
        'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
    
        'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
        'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
    
        'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
        'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
    
        'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
        'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
    
        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
        'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
    
         'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp'
]
cities = ['An Giang','Lạng Sơn']

for city in cities:  
  meta_test_set = pd.DataFrame()
  meta_train_set = pd.DataFrame() 
  #Note: mỗi bộ all_mix_data sẽ có lenght = 251 (1997 -01/01/2018  và vì 1 dòng đầu bị bỏ đi do quá trình statitionary và remove NAN lúc train)
  lenght_whole_data_city = 251
  ######################################
  # Xử lý data của CNN ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_cnn+'mix_train_test_data_'+city+'_cnn.xlsx')
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index() 
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_cnn = result_test.reset_index(drop=True)  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_cnn = result_train.reset_index(drop=True)
  
  ######################################
  # Xử lý data của LSTM  ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm+'mix_train_test_data_'+city+'_lstm.xlsx')  
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm = result_test.reset_index(drop=True)
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm = result_train.reset_index(drop=True)

  ###########################################
  # Xử lý data của LSTM ATT ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm_att+'mix_train_test_data_'+city+'_lstm_att.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm_att = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36]
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm_att = result_train.reset_index(drop=True)


  #############################################
  # Xử lý data của Transformer ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_tf+'mix_train_test_data_'+city+'_tf.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
  meta_test_tf = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36] # Lấy từ meta_lookback_window cho đến -36 (3 năm cuối)
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_tf = result_train.reset_index(drop=True)

  
  meta_test_set['cnn_pred'] = meta_test_cnn
  meta_test_set['lstm_pred'] = meta_test_lstm
  meta_test_set['lstm_att_pred'] = meta_test_lstm_att
  meta_test_set['tf_pred'] = meta_test_tf
  meta_test_set['Observed'] = meta_test_observed
   
  meta_train_set['cnn_pred'] = meta_train_cnn
  meta_train_set['lstm_pred'] = meta_train_lstm
  meta_train_set['lstm_att_pred'] = meta_train_lstm_att 
  meta_train_set['tf_pred'] = meta_train_tf  
  meta_train_set['Observed'] = meta_train_observed

  meta_test_set_city[city] = meta_test_set # test set có chiều dài 39
  meta_train_set_city[city] = meta_train_set # train set có chiều dài 212 = 252 -36 (train) - 1 (station) - 3 (meta_lookback_window)

  # Đoạn này làm thêm. Nối dài meta_test_set_city và meta_train_set_city
  # lưu ý đoạn này sẽ tạo ra data có chiều dài = 252 - 1 (bỏ đi 1 tháng đầu do xử lý stationary) - meta_lookback_window
  df = meta_train_set.append(meta_test_set[3:])
  df = df.reset_index(drop=True)
  # range date từ 1 + lookback_window tháng đầu tiên
  df['year_month'] = pd.Series(pd.date_range("1997-05-01", periods=248, freq="M"))  
  meta_data_set_city[city] = df
  df.to_excel(prj_path_result_ensemble+'/meta_data/meta_data_'+city+'.xlsx')
# Out:
# <ipython-input-5-d1bbe697d129>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-d1bbe697d129>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-5-d1bbe697d129>:32: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:47: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:66: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-d1bbe697d129>:89: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-d1bbe697d129>:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])

# %%
# meta_train_set_city['Lạng Sơn']
# Out:
#        cnn_pred   lstm_pred  lstm_att_pred    tf_pred    Observed
# 0     77.292201   88.424680      80.496828  85.670853   99.611343
# 1     88.682030   88.671098      86.903221  85.546341  168.418022
# 2    112.834587  121.816570      99.930584  85.427779  142.363610
# 3    123.810786  118.304835     103.982703  85.638943  123.362603
# 4    107.534822  112.004516     106.373317  86.036705  139.628617
# ..          ...         ...            ...        ...         ...
# 207   56.956432   59.894504      69.409478  86.013486   63.951174
# 208   65.547753   56.022345      63.906276  85.793388   60.103489
# 209   68.079825   59.382600      60.855734  85.604366   52.540799
# 210   54.464534   52.553093      58.654769  85.660178   56.653841
# 211   58.847407   51.232785      57.065804  85.776182   74.963513
#
# [212 rows x 5 columns]

# %%
# meta_test_set_city['Lạng Sơn']
# Out:
#      cnn_pred  lstm_pred  lstm_att_pred    tf_pred   Observed
# 0   68.079825  59.382600      60.855734  85.604366  52.540799
# 1   54.464534  52.553093      58.654769  85.660178  56.653841
# 2   58.847407  51.232785      57.065804  85.776182  74.963513
# 3   66.224684  60.952425      62.089855  86.301625  54.036287
# 4   72.092165  67.537299      65.216016  86.103282  78.753616
# 5   73.683446  74.376287      70.924344  85.641222  64.159874
# 6   70.758599  65.257426      65.725454  85.642020  60.741520
# 7   71.035677  70.356204      71.294814  85.608848  59.821194
# 8   68.349486  66.914674      67.743101  85.591952  63.765448
# 9   48.868097  45.966066      56.862959  85.788636  58.506442
# 10  58.705811  49.357787      57.204644  85.763330  63.239548
# 11  58.925738  59.273873      62.323305  85.931366  65.869051
# 12  69.544357  58.744766      61.443650  85.624795  52.327110
# 13  58.510506  55.066422      59.953941  85.642830  66.263476
# 14  64.726317  61.311249      63.118730  85.736749  61.398896
# 15  46.700933  55.536373      59.955932  86.402707  34.603877
# 16  62.030059  51.760243      57.549289  86.117916  40.718095
# 17  50.324877  52.260858      54.926075  85.792891  52.426174
# 18  57.318348  55.033522      51.503746  85.546911  49.043840
# 19  53.365996  57.983426      55.591744  85.619721  58.280213
# 20  58.416332  46.409483      52.776323  85.544292  30.831274
# 21  51.174336  30.627211      43.929221  85.576781  26.668401
# 22  39.101552  26.057277      40.293146  85.719202  55.808508
# 23  48.922812  42.536995      42.627308  85.976771  45.401327
# 24  31.553300  40.822914      44.408285  85.947043  40.197736
# 25  52.290835  41.907819      48.772564  85.421460  40.067647
# 26  42.197913  43.880195      49.916956  85.911026   7.545206
# 27  38.327584  33.711868      40.994499  86.098887  30.050735
# 28  43.058995  37.404267      41.128367  85.871168  34.213607
# 29  40.483128  36.030821      34.326115  85.978258  34.864056
# 30  48.115597  40.575063      41.776221  85.630487  37.595941
# 31  41.945192  40.756889      42.023424  85.727515  50.604917
# 32  51.120418  46.900083      46.025769  85.514044  42.409262
# 33  44.141098  40.677730      45.870171  85.769526  34.994146
# 34  37.155328  25.322640      40.447087  85.900544  33.302979
# 35  48.364841  28.666110      37.818653  85.702933  26.798491
# 36  42.147973  34.125390      38.966473  85.657346  27.579030
# 37  38.695758  29.388537      36.706528  85.735077  23.936516
# 38  31.371428  29.757716      36.158466  86.002181  29.920645

# %% [markdown]
# # Danh sách các based Model và các Combination có thể của nó

# %%
# Danh sách các based Model và các Combination có thể của nó
list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

combs_features = list(combinations(list_based_model[0:], 2)) + list(combinations(list_based_model[0:], 3)) + list(combinations(list_based_model[0:], 4))

# list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

# combs_features = list(combinations(list_based_model[0:], 3)) 
combs_features
# Out:
# [('cnn_pred', 'lstm_att_pred'),
#  ('cnn_pred', 'lstm_pred'),
#  ('cnn_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred'),
#  ('lstm_att_pred', 'tf_pred'),
#  ('lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred', 'tf_pred')]

# %% [markdown]
# # Selected 5 Combination

# %%
# Bộ sai đầu tiên
# selected_combs = ['CNN*lstm_att_pred-tf_pred-Observed','CNN*cnn_pred-lstm_pred-Observed',
#                   'CNN*lstm_pred-tf_pred-Observed', 'CNN*cnn_pred-lstm_att_pred-lstm_pred-Observed',
#                   'LSTM*lstm_att_pred-lstm_pred-tf_pred-Observed'                 
#                  ]
# # Bộ này theo top 5 cố định RMSE
# selected_combs = ['LSTM*cnn_pred-tf_pred-Observed',
#                   'LSTM*lstm_att_pred-lstm_pred-Observed',     

#                   'LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed',
#                   'CNN*lstm_att_pred-lstm_pred-Observed', 
#                   'LSTM*cnn_pred-lstm_pred-Observed'           
#                  ]

# Bộ này theo top 5 cố định MAE
# selected_combs = ['LSTM*lstm_att_pred-lstm_pred-tf_pred-Observed',
#                   'CNN*lstm_att_pred-tf_pred-Observed', 
#                   'LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed',
#                   'CNN*lstm_att_pred-lstm_pred-Observed',
#                   'LSTM*cnn_pred-lstm_pred-Observed'
                
#                  ]
# selected_combs = ['LSTM*lstm_att_pred-lstm_pred-tf_pred-Observed',                    
#                   'CNN*lstm_att_pred-tf_pred-Observed'
                #  ]
selected_combs = ['LSTM*cnn_pred-lstm_att_pred-Observed',
                  'LSTM*lstm_att_pred-lstm_pred-Observed', 
                  'CNN*cnn_pred-lstm_pred-Observed',
                  'CNN*lstm_pred-tf_pred-Observed', 
                  'CNN*lstm_att_pred-lstm_pred-Observed',
                  'CNN*lstm_att_pred-lstm_pred-tf_pred-Observed',
                  'LSTM*cnn_pred-lstm_att_pred-lstm_pred-Observed',
                  'CNN*cnn_pred-lstm_att_pred-Observed'
                 ]

def is_in_Selected_combination(comb_string = ''):
    return any(comb_string in x for x in selected_combs)

# %% [markdown]
# # Support Functions and Train class

# %%
import requests

def send_to_telegram(message):

    apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
    chatID = '@ptn_announcement'
    apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

    try:
        response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
        print(response.text)
    except Exception as e:
        print(e)


def seed_everything(seed: int):
    import random, os    
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything(42)

# Set hyperparameters as args using the Configuration class
class Configuration():
    def __init__(self):
      # lấy bộ test dài 36 tháng = 3 năm
        self.test_size = 36
        # là nhìn vào dữ liệu trước 3 tháng và dự phóng        
        self.look_back = 3
        # dự phóng 3 tháng
        self.n_predicted_month = 3
        self.n_features = 3
        self.seed = 42
        # mỗi phần tử x trong tập suppervise có độ lớn là 16 = 16 tháng
        self.batch_size = 16
        # self.device = torch.device("cuda")
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.epochs = 300
     

# Biến args lưu giá trị Global.
args = Configuration()


# Lưu ý sau khi stationnary thì dòng đầu tiên trừ cho dòng trước nữa là ko có cho nên về cơ bản sẽ thành NaN
# Cần remove dòng đầu tiên ra khỏi data để train và test. Cho nên cơ bản là data sau khi in ra sẽ thiếu 1 đơn vị đầu tiên
def convert_to_stationary(city_data):
    """Subtracts previous value for all cols except disease rates"""
    for col_name in city_data.columns:
        if col_name != 'Diarrhoea_rates':
            try:
                city_data[col_name] = city_data[col_name] - city_data[col_name].shift()
            except:
                print(col_name)
    return city_data

def impute_missing_value(city_data):
    """
    Cơ bản dữ liệu bị thiếu sót rất nhiều: Như Điện Biên 1997 -2003 là thiếu dữ liệu về bệnh
    Hàm này sẽ tự sinh ra dữ liệu bị thiếu. Nếu tháng nào không có số liệu thì tính như sau:
    12 tháng đầu không có số liệu thì gán = 0
    tháng 13-24 không có số liệu, sẽ lấy giá trị của tháng cùng kỳ năm trước
    tháng từ 24 trở đi sẽ lấy giá trị nhỏ nhất của 2 tháng cùng kỳ trong 2 năm gần nhất.
    Do Điện Biên bằng 0 nên sau khi xử lý từ 1997 -2003 là đều = 0.  
    """
    for col in city_data.columns:
        for index in range(len(city_data[col])):
            if np.isnan(city_data[col].iloc[index]):
                if index < 12:
                    city_data[col].iloc[index] = 0
                elif index >= 12 and index <= 24:
                    city_data[col].iloc[index] = city_data[col].iloc[index - 12]
                else:
                    city_data[col].iloc[index] = min(city_data[col].iloc[index - 12], city_data[col].iloc[index - 24])
    return city_data

def split_data(data, look_back ):
    """Splits data into train and test sets based on args (Configuration class)"""
    train = data[: -args.test_size]    
    test = data[-args.test_size - look_back: ]
    return train, test

def to_supervised(data, d_in=args.look_back, d_out=args.n_predicted_month, features_list=[]):
    """
    Frames time-series as supervised learning dataset.
    
    Args:
      d_in: lookback window
      d_out: number of predicted months
      features_list: list of all features **where last col is the disease incidence**

    Returns:
      Numpy arrays of disease incidence (y) and other predictors (X)
    """
    X, y = list(), list()
    for index, _ in enumerate(data):
        in_end = index + d_in
        out_end = in_end + d_out
        if out_end <= len(data):
            if len(features_list) == 0 :
                X.append(data[index: in_end, :])
            else:
                X.append(data[index: in_end, features_list])
            y.append(data[in_end: out_end, -1])
    return np.array(X), np.array(y)


def get_data(train_np, test_np, batch_size, list_selected_features, origin_city_meta_data):
    """
    Returns important feature list and data formatted for input into Pytorch 
    models
    """ 
    # origin_city_meta_data chứa data mẫu để lấy index 
    # important_features = arrary index nên ta phải truyền indexex của columns
    important_features = [origin_city_meta_data.columns.get_loc(c) for c in list_selected_features if c in origin_city_meta_data]  

    train_X, train_y = to_supervised(train_np, features_list=important_features)
    test_X, test_y = to_supervised(test_np, features_list=important_features)
    train_tensor = TensorDataset(torch.from_numpy(train_X), torch.from_numpy(train_y))
    test_tensor = (torch.from_numpy(test_X), torch.from_numpy(test_y))

    train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

    return important_features, train_loader, test_tensor

#Define Pytorch LSTM model
class MultiVariateLSTM(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = output[:, -1, :]
        y_predicted = self.linear(last_hidden_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            #return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

#Define Pytorch LSTM-ATT model
class MultiVariateLSTM_Attention(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.attention_linear = nn.Linear(hidden_size, hidden_size)
        # self.linear = nn.Linear(hidden_size*2, args.n_predicted_month)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = last_hidden[-1]
        remain_hidden_vector = output
        e_t = remain_hidden_vector.bmm(self.attention_linear(last_hidden_vector).unsqueeze(2)).squeeze(-1)
        alpha_t = F.softmax(e_t, dim=1)
        attenion_vector = remain_hidden_vector.transpose(2, 1).bmm(alpha_t.unsqueeze(2)).squeeze(-1)
        # combine_vector = torch.cat((last_hidden_vector, attenion_vector), dim=1)
        # combine_vector = last_hidden_vector + attenion_vector
        y_predicted = self.linear(attenion_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Define Pytorch CNN model
class MultivariateCNN(nn.Module):
    def __init__(self, num_filters=[100, 100, 100], dropout=0.01):
        super(MultivariateCNN, self).__init__()
        self.loss_fn = loss = nn.MSELoss()
        self.filter_sizes = [1, 2, 3]
        self.conv1d_list = nn.ModuleList([nn.Conv1d(args.n_features, num_filters[i], self.filter_sizes[i]) for i in range(len(self.filter_sizes))])
        self.linear = nn.Linear(np.sum(num_filters), args.n_predicted_month)
        self.dropout = nn.Dropout(dropout)
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))

    def forward(self, X_batch, y_batch=None):
        X_batch = X_batch.permute(0, 2, 1)  #(batch_size, n_features, n_look_back)
        X_conv_list = [F.relu(conv1d(X_batch)) for conv1d in self.conv1d_list]
        X_pool_list = [F.max_pool1d(x_conv, kernel_size=x_conv.shape[2]) for x_conv in X_conv_list]
        X_fc = torch.cat([x_pool.squeeze(dim=2) for x_pool in X_pool_list], dim=1)
        y_predicted = self.linear(self.dropout(X_fc))
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted

    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Transformer Model
# Transformer Model
class PositionalEncoder(nn.Module):
    def __init__(self, n_feature=3, dropout=0.1, max_length=24):
        super().__init__()
        
        self.hidden_dim = n_feature
        self.max_length = max_length
        self.dropout = nn.Dropout(dropout)
        
        pe = torch.zeros(max_length, self.hidden_dim)
        for pos in range(max_length):
            for i in range(0, self.hidden_dim, 2):
                pe[pos, i] = math.sin(pos/(10000**(2*i/self.hidden_dim)))
                if i + 1 < self.hidden_dim:
                    pe[pos, i+1] = math.cos(pos/(10000**((2*i+1)/self.hidden_dim)))
        pe = pe.unsqueeze(0)        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x*math.sqrt(self.hidden_dim)
        length = x.size(1)
        pe = Variable(self.pe[:, :length], requires_grad=False)
        if x.is_cuda:
            pe.cuda()
        x = x + pe
        x = self.dropout(x)
        
        return x

class TransformerModel(nn.Module):
    def __init__(self, d_input, n_look_back, hidden_size, n_layers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.hidden_size = hidden_size

        self.pe = PositionalEncoder(n_feature=args.n_features, dropout=dropout)

        encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dim_feedforward=hidden_size, dropout=dropout, activation='gelu')
        # encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)
        self.decoder = nn.Linear(d_input*n_look_back, args.n_predicted_month)

        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
        
        self.loss_fn = nn.MSELoss()
        
    
    def forward(self, X_batch, y_batch=None):
        X_batch = self.pe(X_batch)
        X_batch = self.transformer_encoder(X_batch)
        X_batch = X_batch.view(X_batch.size(0), -1)
        
        y_predicted = self.decoder(X_batch)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
        else:
            return y_predicted
        return X_batch
    
    def predict(self, X):
        with torch.no_grad():
            X = torch.tensor(X, device=args.device)
        return self.forward(X).squeeze()

# Create class to train and evaluate models
class Trainer():
    def __init__(self, city, model_type, learning_rate, important_features, train_loader, test_tensor, n_layers=2, hidden_size=128, num_filters=[100, 100, 100], dropout=0.01):
        """
        Initialise trainer, allowing input of LSTM, LSTM-ATT, or CNN 
        hyperparameters. Adam optimiser used for all models.
        """
        self.model_type = model_type    
        self.city = city    
        self.model = self.init_model(model_type, n_layers, hidden_size, num_filters, dropout, city)
        self.model.double().to(args.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.important_features, self.train_loader, self.test_tensor = important_features, train_loader, test_tensor
    
    def init_model(self, model_type, n_layers, hidden_size, num_filters, dropout, city):        
        #Get hyper param by name and set for n_layers, hidden_size, num_filters, dropout and overwrite the input param  
        # n_layers, hidden_size,num_filters, dropout= get_opt_param_by_name( algo = model_type, city = city)
    
        """Initialise a model based on whether LSTM, LSTM-ATT, or CNN is chosen."""
        if model_type.lower() == 'lstm':
            model = MultiVariateLSTM(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'lstm_attention':
            model = MultiVariateLSTM_Attention(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'cnn':
            model = MultivariateCNN(num_filters, dropout)
        elif model_type.lower() == 'transformers':
            model = TransformerModel(d_input=args.n_features, n_look_back=args.look_back, hidden_size=hidden_size, n_layers=n_layers, dropout=dropout)
        return model

    def step(self, batch):
        self.model.train()
        X_batch, y_batch = tuple(t.to(args.device) for t in batch)
        self.optimizer.zero_grad()
        y_pred, loss = self.model.forward(X_batch, y_batch)
        loss.backward()
        self.optimizer.step()
        return loss.mean().item()

    def validation(self):
        self.model.eval()
        eval_loss = 0.0

        result = {}

        y_true = np.array([])
        y_pred = np.array([])

        X_batch, y_batch = tuple(t.to(args.device) for t in self.test_tensor)
        with torch.no_grad():
            outputs, loss = self.model.forward(X_batch, y_batch)
            eval_loss = loss.mean().item()

        return eval_loss

    def train(self, epochs=20):
        # print('param of model')
        # print('hidensize',self.model.hidden_size)
        # print('nlayer',self.model.n_layers)  
        best_lost = float("inf")
        best_model = None
        for epoch in range(epochs):
            total_loss = 0.0
            for batch in self.train_loader:
                loss = self.step(batch)
                total_loss += loss
            train_loss = total_loss/len(self.train_loader)
            eval_loss = self.validation()
            if eval_loss < best_lost:
                best_lost = eval_loss
                best_model = copy.deepcopy(self.model)
            if (epoch + 1) == epochs or (epoch + 1) in [c + 1 for c in range(epochs) if c % int(epochs/4) == 0]:
                print(f"Epoch: {epoch:2}/{epochs:2} - train_loss: {train_loss:.4f} - test_loss: {eval_loss:4f}")
        self.model = best_model
        self.model.eval()
        return None



    # Lưu model vào trong thư mục models
    def save_model_to(self, path = '', city =''):       
        torch.save(self.model, path)

    def load_model_to(self, path = ''):       
        return torch.load(path)

    def evaluate_model(self, np_data=None, plot=True, scaled=True, city=None, k_steps=None, y_scaler =None):
        assert scaled, "data must be scaled"
        self.model.eval()
        tensor_data = torch.from_numpy(np_data)
        rmse_list = []
        mae_list = [] 
        mape_list = []

        y_predicted_list = []
        y_true_list = []

        for k_steps in range(1, args.n_predicted_month + 1):
            y_predicted = []
            y_true = []
            for index in range(tensor_data.size(0) - args.look_back):
                X = tensor_data[index: index + args.look_back, self.important_features]
                # yhat = self.model.predict(X.unsqueeze(0)).squeeze()

                yhat = self.model.predict(X.unsqueeze(0))
                yhat = yhat.squeeze()

                y_predicted.append(yhat.detach().cpu().numpy()[k_steps - 1])
                y_true.append(tensor_data[index + args.look_back, -1].detach().cpu().numpy())

            y_predicted = y_scaler.inverse_transform(np.array(y_predicted).reshape(-1, 1)).reshape(-1, )
            y_true = y_scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).reshape(-1, )

            

            rmse = mean_squared_error(y_true, y_predicted, squared=False)
            mae = mean_absolute_error(y_true, y_predicted)
            mape = mean_absolute_percentage_error(y_true, y_predicted)

            rmse_list.append(rmse)
            mae_list.append(mae)
            mape_list.append(mape)

            print('City: '+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))          
            if plot==True:
              plt.grid(True)
              plt.plot(y_predicted, label='predicted')
              plt.plot(y_true, label='actual')
              plt.title(f"k-steps = {k_steps} - city: "+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))
              plt.legend()
              plt.show()

              plt.show()
            y_predicted_list.append(y_predicted)
            y_true_list.append(y_true)

        return y_true_list, y_predicted_list, rmse_list, mae_list, mape_list

# %% [markdown]
# # Get optimized Hyper param

# %%
def convert_str_num_filter_array(str_filter = ''):  
  arr_filter = str_filter.split(',')  
  int_arr_filter= [int(x) for x in arr_filter]
  return int_arr_filter


opt_param_cnn = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_cnn.xlsx', index_col = 'City')
opt_param_lstm = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm.xlsx', index_col = 'City')
opt_param_lstm_att = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm_att.xlsx', index_col = 'City')
opt_param_transformer = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_transformer.xlsx', index_col = 'City')

def get_opt_param_by_name(algo = 'transformers', city = None):
  if algo == 'cnn':
    city_param = opt_param_cnn.loc[city]
    #load  param
    n_layers = ''
    hidden_size = ''
    num_filters = convert_str_num_filter_array(city_param['Num. filters'])
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm':
    city_param = opt_param_lstm.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm_attention':
    city_param = opt_param_lstm_att.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'transformers':
    city_param = opt_param_transformer.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hidden Size'])
    num_filters = ''
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  return n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window


# Manual Check param before train
n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window= get_opt_param_by_name(algo='lstm', city='Cao Bằng')
lookback_window,epoch, hidden_size, n_layers,learning_rate, num_filters, dropout
# Out:
# (3, 190, 168, 6, 0.004015679480821153, '', '')

# %% [markdown]
# # Create Cross validation Train/Test set

# %%
# Cross validation chỉ trên chiều dài của bộ train = 212 (1997 - 1/1/2018 bỏ đi (36 + 3 windows + 1 station))
# tạo l_train_indices\l_test_indices
data = list(range(212))
min_train_size = 72 # Chiều dài ban đầu train size = 6 năm = 72
test_size = 36 # chiều dài test size 36 tháng
l_train_indices= []
l_test_indices = []
for i in range(min_train_size, len(data)-test_size+1):
    train = np.array(data[0:i])
    test = np.array(data[i:i+test_size])    
    l_train_indices.append(train)
    l_test_indices.append(test)

len(l_test_indices)
# Out:
# 105

# %% [markdown]
# # Function Tạo và Predict. Important (epoch = 1 for test)

# %%
def do_train_predict(city ='', algo = '', list_selected_features = '', origin_city_meta_test_set= '', y_scaler = '', s_selected_features= '', train ='', test ='', sample_idx ='', combination_idx= ''):
    
    metric_reslt = pd.DataFrame()
    n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = algo, city = city)
    # Get data to run model
    important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   

#     epoch = 1 # comment when do experiment
    
    if( algo =='cnn'): 
        algo = 'CNN'    # upper case only
        trainer = Trainer(
                            model_type='cnn',  
                            city = city,                    
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            num_filters= num_filters, 
                            dropout=dropout )

    if( algo =='lstm'):
        algo = 'LSTM'    # upper case only        
        trainer = Trainer(
                            model_type='lstm', 
                            city = city,
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size)

    if( algo =='lstm_attention'): 
        algo = 'LSTM ATT'    # upper case only       
        trainer = Trainer(
                            model_type= 'lstm_attention',
                            city = city,
                            learning_rate= learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers= n_layers,
                            hidden_size=hidden_size )

    if( algo =='transformers'): 
        algo = 'TF'    # upper case only       
        trainer = Trainer(
                            model_type='transformers',
                            city = city, 
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size,
                            dropout=dropout)

    
    # Train model with province-specific epochs
    trainer.train(epochs=epoch)  
    # Evaluate test set   
    y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
        
    metric_reslt = pd.DataFrame({
                                'City': city,
                                'Meta_Model_Name': algo, 
                                'sample_index':sample_idx,
                                'Based_Models': s_selected_features,                                                      
                                # algo+'_'+str(combination_idx)+'_rmse': rmse_list[0],
                                # algo+'_'+str(combination_idx)+'_mae': mae_list[0]
                                algo+'*'+s_selected_features+'_rmse': rmse_list[0],
                                algo+'*'+s_selected_features+'_mae': mae_list[0]
                                }, index=[0]) # do có 1 dòng nên pandas cần index = 0    
  

        
    return metric_reslt

# %% [markdown]
# # Main Cross Validation Metrics Creation
# Tạo ra 105 bộ validation. Xuất ra Metrics (RMSE và MAE) cho 5 bộ giải thuật chọn lựa. (10 cột cho 1 dòng validation )

# %%
dt_started = datetime.now()

l_errCity = {} # có lỗi sẽ lưu vào đây, kiểm tra ngay cell sau


# Với mỗi thành phố, loop qua từng bộ tr/validation, cho train/predict N tổ hợp models
for city in cities:
  pd_all_rows_new_meta_data = pd.DataFrame()

  for sample_index in  range(0,len(l_train_indices)):

    pd_one_row_new_meta_data = pd.DataFrame()
    combination_idx = 0
    for combination_features in combs_features:            
      list_selected_features = [x for x in combination_features] +['Observed'] # Lấy danh sách tên các features + cột Observed 
      s_selected_features = '-'.join([str(elem) for elem in list_selected_features])      

      # Có trong danh sách chọn lựa thì thực hiện dự đoán
      if((is_in_Selected_combination('CNN*'+s_selected_features)==True) or (is_in_Selected_combination('LSTM*'+s_selected_features) == True)):        
        args.n_features = len(list_selected_features) 
        args.look_back = meta_lookback_window  
        cnn_metrics = pd.DataFrame()
        lstm_metrics = pd.DataFrame()

        try:
          # Lấy data từ train set và chia ra theo valiation
          origin_city_meta_train_set = meta_train_set_city[city]
          origin_city_meta_test_set = meta_test_set_city[city]
          
          train = origin_city_meta_train_set.iloc[l_train_indices[sample_index]]
          test = origin_city_meta_train_set.iloc[l_test_indices[sample_index]]        

          # Data train/test processing for all Meta model
          train = train.astype(float)
          test = test.astype(float)

          train = train.replace((np.inf, -np.inf, np.nan), 0)
          test = test.replace((np.inf, -np.inf, np.nan), 0) 
        
          # Đoạn này impute các trường hợp rỗng
          train = impute_missing_value(train)
          test = impute_missing_value(test)

          # Fit data scaler to training data
          full_scaler = MinMaxScaler().fit(train)
          y_scaler = MinMaxScaler().fit(train.values[:, -1].reshape(-1, 1))

          # Scale train and test data
          train = full_scaler.transform(train)
          test = full_scaler.transform(test)

          if(is_in_Selected_combination('CNN*'+s_selected_features)==True):
            ########################################
            ########## CNN 
            ########################################
            cnn_metrics = do_train_predict(city =city, algo='cnn', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)

          if(is_in_Selected_combination('LSTM*'+s_selected_features)==True):
            ########################################
            ########## LSTM 
            ########################################
            lstm_metrics = do_train_predict(city =city, algo='lstm', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)
          

          
          
          ###############################   
          ## Khúc này rất thủ công
          if(cnn_metrics.empty==False and lstm_metrics.empty ==False):              
            join_2_results = pd.concat([cnn_metrics.iloc[:, [4, 5]], lstm_metrics.iloc[:, [4, 5]]], axis=1)
          
          if(cnn_metrics.empty== False and lstm_metrics.empty ==True):
            join_2_results = cnn_metrics.iloc[:, [4, 5]]
          
          if(cnn_metrics.empty== True and lstm_metrics.empty ==False):
            join_2_results = lstm_metrics.iloc[:, [4, 5]]

          if(pd_one_row_new_meta_data.empty):
            pd_one_row_new_meta_data = join_2_results
          else:
            pd_one_row_new_meta_data = pd.concat([join_2_results, pd_one_row_new_meta_data], axis=1)       

          combination_idx = combination_idx + 1
        except Exception as e:
          l_errCity[city] = e
          break    

        
    # Hết vòng lập pd_one_row_new_meta_data chứa 5 bộ kết quả của 1 sameple    
    # Qua sample kế tiếp   
    pd_all_rows_new_meta_data = pd.concat([pd_all_rows_new_meta_data, pd_one_row_new_meta_data], axis=0) 

  
  # Kết thúc hết tất cả validation -> Lưu kết quả cuối cùng ứng với từng thành phố
  pd_all_rows_new_meta_data.to_excel(com_path_validation_metrics+ city+'_5_comb_cv_metrics.xlsx')
  
  # Telegram vào
  send_to_telegram('Server Chạy xong city: '+ city)

dt_ended = datetime.now()
run_time = round((dt_ended - dt_started).total_seconds()/60)
print('kết thúc train trong:', run_time)
print ('danh sách error city: ')
print(l_errCity)
# Out:
# Epoch:  0/ 1 - train_loss: 0.8247 - test_loss: 0.682988
# City: An Giang  _algo:cnn  -RMSE: 79.67676315464317
# City: An Giang  _algo:cnn  -RMSE: 65.67541648993678
# City: An Giang  _algo:cnn  -RMSE: 98.67518372545095
# Epoch:  0/ 1 - train_loss: 0.9169 - test_loss: 0.642422
# City: An Giang  _algo:lstm  -RMSE: 29.623743888572793
# City: An Giang  _algo:lstm  -RMSE: 35.868502721265855
# City: An Giang  _algo:lstm  -RMSE: 36.130692545821425
# Epoch:  0/ 1 - train_loss: 0.8228 - test_loss: 0.695679
# City: An Giang  _algo:cnn  -RMSE: 113.7351862514585
# City: An Giang  _algo:cnn  -RMSE: 57.995885699463294
# City: An Giang  _algo:cnn  -RMSE: 103.79779214132537
# Epoch:  0/ 1 - train_loss: 0.8348 - test_loss: 0.691779
# City: An Giang  _algo:cnn  -RMSE: 114.90205175885089
# City: An Giang  _algo:cnn  -RMSE: 84.40852616816979
# City: An Giang  _algo:cnn  -RMSE: 66.6452682389547
# Epoch:  0/ 1 - train_loss: 0.7789 - test_loss: 0.703570
# City: An Giang  _algo:lstm  -RMSE: 106.03122324112012
# City: An Giang  _algo:lstm  -RMSE: 119.62343212407282
# City: An Giang  _algo:lstm  -RMSE: 114.24182182039509
# Epoch:  0/ 1 - train_loss: 0.8476 - test_loss: 0.768775
# City: An Giang  _algo:cnn  -RMSE: 154.18597683995384
# City: An Giang  _algo:cnn  -RMSE: 158.28297547409977
# City: An Giang  _algo:cnn  -RMSE: 135.37691795834897
# Epoch:  0/ 1 - train_loss: 0.7836 - test_loss: 0.650628
# City: An Giang  _algo:lstm  -RMSE: 45.64150571419895
# City: An Giang  _algo:lstm  -RMSE: 53.502418462891086
# City: An Giang  _algo:lstm  -RMSE: 71.56976746799982
# Epoch:  0/ 1 - train_loss: 0.8103 - test_loss: 0.655964
# City: An Giang  _algo:cnn  -RMSE: 52.686037744062396
# City: An Giang  _algo:cnn  -RMSE: 34.28934218387439
# City: An Giang  _algo:cnn  -RMSE: 40.3825606046463
# Epoch:  0/ 1 - train_loss: 0.8287 - test_loss: 0.702637
# City: An Giang  _algo:cnn  -RMSE: 61.06871036616892
# City: An Giang  _algo:cnn  -RMSE: 98.66766537805202
# City: An Giang  _algo:cnn  -RMSE: 134.85522601686625
# Epoch:  0/ 1 - train_loss: 0.7820 - test_loss: 0.641853
# City: An Giang  _algo:lstm  -RMSE: 49.17966125898432
# City: An Giang  _algo:lstm  -RMSE: 29.65591780766917
# City: An Giang  _algo:lstm  -RMSE: 46.85862101957506
# Epoch:  0/ 1 - train_loss: 0.9185 - test_loss: 0.707092
# City: An Giang  _algo:cnn  -RMSE: 111.20415070089153
# City: An Giang  _algo:cnn  -RMSE: 126.65344671141321
# City: An Giang  _algo:cnn  -RMSE: 72.86879784274974
# Epoch:  0/ 1 - train_loss: 0.9233 - test_loss: 0.692150
# City: An Giang  _algo:cnn  -RMSE: 73.23584252660581
# City: An Giang  _algo:cnn  -RMSE: 109.74321795294634
# City: An Giang  _algo:cnn  -RMSE: 88.52226181095203
# Epoch:  0/ 1 - train_loss: 0.7751 - test_loss: 0.659241
# City: An Giang  _algo:lstm  -RMSE: 74.56262370992165
# City: An Giang  _algo:lstm  -RMSE: 88.79641705557586
# City: An Giang  _algo:lstm  -RMSE: 39.78764158074687
# Epoch:  0/ 1 - train_loss: 0.8478 - test_loss: 0.685816
# City: An Giang  _algo:cnn  -RMSE: 82.30874621410162
# City: An Giang  _algo:cnn  -RMSE: 73.55314838952954
# City: An Giang  _algo:cnn  -RMSE: 100.81723132608693
# Epoch:  0/ 1 - train_loss: 0.8111 - test_loss: 0.640894
# City: An Giang  _algo:lstm  -RMSE: 25.727844554701694
# City: An Giang  _algo:lstm  -RMSE: 58.27060958989547
# City: An Giang  _algo:lstm  -RMSE: 30.264362588815594
# Epoch:  0/ 1 - train_loss: 0.8415 - test_loss: 0.681287
# City: An Giang  _algo:cnn  -RMSE: 64.9317726295153
# City: An Giang  _algo:cnn  -RMSE: 88.03723335321185
# City: An Giang  _algo:cnn  -RMSE: 89.09411375989593
# Epoch:  0/ 1 - train_loss: 0.8217 - test_loss: 0.710229
# City: An Giang  _algo:cnn  -RMSE: 138.05959924108274
# City: An Giang  _algo:cnn  -RMSE: 89.41631308718013
# City: An Giang  _algo:cnn  -RMSE: 96.44199596483872
# Epoch:  0/ 1 - train_loss: 0.7784 - test_loss: 0.702210
# City: An Giang  _algo:lstm  -RMSE: 125.41087573607264
# City: An Giang  _algo:lstm  -RMSE: 48.007355337284025
# City: An Giang  _algo:lstm  -RMSE: 143.27352640592852
# Epoch:  0/ 1 - train_loss: 0.8410 - test_loss: 0.694530
# City: An Giang  _algo:cnn  -RMSE: 105.28959700469555
# City: An Giang  _algo:cnn  -RMSE: 94.50741215184729
# City: An Giang  _algo:cnn  -RMSE: 86.13741017159658
# Epoch:  0/ 1 - train_loss: 0.8298 - test_loss: 0.698417
# City: An Giang  _algo:cnn  -RMSE: 80.14692086269686
# City: An Giang  _algo:cnn  -RMSE: 104.86015252682573
# City: An Giang  _algo:cnn  -RMSE: 108.87141904306286
# Epoch:  0/ 1 - train_loss: 0.7690 - test_loss: 0.662912
# City: An Giang  _algo:lstm  -RMSE: 30.15401150864549
# City: An Giang  _algo:lstm  -RMSE: 36.46792366392208
# City: An Giang  _algo:lstm  -RMSE: 121.13401506261498
# Epoch:  0/ 1 - train_loss: 0.8259 - test_loss: 0.689705
# City: An Giang  _algo:cnn  -RMSE: 108.57024227785936
# City: An Giang  _algo:cnn  -RMSE: 98.71471851460004
# City: An Giang  _algo:cnn  -RMSE: 55.505286740780235
# Epoch:  0/ 1 - train_loss: 0.8268 - test_loss: 0.636687
# City: An Giang  _algo:lstm  -RMSE: 26.43522539700312
# City: An Giang  _algo:lstm  -RMSE: 27.0090032775689
# City: An Giang  _algo:lstm  -RMSE: 32.58167081605007
# Epoch:  0/ 1 - train_loss: 0.8563 - test_loss: 0.715911
# City: An Giang  _algo:cnn  -RMSE: 116.55468348397676
# City: An Giang  _algo:cnn  -RMSE: 158.6197362128734
# City: An Giang  _algo:cnn  -RMSE: 25.162207146598597
# Epoch:  0/ 1 - train_loss: 0.8645 - test_loss: 0.676339
# City: An Giang  _algo:cnn  -RMSE: 25.475636897566236
# City: An Giang  _algo:cnn  -RMSE: 24.96515136596227
# City: An Giang  _algo:cnn  -RMSE: 125.04340242719158
# Epoch:  0/ 1 - train_loss: 0.8198 - test_loss: 0.639476
# City: An Giang  _algo:lstm  -RMSE: 45.690929938132186
# City: An Giang  _algo:lstm  -RMSE: 37.43899716540293
# City: An Giang  _algo:lstm  -RMSE: 25.616575245741984
# Epoch:  0/ 1 - train_loss: 0.8597 - test_loss: 0.673420
# City: An Giang  _algo:cnn  -RMSE: 32.465999421458676
# City: An Giang  _algo:cnn  -RMSE: 68.81796728679174
# City: An Giang  _algo:cnn  -RMSE: 97.61463896878968
# Epoch:  0/ 1 - train_loss: 0.8178 - test_loss: 0.680724
# City: An Giang  _algo:cnn  -RMSE: 105.9621859564038
# City: An Giang  _algo:cnn  -RMSE: 62.441531318677676
# City: An Giang  _algo:cnn  -RMSE: 68.14846165210702
# Epoch:  0/ 1 - train_loss: 0.9439 - test_loss: 0.644470
# City: An Giang  _algo:lstm  -RMSE: 27.76664818022498
# City: An Giang  _algo:lstm  -RMSE: 41.49567124427565
# City: An Giang  _algo:lstm  -RMSE: 39.107437832672964
# Epoch:  0/ 1 - train_loss: 0.9040 - test_loss: 0.711288
# City: An Giang  _algo:cnn  -RMSE: 103.21883891325454
# City: An Giang  _algo:cnn  -RMSE: 99.59276501927495
# City: An Giang  _algo:cnn  -RMSE: 125.25258711252815
# Epoch:  0/ 1 - train_loss: 0.8475 - test_loss: 0.641665
# City: An Giang  _algo:lstm  -RMSE: 48.687999976303125
# City: An Giang  _algo:lstm  -RMSE: 41.519943212279834
# City: An Giang  _algo:lstm  -RMSE: 35.76030840386163
# Epoch:  0/ 1 - train_loss: 0.8929 - test_loss: 0.703895
# City: An Giang  _algo:cnn  -RMSE: 132.23389481530475
# City: An Giang  _algo:cnn  -RMSE: 73.99959366643675
# City: An Giang  _algo:cnn  -RMSE: 98.70031660382823
# Epoch:  0/ 1 - train_loss: 0.8423 - test_loss: 0.681987
# City: An Giang  _algo:cnn  -RMSE: 40.65719558008009
# City: An Giang  _algo:cnn  -RMSE: 128.62114498769643
# City: An Giang  _algo:cnn  -RMSE: 44.34636562142102
# Epoch:  0/ 1 - train_loss: 0.7753 - test_loss: 0.645870
# City: An Giang  _algo:lstm  -RMSE: 36.02280810199967
# City: An Giang  _algo:lstm  -RMSE: 48.76518856790459
# City: An Giang  _algo:lstm  -RMSE: 63.1419001777841
# Epoch:  0/ 1 - train_loss: 0.8693 - test_loss: 0.713785
# City: An Giang  _algo:cnn  -RMSE: 144.5560417732568
# City: An Giang  _algo:cnn  -RMSE: 95.86542417521329
# City: An Giang  _algo:cnn  -RMSE: 89.62070339063973
# Epoch:  0/ 1 - train_loss: 0.8476 - test_loss: 0.682874
# City: An Giang  _algo:cnn  -RMSE: 86.9668169579304
# City: An Giang  _algo:cnn  -RMSE: 92.2722473935522
# City: An Giang  _algo:cnn  -RMSE: 70.00155464277856
# Epoch:  0/ 1 - train_loss: 0.9235 - test_loss: 0.640653
# City: An Giang  _algo:lstm  -RMSE: 34.89791101961715
# City: An Giang  _algo:lstm  -RMSE: 25.887449602563212
# City: An Giang  _algo:lstm  -RMSE: 37.319623494937865
# Epoch:  0/ 1 - train_loss: 0.8123 - test_loss: 0.696796
# City: An Giang  _algo:cnn  -RMSE: 103.23941895587727
# City: An Giang  _algo:cnn  -RMSE: 93.03638198317206
# City: An Giang  _algo:cnn  -RMSE: 96.90800212041222
# Epoch:  0/ 1 - train_loss: 0.8023 - test_loss: 0.645488
# City: An Giang  _algo:lstm  -RMSE: 29.28810323649969
# City: An Giang  _algo:lstm  -RMSE: 48.015172327390786
# City: An Giang  _algo:lstm  -RMSE: 64.71889357639824
# Epoch:  0/ 1 - train_loss: 0.8189 - test_loss: 0.675348
# City: An Giang  _algo:cnn  -RMSE: 84.87577480935782
# City: An Giang  _algo:cnn  -RMSE: 55.87020364609218
# City: An Giang  _algo:cnn  -RMSE: 79.81334616205848
# Epoch:  0/ 1 - train_loss: 0.8721 - test_loss: 0.700053
# City: An Giang  _algo:cnn  -RMSE: 99.71394922951548
# City: An Giang  _algo:cnn  -RMSE: 46.52324668025524
# City: An Giang  _algo:cnn  -RMSE: 134.16610901834213
# Epoch:  0/ 1 - train_loss: 0.7764 - test_loss: 0.664780
# City: An Giang  _algo:lstm  -RMSE: 97.37849518829482
# City: An Giang  _algo:lstm  -RMSE: 66.40641494710896
# City: An Giang  _algo:lstm  -RMSE: 65.22923697396735
# Epoch:  0/ 1 - train_loss: 0.8569 - test_loss: 0.718304
# City: An Giang  _algo:cnn  -RMSE: 108.36778419023278
# City: An Giang  _algo:cnn  -RMSE: 86.67496184382377
# City: An Giang  _algo:cnn  -RMSE: 144.72685586612292
# Epoch:  0/ 1 - train_loss: 0.8337 - test_loss: 0.729642
# City: An Giang  _algo:cnn  -RMSE: 75.32849554040216
# City: An Giang  _algo:cnn  -RMSE: 182.02498814364031
# City: An Giang  _algo:cnn  -RMSE: 89.50216681949209
# Epoch:  0/ 1 - train_loss: 0.7611 - test_loss: 0.645496
# City: An Giang  _algo:lstm  -RMSE: 66.4460723185832
# City: An Giang  _algo:lstm  -RMSE: 41.06674911489098
# City: An Giang  _algo:lstm  -RMSE: 39.93908089406782
# Epoch:  0/ 1 - train_loss: 0.8050 - test_loss: 0.697891
# City: An Giang  _algo:cnn  -RMSE: 119.01871639953463
# City: An Giang  _algo:cnn  -RMSE: 98.68823699005291
# City: An Giang  _algo:cnn  -RMSE: 73.31156377699047
# Epoch:  0/ 1 - train_loss: 0.7742 - test_loss: 0.640813
# City: An Giang  _algo:lstm  -RMSE: 49.48654505421565
# City: An Giang  _algo:lstm  -RMSE: 45.181428398432764
# City: An Giang  _algo:lstm  -RMSE: 26.025481740282423
# Epoch:  0/ 1 - train_loss: 0.8205 - test_loss: 0.732232
# City: An Giang  _algo:cnn  -RMSE: 114.52916438788087
# City: An Giang  _algo:cnn  -RMSE: 168.78337107163716
# City: An Giang  _algo:cnn  -RMSE: 82.38234516524805
# Epoch:  0/ 1 - train_loss: 0.8079 - test_loss: 0.669088
# City: An Giang  _algo:cnn  -RMSE: 90.85270105967528
# City: An Giang  _algo:cnn  -RMSE: 55.3324844643514
# City: An Giang  _algo:cnn  -RMSE: 44.02133395113659
# Epoch:  0/ 1 - train_loss: 0.7637 - test_loss: 0.662293
# City: An Giang  _algo:lstm  -RMSE: 105.62399941901697
# City: An Giang  _algo:lstm  -RMSE: 55.39878665432951
# City: An Giang  _algo:lstm  -RMSE: 51.19336342103664
# Epoch:  0/ 1 - train_loss: 0.8077 - test_loss: 0.688467
# City: An Giang  _algo:cnn  -RMSE: 87.36589337865138
# City: An Giang  _algo:cnn  -RMSE: 95.75728744309082
# City: An Giang  _algo:cnn  -RMSE: 84.25154312933283
# Epoch:  0/ 1 - train_loss: 0.8217 - test_loss: 0.714654
# City: An Giang  _algo:cnn  -RMSE: 97.3512967333962
# City: An Giang  _algo:cnn  -RMSE: 92.69858874391474
# City: An Giang  _algo:cnn  -RMSE: 142.02462100283165
# Epoch:  0/ 1 - train_loss: 0.7794 - test_loss: 0.691133
# City: An Giang  _algo:lstm  -RMSE: 169.80068052575388
# City: An Giang  _algo:lstm  -RMSE: 46.79480086890408
# City: An Giang  _algo:lstm  -RMSE: 43.05933270472419
# Epoch:  0/ 1 - train_loss: 0.8525 - test_loss: 0.709456
# City: An Giang  _algo:cnn  -RMSE: 35.46540682851536
# City: An Giang  _algo:cnn  -RMSE: 77.39045810599313
# City: An Giang  _algo:cnn  -RMSE: 167.36962109384365
# Epoch:  0/ 1 - train_loss: 0.7978 - test_loss: 0.649042
# City: An Giang  _algo:lstm  -RMSE: 53.536710734785906
# City: An Giang  _algo:lstm  -RMSE: 30.319233791547294
# City: An Giang  _algo:lstm  -RMSE: 75.02035855423402
# Epoch:  0/ 1 - train_loss: 0.8519 - test_loss: 0.737256
# City: An Giang  _algo:cnn  -RMSE: 152.60101521883263
# City: An Giang  _algo:cnn  -RMSE: 129.4940168830652
# City: An Giang  _algo:cnn  -RMSE: 104.21150048247004
# Epoch:  0/ 1 - train_loss: 0.8430 - test_loss: 0.693540
# City: An Giang  _algo:cnn  -RMSE: 62.59021137425647
# City: An Giang  _algo:cnn  -RMSE: 87.26177750201448
# City: An Giang  _algo:cnn  -RMSE: 122.75152995444627
# Epoch:  0/ 1 - train_loss: 0.7602 - test_loss: 0.657040
# City: An Giang  _algo:lstm  -RMSE: 34.832774926101216
# City: An Giang  _algo:lstm  -RMSE: 83.0213459011717
# City: An Giang  _algo:lstm  -RMSE: 74.736573344988
# Epoch:  0/ 1 - train_loss: 0.8945 - test_loss: 0.711022
# City: An Giang  _algo:cnn  -RMSE: 58.07505327924469
# City: An Giang  _algo:cnn  -RMSE: 102.00868170875616
# City: An Giang  _algo:cnn  -RMSE: 146.21827057189344
# Epoch:  0/ 1 - train_loss: 0.8786 - test_loss: 0.675750
# City: An Giang  _algo:cnn  -RMSE: 99.57699518010419
# City: An Giang  _algo:cnn  -RMSE: 25.34051871323651
# City: An Giang  _algo:cnn  -RMSE: 80.64372975836817
# Epoch:  0/ 1 - train_loss: 0.7919 - test_loss: 0.644980
# City: An Giang  _algo:lstm  -RMSE: 29.52618336438055
# City: An Giang  _algo:lstm  -RMSE: 40.595277806467514
# City: An Giang  _algo:lstm  -RMSE: 67.23631882738306
# Epoch:  0/ 1 - train_loss: 0.8520 - test_loss: 0.711785
# City: An Giang  _algo:cnn  -RMSE: 156.8670751095364
# City: An Giang  _algo:cnn  -RMSE: 70.16276237245516
# City: An Giang  _algo:cnn  -RMSE: 85.6673930334332
# Epoch:  0/ 1 - train_loss: 0.7708 - test_loss: 0.648594
# City: An Giang  _algo:lstm  -RMSE: 72.65779581890143
# City: An Giang  _algo:lstm  -RMSE: 32.24216177391104
# City: An Giang  _algo:lstm  -RMSE: 54.19996865820442
# Epoch:  0/ 1 - train_loss: 0.8261 - test_loss: 0.727095
# City: An Giang  _algo:cnn  -RMSE: 122.39944809864379
# City: An Giang  _algo:cnn  -RMSE: 94.3006297187827
# City: An Giang  _algo:cnn  -RMSE: 146.24727131770922
# Epoch:  0/ 1 - train_loss: 0.8378 - test_loss: 0.668424
# City: An Giang  _algo:cnn  -RMSE: 25.89817220452895
# City: An Giang  _algo:cnn  -RMSE: 102.13374553074303
# City: An Giang  _algo:cnn  -RMSE: 40.49362650738911
# Epoch:  0/ 1 - train_loss: 0.7825 - test_loss: 0.646124
# City: An Giang  _algo:lstm  -RMSE: 65.31158850602108
# City: An Giang  _algo:lstm  -RMSE: 30.258282075979984
# City: An Giang  _algo:lstm  -RMSE: 51.856413594778445
# Epoch:  0/ 1 - train_loss: 0.8615 - test_loss: 0.683826
# City: An Giang  _algo:cnn  -RMSE: 139.7030160409683
# City: An Giang  _algo:cnn  -RMSE: 26.27294086734934
# City: An Giang  _algo:cnn  -RMSE: 36.126847567872375
# Epoch:  0/ 1 - train_loss: 0.8569 - test_loss: 0.667952
# City: An Giang  _algo:cnn  -RMSE: 59.81216959908154
# City: An Giang  _algo:cnn  -RMSE: 75.89733708572975
# City: An Giang  _algo:cnn  -RMSE: 52.80999077791697
# Epoch:  0/ 1 - train_loss: 0.7989 - test_loss: 0.662245
# City: An Giang  _algo:lstm  -RMSE: 94.24376061284947
# City: An Giang  _algo:lstm  -RMSE: 29.284858849925925
# City: An Giang  _algo:lstm  -RMSE: 82.23919406459943
# Epoch:  0/ 1 - train_loss: 0.8241 - test_loss: 0.690127
# City: An Giang  _algo:cnn  -RMSE: 75.0024663255465
# City: An Giang  _algo:cnn  -RMSE: 101.37006331973312
# City: An Giang  _algo:cnn  -RMSE: 92.07213781652815
# Epoch:  0/ 1 - train_loss: 0.7722 - test_loss: 0.651350
# City: An Giang  _algo:lstm  -RMSE: 46.61853678307183
# City: An Giang  _algo:lstm  -RMSE: 71.7969170916889
# City: An Giang  _algo:lstm  -RMSE: 56.11627302571694
# Epoch:  0/ 1 - train_loss: 0.8160 - test_loss: 0.698440
# City: An Giang  _algo:cnn  -RMSE: 129.72477850349676
# City: An Giang  _algo:cnn  -RMSE: 88.64130588621616
# City: An Giang  _algo:cnn  -RMSE: 68.71122513891005
# Epoch:  0/ 1 - train_loss: 0.8005 - test_loss: 0.693385
# City: An Giang  _algo:cnn  -RMSE: 70.36469345743268
# City: An Giang  _algo:cnn  -RMSE: 123.81367034408827
# City: An Giang  _algo:cnn  -RMSE: 76.96400072451303
# Epoch:  0/ 1 - train_loss: 0.7969 - test_loss: 0.640165
# City: An Giang  _algo:lstm  -RMSE: 42.894920698677694
# City: An Giang  _algo:lstm  -RMSE: 41.98596909555351
# City: An Giang  _algo:lstm  -RMSE: 28.264092972657853
# Epoch:  0/ 1 - train_loss: 0.8055 - test_loss: 0.681162
# City: An Giang  _algo:cnn  -RMSE: 67.19324033446067
# City: An Giang  _algo:cnn  -RMSE: 30.27834987352365
# City: An Giang  _algo:cnn  -RMSE: 118.62075544258015
# Epoch:  0/ 1 - train_loss: 0.8822 - test_loss: 0.722096
# City: An Giang  _algo:cnn  -RMSE: 95.67950626963444
# City: An Giang  _algo:cnn  -RMSE: 117.27983465317601
# City: An Giang  _algo:cnn  -RMSE: 137.80749380732308
# Epoch:  0/ 1 - train_loss: 0.8698 - test_loss: 0.640455
# City: An Giang  _algo:lstm  -RMSE: 32.00220277177095
# City: An Giang  _algo:lstm  -RMSE: 37.49819105516801
# City: An Giang  _algo:lstm  -RMSE: 38.02286057991895
# Epoch:  0/ 1 - train_loss: 0.8449 - test_loss: 0.757594
# City: An Giang  _algo:cnn  -RMSE: 63.13038814235153
# City: An Giang  _algo:cnn  -RMSE: 202.1280386791741
# City: An Giang  _algo:cnn  -RMSE: 130.17516509502553
# Epoch:  0/ 1 - train_loss: 0.7834 - test_loss: 0.642622
# City: An Giang  _algo:lstm  -RMSE: 29.977038017095865
# City: An Giang  _algo:lstm  -RMSE: 62.30630325892932
# City: An Giang  _algo:lstm  -RMSE: 33.244713324007556
# Epoch:  0/ 1 - train_loss: 0.7944 - test_loss: 0.677058
# City: An Giang  _algo:cnn  -RMSE: 48.612470096781436
# City: An Giang  _algo:cnn  -RMSE: 74.35554146389453
# City: An Giang  _algo:cnn  -RMSE: 97.36815165367895
# Epoch:  0/ 1 - train_loss: 0.7886 - test_loss: 0.660488
# City: An Giang  _algo:cnn  -RMSE: 59.13474032301821
# City: An Giang  _algo:cnn  -RMSE: 60.57437104869055
# City: An Giang  _algo:cnn  -RMSE: 37.10433995739803
# Epoch:  0/ 1 - train_loss: 0.7828 - test_loss: 0.642688
# City: An Giang  _algo:lstm  -RMSE: 29.07489932842847
# City: An Giang  _algo:lstm  -RMSE: 43.29865135789263
# City: An Giang  _algo:lstm  -RMSE: 58.07951022787331
# Epoch:  0/ 1 - train_loss: 0.8086 - test_loss: 0.712275
# City: An Giang  _algo:cnn  -RMSE: 127.17037617455843
# City: An Giang  _algo:cnn  -RMSE: 76.83829622972267
# City: An Giang  _algo:cnn  -RMSE: 123.47632731592999
# Epoch:  0/ 1 - train_loss: 0.8012 - test_loss: 0.683921
# City: An Giang  _algo:cnn  -RMSE: 33.69992497360358
# City: An Giang  _algo:cnn  -RMSE: 36.78337354604232
# City: An Giang  _algo:cnn  -RMSE: 138.62740645063155
# Epoch:  0/ 1 - train_loss: 0.7876 - test_loss: 0.652859
# City: An Giang  _algo:lstm  -RMSE: 70.44875166608583
# City: An Giang  _algo:lstm  -RMSE: 51.610417118593155
# City: An Giang  _algo:lstm  -RMSE: 64.37513493804586
# Epoch:  0/ 1 - train_loss: 0.8116 - test_loss: 0.672411
# City: An Giang  _algo:cnn  -RMSE: 53.11441908469517
# City: An Giang  _algo:cnn  -RMSE: 61.853761112474366
# City: An Giang  _algo:cnn  -RMSE: 91.84503849542823
# Epoch:  0/ 1 - train_loss: 0.8536 - test_loss: 0.640609
# City: An Giang  _algo:lstm  -RMSE: 32.82468223518574
# City: An Giang  _algo:lstm  -RMSE: 36.559078610844644
# City: An Giang  _algo:lstm  -RMSE: 41.70090368904145
# Epoch:  0/ 1 - train_loss: 0.8656 - test_loss: 0.690693
# City: An Giang  _algo:cnn  -RMSE: 77.51522022343968
# City: An Giang  _algo:cnn  -RMSE: 111.61909897172377
# City: An Giang  _algo:cnn  -RMSE: 81.97318906101906
# Epoch:  0/ 1 - train_loss: 0.8597 - test_loss: 0.728328
# City: An Giang  _algo:cnn  -RMSE: 126.22983421225778
# City: An Giang  _algo:cnn  -RMSE: 150.94325612864228
# City: An Giang  _algo:cnn  -RMSE: 89.20739067599332
# Epoch:  0/ 1 - train_loss: 0.7698 - test_loss: 0.640747
# City: An Giang  _algo:lstm  -RMSE: 46.73990180628996
# City: An Giang  _algo:lstm  -RMSE: 38.178640583327386
# City: An Giang  _algo:lstm  -RMSE: 40.06138091893073
# Epoch:  0/ 1 - train_loss: 0.8208 - test_loss: 0.669406
# City: An Giang  _algo:cnn  -RMSE: 102.63124687589593
# City: An Giang  _algo:cnn  -RMSE: 46.99249550787828
# City: An Giang  _algo:cnn  -RMSE: 31.77111402555124
# Epoch:  0/ 1 - train_loss: 0.8606 - test_loss: 0.701207
# City: An Giang  _algo:cnn  -RMSE: 65.65762099000479
# City: An Giang  _algo:cnn  -RMSE: 98.39958022384522
# City: An Giang  _algo:cnn  -RMSE: 132.06503199195242
# Epoch:  0/ 1 - train_loss: 0.8153 - test_loss: 0.642061
# City: An Giang  _algo:lstm  -RMSE: 53.56823233779163
# City: An Giang  _algo:lstm  -RMSE: 36.17390647616817
# City: An Giang  _algo:lstm  -RMSE: 41.75804642943543
# Epoch:  0/ 1 - train_loss: 0.8812 - test_loss: 0.803817
# City: An Giang  _algo:cnn  -RMSE: 193.58121527691753
# City: An Giang  _algo:cnn  -RMSE: 159.55755470018778
# City: An Giang  _algo:cnn  -RMSE: 162.2757740895107
# Epoch:  0/ 1 - train_loss: 0.7575 - test_loss: 0.642605
# City: An Giang  _algo:lstm  -RMSE: 40.25431177581003
# City: An Giang  _algo:lstm  -RMSE: 52.532726439295146
# City: An Giang  _algo:lstm  -RMSE: 43.47575144994417
# Epoch:  0/ 1 - train_loss: 0.8172 - test_loss: 0.671854
# City: An Giang  _algo:cnn  -RMSE: 34.195217787145445
# City: An Giang  _algo:cnn  -RMSE: 106.22311812081212
# City: An Giang  _algo:cnn  -RMSE: 53.8568171937547
# Epoch:  0/ 1 - train_loss: 0.8831 - test_loss: 0.717972
# City: An Giang  _algo:cnn  -RMSE: 120.87507264294304
# City: An Giang  _algo:cnn  -RMSE: 116.32821345957157
# City: An Giang  _algo:cnn  -RMSE: 109.64732535453663
# Epoch:  0/ 1 - train_loss: 0.8451 - test_loss: 0.638190
# City: An Giang  _algo:lstm  -RMSE: 35.285035264001436
# City: An Giang  _algo:lstm  -RMSE: 22.958752006771075
# City: An Giang  _algo:lstm  -RMSE: 38.486615862141456
# Epoch:  0/ 1 - train_loss: 0.8958 - test_loss: 0.703653
# City: An Giang  _algo:cnn  -RMSE: 88.10221748425855
# City: An Giang  _algo:cnn  -RMSE: 140.30020158718796
# City: An Giang  _algo:cnn  -RMSE: 68.17415832443726
# Epoch:  0/ 1 - train_loss: 0.8365 - test_loss: 0.706239
# City: An Giang  _algo:cnn  -RMSE: 48.3628567996631
# City: An Giang  _algo:cnn  -RMSE: 151.80079618434422
# City: An Giang  _algo:cnn  -RMSE: 91.23485262458605
# Epoch:  0/ 1 - train_loss: 0.8299 - test_loss: 0.640789
# City: An Giang  _algo:lstm  -RMSE: 40.513824795212926
# City: An Giang  _algo:lstm  -RMSE: 34.14407109261157
# City: An Giang  _algo:lstm  -RMSE: 41.243379925780154
# Epoch:  0/ 1 - train_loss: 0.8797 - test_loss: 0.767329
# City: An Giang  _algo:cnn  -RMSE: 169.78039867618412
# City: An Giang  _algo:cnn  -RMSE: 150.3161411175532
# City: An Giang  _algo:cnn  -RMSE: 129.01100834247364
# Epoch:  0/ 1 - train_loss: 0.7716 - test_loss: 0.648043
# City: An Giang  _algo:lstm  -RMSE: 64.13656964170644
# City: An Giang  _algo:lstm  -RMSE: 53.8873021852055
# City: An Giang  _algo:lstm  -RMSE: 43.53273839410557
# Epoch:  0/ 1 - train_loss: 0.8207 - test_loss: 0.694302
# City: An Giang  _algo:cnn  -RMSE: 85.73877752748379
# City: An Giang  _algo:cnn  -RMSE: 122.71551200286396
# City: An Giang  _algo:cnn  -RMSE: 70.03775785054464
# Epoch:  0/ 1 - train_loss: 0.8038 - test_loss: 0.660835
# City: An Giang  _algo:cnn  -RMSE: 69.07550253631575
# City: An Giang  _algo:cnn  -RMSE: 55.859885629741036
# City: An Giang  _algo:cnn  -RMSE: 29.47200069487721
# Epoch:  0/ 1 - train_loss: 0.7862 - test_loss: 0.652402
# City: An Giang  _algo:lstm  -RMSE: 63.0692094762779
# City: An Giang  _algo:lstm  -RMSE: 44.757753807663086
# City: An Giang  _algo:lstm  -RMSE: 73.45699762860716
# Epoch:  0/ 1 - train_loss: 0.8084 - test_loss: 0.666818
# City: An Giang  _algo:cnn  -RMSE: 34.842823572806246
# City: An Giang  _algo:cnn  -RMSE: 91.94830384339578
# City: An Giang  _algo:cnn  -RMSE: 47.00701483485097
# Epoch:  0/ 1 - train_loss: 0.8884 - test_loss: 0.732737
# City: An Giang  _algo:cnn  -RMSE: 146.87415570347562
# City: An Giang  _algo:cnn  -RMSE: 133.263905683748
# City: An Giang  _algo:cnn  -RMSE: 93.05111472475866
# Epoch:  0/ 1 - train_loss: 0.7819 - test_loss: 0.637888
# City: An Giang  _algo:lstm  -RMSE: 32.40817610997735
# City: An Giang  _algo:lstm  -RMSE: 30.389930082687755
# City: An Giang  _algo:lstm  -RMSE: 36.609254863592646
# Epoch:  0/ 1 - train_loss: 0.8792 - test_loss: 0.691548
# City: An Giang  _algo:cnn  -RMSE: 38.7548175956882
# City: An Giang  _algo:cnn  -RMSE: 25.128510670534205
# City: An Giang  _algo:cnn  -RMSE: 153.2487422318004
# Epoch:  0/ 1 - train_loss: 0.7559 - test_loss: 0.653405
# City: An Giang  _algo:lstm  -RMSE: 78.92723516761964
# City: An Giang  _algo:lstm  -RMSE: 60.149847345459094
# City: An Giang  _algo:lstm  -RMSE: 45.229130364641605
# Epoch:  0/ 1 - train_loss: 0.7970 - test_loss: 0.673636
# City: An Giang  _algo:cnn  -RMSE: 89.89342117850032
# City: An Giang  _algo:cnn  -RMSE: 24.33024623163785
# City: An Giang  _algo:cnn  -RMSE: 87.74160600104415
# Epoch:  0/ 1 - train_loss: 0.8105 - test_loss: 0.655104
# City: An Giang  _algo:cnn  -RMSE: 28.537219784383847
# City: An Giang  _algo:cnn  -RMSE: 34.57604441675482
# City: An Giang  _algo:cnn  -RMSE: 96.25339887012144
# Epoch:  0/ 1 - train_loss: 0.7485 - test_loss: 0.653810
# City: An Giang  _algo:lstm  -RMSE: 91.28371473430025
# City: An Giang  _algo:lstm  -RMSE: 66.03752267911392
# City: An Giang  _algo:lstm  -RMSE: 80.3458965207374
# Epoch:  0/ 1 - train_loss: 0.8049 - test_loss: 0.647487
# City: An Giang  _algo:cnn  -RMSE: 68.154321819217
# City: An Giang  _algo:cnn  -RMSE: 24.16473163334319
# City: An Giang  _algo:cnn  -RMSE: 40.33818040810873
# Epoch:  0/ 1 - train_loss: 0.8276 - test_loss: 0.674527
# City: An Giang  _algo:cnn  -RMSE: 38.42025624243705
# City: An Giang  _algo:cnn  -RMSE: 135.6398375811547
# City: An Giang  _algo:cnn  -RMSE: 42.42117133981646
# Epoch:  0/ 1 - train_loss: 0.7444 - test_loss: 0.624209
# City: An Giang  _algo:lstm  -RMSE: 31.165163066397312
# City: An Giang  _algo:lstm  -RMSE: 25.816848673369343
# City: An Giang  _algo:lstm  -RMSE: 35.441185855943445
# Epoch:  0/ 1 - train_loss: 0.8234 - test_loss: 0.673523
# City: An Giang  _algo:cnn  -RMSE: 101.12851175030619
# City: An Giang  _algo:cnn  -RMSE: 81.06701271430403
# City: An Giang  _algo:cnn  -RMSE: 69.67765039000231
# Epoch:  0/ 1 - train_loss: 0.7506 - test_loss: 0.628822
# City: An Giang  _algo:lstm  -RMSE: 25.322214108231343
# City: An Giang  _algo:lstm  -RMSE: 27.25722598234559
# City: An Giang  _algo:lstm  -RMSE: 62.32418471171079
# Epoch:  0/ 1 - train_loss: 0.7992 - test_loss: 0.692870
# City: An Giang  _algo:cnn  -RMSE: 71.75355063380718
# City: An Giang  _algo:cnn  -RMSE: 111.2367299338813
# City: An Giang  _algo:cnn  -RMSE: 123.2113553069011
# Epoch:  0/ 1 - train_loss: 0.7938 - test_loss: 0.699683
# City: An Giang  _algo:cnn  -RMSE: 99.78492021595122
# City: An Giang  _algo:cnn  -RMSE: 94.25514488381698
# City: An Giang  _algo:cnn  -RMSE: 132.5692951643019
# Epoch:  0/ 1 - train_loss: 0.7453 - test_loss: 0.637307
# City: An Giang  _algo:lstm  -RMSE: 67.46232919660707
# City: An Giang  _algo:lstm  -RMSE: 61.102869780288785
# City: An Giang  _algo:lstm  -RMSE: 44.63945229058817
# Epoch:  0/ 1 - train_loss: 0.8186 - test_loss: 0.680567
# City: An Giang  _algo:cnn  -RMSE: 37.44009943902698
# City: An Giang  _algo:cnn  -RMSE: 88.41564943307348
# City: An Giang  _algo:cnn  -RMSE: 127.46158559199868
# Epoch:  0/ 1 - train_loss: 0.8515 - test_loss: 0.673963
# City: An Giang  _algo:cnn  -RMSE: 84.43550910347463
# City: An Giang  _algo:cnn  -RMSE: 119.18911704894778
# City: An Giang  _algo:cnn  -RMSE: 21.63716452527009
# Epoch:  0/ 1 - train_loss: 0.7495 - test_loss: 0.635871
# City: An Giang  _algo:lstm  -RMSE: 63.73370516792173
# City: An Giang  _algo:lstm  -RMSE: 64.92790516810885
# City: An Giang  _algo:lstm  -RMSE: 37.095008951721375
# Epoch:  0/ 1 - train_loss: 0.8280 - test_loss: 0.661139
# City: An Giang  _algo:cnn  -RMSE: 27.430780975014596
# City: An Giang  _algo:cnn  -RMSE: 68.81435045191083
# City: An Giang  _algo:cnn  -RMSE: 96.67744407970523
# Epoch:  0/ 1 - train_loss: 0.7825 - test_loss: 0.705353
# City: An Giang  _algo:lstm  -RMSE: 121.42255606725028
# City: An Giang  _algo:lstm  -RMSE: 133.7498530356994
# City: An Giang  _algo:lstm  -RMSE: 122.19007030703996
# Epoch:  0/ 1 - train_loss: 0.7871 - test_loss: 0.665559
# City: An Giang  _algo:cnn  -RMSE: 51.18517760988444
# City: An Giang  _algo:cnn  -RMSE: 44.76922807895761
# City: An Giang  _algo:cnn  -RMSE: 113.14956929440095
# Epoch:  0/ 1 - train_loss: 0.8515 - test_loss: 0.661165
# City: An Giang  _algo:cnn  -RMSE: 42.09706468144373
# City: An Giang  _algo:cnn  -RMSE: 29.94750717853745
# City: An Giang  _algo:cnn  -RMSE: 103.9033751173356
# Epoch:  0/ 1 - train_loss: 0.8610 - test_loss: 0.635354
# City: An Giang  _algo:lstm  -RMSE: 29.200381972668296
# City: An Giang  _algo:lstm  -RMSE: 56.98309785793341
# City: An Giang  _algo:lstm  -RMSE: 53.95992247602929
# Epoch:  0/ 1 - train_loss: 0.8179 - test_loss: 0.659122
# City: An Giang  _algo:cnn  -RMSE: 79.73232099452724
# City: An Giang  _algo:cnn  -RMSE: 68.38334719652244
# City: An Giang  _algo:cnn  -RMSE: 41.74047249560768
# Epoch:  0/ 1 - train_loss: 0.8313 - test_loss: 0.662197
# City: An Giang  _algo:cnn  -RMSE: 92.62499636642119
# City: An Giang  _algo:cnn  -RMSE: 67.55984458881545
# City: An Giang  _algo:cnn  -RMSE: 37.81723997266731
# Epoch:  0/ 1 - train_loss: 0.7828 - test_loss: 0.639250
# City: An Giang  _algo:lstm  -RMSE: 50.41592942361587
# City: An Giang  _algo:lstm  -RMSE: 68.82050597375799
# City: An Giang  _algo:lstm  -RMSE: 55.70065957670227
# Epoch:  0/ 1 - train_loss: 0.7984 - test_loss: 0.662276
# City: An Giang  _algo:cnn  -RMSE: 83.8340534574535
# City: An Giang  _algo:cnn  -RMSE: 53.61333152271652
# City: An Giang  _algo:cnn  -RMSE: 68.56070386641242
# Epoch:  0/ 1 - train_loss: 0.7476 - test_loss: 0.634586
# City: An Giang  _algo:lstm  -RMSE: 38.274244877357866
# City: An Giang  _algo:lstm  -RMSE: 44.104477189778564
# City: An Giang  _algo:lstm  -RMSE: 67.45419283924244
# Epoch:  0/ 1 - train_loss: 0.8359 - test_loss: 0.672234
# City: An Giang  _algo:cnn  -RMSE: 59.75615160401646
# City: An Giang  _algo:cnn  -RMSE: 22.97831103846002
# City: An Giang  _algo:cnn  -RMSE: 125.44693400195425
# Epoch:  0/ 1 - train_loss: 0.8311 - test_loss: 0.683170
# City: An Giang  _algo:cnn  -RMSE: 30.042220374159193
# City: An Giang  _algo:cnn  -RMSE: 85.93113216520283
# City: An Giang  _algo:cnn  -RMSE: 131.32822804845122
# Epoch:  0/ 1 - train_loss: 0.7558 - test_loss: 0.644050
# City: An Giang  _algo:lstm  -RMSE: 66.57165506755278
# City: An Giang  _algo:lstm  -RMSE: 60.97395124509046
# City: An Giang  _algo:lstm  -RMSE: 69.49014673209503
# Epoch:  0/ 1 - train_loss: 0.7835 - test_loss: 0.664026
# City: An Giang  _algo:cnn  -RMSE: 67.84544626607948
# City: An Giang  _algo:cnn  -RMSE: 70.71967659530867
# City: An Giang  _algo:cnn  -RMSE: 75.59879474355338
# Epoch:  0/ 1 - train_loss: 0.8220 - test_loss: 0.685729
# City: An Giang  _algo:cnn  -RMSE: 126.88668735493589
# City: An Giang  _algo:cnn  -RMSE: 93.18253063759552
# City: An Giang  _algo:cnn  -RMSE: 52.19427877662049
# Epoch:  0/ 1 - train_loss: 0.7606 - test_loss: 0.651104
# City: An Giang  _algo:lstm  -RMSE: 92.94716421897252
# City: An Giang  _algo:lstm  -RMSE: 68.20871301243085
# City: An Giang  _algo:lstm  -RMSE: 59.4232664051511
# Epoch:  0/ 1 - train_loss: 0.7881 - test_loss: 0.659377
# City: An Giang  _algo:cnn  -RMSE: 49.006049608103886
# City: An Giang  _algo:cnn  -RMSE: 55.1882861796944
# City: An Giang  _algo:cnn  -RMSE: 84.82365426973675
# Epoch:  0/ 1 - train_loss: 0.7551 - test_loss: 0.643286
# City: An Giang  _algo:lstm  -RMSE: 88.7547351082893
# City: An Giang  _algo:lstm  -RMSE: 37.34026181230461
# City: An Giang  _algo:lstm  -RMSE: 59.36898174669101
# Epoch:  0/ 1 - train_loss: 0.7800 - test_loss: 0.638726
# City: An Giang  _algo:cnn  -RMSE: 28.93969384165862
# City: An Giang  _algo:cnn  -RMSE: 18.256914654150663
# City: An Giang  _algo:cnn  -RMSE: 25.567817677359503
# Epoch:  0/ 1 - train_loss: 0.8078 - test_loss: 0.665458
# City: An Giang  _algo:cnn  -RMSE: 88.16631858193651
# City: An Giang  _algo:cnn  -RMSE: 55.66691887278655
# City: An Giang  _algo:cnn  -RMSE: 71.80950540429903
# Epoch:  0/ 1 - train_loss: 0.8314 - test_loss: 0.631235
# City: An Giang  _algo:lstm  -RMSE: 61.13314155945293
# City: An Giang  _algo:lstm  -RMSE: 37.30646969740321
# City: An Giang  _algo:lstm  -RMSE: 21.859196149631572
# Epoch:  0/ 1 - train_loss: 0.8318 - test_loss: 0.650585
# City: An Giang  _algo:cnn  -RMSE: 15.296194446636479
# City: An Giang  _algo:cnn  -RMSE: 20.707491601995468
# City: An Giang  _algo:cnn  -RMSE: 85.21499059094603
# Epoch:  0/ 1 - train_loss: 0.8198 - test_loss: 0.703213
# City: An Giang  _algo:cnn  -RMSE: 18.70915839512464
# City: An Giang  _algo:cnn  -RMSE: 130.5335880508148
# City: An Giang  _algo:cnn  -RMSE: 137.07674203200278
# Epoch:  0/ 1 - train_loss: 0.7655 - test_loss: 0.630031
# City: An Giang  _algo:lstm  -RMSE: 31.344822351603085
# City: An Giang  _algo:lstm  -RMSE: 61.27464510702442
# City: An Giang  _algo:lstm  -RMSE: 29.70669059009608
# Epoch:  0/ 1 - train_loss: 0.8121 - test_loss: 0.648493
# City: An Giang  _algo:cnn  -RMSE: 64.39829806060473
# City: An Giang  _algo:cnn  -RMSE: 32.73261207572584
# City: An Giang  _algo:cnn  -RMSE: 43.21280715221123
# Epoch:  0/ 1 - train_loss: 0.7591 - test_loss: 0.635334
# City: An Giang  _algo:lstm  -RMSE: 41.742725670054966
# City: An Giang  _algo:lstm  -RMSE: 65.95343909469561
# City: An Giang  _algo:lstm  -RMSE: 47.75393878696003
# Epoch:  0/ 1 - train_loss: 0.8226 - test_loss: 0.666592
# City: An Giang  _algo:cnn  -RMSE: 108.97377074381248
# City: An Giang  _algo:cnn  -RMSE: 20.319058471139773
# City: An Giang  _algo:cnn  -RMSE: 68.94516250050224
# Epoch:  0/ 1 - train_loss: 0.8064 - test_loss: 0.640334
# City: An Giang  _algo:cnn  -RMSE: 14.863763704634666
# City: An Giang  _algo:cnn  -RMSE: 45.98171885952918
# City: An Giang  _algo:cnn  -RMSE: 23.79431796344907
# Epoch:  0/ 1 - train_loss: 0.7446 - test_loss: 0.633681
# City: An Giang  _algo:lstm  -RMSE: 57.883604843519954
# City: An Giang  _algo:lstm  -RMSE: 52.91632548783975
# City: An Giang  _algo:lstm  -RMSE: 41.6849400319042
# Epoch:  0/ 1 - train_loss: 0.8075 - test_loss: 0.654482
# City: An Giang  _algo:cnn  -RMSE: 84.93765773507214
# City: An Giang  _algo:cnn  -RMSE: 28.554159684028416
# City: An Giang  _algo:cnn  -RMSE: 50.42878903622195
# Epoch:  0/ 1 - train_loss: 0.7821 - test_loss: 0.650075
# City: An Giang  _algo:cnn  -RMSE: 17.322515068881916
# City: An Giang  _algo:cnn  -RMSE: 79.43719416361601
# City: An Giang  _algo:cnn  -RMSE: 38.32981289792622
# Epoch:  0/ 1 - train_loss: 0.7494 - test_loss: 0.626787
# City: An Giang  _algo:lstm  -RMSE: 19.926815434103865
# City: An Giang  _algo:lstm  -RMSE: 41.888423348876
# City: An Giang  _algo:lstm  -RMSE: 43.76941476715235
# Epoch:  0/ 1 - train_loss: 0.8621 - test_loss: 0.656862
# City: An Giang  _algo:cnn  -RMSE: 58.639130571728266
# City: An Giang  _algo:cnn  -RMSE: 71.45704048960688
# City: An Giang  _algo:cnn  -RMSE: 56.005474447477724
# Epoch:  0/ 1 - train_loss: 0.7501 - test_loss: 0.676932
# City: An Giang  _algo:lstm  -RMSE: 47.77773588201236
# City: An Giang  _algo:lstm  -RMSE: 115.77035659823156
# City: An Giang  _algo:lstm  -RMSE: 124.04488534333582
# Epoch:  0/ 1 - train_loss: 0.8277 - test_loss: 0.672946
# City: An Giang  _algo:cnn  -RMSE: 101.50554330380938
# City: An Giang  _algo:cnn  -RMSE: 92.30135868597722
# City: An Giang  _algo:cnn  -RMSE: 47.49833403434133
# Epoch:  0/ 1 - train_loss: 0.8549 - test_loss: 0.703784
# City: An Giang  _algo:cnn  -RMSE: 58.69551249760826
# City: An Giang  _algo:cnn  -RMSE: 108.42804623182852
# City: An Giang  _algo:cnn  -RMSE: 147.9682955932413
# Epoch:  0/ 1 - train_loss: 0.7514 - test_loss: 0.679769
# City: An Giang  _algo:lstm  -RMSE: 108.11033647824287
# City: An Giang  _algo:lstm  -RMSE: 79.55515198164176
# City: An Giang  _algo:lstm  -RMSE: 120.7323719030269
# Epoch:  0/ 1 - train_loss: 0.7863 - test_loss: 0.655432
# City: An Giang  _algo:cnn  -RMSE: 52.497943693040945
# City: An Giang  _algo:cnn  -RMSE: 30.4193086953144
# City: An Giang  _algo:cnn  -RMSE: 85.37276163475883
# Epoch:  0/ 1 - train_loss: 0.8149 - test_loss: 0.677288
# City: An Giang  _algo:cnn  -RMSE: 42.19332420301508
# City: An Giang  _algo:cnn  -RMSE: 84.33594957823078
# City: An Giang  _algo:cnn  -RMSE: 117.98962755732428
# Epoch:  0/ 1 - train_loss: 0.7533 - test_loss: 0.681071
# City: An Giang  _algo:lstm  -RMSE: 130.24875039537824
# City: An Giang  _algo:lstm  -RMSE: 91.2301286494866
# City: An Giang  _algo:lstm  -RMSE: 91.28344901783203
# Epoch:  0/ 1 - train_loss: 0.8298 - test_loss: 0.662366
# City: An Giang  _algo:cnn  -RMSE: 76.17706113155958
# City: An Giang  _algo:cnn  -RMSE: 89.81311363090366
# City: An Giang  _algo:cnn  -RMSE: 29.769854023461434
# Epoch:  0/ 1 - train_loss: 0.7556 - test_loss: 0.640573
# City: An Giang  _algo:lstm  -RMSE: 61.98501899980536
# City: An Giang  _algo:lstm  -RMSE: 43.9706164318479
# City: An Giang  _algo:lstm  -RMSE: 75.00843358164859
# Epoch:  0/ 1 - train_loss: 0.7855 - test_loss: 0.647666
# City: An Giang  _algo:cnn  -RMSE: 17.06493522054255
# City: An Giang  _algo:cnn  -RMSE: 18.595448184493485
# City: An Giang  _algo:cnn  -RMSE: 76.37666413811843
# Epoch:  0/ 1 - train_loss: 0.7971 - test_loss: 0.649041
# City: An Giang  _algo:cnn  -RMSE: 50.405417019058305
# City: An Giang  _algo:cnn  -RMSE: 52.825491549672904
# City: An Giang  _algo:cnn  -RMSE: 44.15250772661962
# Epoch:  0/ 1 - train_loss: 0.7968 - test_loss: 0.623887
# City: An Giang  _algo:lstm  -RMSE: 32.23364417407598
# City: An Giang  _algo:lstm  -RMSE: 26.800906255046304
# City: An Giang  _algo:lstm  -RMSE: 28.955334469417682
# Epoch:  0/ 1 - train_loss: 0.8260 - test_loss: 0.668878
# City: An Giang  _algo:cnn  -RMSE: 91.6373968348138
# City: An Giang  _algo:cnn  -RMSE: 61.62934040089097
# City: An Giang  _algo:cnn  -RMSE: 76.84510121800322
# Epoch:  0/ 1 - train_loss: 0.8511 - test_loss: 0.714361
# City: An Giang  _algo:cnn  -RMSE: 52.18810039013845
# City: An Giang  _algo:cnn  -RMSE: 32.716833333155044
# City: An Giang  _algo:cnn  -RMSE: 197.53849583958967
# Epoch:  0/ 1 - train_loss: 0.7522 - test_loss: 0.631664
# City: An Giang  _algo:lstm  -RMSE: 45.32568937756083
# City: An Giang  _algo:lstm  -RMSE: 60.223331582615494
# City: An Giang  _algo:lstm  -RMSE: 29.377519529866962
# Epoch:  0/ 1 - train_loss: 0.8121 - test_loss: 0.681082
# City: An Giang  _algo:cnn  -RMSE: 140.07990667786072
# City: An Giang  _algo:cnn  -RMSE: 14.85824908788362
# City: An Giang  _algo:cnn  -RMSE: 73.39406446878584
# Epoch:  0/ 1 - train_loss: 0.7750 - test_loss: 0.624531
# City: An Giang  _algo:lstm  -RMSE: 30.37596340252396
# City: An Giang  _algo:lstm  -RMSE: 39.45029686314008
# City: An Giang  _algo:lstm  -RMSE: 18.818736257086364
# Epoch:  0/ 1 - train_loss: 0.8276 - test_loss: 0.668520
# City: An Giang  _algo:cnn  -RMSE: 48.61945950204845
# City: An Giang  _algo:cnn  -RMSE: 20.885084192044765
# City: An Giang  _algo:cnn  -RMSE: 122.40793506244663
# Epoch:  0/ 1 - train_loss: 0.8147 - test_loss: 0.641802
# City: An Giang  _algo:cnn  -RMSE: 17.305048552294586
# City: An Giang  _algo:cnn  -RMSE: 46.58683558343303
# City: An Giang  _algo:cnn  -RMSE: 33.32729530988191
# Epoch:  0/ 1 - train_loss: 0.7544 - test_loss: 0.676941
# City: An Giang  _algo:lstm  -RMSE: 58.19534993681307
# City: An Giang  _algo:lstm  -RMSE: 85.66411775168665
# City: An Giang  _algo:lstm  -RMSE: 141.30242006428688
# Epoch:  0/ 1 - train_loss: 0.8163 - test_loss: 0.689217
# City: An Giang  _algo:cnn  -RMSE: 148.40603150572187
# City: An Giang  _algo:cnn  -RMSE: 49.73415543189981
# City: An Giang  _algo:cnn  -RMSE: 70.98981975475621
# Epoch:  0/ 1 - train_loss: 0.8009 - test_loss: 0.647033
# City: An Giang  _algo:cnn  -RMSE: 49.61891741056641
# City: An Giang  _algo:cnn  -RMSE: 50.12653843074534
# City: An Giang  _algo:cnn  -RMSE: 35.57095025347505
# Epoch:  0/ 1 - train_loss: 0.7469 - test_loss: 0.655311
# City: An Giang  _algo:lstm  -RMSE: 87.20455051783377
# City: An Giang  _algo:lstm  -RMSE: 88.60949183848909
# City: An Giang  _algo:lstm  -RMSE: 62.158582958685194
# Epoch:  0/ 1 - train_loss: 0.7734 - test_loss: 0.648244
# City: An Giang  _algo:cnn  -RMSE: 44.839297656726636
# City: An Giang  _algo:cnn  -RMSE: 51.40928407863646
# City: An Giang  _algo:cnn  -RMSE: 46.772199217745715
# Epoch:  0/ 1 - train_loss: 0.7433 - test_loss: 0.630966
# City: An Giang  _algo:lstm  -RMSE: 41.90658136802638
# City: An Giang  _algo:lstm  -RMSE: 49.145896568415445
# City: An Giang  _algo:lstm  -RMSE: 44.26201190074597
# Epoch:  0/ 1 - train_loss: 0.8196 - test_loss: 0.659114
# City: An Giang  _algo:cnn  -RMSE: 61.58850910574051
# City: An Giang  _algo:cnn  -RMSE: 73.39408606291676
# City: An Giang  _algo:cnn  -RMSE: 61.93555909950268
# Epoch:  0/ 1 - train_loss: 0.7916 - test_loss: 0.638338
# City: An Giang  _algo:cnn  -RMSE: 11.156815188443119
# City: An Giang  _algo:cnn  -RMSE: 12.945133227201335
# City: An Giang  _algo:cnn  -RMSE: 35.221063671135134
# Epoch:  0/ 1 - train_loss: 0.7952 - test_loss: 0.622017
# City: An Giang  _algo:lstm  -RMSE: 12.432973324742465
# City: An Giang  _algo:lstm  -RMSE: 28.99781987088947
# City: An Giang  _algo:lstm  -RMSE: 15.631063382006168
# Epoch:  0/ 1 - train_loss: 0.7791 - test_loss: 0.648498
# City: An Giang  _algo:cnn  -RMSE: 67.02860989163969
# City: An Giang  _algo:cnn  -RMSE: 41.24131857443325
# City: An Giang  _algo:cnn  -RMSE: 30.58624297814919
# Epoch:  0/ 1 - train_loss: 0.8300 - test_loss: 0.649801
# City: An Giang  _algo:cnn  -RMSE: 15.869154126792024
# City: An Giang  _algo:cnn  -RMSE: 40.874538855048485
# City: An Giang  _algo:cnn  -RMSE: 76.61863966046147
# Epoch:  0/ 1 - train_loss: 0.7994 - test_loss: 0.621441
# City: An Giang  _algo:lstm  -RMSE: 13.038482097995265
# City: An Giang  _algo:lstm  -RMSE: 22.72097962922627
# City: An Giang  _algo:lstm  -RMSE: 16.672198431293296
# Epoch:  0/ 1 - train_loss: 0.8443 - test_loss: 0.684234
# City: An Giang  _algo:cnn  -RMSE: 106.92247554675632
# City: An Giang  _algo:cnn  -RMSE: 37.046451004960836
# City: An Giang  _algo:cnn  -RMSE: 119.2319199675865
# Epoch:  0/ 1 - train_loss: 0.7566 - test_loss: 0.625478
# City: An Giang  _algo:lstm  -RMSE: 43.116388852767095
# City: An Giang  _algo:lstm  -RMSE: 24.16603794568444
# City: An Giang  _algo:lstm  -RMSE: 28.372921313069902
# Epoch:  0/ 1 - train_loss: 0.8467 - test_loss: 0.669076
# City: An Giang  _algo:cnn  -RMSE: 89.02793858969763
# City: An Giang  _algo:cnn  -RMSE: 85.65712624151587
# City: An Giang  _algo:cnn  -RMSE: 55.12587856780893
# Epoch:  0/ 1 - train_loss: 0.7756 - test_loss: 0.640772
# City: An Giang  _algo:cnn  -RMSE: 38.25108985934584
# City: An Giang  _algo:cnn  -RMSE: 12.442459880622378
# City: An Giang  _algo:cnn  -RMSE: 36.5162914383843
# Epoch:  0/ 1 - train_loss: 0.8861 - test_loss: 0.628694
# City: An Giang  _algo:lstm  -RMSE: 31.36139722785424
# City: An Giang  _algo:lstm  -RMSE: 18.51785111133022
# City: An Giang  _algo:lstm  -RMSE: 11.197788998172587
# Epoch:  0/ 1 - train_loss: 0.8204 - test_loss: 0.650068
# City: An Giang  _algo:cnn  -RMSE: 33.536932036227356
# City: An Giang  _algo:cnn  -RMSE: 14.050707763009589
# City: An Giang  _algo:cnn  -RMSE: 81.33657175306148
# Epoch:  0/ 1 - train_loss: 0.8136 - test_loss: 0.658742
# City: An Giang  _algo:cnn  -RMSE: 96.6712017918263
# City: An Giang  _algo:cnn  -RMSE: 55.15792226724774
# City: An Giang  _algo:cnn  -RMSE: 22.746550896105617
# Epoch:  0/ 1 - train_loss: 0.7505 - test_loss: 0.645027
# City: An Giang  _algo:lstm  -RMSE: 78.18847102902856
# City: An Giang  _algo:lstm  -RMSE: 52.1558238834155
# City: An Giang  _algo:lstm  -RMSE: 70.64696597082404
# Epoch:  0/ 1 - train_loss: 0.8050 - test_loss: 0.642811
# City: An Giang  _algo:cnn  -RMSE: 52.43115332694672
# City: An Giang  _algo:cnn  -RMSE: 19.27664905544944
# City: An Giang  _algo:cnn  -RMSE: 30.374802395806675
# Epoch:  0/ 1 - train_loss: 0.7499 - test_loss: 0.661403
# City: An Giang  _algo:lstm  -RMSE: 92.6321497198202
# City: An Giang  _algo:lstm  -RMSE: 61.69295843994378
# City: An Giang  _algo:lstm  -RMSE: 101.92498173260188
# Epoch:  0/ 1 - train_loss: 0.8230 - test_loss: 0.653777
# City: An Giang  _algo:cnn  -RMSE: 80.15081335545212
# City: An Giang  _algo:cnn  -RMSE: 45.05784858076509
# City: An Giang  _algo:cnn  -RMSE: 40.71738286109778
# Epoch:  0/ 1 - train_loss: 0.8452 - test_loss: 0.710234
# City: An Giang  _algo:cnn  -RMSE: 159.5863126047192
# City: An Giang  _algo:cnn  -RMSE: 88.33884351256481
# City: An Giang  _algo:cnn  -RMSE: 86.87725622679656
# Epoch:  0/ 1 - train_loss: 0.7665 - test_loss: 0.622831
# City: An Giang  _algo:lstm  -RMSE: 27.319697232549437
# City: An Giang  _algo:lstm  -RMSE: 29.109946522767405
# City: An Giang  _algo:lstm  -RMSE: 13.748266293736943
# Epoch:  0/ 1 - train_loss: 0.7907 - test_loss: 0.644375
# City: An Giang  _algo:cnn  -RMSE: 60.42929845191498
# City: An Giang  _algo:cnn  -RMSE: 14.144607533144173
# City: An Giang  _algo:cnn  -RMSE: 33.30320313765766
# Epoch:  0/ 1 - train_loss: 0.8279 - test_loss: 0.706380
# City: An Giang  _algo:cnn  -RMSE: 52.11928334428557
# City: An Giang  _algo:cnn  -RMSE: 154.37490464962127
# City: An Giang  _algo:cnn  -RMSE: 112.37158853370174
# Epoch:  0/ 1 - train_loss: 0.8059 - test_loss: 0.623137
# City: An Giang  _algo:lstm  -RMSE: 27.57506949270868
# City: An Giang  _algo:lstm  -RMSE: 17.948413955501508
# City: An Giang  _algo:lstm  -RMSE: 19.399704266848868
# Epoch:  0/ 1 - train_loss: 0.7813 - test_loss: 0.657537
# City: An Giang  _algo:cnn  -RMSE: 24.009318815011387
# City: An Giang  _algo:cnn  -RMSE: 73.51321042207854
# City: An Giang  _algo:cnn  -RMSE: 79.55122487617302
# Epoch:  0/ 1 - train_loss: 0.7470 - test_loss: 0.643996
# City: An Giang  _algo:lstm  -RMSE: 77.42284247428881
# City: An Giang  _algo:lstm  -RMSE: 53.3829149036297
# City: An Giang  _algo:lstm  -RMSE: 65.17297622622344
# Epoch:  0/ 1 - train_loss: 0.7953 - test_loss: 0.649748
# City: An Giang  _algo:cnn  -RMSE: 54.50459781571208
# City: An Giang  _algo:cnn  -RMSE: 67.77494362208903
# City: An Giang  _algo:cnn  -RMSE: 16.219507525807895
# Epoch:  0/ 1 - train_loss: 0.7950 - test_loss: 0.649689
# City: An Giang  _algo:cnn  -RMSE: 27.217276999071114
# City: An Giang  _algo:cnn  -RMSE: 23.485923753335815
# City: An Giang  _algo:cnn  -RMSE: 81.92052391555924
# Epoch:  0/ 1 - train_loss: 0.7526 - test_loss: 0.650844
# City: An Giang  _algo:lstm  -RMSE: 85.66222811505368
# City: An Giang  _algo:lstm  -RMSE: 76.3637459208955
# City: An Giang  _algo:lstm  -RMSE: 60.39770822523487
# Epoch:  0/ 1 - train_loss: 0.7924 - test_loss: 0.658436
# City: An Giang  _algo:cnn  -RMSE: 70.39796406466438
# City: An Giang  _algo:cnn  -RMSE: 55.60516607504742
# City: An Giang  _algo:cnn  -RMSE: 67.91999654063592
# Epoch:  0/ 1 - train_loss: 0.8113 - test_loss: 0.659498
# City: An Giang  _algo:cnn  -RMSE: 31.76646485456858
# City: An Giang  _algo:cnn  -RMSE: 29.032390311803063
# City: An Giang  _algo:cnn  -RMSE: 107.90135129969343
# Epoch:  0/ 1 - train_loss: 0.7498 - test_loss: 0.634968
# City: An Giang  _algo:lstm  -RMSE: 42.0982776727901
# City: An Giang  _algo:lstm  -RMSE: 62.84433627002634
# City: An Giang  _algo:lstm  -RMSE: 51.05176497732563
# Epoch:  0/ 1 - train_loss: 0.7986 - test_loss: 0.661609
# City: An Giang  _algo:cnn  -RMSE: 59.55689939221285
# City: An Giang  _algo:cnn  -RMSE: 84.54699328261744
# City: An Giang  _algo:cnn  -RMSE: 60.99846949093251
# Epoch:  0/ 1 - train_loss: 0.7862 - test_loss: 0.622175
# City: An Giang  _algo:lstm  -RMSE: 22.734448600578247
# City: An Giang  _algo:lstm  -RMSE: 16.262894278103357
# City: An Giang  _algo:lstm  -RMSE: 14.487104209573175
# Epoch:  0/ 1 - train_loss: 0.7943 - test_loss: 0.651801
# City: An Giang  _algo:cnn  -RMSE: 50.47401929930462
# City: An Giang  _algo:cnn  -RMSE: 57.02315776526972
# City: An Giang  _algo:cnn  -RMSE: 57.382463547849746
# Epoch:  0/ 1 - train_loss: 0.8428 - test_loss: 0.673002
# City: An Giang  _algo:cnn  -RMSE: 59.60656188111678
# City: An Giang  _algo:cnn  -RMSE: 64.65085746342736
# City: An Giang  _algo:cnn  -RMSE: 116.81077125216767
# Epoch:  0/ 1 - train_loss: 0.7484 - test_loss: 0.630981
# City: An Giang  _algo:lstm  -RMSE: 44.6994978612798
# City: An Giang  _algo:lstm  -RMSE: 62.00726504225391
# City: An Giang  _algo:lstm  -RMSE: 20.722411776437376
# Epoch:  0/ 1 - train_loss: 0.8237 - test_loss: 0.644260
# City: An Giang  _algo:cnn  -RMSE: 39.102136717290485
# City: An Giang  _algo:cnn  -RMSE: 47.7691373411314
# City: An Giang  _algo:cnn  -RMSE: 35.4414988298914
# Epoch:  0/ 1 - train_loss: 0.8136 - test_loss: 0.662609
# City: An Giang  _algo:cnn  -RMSE: 51.49963600980257
# City: An Giang  _algo:cnn  -RMSE: 105.70045986201505
# City: An Giang  _algo:cnn  -RMSE: 38.11737883377842
# Epoch:  0/ 1 - train_loss: 0.7622 - test_loss: 0.659659
# City: An Giang  _algo:lstm  -RMSE: 53.9005884452085
# City: An Giang  _algo:lstm  -RMSE: 64.30431666064524
# City: An Giang  _algo:lstm  -RMSE: 123.17907271388145
# Epoch:  0/ 1 - train_loss: 0.7975 - test_loss: 0.715030
# City: An Giang  _algo:cnn  -RMSE: 137.66885302501328
# City: An Giang  _algo:cnn  -RMSE: 125.5653241355517
# City: An Giang  _algo:cnn  -RMSE: 99.39092611133897
# Epoch:  0/ 1 - train_loss: 0.7610 - test_loss: 0.625048
# City: An Giang  _algo:lstm  -RMSE: 31.809787895821866
# City: An Giang  _algo:lstm  -RMSE: 40.52079921036802
# City: An Giang  _algo:lstm  -RMSE: 22.230197832550957
# Epoch:  0/ 1 - train_loss: 0.7884 - test_loss: 0.655990
# City: An Giang  _algo:cnn  -RMSE: 52.46545603773636
# City: An Giang  _algo:cnn  -RMSE: 49.72012397218382
# City: An Giang  _algo:cnn  -RMSE: 80.97104415963496
# Epoch:  0/ 1 - train_loss: 0.8087 - test_loss: 0.651187
# ...
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.325062064691803
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.391235441916457
# City: Lạng Sơn  _algo:cnn  -RMSE: 39.02989111555471
# Epoch:  0/ 1 - train_loss: 0.7694 - test_loss: 0.591972
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.693609600039123
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.805535887765288
# City: Lạng Sơn  _algo:cnn  -RMSE: 34.1137255058915
# Epoch:  0/ 1 - train_loss: 0.9611 - test_loss: 0.778246
# City: Lạng Sơn  _algo:lstm  -RMSE: 91.3743217261694
# City: Lạng Sơn  _algo:lstm  -RMSE: 73.2768919347796
# City: Lạng Sơn  _algo:lstm  -RMSE: 37.41612475644886
# Epoch:  0/ 1 - train_loss: 0.8157 - test_loss: 0.603188
# City: Lạng Sơn  _algo:cnn  -RMSE: 34.41329392221965
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.331340330076888
# City: Lạng Sơn  _algo:cnn  -RMSE: 36.692760222874576
# Epoch:  0/ 1 - train_loss: 0.8060 - test_loss: 0.622714
# City: Lạng Sơn  _algo:cnn  -RMSE: 32.110885394589694
# City: Lạng Sơn  _algo:cnn  -RMSE: 40.03431254681095
# City: Lạng Sơn  _algo:cnn  -RMSE: 54.09212919801152
# Epoch:  0/ 1 - train_loss: 0.9726 - test_loss: 0.792817
# City: Lạng Sơn  _algo:lstm  -RMSE: 59.105201728380294
# City: Lạng Sơn  _algo:lstm  -RMSE: 63.77611741348705
# City: Lạng Sơn  _algo:lstm  -RMSE: 98.66476051353031
# Epoch:  0/ 1 - train_loss: 0.8086 - test_loss: 0.598456
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.051192166835495
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.338326515741812
# City: Lạng Sơn  _algo:cnn  -RMSE: 37.70138730293498
# Epoch:  0/ 1 - train_loss: 0.9387 - test_loss: 0.761045
# City: Lạng Sơn  _algo:lstm  -RMSE: 30.104659818195582
# City: Lạng Sơn  _algo:lstm  -RMSE: 77.16240049934665
# City: Lạng Sơn  _algo:lstm  -RMSE: 75.20031505794528
# Epoch:  0/ 1 - train_loss: 0.7399 - test_loss: 0.585540
# City: Lạng Sơn  _algo:cnn  -RMSE: 21.21922178089733
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.853252704549952
# City: Lạng Sơn  _algo:cnn  -RMSE: 12.641933850463275
# Epoch:  0/ 1 - train_loss: 0.7813 - test_loss: 0.601565
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.643951537556983
# City: Lạng Sơn  _algo:cnn  -RMSE: 37.7708242269522
# City: Lạng Sơn  _algo:cnn  -RMSE: 27.88823528800958
# Epoch:  0/ 1 - train_loss: 0.9745 - test_loss: 0.776323
# City: Lạng Sơn  _algo:lstm  -RMSE: 71.84892970453522
# City: Lạng Sơn  _algo:lstm  -RMSE: 53.513967678439236
# City: Lạng Sơn  _algo:lstm  -RMSE: 81.57336426937957
# Epoch:  0/ 1 - train_loss: 0.8003 - test_loss: 0.588064
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.22913382120736
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.72507478546035
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.70452046868057
# Epoch:  0/ 1 - train_loss: 0.7609 - test_loss: 0.629113
# City: Lạng Sơn  _algo:cnn  -RMSE: 51.59369804005292
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.973462017289357
# City: Lạng Sơn  _algo:cnn  -RMSE: 50.49803495266698
# Epoch:  0/ 1 - train_loss: 1.0097 - test_loss: 0.805273
# City: Lạng Sơn  _algo:lstm  -RMSE: 75.91753218657718
# City: Lạng Sơn  _algo:lstm  -RMSE: 80.11906400005788
# City: Lạng Sơn  _algo:lstm  -RMSE: 82.54411504522345
# Epoch:  0/ 1 - train_loss: 0.8359 - test_loss: 0.603703
# City: Lạng Sơn  _algo:cnn  -RMSE: 36.19930687550034
# City: Lạng Sơn  _algo:cnn  -RMSE: 34.33011691894778
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.340030441343618
# Epoch:  0/ 1 - train_loss: 0.9211 - test_loss: 0.744817
# City: Lạng Sơn  _algo:lstm  -RMSE: 64.24559337385139
# City: Lạng Sơn  _algo:lstm  -RMSE: 45.646300674843246
# City: Lạng Sơn  _algo:lstm  -RMSE: 61.42055751000244
# Epoch:  0/ 1 - train_loss: 0.7679 - test_loss: 0.601222
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.748809106788077
# City: Lạng Sơn  _algo:cnn  -RMSE: 45.89507119164005
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.62669885570058
# Epoch:  0/ 1 - train_loss: 0.8265 - test_loss: 0.596049
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.10158389988308
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.809644402203272
# City: Lạng Sơn  _algo:cnn  -RMSE: 28.873370241553136
# Epoch:  0/ 1 - train_loss: 0.9394 - test_loss: 0.760108
# City: Lạng Sơn  _algo:lstm  -RMSE: 80.7767656407805
# City: Lạng Sơn  _algo:lstm  -RMSE: 48.88136622907572
# City: Lạng Sơn  _algo:lstm  -RMSE: 56.97553360041378
# Epoch:  0/ 1 - train_loss: 0.7804 - test_loss: 0.593212
# City: Lạng Sơn  _algo:cnn  -RMSE: 28.17480732284119
# City: Lạng Sơn  _algo:cnn  -RMSE: 29.68342886147051
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.973593160442618
# Epoch:  0/ 1 - train_loss: 0.7743 - test_loss: 0.588584
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.133225236803412
# City: Lạng Sơn  _algo:cnn  -RMSE: 23.3641385923874
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.288050024594344
# Epoch:  0/ 1 - train_loss: 0.9185 - test_loss: 0.757037
# City: Lạng Sơn  _algo:lstm  -RMSE: 65.29314477630066
# City: Lạng Sơn  _algo:lstm  -RMSE: 74.24825422686388
# City: Lạng Sơn  _algo:lstm  -RMSE: 43.81639610978405
# Epoch:  0/ 1 - train_loss: 0.7990 - test_loss: 0.587230
# City: Lạng Sơn  _algo:cnn  -RMSE: 12.630376063497271
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.84950249695595
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.78786367451208
# Epoch:  0/ 1 - train_loss: 0.8790 - test_loss: 0.736423
# City: Lạng Sơn  _algo:lstm  -RMSE: 21.111022489579696
# City: Lạng Sơn  _algo:lstm  -RMSE: 85.42129598694135
# City: Lạng Sơn  _algo:lstm  -RMSE: 30.033131193054647
# Epoch:  0/ 1 - train_loss: 0.7644 - test_loss: 0.586650
# City: Lạng Sơn  _algo:cnn  -RMSE: 24.149826217469467
# City: Lạng Sơn  _algo:cnn  -RMSE: 13.526953452387456
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.659380440059811
# Epoch:  0/ 1 - train_loss: 0.8071 - test_loss: 0.601306
# City: Lạng Sơn  _algo:cnn  -RMSE: 43.289550818965374
# City: Lạng Sơn  _algo:cnn  -RMSE: 28.669071635812966
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.29119508461619
# Epoch:  0/ 1 - train_loss: 0.8675 - test_loss: 0.718722
# City: Lạng Sơn  _algo:lstm  -RMSE: 42.90842690650672
# City: Lạng Sơn  _algo:lstm  -RMSE: 29.13987686286831
# City: Lạng Sơn  _algo:lstm  -RMSE: 57.090404167673206
# Epoch:  0/ 1 - train_loss: 0.8725 - test_loss: 0.615728
# City: Lạng Sơn  _algo:cnn  -RMSE: 51.18680681869407
# City: Lạng Sơn  _algo:cnn  -RMSE: 25.667764343895165
# City: Lạng Sơn  _algo:cnn  -RMSE: 29.68109233509004
# Epoch:  0/ 1 - train_loss: 0.8112 - test_loss: 0.600524
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.5382807711898
# City: Lạng Sơn  _algo:cnn  -RMSE: 30.088386208501873
# City: Lạng Sơn  _algo:cnn  -RMSE: 36.60540005084028
# Epoch:  0/ 1 - train_loss: 0.9072 - test_loss: 0.742258
# City: Lạng Sơn  _algo:lstm  -RMSE: 38.513528326330835
# City: Lạng Sơn  _algo:lstm  -RMSE: 72.76430697347976
# City: Lạng Sơn  _algo:lstm  -RMSE: 50.881436431687526
# Epoch:  0/ 1 - train_loss: 0.8069 - test_loss: 0.600667
# City: Lạng Sơn  _algo:cnn  -RMSE: 25.32523013907627
# City: Lạng Sơn  _algo:cnn  -RMSE: 41.84314801576732
# City: Lạng Sơn  _algo:cnn  -RMSE: 23.937212704000178
# Epoch:  0/ 1 - train_loss: 0.8552 - test_loss: 0.712177
# City: Lạng Sơn  _algo:lstm  -RMSE: 18.647242789659256
# City: Lạng Sơn  _algo:lstm  -RMSE: 37.83380012391488
# City: Lạng Sơn  _algo:lstm  -RMSE: 56.6629327493837
# Epoch:  0/ 1 - train_loss: 0.8030 - test_loss: 0.589173
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.11883418429668
# City: Lạng Sơn  _algo:cnn  -RMSE: 13.904814351687987
# City: Lạng Sơn  _algo:cnn  -RMSE: 27.388787014269646
# Epoch:  0/ 1 - train_loss: 0.8071 - test_loss: 0.589887
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.215165739702005
# City: Lạng Sơn  _algo:cnn  -RMSE: 24.91978024745216
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.620745306653331
# Epoch:  0/ 1 - train_loss: 0.8774 - test_loss: 0.720468
# City: Lạng Sơn  _algo:lstm  -RMSE: 41.940901210081094
# City: Lạng Sơn  _algo:lstm  -RMSE: 53.445746417876975
# City: Lạng Sơn  _algo:lstm  -RMSE: 38.93808067478438
# Epoch:  0/ 1 - train_loss: 0.8074 - test_loss: 0.594235
# City: Lạng Sơn  _algo:cnn  -RMSE: 18.086345081231364
# City: Lạng Sơn  _algo:cnn  -RMSE: 39.25262302760976
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.09885318388579
# Epoch:  0/ 1 - train_loss: 0.7976 - test_loss: 0.591922
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.033578071564147
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.70888268249589
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.69622501438523
# Epoch:  0/ 1 - train_loss: 0.8724 - test_loss: 0.720816
# City: Lạng Sơn  _algo:lstm  -RMSE: 70.78165541223514
# City: Lạng Sơn  _algo:lstm  -RMSE: 22.024440232360416
# City: Lạng Sơn  _algo:lstm  -RMSE: 25.345734104834143
# Epoch:  0/ 1 - train_loss: 0.7744 - test_loss: 0.592936
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.280792052954045
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.792524916279344
# City: Lạng Sơn  _algo:cnn  -RMSE: 36.132933980281685
# Epoch:  0/ 1 - train_loss: 0.8665 - test_loss: 0.721580
# City: Lạng Sơn  _algo:lstm  -RMSE: 37.10059865315388
# City: Lạng Sơn  _algo:lstm  -RMSE: 53.935563065323336
# City: Lạng Sơn  _algo:lstm  -RMSE: 44.936137977116836
# Epoch:  0/ 1 - train_loss: 0.7892 - test_loss: 0.597143
# City: Lạng Sơn  _algo:cnn  -RMSE: 38.088784135255096
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.281070068457076
# City: Lạng Sơn  _algo:cnn  -RMSE: 21.74906980223617
# Epoch:  0/ 1 - train_loss: 0.7761 - test_loss: 0.590165
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.227024287771417
# City: Lạng Sơn  _algo:cnn  -RMSE: 27.7835455916897
# City: Lạng Sơn  _algo:cnn  -RMSE: 21.781459160429474
# Epoch:  0/ 1 - train_loss: 0.9335 - test_loss: 0.760493
# City: Lạng Sơn  _algo:lstm  -RMSE: 52.12279807217733
# City: Lạng Sơn  _algo:lstm  -RMSE: 64.09766889661046
# City: Lạng Sơn  _algo:lstm  -RMSE: 71.58351040889363
# Epoch:  0/ 1 - train_loss: 0.7885 - test_loss: 0.597689
# City: Lạng Sơn  _algo:cnn  -RMSE: 39.794918630741435
# City: Lạng Sơn  _algo:cnn  -RMSE: 23.306921826480387
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.311342062926446
# Epoch:  0/ 1 - train_loss: 0.8381 - test_loss: 0.594288
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.448370704032584
# City: Lạng Sơn  _algo:cnn  -RMSE: 32.78725161376449
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.309101573577255
# Epoch:  0/ 1 - train_loss: 0.8695 - test_loss: 0.718703
# City: Lạng Sơn  _algo:lstm  -RMSE: 42.069170035775734
# City: Lạng Sơn  _algo:lstm  -RMSE: 58.9858618334029
# City: Lạng Sơn  _algo:lstm  -RMSE: 24.079232939340088
# Epoch:  0/ 1 - train_loss: 0.7661 - test_loss: 0.592822
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.713106022383627
# City: Lạng Sơn  _algo:cnn  -RMSE: 34.505661055300514
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.095089545527166
# Epoch:  0/ 1 - train_loss: 0.9510 - test_loss: 0.771092
# City: Lạng Sơn  _algo:lstm  -RMSE: 60.29857928552306
# City: Lạng Sơn  _algo:lstm  -RMSE: 87.71426834409309
# City: Lạng Sơn  _algo:lstm  -RMSE: 46.395228019483866
# Epoch:  0/ 1 - train_loss: 0.7527 - test_loss: 0.587008
# City: Lạng Sơn  _algo:cnn  -RMSE: 18.77881016897799
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.635905289299842
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.193751574695103
# Epoch:  0/ 1 - train_loss: 0.8614 - test_loss: 0.625145
# City: Lạng Sơn  _algo:cnn  -RMSE: 34.2058940778179
# City: Lạng Sơn  _algo:cnn  -RMSE: 49.7234925644908
# City: Lạng Sơn  _algo:cnn  -RMSE: 39.90549986381988
# Epoch:  0/ 1 - train_loss: 0.9209 - test_loss: 0.753367
# City: Lạng Sơn  _algo:lstm  -RMSE: 53.95572221950474
# City: Lạng Sơn  _algo:lstm  -RMSE: 74.73095942342704
# City: Lạng Sơn  _algo:lstm  -RMSE: 48.09437232684867
# Epoch:  0/ 1 - train_loss: 0.8116 - test_loss: 0.592746
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.146667547074358
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.881048086647535
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.25578878024034
# Epoch:  0/ 1 - train_loss: 0.8287 - test_loss: 0.609266
# City: Lạng Sơn  _algo:cnn  -RMSE: 29.622033360389484
# City: Lạng Sơn  _algo:cnn  -RMSE: 45.162137024901305
# City: Lạng Sơn  _algo:cnn  -RMSE: 27.47393131160129
# Epoch:  0/ 1 - train_loss: 0.8653 - test_loss: 0.720244
# City: Lạng Sơn  _algo:lstm  -RMSE: 44.82228825533806
# City: Lạng Sơn  _algo:lstm  -RMSE: 58.07110531520337
# City: Lạng Sơn  _algo:lstm  -RMSE: 24.799083161563505
# Epoch:  0/ 1 - train_loss: 0.8063 - test_loss: 0.591709
# City: Lạng Sơn  _algo:cnn  -RMSE: 25.08161741858948
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.748967698900568
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.789063947028005
# Epoch:  0/ 1 - train_loss: 0.9947 - test_loss: 0.802463
# City: Lạng Sơn  _algo:lstm  -RMSE: 81.79158835183091
# City: Lạng Sơn  _algo:lstm  -RMSE: 101.83619461073775
# City: Lạng Sơn  _algo:lstm  -RMSE: 29.903965608339867
# Epoch:  0/ 1 - train_loss: 0.7708 - test_loss: 0.586966
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.193089692870608
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.538674580739094
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.31413281079112
# Epoch:  0/ 1 - train_loss: 0.7890 - test_loss: 0.588243
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.414565704687746
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.72842813768869
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.222547101602803
# Epoch:  0/ 1 - train_loss: 0.8730 - test_loss: 0.719568
# City: Lạng Sơn  _algo:lstm  -RMSE: 43.306332943148185
# City: Lạng Sơn  _algo:lstm  -RMSE: 37.830249797256585
# City: Lạng Sơn  _algo:lstm  -RMSE: 52.31934100835239
# Epoch:  0/ 1 - train_loss: 0.7709 - test_loss: 0.603189
# City: Lạng Sơn  _algo:cnn  -RMSE: 29.521699632329728
# City: Lạng Sơn  _algo:cnn  -RMSE: 43.92802064859184
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.439528521177978
# Epoch:  0/ 1 - train_loss: 0.7827 - test_loss: 0.613269
# City: Lạng Sơn  _algo:cnn  -RMSE: 18.87773245335598
# City: Lạng Sơn  _algo:cnn  -RMSE: 49.61856041603546
# City: Lạng Sơn  _algo:cnn  -RMSE: 38.008489593853206
# Epoch:  0/ 1 - train_loss: 0.9744 - test_loss: 0.784180
# City: Lạng Sơn  _algo:lstm  -RMSE: 27.48562530870049
# City: Lạng Sơn  _algo:lstm  -RMSE: 82.81032974711644
# City: Lạng Sơn  _algo:lstm  -RMSE: 89.52719596597598
# Epoch:  0/ 1 - train_loss: 0.7589 - test_loss: 0.590635
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.23831767848851
# City: Lạng Sơn  _algo:cnn  -RMSE: 28.250235512130487
# City: Lạng Sơn  _algo:cnn  -RMSE: 20.269931700925067
# Epoch:  0/ 1 - train_loss: 0.8981 - test_loss: 0.733698
# City: Lạng Sơn  _algo:lstm  -RMSE: 42.33783860263688
# City: Lạng Sơn  _algo:lstm  -RMSE: 52.140293812420886
# City: Lạng Sơn  _algo:lstm  -RMSE: 60.10611239852071
# Epoch:  0/ 1 - train_loss: 0.7684 - test_loss: 0.586816
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.18615483983512
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.779890460797928
# City: Lạng Sơn  _algo:cnn  -RMSE: 22.00701548110554
# Epoch:  0/ 1 - train_loss: 0.7870 - test_loss: 0.604123
# City: Lạng Sơn  _algo:cnn  -RMSE: 49.35608710153024
# City: Lạng Sơn  _algo:cnn  -RMSE: 17.799074086334926
# City: Lạng Sơn  _algo:cnn  -RMSE: 24.255854285754154
# Epoch:  0/ 1 - train_loss: 0.8302 - test_loss: 0.699187
# City: Lạng Sơn  _algo:lstm  -RMSE: 40.68804286533242
# City: Lạng Sơn  _algo:lstm  -RMSE: 15.534579048751647
# City: Lạng Sơn  _algo:lstm  -RMSE: 35.708644684398124
# Epoch:  0/ 1 - train_loss: 0.7870 - test_loss: 0.593487
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.461151060012764
# City: Lạng Sơn  _algo:cnn  -RMSE: 36.822617806097426
# City: Lạng Sơn  _algo:cnn  -RMSE: 15.678015809341147
# Epoch:  0/ 1 - train_loss: 0.8029 - test_loss: 0.601779
# City: Lạng Sơn  _algo:cnn  -RMSE: 26.04119423546121
# City: Lạng Sơn  _algo:cnn  -RMSE: 33.993314806770044
# City: Lạng Sơn  _algo:cnn  -RMSE: 30.91219976272204
# Epoch:  0/ 1 - train_loss: 0.8961 - test_loss: 0.732829
# City: Lạng Sơn  _algo:lstm  -RMSE: 66.90545970805636
# City: Lạng Sơn  _algo:lstm  -RMSE: 46.7435295156609
# City: Lạng Sơn  _algo:lstm  -RMSE: 38.64134812431314
# Epoch:  0/ 1 - train_loss: 0.7818 - test_loss: 0.600656
# City: Lạng Sơn  _algo:cnn  -RMSE: 31.01700295233752
# City: Lạng Sơn  _algo:cnn  -RMSE: 39.74886363177796
# City: Lạng Sơn  _algo:cnn  -RMSE: 16.733821983852458
# Epoch:  0/ 1 - train_loss: 0.9535 - test_loss: 0.765173
# City: Lạng Sơn  _algo:lstm  -RMSE: 53.118972827028934
# City: Lạng Sơn  _algo:lstm  -RMSE: 49.94417817728904
# City: Lạng Sơn  _algo:lstm  -RMSE: 88.28294691821075
# Epoch:  0/ 1 - train_loss: 0.7774 - test_loss: 0.584650
# City: Lạng Sơn  _algo:cnn  -RMSE: 18.39037160933758
# City: Lạng Sơn  _algo:cnn  -RMSE: 19.038352093427058
# City: Lạng Sơn  _algo:cnn  -RMSE: 14.10883700380655
# {"ok":true,"result":{"message_id":1114,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676636876,"text":"Server Ch\u1ea1y xong city: L\u1ea1ng S\u01a1n"}}
# kết thúc train trong: 3
# danh sách error city:
# {}
