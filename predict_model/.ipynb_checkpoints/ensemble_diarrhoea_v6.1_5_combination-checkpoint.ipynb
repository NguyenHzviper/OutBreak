# %% [markdown]
# # Matrix of metrics of Cross validation  for 5 top Simple Combination
# Date: 09/12/2022
# Description: Create cross validation metrics
# Use 5 combinations only regarding to the ranking from simple combination result.
# This file creates cross validation metrics for next steps
# Modificaiton 02/01/2023
# Sử dụng 5 combination mới

# %%
# !nvidia-smi
# Out:
# Fri Feb  3 09:37:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.13    Driver Version: 525.60.13    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 6000     On   | 00000000:21:00.0 Off |                  Off |
# | 34%   56C    P2   110W / 260W |   4185MiB / 24576MiB |     97%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     22716      C   ..._diseases_py39/bin/python     1026MiB |
# |    0   N/A  N/A     22778      C   ..._diseases_py39/bin/python     1088MiB |
# |    0   N/A  N/A     22847      C   ..._diseases_py39/bin/python     1020MiB |
# |    0   N/A  N/A     22907      C   ..._diseases_py39/bin/python     1048MiB |
# +-----------------------------------------------------------------------------+

# %%
# Install packages
# !pip install -U scikit-learn
# !pip install ftfy
# !pip install xlsxwriter 
# !pip install xlwt
# Out:
# Requirement already satisfied: scikit-learn in /home/mlworker/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.8.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ftfy in /home/mlworker/lib/python3.10/site-packages (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/mlworker/lib/python3.10/site-packages (from ftfy) (0.2.5)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
import tensorflow as tf 
# from google.colab import drive
import os

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense

import traceback
import sys
import copy
import numpy as np
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# lib for LSTM of Meta model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

from ftfy import fix_text
import warnings
warnings.simplefilter("ignore", UserWarning)

plt.rcParams['figure.figsize'] = [7, 3]
import math
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# # Global param and project path
# All mix data 1997-2018

# %%
# Attach Google Drive for reading and saving files
# drive.mount('/content/drive')
prj_path = '/home/mlworker/Quang/HealthCare/Source_14012023_v4/'

path_all_mix_data =             prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/'
path_all_mix_data_cnn =         path_all_mix_data+ '/cnn/'
path_all_mix_data_lstm =        path_all_mix_data+ '/lstm/'
path_all_mix_data_lstm_att =    path_all_mix_data+ '/lstm_att/'
path_all_mix_data_tf =          path_all_mix_data+ '/transformer/'

prj_path_opt= prj_path + '/optimize_hyperparam/opt_results/optimize_1997_2018/'

prj_path_result_ensemble =      prj_path+ '/results/ensemble/'
com_path_validation_metrics =   prj_path_result_ensemble+ '/result/weighted_combination/cv_metrics/'

com_eval_path_validation_metrics = prj_path + '/eval_result/21_12_2022_weighted_combination-5-cities/'


# loockback_window for meta model
meta_lookback_window = 3

# %%
com_path_validation_metrics
# Out:
# '/home/mlworker/Quang/HealthCare/Source_14012023_v4//results/ensemble//result/weighted_combination/cv_metrics/'

# %%
# com_eval_path_validation_metrics

# %% [markdown]
# # Xây dựng Meta Data Set

# %%
##########################
# Xây Dựng Meta Data Set
meta_test_set_city = {}
meta_train_set_city = {}
meta_data_set_city = {}
# cities = ['An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
#         'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
#         'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
#         'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
#         'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
#         'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
#          'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp']

cities = [
 #     'An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau','Đà Nẵng',
        
#     'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
        
#     'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng', 'Đắk Nông',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
        
#     'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Đắk Lắk',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
        
#     'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
#         'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên','Đồng Tháp'
]

for city in cities:  
  meta_test_set = pd.DataFrame()
  meta_train_set = pd.DataFrame() 
  #Note: mỗi bộ all_mix_data sẽ có lenght = 251 (10997 -01/01/2018  và vì 1 dòng đầu bị bỏ đi do quá trình statitionary và remove NAN lúc train)
  lenght_whole_data_city = 251
  ######################################
  # Xử lý data của CNN ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_cnn+'mix_train_test_data_'+city+'_cnn.xlsx')
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index() 
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_cnn = result_test.reset_index(drop=True)  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_cnn = result_train.reset_index(drop=True)
  
  ######################################
  # Xử lý data của LSTM  ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm+'mix_train_test_data_'+city+'_lstm.xlsx')  
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm = result_test.reset_index(drop=True)
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm = result_train.reset_index(drop=True)

  ###########################################
  # Xử lý data của LSTM ATT ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm_att+'mix_train_test_data_'+city+'_lstm_att.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm_att = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36]
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm_att = result_train.reset_index(drop=True)


  #############################################
  # Xử lý data của Transformer ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_tf+'mix_train_test_data_'+city+'_tf.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
  meta_test_tf = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36] # Lấy từ meta_lookback_window cho đến -36 (3 năm cuối)
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_tf = result_train.reset_index(drop=True)

  
  meta_test_set['cnn_pred'] = meta_test_cnn
  meta_test_set['lstm_pred'] = meta_test_lstm
  meta_test_set['lstm_att_pred'] = meta_test_lstm_att
  meta_test_set['tf_pred'] = meta_test_tf
  meta_test_set['Observed'] = meta_test_observed
   
  meta_train_set['cnn_pred'] = meta_train_cnn
  meta_train_set['lstm_pred'] = meta_train_lstm
  meta_train_set['lstm_att_pred'] = meta_train_lstm_att 
  meta_train_set['tf_pred'] = meta_train_tf  
  meta_train_set['Observed'] = meta_train_observed

  meta_test_set_city[city] = meta_test_set # test set có chiều dài 39
  meta_train_set_city[city] = meta_train_set # train set có chiều dài 212 = 252 -36 (train) - 1 (station) - 3 (meta_lookback_window)

  # Đoạn này làm thêm. Nối dài meta_test_set_city và meta_train_set_city
  # lưu ý đoạn này sẽ tạo ra data có chiều dài = 252 - 1 (bỏ đi 1 tháng đầu do xử lý stationary) - meta_lookback_window
  df = meta_train_set.append(meta_test_set[3:])
  df = df.reset_index(drop=True)
  # range date từ 1 + lookback_window tháng đầu tiên
  df['year_month'] = pd.Series(pd.date_range("1997-05-01", periods=248, freq="M"))  
  meta_data_set_city[city] = df
  df.to_excel(prj_path_result_ensemble+'/meta_data/meta_data_'+city+'.xlsx')

# %%
# meta_train_set_city['Lạng Sơn']

# %% [markdown]
# # Danh sách các based Model và các Combination có thể của nó

# %%
# Danh sách các based Model và các Combination có thể của nó
list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

combs_features = list(combinations(list_based_model[0:], 2)) + list(combinations(list_based_model[0:], 3)) + list(combinations(list_based_model[0:], 4))

# list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

# combs_features = list(combinations(list_based_model[0:], 3)) 
combs_features
# Out:
# [('cnn_pred', 'lstm_att_pred'),
#  ('cnn_pred', 'lstm_pred'),
#  ('cnn_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred'),
#  ('lstm_att_pred', 'tf_pred'),
#  ('lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred', 'tf_pred')]

# %% [markdown]
# # Selected 5 Combination

# %%
# selected_combs = ['CNN*lstm_att_pred-tf_pred-Observed','CNN*cnn_pred-lstm_pred-Observed',
#                   'CNN*lstm_pred-tf_pred-Observed', 'CNN*cnn_pred-lstm_att_pred-lstm_pred-Observed',
#                   'LSTM*lstm_att_pred-lstm_pred-tf_pred-Observed'                 
#                  ]
selected_combs = ['LSTM*cnn_pred-tf_pred-Observed','LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed',
                  'CNN*lstm_att_pred-lstm_pred-Observed', 'LSTM*cnn_pred-lstm_pred-Observed',
                  'LSTM*lstm_att_pred-lstm_pred-Observed'                 
                 ]
def is_in_Selected_combination(comb_string = ''):
    return any(comb_string in x for x in selected_combs)

# %% [markdown]
# # Support Functions and Train class

# %%
import requests

def send_to_telegram(message):

    apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
    chatID = '@ptn_announcement'
    apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

    try:
        response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
        print(response.text)
    except Exception as e:
        print(e)


def seed_everything(seed: int):
    import random, os    
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything(42)

# Set hyperparameters as args using the Configuration class
class Configuration():
    def __init__(self):
      # lấy bộ test dài 36 tháng = 3 năm
        self.test_size = 36
        # là nhìn vào dữ liệu trước 3 tháng và dự phóng        
        self.look_back = 3
        # dự phóng 3 tháng
        self.n_predicted_month = 3
        self.n_features = 3
        self.seed = 42
        # mỗi phần tử x trong tập suppervise có độ lớn là 16 = 16 tháng
        self.batch_size = 16
        # self.device = torch.device("cuda")
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.epochs = 300
     

# Biến args lưu giá trị Global.
args = Configuration()


# Lưu ý sau khi stationnary thì dòng đầu tiên trừ cho dòng trước nữa là ko có cho nên về cơ bản sẽ thành NaN
# Cần remove dòng đầu tiên ra khỏi data để train và test. Cho nên cơ bản là data sau khi in ra sẽ thiếu 1 đơn vị đầu tiên
def convert_to_stationary(city_data):
    """Subtracts previous value for all cols except disease rates"""
    for col_name in city_data.columns:
        if col_name != 'Diarrhoea_rates':
            try:
                city_data[col_name] = city_data[col_name] - city_data[col_name].shift()
            except:
                print(col_name)
    return city_data

def impute_missing_value(city_data):
    """
    Cơ bản dữ liệu bị thiếu sót rất nhiều: Như Điện Biên 1997 -2003 là thiếu dữ liệu về bệnh
    Hàm này sẽ tự sinh ra dữ liệu bị thiếu. Nếu tháng nào không có số liệu thì tính như sau:
    12 tháng đầu không có số liệu thì gán = 0
    tháng 13-24 không có số liệu, sẽ lấy giá trị của tháng cùng kỳ năm trước
    tháng từ 24 trở đi sẽ lấy giá trị nhỏ nhất của 2 tháng cùng kỳ trong 2 năm gần nhất.
    Do Điện Biên bằng 0 nên sau khi xử lý từ 1997 -2003 là đều = 0.  
    """
    for col in city_data.columns:
        for index in range(len(city_data[col])):
            if np.isnan(city_data[col].iloc[index]):
                if index < 12:
                    city_data[col].iloc[index] = 0
                elif index >= 12 and index <= 24:
                    city_data[col].iloc[index] = city_data[col].iloc[index - 12]
                else:
                    city_data[col].iloc[index] = min(city_data[col].iloc[index - 12], city_data[col].iloc[index - 24])
    return city_data

def split_data(data, look_back ):
    """Splits data into train and test sets based on args (Configuration class)"""
    train = data[: -args.test_size]    
    test = data[-args.test_size - look_back: ]
    return train, test

def to_supervised(data, d_in=args.look_back, d_out=args.n_predicted_month, features_list=[]):
    """
    Frames time-series as supervised learning dataset.
    
    Args:
      d_in: lookback window
      d_out: number of predicted months
      features_list: list of all features **where last col is the disease incidence**

    Returns:
      Numpy arrays of disease incidence (y) and other predictors (X)
    """
    X, y = list(), list()
    for index, _ in enumerate(data):
        in_end = index + d_in
        out_end = in_end + d_out
        if out_end <= len(data):
            if len(features_list) == 0 :
                X.append(data[index: in_end, :])
            else:
                X.append(data[index: in_end, features_list])
            y.append(data[in_end: out_end, -1])
    return np.array(X), np.array(y)


def get_data(train_np, test_np, batch_size, list_selected_features, origin_city_meta_data):
    """
    Returns important feature list and data formatted for input into Pytorch 
    models
    """ 
    # origin_city_meta_data chứa data mẫu để lấy index 
    # important_features = arrary index nên ta phải truyền indexex của columns
    important_features = [origin_city_meta_data.columns.get_loc(c) for c in list_selected_features if c in origin_city_meta_data]  

    train_X, train_y = to_supervised(train_np, features_list=important_features)
    test_X, test_y = to_supervised(test_np, features_list=important_features)
    train_tensor = TensorDataset(torch.from_numpy(train_X), torch.from_numpy(train_y))
    test_tensor = (torch.from_numpy(test_X), torch.from_numpy(test_y))

    train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

    return important_features, train_loader, test_tensor

#Define Pytorch LSTM model
class MultiVariateLSTM(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = output[:, -1, :]
        y_predicted = self.linear(last_hidden_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            #return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

#Define Pytorch LSTM-ATT model
class MultiVariateLSTM_Attention(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.attention_linear = nn.Linear(hidden_size, hidden_size)
        # self.linear = nn.Linear(hidden_size*2, args.n_predicted_month)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = last_hidden[-1]
        remain_hidden_vector = output
        e_t = remain_hidden_vector.bmm(self.attention_linear(last_hidden_vector).unsqueeze(2)).squeeze(-1)
        alpha_t = F.softmax(e_t, dim=1)
        attenion_vector = remain_hidden_vector.transpose(2, 1).bmm(alpha_t.unsqueeze(2)).squeeze(-1)
        # combine_vector = torch.cat((last_hidden_vector, attenion_vector), dim=1)
        # combine_vector = last_hidden_vector + attenion_vector
        y_predicted = self.linear(attenion_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Define Pytorch CNN model
class MultivariateCNN(nn.Module):
    def __init__(self, num_filters=[100, 100, 100], dropout=0.01):
        super(MultivariateCNN, self).__init__()
        self.loss_fn = loss = nn.MSELoss()
        self.filter_sizes = [1, 2, 3]
        self.conv1d_list = nn.ModuleList([nn.Conv1d(args.n_features, num_filters[i], self.filter_sizes[i]) for i in range(len(self.filter_sizes))])
        self.linear = nn.Linear(np.sum(num_filters), args.n_predicted_month)
        self.dropout = nn.Dropout(dropout)
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))

    def forward(self, X_batch, y_batch=None):
        X_batch = X_batch.permute(0, 2, 1)  #(batch_size, n_features, n_look_back)
        X_conv_list = [F.relu(conv1d(X_batch)) for conv1d in self.conv1d_list]
        X_pool_list = [F.max_pool1d(x_conv, kernel_size=x_conv.shape[2]) for x_conv in X_conv_list]
        X_fc = torch.cat([x_pool.squeeze(dim=2) for x_pool in X_pool_list], dim=1)
        y_predicted = self.linear(self.dropout(X_fc))
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted

    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Transformer Model
# Transformer Model
class PositionalEncoder(nn.Module):
    def __init__(self, n_feature=3, dropout=0.1, max_length=24):
        super().__init__()
        
        self.hidden_dim = n_feature
        self.max_length = max_length
        self.dropout = nn.Dropout(dropout)
        
        pe = torch.zeros(max_length, self.hidden_dim)
        for pos in range(max_length):
            for i in range(0, self.hidden_dim, 2):
                pe[pos, i] = math.sin(pos/(10000**(2*i/self.hidden_dim)))
                if i + 1 < self.hidden_dim:
                    pe[pos, i+1] = math.cos(pos/(10000**((2*i+1)/self.hidden_dim)))
        pe = pe.unsqueeze(0)        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x*math.sqrt(self.hidden_dim)
        length = x.size(1)
        pe = Variable(self.pe[:, :length], requires_grad=False)
        if x.is_cuda:
            pe.cuda()
        x = x + pe
        x = self.dropout(x)
        
        return x

class TransformerModel(nn.Module):
    def __init__(self, d_input, n_look_back, hidden_size, n_layers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.hidden_size = hidden_size

        self.pe = PositionalEncoder(n_feature=args.n_features, dropout=dropout)

        encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dim_feedforward=hidden_size, dropout=dropout, activation='gelu')
        # encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)
        self.decoder = nn.Linear(d_input*n_look_back, args.n_predicted_month)

        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
        
        self.loss_fn = nn.MSELoss()
        
    
    def forward(self, X_batch, y_batch=None):
        X_batch = self.pe(X_batch)
        X_batch = self.transformer_encoder(X_batch)
        X_batch = X_batch.view(X_batch.size(0), -1)
        
        y_predicted = self.decoder(X_batch)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
        else:
            return y_predicted
        return X_batch
    
    def predict(self, X):
        with torch.no_grad():
            X = torch.tensor(X, device=args.device)
        return self.forward(X).squeeze()

# Create class to train and evaluate models
class Trainer():
    def __init__(self, city, model_type, learning_rate, important_features, train_loader, test_tensor, n_layers=2, hidden_size=128, num_filters=[100, 100, 100], dropout=0.01):
        """
        Initialise trainer, allowing input of LSTM, LSTM-ATT, or CNN 
        hyperparameters. Adam optimiser used for all models.
        """
        self.model_type = model_type    
        self.city = city    
        self.model = self.init_model(model_type, n_layers, hidden_size, num_filters, dropout, city)
        self.model.double().to(args.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.important_features, self.train_loader, self.test_tensor = important_features, train_loader, test_tensor
    
    def init_model(self, model_type, n_layers, hidden_size, num_filters, dropout, city):        
        #Get hyper param by name and set for n_layers, hidden_size, num_filters, dropout and overwrite the input param  
        # n_layers, hidden_size,num_filters, dropout= get_opt_param_by_name( algo = model_type, city = city)
    
        """Initialise a model based on whether LSTM, LSTM-ATT, or CNN is chosen."""
        if model_type.lower() == 'lstm':
            model = MultiVariateLSTM(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'lstm_attention':
            model = MultiVariateLSTM_Attention(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'cnn':
            model = MultivariateCNN(num_filters, dropout)
        elif model_type.lower() == 'transformers':
            model = TransformerModel(d_input=args.n_features, n_look_back=args.look_back, hidden_size=hidden_size, n_layers=n_layers, dropout=dropout)
        return model

    def step(self, batch):
        self.model.train()
        X_batch, y_batch = tuple(t.to(args.device) for t in batch)
        self.optimizer.zero_grad()
        y_pred, loss = self.model.forward(X_batch, y_batch)
        loss.backward()
        self.optimizer.step()
        return loss.mean().item()

    def validation(self):
        self.model.eval()
        eval_loss = 0.0

        result = {}

        y_true = np.array([])
        y_pred = np.array([])

        X_batch, y_batch = tuple(t.to(args.device) for t in self.test_tensor)
        with torch.no_grad():
            outputs, loss = self.model.forward(X_batch, y_batch)
            eval_loss = loss.mean().item()

        return eval_loss

    def train(self, epochs=20):
        # print('param of model')
        # print('hidensize',self.model.hidden_size)
        # print('nlayer',self.model.n_layers)  
        best_lost = float("inf")
        best_model = None
        for epoch in range(epochs):
            total_loss = 0.0
            for batch in self.train_loader:
                loss = self.step(batch)
                total_loss += loss
            train_loss = total_loss/len(self.train_loader)
            eval_loss = self.validation()
            if eval_loss < best_lost:
                best_lost = eval_loss
                best_model = copy.deepcopy(self.model)
            if (epoch + 1) == epochs or (epoch + 1) in [c + 1 for c in range(epochs) if c % int(epochs/4) == 0]:
                print(f"Epoch: {epoch:2}/{epochs:2} - train_loss: {train_loss:.4f} - test_loss: {eval_loss:4f}")
        self.model = best_model
        self.model.eval()
        return None



    # Lưu model vào trong thư mục models
    def save_model_to(self, path = '', city =''):       
        torch.save(self.model, path)

    def load_model_to(self, path = ''):       
        return torch.load(path)

    def evaluate_model(self, np_data=None, plot=True, scaled=True, city=None, k_steps=None, y_scaler =None):
        assert scaled, "data must be scaled"
        self.model.eval()
        tensor_data = torch.from_numpy(np_data)
        rmse_list = []
        mae_list = [] 
        mape_list = []

        y_predicted_list = []
        y_true_list = []

        for k_steps in range(1, args.n_predicted_month + 1):
            y_predicted = []
            y_true = []
            for index in range(tensor_data.size(0) - args.look_back):
                X = tensor_data[index: index + args.look_back, self.important_features]
                # yhat = self.model.predict(X.unsqueeze(0)).squeeze()

                yhat = self.model.predict(X.unsqueeze(0))
                yhat = yhat.squeeze()

                y_predicted.append(yhat.detach().cpu().numpy()[k_steps - 1])
                y_true.append(tensor_data[index + args.look_back, -1].detach().cpu().numpy())

            y_predicted = y_scaler.inverse_transform(np.array(y_predicted).reshape(-1, 1)).reshape(-1, )
            y_true = y_scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).reshape(-1, )

            

            rmse = mean_squared_error(y_true, y_predicted, squared=False)
            mae = mean_absolute_error(y_true, y_predicted)
            mape = mean_absolute_percentage_error(y_true, y_predicted)

            rmse_list.append(rmse)
            mae_list.append(mae)
            mape_list.append(mape)

            print('City: '+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))          
            if plot==True:
              plt.grid(True)
              plt.plot(y_predicted, label='predicted')
              plt.plot(y_true, label='actual')
              plt.title(f"k-steps = {k_steps} - city: "+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))
              plt.legend()
              plt.show()

              plt.show()
            y_predicted_list.append(y_predicted)
            y_true_list.append(y_true)

        return y_true_list, y_predicted_list, rmse_list, mae_list, mape_list

# %% [markdown]
# # Get optimized Hyper param

# %%
def convert_str_num_filter_array(str_filter = ''):  
  arr_filter = str_filter.split(',')  
  int_arr_filter= [int(x) for x in arr_filter]
  return int_arr_filter


opt_param_cnn = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_cnn.xlsx', index_col = 'City')
opt_param_lstm = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm.xlsx', index_col = 'City')
opt_param_lstm_att = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm_att.xlsx', index_col = 'City')
opt_param_transformer = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_transformer.xlsx', index_col = 'City')

def get_opt_param_by_name(algo = 'transformers', city = None):
  if algo == 'cnn':
    city_param = opt_param_cnn.loc[city]
    #load  param
    n_layers = ''
    hidden_size = ''
    num_filters = convert_str_num_filter_array(city_param['Num. filters'])
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm':
    city_param = opt_param_lstm.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm_attention':
    city_param = opt_param_lstm_att.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'transformers':
    city_param = opt_param_transformer.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hidden Size'])
    num_filters = ''
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  return n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window


# Manual Check param before train
n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window= get_opt_param_by_name(algo='transformers', city='Cao Bằng')
lookback_window,epoch, hidden_size, n_layers,learning_rate, num_filters, dropout
# Out:
# (3, 270, 36, 6, 0.001205121044593835, '', 0.4761287407623291)

# %% [markdown]
# # Create Cross validation Train/Test set

# %%
# tạo l_train_indices\l_test_indices
data = list(range(212))
min_train_size = 72 # Chiều dài ban đầu train size = 6 năm = 72
test_size = 36 # chiều dài test size 36 tháng
l_train_indices= []
l_test_indices = []
for i in range(min_train_size, len(data)-test_size+1):
    train = np.array(data[0:i])
    test = np.array(data[i:i+test_size])    
    l_train_indices.append(train)
    l_test_indices.append(test)

len(l_test_indices)
# Out:
# 105

# %% [markdown]
# # Function Tạo và Predict. Important (epoch = 1 for test)

# %%
def do_train_predict(city ='', algo = '', list_selected_features = '', origin_city_meta_test_set= '', y_scaler = '', s_selected_features= '', train ='', test ='', sample_idx ='', combination_idx= ''):
    
    metric_reslt = pd.DataFrame()
    n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = algo, city = city)
    # Get data to run model
    important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   

#     epoch = 1 # comment when do experiment
    
    if( algo =='cnn'): 
        algo = 'CNN'    # upper case only
        trainer = Trainer(
                            model_type='cnn',  
                            city = city,                    
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            num_filters= num_filters, 
                            dropout=dropout )

    if( algo =='lstm'):
        algo = 'LSTM'    # upper case only        
        trainer = Trainer(
                            model_type='lstm', 
                            city = city,
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size)

    if( algo =='lstm_attention'): 
        algo = 'LSTM ATT'    # upper case only       
        trainer = Trainer(
                            model_type= 'lstm_attention',
                            city = city,
                            learning_rate= learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers= n_layers,
                            hidden_size=hidden_size )

    if( algo =='transformers'): 
        algo = 'TF'    # upper case only       
        trainer = Trainer(
                            model_type='transformers',
                            city = city, 
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size,
                            dropout=dropout)

    
    # Train model with province-specific epochs
    trainer.train(epochs=epoch)  
    # Evaluate test set   
    y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
        
    metric_reslt = pd.DataFrame({
                                'City': city,
                                'Meta_Model_Name': algo, 
                                'sample_index':sample_idx,
                                'Based_Models': s_selected_features,                                                      
                                # algo+'_'+str(combination_idx)+'_rmse': rmse_list[0],
                                # algo+'_'+str(combination_idx)+'_mae': mae_list[0]
                                algo+'*'+s_selected_features+'_rmse': rmse_list[0],
                                algo+'*'+s_selected_features+'_mae': mae_list[0]
                                }, index=[0]) # do có 1 dòng nên pandas cần index = 0    
  

        
    return metric_reslt

# %% [markdown]
# # Main Cross Validation Metrics Creation
# Tạo ra 105 bộ validation. Xuất ra Metrics (RMSE và MAE) cho 5 bộ giải thuật chọn lựa. (10 cột cho 1 dòng validation )

# %%
dt_started = datetime.now()

l_errCity = {} # có lỗi sẽ lưu vào đây, kiểm tra ngay cell sau

dict_comb_result = {}
df_all_combs_result_all = pd.DataFrame() # Lưu tất cả các loại combination
df_all_combs_2_result_all = pd.DataFrame()
df_all_combs_3_result_all = pd.DataFrame()
df_all_combs_4_result_all = pd.DataFrame()


dict_comb_metrics_result = {}
df_all_combs_metrics_result_all = pd.DataFrame() # Lưu tất cả các loại combination
df_all_combs_2_metrics_result_all = pd.DataFrame()
df_all_combs_3_metrics_result_all = pd.DataFrame()
df_all_combs_4_metrics_result_all = pd.DataFrame()

# Với mỗi thành phố, loop qua từng bộ tr/validation, cho train/predict N tổ hợp models
for city in cities:
  pd_all_rows_new_meta_data = pd.DataFrame()

  for sample_index in  range(0,len(l_train_indices)):

    pd_one_row_new_meta_data = pd.DataFrame()
    combination_idx = 0
    for combination_features in combs_features:            
      list_selected_features = [x for x in combination_features] +['Observed'] # Lấy danh sách tên các features + cột Observed 
      s_selected_features = '-'.join([str(elem) for elem in list_selected_features])      

      # Có trong danh sách chọn lựa thì thực hiện dự đoán
      if((is_in_Selected_combination('CNN*'+s_selected_features)==True) or (is_in_Selected_combination('LSTM*'+s_selected_features) == True)):        
        args.n_features = len(list_selected_features) 
        args.look_back = meta_lookback_window  
        cnn_metrics = pd.DataFrame()
        lstm_metrics = pd.DataFrame()

        try:
          # Lấy data từ train set và chia ra theo valiation
          origin_city_meta_train_set = meta_train_set_city[city]
          origin_city_meta_test_set = meta_test_set_city[city]
          
          train = origin_city_meta_train_set.iloc[l_train_indices[sample_index]]
          test = origin_city_meta_train_set.iloc[l_test_indices[sample_index]]        

          # Data train/test processing for all Meta model
          train = train.astype(float)
          test = test.astype(float)

          train = train.replace((np.inf, -np.inf, np.nan), 0)
          test = test.replace((np.inf, -np.inf, np.nan), 0) 
        
          # Đoạn này impute các trường hợp rỗng
          train = impute_missing_value(train)
          test = impute_missing_value(test)

          # Fit data scaler to training data
          full_scaler = MinMaxScaler().fit(train)
          y_scaler = MinMaxScaler().fit(train.values[:, -1].reshape(-1, 1))

          # Scale train and test data
          train = full_scaler.transform(train)
          test = full_scaler.transform(test)

          if(is_in_Selected_combination('CNN*'+s_selected_features)==True):
            ########################################
            ########## CNN 
            ########################################
            cnn_metrics = do_train_predict(city =city, algo='cnn', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)

          if(is_in_Selected_combination('LSTM*'+s_selected_features)==True):
            ########################################
            ########## LSTM 
            ########################################
            lstm_metrics = do_train_predict(city =city, algo='lstm', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)
          

          
          
          ###############################   
          ## Khúc này rất thủ công
          if(cnn_metrics.empty==False and lstm_metrics.empty ==False):              
            join_2_results = pd.concat([cnn_metrics.iloc[:, [4, 5]], lstm_metrics.iloc[:, [4, 5]]], axis=1)
          
          if(cnn_metrics.empty== False and lstm_metrics.empty ==True):
            join_2_results = cnn_metrics.iloc[:, [4, 5]]
          
          if(cnn_metrics.empty== True and lstm_metrics.empty ==False):
            join_2_results = lstm_metrics.iloc[:, [4, 5]]

          if(pd_one_row_new_meta_data.empty):
            pd_one_row_new_meta_data = join_2_results
          else:
            pd_one_row_new_meta_data = pd.concat([join_2_results, pd_one_row_new_meta_data], axis=1)       

          combination_idx = combination_idx + 1
        except Exception as e:
          l_errCity[city] = e
          break    

        
    # Hết vòng lập pd_one_row_new_meta_data chứa 5 bộ kết quả của 1 sameple    
    # Qua sample kế tiếp   
    pd_all_rows_new_meta_data = pd.concat([pd_all_rows_new_meta_data, pd_one_row_new_meta_data], axis=0) 

  
  # Kết thúc hết tất cả validation -> Lưu kết quả cuối cùng ứng với từng thành phố
  pd_all_rows_new_meta_data.to_excel(com_path_validation_metrics + "/" + city+'_5_comb_cv_metrics.xlsx')
  
  # send_to_telegram('Server Chạy city: '+ city)

dt_ended = datetime.now()
run_time = round((dt_ended - dt_started).total_seconds()/60)
print('kết thúc train trong:', run_time)
print ('danh sách error city: ')
print(l_errCity)
# Out:
# Epoch:  0/340 - train_loss: 0.7522 - test_loss: 0.711480
# Epoch: 85/340 - train_loss: 0.3737 - test_loss: 0.269616
# Epoch: 170/340 - train_loss: 0.2117 - test_loss: 0.117768
# Epoch: 255/340 - train_loss: 0.2050 - test_loss: 0.098690
# Epoch: 339/340 - train_loss: 0.2046 - test_loss: 0.094036
# City: Đà Nẵng  _algo:lstm  -RMSE: 30.028620270541115
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.770983733405824
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.28363852600403
# Epoch:  0/340 - train_loss: 0.8067 - test_loss: 0.728346
# Epoch: 85/340 - train_loss: 0.3195 - test_loss: 0.267564
# Epoch: 170/340 - train_loss: 0.2149 - test_loss: 0.119190
# Epoch: 255/340 - train_loss: 0.2053 - test_loss: 0.097606
# Epoch: 339/340 - train_loss: 0.2057 - test_loss: 0.100679
# City: Đà Nẵng  _algo:lstm  -RMSE: 28.819870482012927
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.81697042670005
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.446798370802373
# Epoch:  0/200 - train_loss: 0.8172 - test_loss: 0.648387
# Epoch: 50/200 - train_loss: 0.2154 - test_loss: 0.116127
# Epoch: 100/200 - train_loss: 0.2077 - test_loss: 0.097500
# Epoch: 150/200 - train_loss: 0.2299 - test_loss: 0.095111
# Epoch: 199/200 - train_loss: 0.2134 - test_loss: 0.112497
# City: Đà Nẵng  _algo:cnn  -RMSE: 27.311666286464586
# City: Đà Nẵng  _algo:cnn  -RMSE: 28.371847966559386
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.173939031270024
# Epoch:  0/340 - train_loss: 0.7449 - test_loss: 0.712324
# Epoch: 85/340 - train_loss: 0.3915 - test_loss: 0.271964
# Epoch: 170/340 - train_loss: 0.4110 - test_loss: 0.120156
# Epoch: 255/340 - train_loss: 0.2230 - test_loss: 0.096410
# Epoch: 339/340 - train_loss: 0.2423 - test_loss: 0.097175
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.482251884251227
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.91483095766777
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.70741310396957
# Epoch:  0/340 - train_loss: 0.7788 - test_loss: 0.743823
# Epoch: 85/340 - train_loss: 0.3733 - test_loss: 0.269920
# Epoch: 170/340 - train_loss: 0.2143 - test_loss: 0.123150
# Epoch: 255/340 - train_loss: 0.2072 - test_loss: 0.100886
# Epoch: 339/340 - train_loss: 0.2048 - test_loss: 0.095165
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.824799365718164
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.081806742708338
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.303389811605985
# Epoch:  0/340 - train_loss: 0.8781 - test_loss: 0.801792
# Epoch: 85/340 - train_loss: 0.3139 - test_loss: 0.259666
# Epoch: 170/340 - train_loss: 0.2128 - test_loss: 0.119415
# Epoch: 255/340 - train_loss: 0.2066 - test_loss: 0.093215
# Epoch: 339/340 - train_loss: 0.2307 - test_loss: 0.095639
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.04894897428683
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.365451142531963
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.043258746932874
# Epoch:  0/340 - train_loss: 0.7702 - test_loss: 0.736885
# Epoch: 85/340 - train_loss: 0.3634 - test_loss: 0.269289
# Epoch: 170/340 - train_loss: 0.2146 - test_loss: 0.117249
# Epoch: 255/340 - train_loss: 0.2858 - test_loss: 0.092909
# Epoch: 339/340 - train_loss: 0.2063 - test_loss: 0.095120
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.103806009109984
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.130615729739866
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.10305976056239
# Epoch:  0/200 - train_loss: 0.8732 - test_loss: 0.648422
# Epoch: 50/200 - train_loss: 0.2296 - test_loss: 0.094127
# Epoch: 100/200 - train_loss: 0.2058 - test_loss: 0.099553
# Epoch: 150/200 - train_loss: 0.2188 - test_loss: 0.098464
# Epoch: 199/200 - train_loss: 0.2053 - test_loss: 0.098635
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.052463454238755
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.29505102066276
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.32709895897026
# Epoch:  0/340 - train_loss: 0.8374 - test_loss: 0.776773
# Epoch: 85/340 - train_loss: 0.3275 - test_loss: 0.262170
# Epoch: 170/340 - train_loss: 0.2484 - test_loss: 0.115573
# Epoch: 255/340 - train_loss: 0.2834 - test_loss: 0.100057
# Epoch: 339/340 - train_loss: 0.2308 - test_loss: 0.095711
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.243753308824417
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.421784515980114
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.40371860326966
# Epoch:  0/340 - train_loss: 0.7826 - test_loss: 0.751547
# Epoch: 85/340 - train_loss: 0.3193 - test_loss: 0.267179
# Epoch: 170/340 - train_loss: 0.2231 - test_loss: 0.121784
# Epoch: 255/340 - train_loss: 0.2064 - test_loss: 0.100972
# Epoch: 339/340 - train_loss: 0.2060 - test_loss: 0.096637
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.80321840103253
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.612906742000803
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.820030846612095
# Epoch:  0/340 - train_loss: 0.8050 - test_loss: 0.752811
# Epoch: 85/340 - train_loss: 0.3189 - test_loss: 0.265983
# Epoch: 170/340 - train_loss: 0.2127 - test_loss: 0.116470
# Epoch: 255/340 - train_loss: 0.2072 - test_loss: 0.100210
# Epoch: 339/340 - train_loss: 0.2072 - test_loss: 0.097725
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.34129481161953
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.33698715822856
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.93797622782939
# Epoch:  0/340 - train_loss: 0.8891 - test_loss: 0.832032
# Epoch: 85/340 - train_loss: 0.3220 - test_loss: 0.259512
# Epoch: 170/340 - train_loss: 0.2138 - test_loss: 0.117514
# Epoch: 255/340 - train_loss: 0.2054 - test_loss: 0.094335
# Epoch: 339/340 - train_loss: 0.2170 - test_loss: 0.106900
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.919094786782196
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.102125062920024
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.88119526501008
# Epoch:  0/200 - train_loss: 0.8874 - test_loss: 0.645198
# Epoch: 50/200 - train_loss: 0.2078 - test_loss: 0.098438
# Epoch: 100/200 - train_loss: 0.2650 - test_loss: 0.092617
# Epoch: 150/200 - train_loss: 0.2068 - test_loss: 0.101475
# Epoch: 199/200 - train_loss: 0.2449 - test_loss: 0.090267
# City: Đà Nẵng  _algo:cnn  -RMSE: 30.991865531375208
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.012648333052
# City: Đà Nẵng  _algo:cnn  -RMSE: 30.80129167215185
# Epoch:  0/340 - train_loss: 0.7795 - test_loss: 0.738433
# Epoch: 85/340 - train_loss: 0.3212 - test_loss: 0.267445
# Epoch: 170/340 - train_loss: 0.2119 - test_loss: 0.115309
# Epoch: 255/340 - train_loss: 0.2049 - test_loss: 0.094698
# Epoch: 339/340 - train_loss: 0.2645 - test_loss: 0.093059
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.614404356166833
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.67182353919275
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.297897751279194
# Epoch:  0/340 - train_loss: 0.7640 - test_loss: 0.712068
# Epoch: 85/340 - train_loss: 0.3477 - test_loss: 0.268264
# Epoch: 170/340 - train_loss: 0.2616 - test_loss: 0.118835
# Epoch: 255/340 - train_loss: 0.2059 - test_loss: 0.097333
# Epoch: 339/340 - train_loss: 0.2651 - test_loss: 0.092260
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.773450978049
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.059878722534272
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.453718327406122
# Epoch:  0/340 - train_loss: 0.8120 - test_loss: 0.772685
# Epoch: 85/340 - train_loss: 0.3176 - test_loss: 0.264440
# Epoch: 170/340 - train_loss: 0.2201 - test_loss: 0.116772
# Epoch: 255/340 - train_loss: 0.2205 - test_loss: 0.097305
# Epoch: 339/340 - train_loss: 0.2485 - test_loss: 0.095603
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.72268950754788
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.569218482719855
# City: Đà Nẵng  _algo:lstm  -RMSE: 30.38907606038101
# Epoch:  0/340 - train_loss: 0.8074 - test_loss: 0.759404
# Epoch: 85/340 - train_loss: 0.3175 - test_loss: 0.264217
# Epoch: 170/340 - train_loss: 0.2170 - test_loss: 0.116296
# Epoch: 255/340 - train_loss: 0.2121 - test_loss: 0.095798
# Epoch: 339/340 - train_loss: 0.2168 - test_loss: 0.094204
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.34884555101263
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.78380459581881
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.391045375159813
# Epoch:  0/200 - train_loss: 0.7928 - test_loss: 0.674546
# Epoch: 50/200 - train_loss: 0.2250 - test_loss: 0.093600
# Epoch: 100/200 - train_loss: 0.2178 - test_loss: 0.092056
# Epoch: 150/200 - train_loss: 0.2201 - test_loss: 0.096048
# Epoch: 199/200 - train_loss: 0.2051 - test_loss: 0.092060
# City: Đà Nẵng  _algo:cnn  -RMSE: 31.100827725342434
# City: Đà Nẵng  _algo:cnn  -RMSE: 31.164263246144316
# City: Đà Nẵng  _algo:cnn  -RMSE: 27.90399473313896
# Epoch:  0/340 - train_loss: 0.7349 - test_loss: 0.691054
# Epoch: 85/340 - train_loss: 0.3222 - test_loss: 0.270047
# Epoch: 170/340 - train_loss: 0.2575 - test_loss: 0.117675
# Epoch: 255/340 - train_loss: 0.2065 - test_loss: 0.098347
# Epoch: 339/340 - train_loss: 0.2260 - test_loss: 0.095916
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.248928046428983
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.188522347107988
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.985497025006516
# Epoch:  0/340 - train_loss: 0.7380 - test_loss: 0.703095
# Epoch: 85/340 - train_loss: 0.3285 - test_loss: 0.269367
# Epoch: 170/340 - train_loss: 0.2310 - test_loss: 0.118615
# Epoch: 255/340 - train_loss: 0.2061 - test_loss: 0.094420
# Epoch: 339/340 - train_loss: 0.2505 - test_loss: 0.093517
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.61501944808593
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.947756223971
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.89383865245403
# Epoch:  0/340 - train_loss: 0.7663 - test_loss: 0.730125
# Epoch: 85/340 - train_loss: 0.3236 - test_loss: 0.267481
# Epoch: 170/340 - train_loss: 0.2127 - test_loss: 0.117300
# Epoch: 255/340 - train_loss: 0.2086 - test_loss: 0.098996
# Epoch: 339/340 - train_loss: 0.2355 - test_loss: 0.100205
# City: Đà Nẵng  _algo:lstm  -RMSE: 38.67517869661905
# City: Đà Nẵng  _algo:lstm  -RMSE: 35.50212099292131
# City: Đà Nẵng  _algo:lstm  -RMSE: 32.15486592112552
# Epoch:  0/340 - train_loss: 0.7522 - test_loss: 0.712374
# Epoch: 85/340 - train_loss: 0.3234 - test_loss: 0.268958
# Epoch: 170/340 - train_loss: 0.2136 - test_loss: 0.117478
# Epoch: 255/340 - train_loss: 0.2175 - test_loss: 0.096977
# Epoch: 339/340 - train_loss: 0.2175 - test_loss: 0.095433
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.57025937034716
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.30935844797315
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.114831868340836
# Epoch:  0/200 - train_loss: 0.8479 - test_loss: 0.653839
# Epoch: 50/200 - train_loss: 0.2177 - test_loss: 0.093029
# Epoch: 100/200 - train_loss: 0.2386 - test_loss: 0.092341
# Epoch: 150/200 - train_loss: 0.2146 - test_loss: 0.091997
# Epoch: 199/200 - train_loss: 0.2043 - test_loss: 0.094220
# City: Đà Nẵng  _algo:cnn  -RMSE: 21.134437637111514
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.5052842990445
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.02471049006692
# Epoch:  0/340 - train_loss: 0.8191 - test_loss: 0.765385
# Epoch: 85/340 - train_loss: 0.3174 - test_loss: 0.263845
# Epoch: 170/340 - train_loss: 0.2122 - test_loss: 0.116825
# Epoch: 255/340 - train_loss: 0.2059 - test_loss: 0.095474
# Epoch: 339/340 - train_loss: 0.2126 - test_loss: 0.090974
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.976823033173325
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.949652481922527
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.022882619118295
# Epoch:  0/340 - train_loss: 0.7443 - test_loss: 0.699623
# Epoch: 85/340 - train_loss: 0.3451 - test_loss: 0.268611
# Epoch: 170/340 - train_loss: 0.2416 - test_loss: 0.116506
# Epoch: 255/340 - train_loss: 0.2113 - test_loss: 0.097370
# Epoch: 339/340 - train_loss: 0.2468 - test_loss: 0.094386
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.22258137740275
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.875489476724617
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.06890037500398
# Epoch:  0/340 - train_loss: 0.7308 - test_loss: 0.700284
# Epoch: 85/340 - train_loss: 0.3346 - test_loss: 0.269827
# Epoch: 170/340 - train_loss: 0.2161 - test_loss: 0.116866
# Epoch: 255/340 - train_loss: 0.2646 - test_loss: 0.093914
# Epoch: 339/340 - train_loss: 0.2205 - test_loss: 0.092209
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.263187231304745
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.094935090111377
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.449300515315816
# Epoch:  0/340 - train_loss: 0.7877 - test_loss: 0.739352
# Epoch: 85/340 - train_loss: 0.3199 - test_loss: 0.266860
# Epoch: 170/340 - train_loss: 0.2162 - test_loss: 0.115487
# Epoch: 255/340 - train_loss: 0.2282 - test_loss: 0.102717
# Epoch: 339/340 - train_loss: 0.2256 - test_loss: 0.104540
# City: Đà Nẵng  _algo:lstm  -RMSE: 41.128194540915196
# City: Đà Nẵng  _algo:lstm  -RMSE: 38.859694022585344
# City: Đà Nẵng  _algo:lstm  -RMSE: 37.26746266846853
# Epoch:  0/200 - train_loss: 0.8997 - test_loss: 0.669720
# Epoch: 50/200 - train_loss: 0.2712 - test_loss: 0.089978
# Epoch: 100/200 - train_loss: 0.2576 - test_loss: 0.095911
# Epoch: 150/200 - train_loss: 0.2028 - test_loss: 0.089884
# Epoch: 199/200 - train_loss: 0.2006 - test_loss: 0.092242
# City: Đà Nẵng  _algo:cnn  -RMSE: 30.579675277208445
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.20082268723268
# City: Đà Nẵng  _algo:cnn  -RMSE: 29.75435769917286
# Epoch:  0/340 - train_loss: 0.7876 - test_loss: 0.746251
# Epoch: 85/340 - train_loss: 0.3193 - test_loss: 0.265944
# Epoch: 170/340 - train_loss: 0.2116 - test_loss: 0.115420
# Epoch: 255/340 - train_loss: 0.2061 - test_loss: 0.094866
# Epoch: 339/340 - train_loss: 0.2061 - test_loss: 0.093995
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.652782405148507
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.01557528204917
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.4409725188749
# Epoch:  0/340 - train_loss: 0.7447 - test_loss: 0.713513
# Epoch: 85/340 - train_loss: 0.3283 - test_loss: 0.268710
# Epoch: 170/340 - train_loss: 0.2649 - test_loss: 0.116933
# Epoch: 255/340 - train_loss: 0.2326 - test_loss: 0.093003
# Epoch: 339/340 - train_loss: 0.2072 - test_loss: 0.091174
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.97947205559689
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.289946989956974
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.81745702314995
# Epoch:  0/340 - train_loss: 0.7729 - test_loss: 0.736301
# Epoch: 85/340 - train_loss: 0.3299 - test_loss: 0.266891
# Epoch: 170/340 - train_loss: 0.2178 - test_loss: 0.116003
# Epoch: 255/340 - train_loss: 0.2059 - test_loss: 0.093841
# Epoch: 339/340 - train_loss: 0.2266 - test_loss: 0.091688
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.80739014157418
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.68479550029181
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.595643417950534
# Epoch:  0/340 - train_loss: 0.7766 - test_loss: 0.745760
# Epoch: 85/340 - train_loss: 0.3223 - test_loss: 0.265730
# Epoch: 170/340 - train_loss: 0.2157 - test_loss: 0.115516
# Epoch: 255/340 - train_loss: 0.2405 - test_loss: 0.092643
# Epoch: 339/340 - train_loss: 0.2059 - test_loss: 0.090409
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.306850199667153
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.590183502780015
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.519427297153097
# Epoch:  0/200 - train_loss: 0.9238 - test_loss: 0.646876
# Epoch: 50/200 - train_loss: 0.2081 - test_loss: 0.091892
# Epoch: 100/200 - train_loss: 0.2051 - test_loss: 0.093029
# Epoch: 150/200 - train_loss: 0.2056 - test_loss: 0.093920
# Epoch: 199/200 - train_loss: 0.2073 - test_loss: 0.101276
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.432595378561906
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.99163939720472
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.529683756729778
# Epoch:  0/340 - train_loss: 0.7401 - test_loss: 0.707668
# Epoch: 85/340 - train_loss: 0.3229 - test_loss: 0.268449
# Epoch: 170/340 - train_loss: 0.2149 - test_loss: 0.116028
# Epoch: 255/340 - train_loss: 0.2058 - test_loss: 0.093375
# Epoch: 339/340 - train_loss: 0.2089 - test_loss: 0.093143
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.416961462162014
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.841997522944705
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.398687762775435
# Epoch:  0/340 - train_loss: 0.7697 - test_loss: 0.738944
# Epoch: 85/340 - train_loss: 0.3199 - test_loss: 0.266701
# Epoch: 170/340 - train_loss: 0.2214 - test_loss: 0.115707
# Epoch: 255/340 - train_loss: 0.2269 - test_loss: 0.092922
# Epoch: 339/340 - train_loss: 0.2126 - test_loss: 0.092308
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.349644822270196
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.021958960391522
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.905555035337773
# Epoch:  0/340 - train_loss: 0.7400 - test_loss: 0.710357
# Epoch: 85/340 - train_loss: 0.3401 - test_loss: 0.268273
# Epoch: 170/340 - train_loss: 0.2239 - test_loss: 0.115681
# Epoch: 255/340 - train_loss: 0.2059 - test_loss: 0.093414
# Epoch: 339/340 - train_loss: 0.2221 - test_loss: 0.092177
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.545385485523525
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.42766259362436
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.411409150748533
# Epoch:  0/340 - train_loss: 0.7606 - test_loss: 0.727870
# Epoch: 85/340 - train_loss: 0.3330 - test_loss: 0.267023
# Epoch: 170/340 - train_loss: 0.2259 - test_loss: 0.115855
# Epoch: 255/340 - train_loss: 0.2057 - test_loss: 0.093599
# Epoch: 339/340 - train_loss: 0.2058 - test_loss: 0.092378
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.43068799819178
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.154023726044215
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.509001221811154
# Epoch:  0/200 - train_loss: 0.8915 - test_loss: 0.669982
# Epoch: 50/200 - train_loss: 0.2061 - test_loss: 0.092394
# Epoch: 100/200 - train_loss: 0.2199 - test_loss: 0.089186
# Epoch: 150/200 - train_loss: 0.2096 - test_loss: 0.093420
# Epoch: 199/200 - train_loss: 0.2019 - test_loss: 0.088064
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.644665832999426
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.863696925647666
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.535748523326276
# Epoch:  0/340 - train_loss: 0.7782 - test_loss: 0.735810
# Epoch: 85/340 - train_loss: 0.3239 - test_loss: 0.266749
# Epoch: 170/340 - train_loss: 0.2251 - test_loss: 0.114329
# Epoch: 255/340 - train_loss: 0.2060 - test_loss: 0.092641
# Epoch: 339/340 - train_loss: 0.2064 - test_loss: 0.092437
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.514105401595156
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.52669639615904
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.38544492746731
# Epoch:  0/340 - train_loss: 0.8017 - test_loss: 0.757256
# Epoch: 85/340 - train_loss: 0.3342 - test_loss: 0.264881
# Epoch: 170/340 - train_loss: 0.2122 - test_loss: 0.115207
# Epoch: 255/340 - train_loss: 0.2111 - test_loss: 0.092541
# Epoch: 339/340 - train_loss: 0.2110 - test_loss: 0.090866
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.86975866894437
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.550301315041832
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.198912680971585
# Epoch:  0/340 - train_loss: 0.7889 - test_loss: 0.758111
# Epoch: 85/340 - train_loss: 0.3194 - test_loss: 0.265176
# Epoch: 170/340 - train_loss: 0.2168 - test_loss: 0.113635
# Epoch: 255/340 - train_loss: 0.2101 - test_loss: 0.091430
# Epoch: 339/340 - train_loss: 0.2057 - test_loss: 0.090603
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.99398885869854
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.990573490486966
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.086043526602552
# Epoch:  0/340 - train_loss: 0.7387 - test_loss: 0.702323
# Epoch: 85/340 - train_loss: 0.3348 - test_loss: 0.268513
# Epoch: 170/340 - train_loss: 0.2253 - test_loss: 0.115837
# Epoch: 255/340 - train_loss: 0.2304 - test_loss: 0.092526
# Epoch: 339/340 - train_loss: 0.2330 - test_loss: 0.090128
# City: Đà Nẵng  _algo:lstm  -RMSE: 28.426204445413372
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.098982049334722
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.066910747939566
# Epoch:  0/200 - train_loss: 0.7959 - test_loss: 0.678259
# Epoch: 50/200 - train_loss: 0.2182 - test_loss: 0.090864
# Epoch: 100/200 - train_loss: 0.2116 - test_loss: 0.087381
# Epoch: 150/200 - train_loss: 0.2175 - test_loss: 0.091884
# Epoch: 199/200 - train_loss: 0.2303 - test_loss: 0.091170
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.782443832110506
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.02613847077043
# City: Đà Nẵng  _algo:cnn  -RMSE: 21.76714946558481
# Epoch:  0/340 - train_loss: 0.8205 - test_loss: 0.772682
# Epoch: 85/340 - train_loss: 0.3165 - test_loss: 0.262817
# Epoch: 170/340 - train_loss: 0.2144 - test_loss: 0.113591
# Epoch: 255/340 - train_loss: 0.2302 - test_loss: 0.093233
# Epoch: 339/340 - train_loss: 0.2222 - test_loss: 0.089844
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.208079212388082
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.056149748854665
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.659991751998508
# Epoch:  0/340 - train_loss: 0.8168 - test_loss: 0.771459
# Epoch: 85/340 - train_loss: 0.3305 - test_loss: 0.262777
# Epoch: 170/340 - train_loss: 0.2110 - test_loss: 0.114015
# Epoch: 255/340 - train_loss: 0.2180 - test_loss: 0.091582
# Epoch: 339/340 - train_loss: 0.2146 - test_loss: 0.094929
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.90643200774063
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.21649673167771
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.518662300117395
# Epoch:  0/340 - train_loss: 0.7489 - test_loss: 0.709471
# Epoch: 85/340 - train_loss: 0.3212 - test_loss: 0.267952
# Epoch: 170/340 - train_loss: 0.2113 - test_loss: 0.114271
# Epoch: 255/340 - train_loss: 0.2058 - test_loss: 0.090850
# Epoch: 339/340 - train_loss: 0.2056 - test_loss: 0.089929
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.593193631949152
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.59037099570181
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.567238217615984
# Epoch:  0/340 - train_loss: 0.7514 - test_loss: 0.715997
# Epoch: 85/340 - train_loss: 0.3252 - test_loss: 0.267864
# Epoch: 170/340 - train_loss: 0.2207 - test_loss: 0.114552
# Epoch: 255/340 - train_loss: 0.2069 - test_loss: 0.092199
# Epoch: 339/340 - train_loss: 0.2053 - test_loss: 0.089149
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.22165759633448
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.799587704549275
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.225407546447787
# Epoch:  0/200 - train_loss: 0.8787 - test_loss: 0.644143
# Epoch: 50/200 - train_loss: 0.2128 - test_loss: 0.087432
# Epoch: 100/200 - train_loss: 0.2170 - test_loss: 0.088610
# Epoch: 150/200 - train_loss: 0.2067 - test_loss: 0.090546
# Epoch: 199/200 - train_loss: 0.2150 - test_loss: 0.089155
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.26908467933211
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.74477150987746
# City: Đà Nẵng  _algo:cnn  -RMSE: 21.923297022337373
# Epoch:  0/340 - train_loss: 0.7558 - test_loss: 0.719744
# Epoch: 85/340 - train_loss: 0.3260 - test_loss: 0.266898
# Epoch: 170/340 - train_loss: 0.2115 - test_loss: 0.114551
# Epoch: 255/340 - train_loss: 0.2158 - test_loss: 0.091102
# Epoch: 339/340 - train_loss: 0.2147 - test_loss: 0.089230
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.424961598007553
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.707488547181534
# City: Đà Nẵng  _algo:lstm  -RMSE: 28.24682059892352
# Epoch:  0/340 - train_loss: 0.7664 - test_loss: 0.730180
# Epoch: 85/340 - train_loss: 0.3245 - test_loss: 0.266217
# Epoch: 170/340 - train_loss: 0.2115 - test_loss: 0.114346
# Epoch: 255/340 - train_loss: 0.2104 - test_loss: 0.090930
# Epoch: 339/340 - train_loss: 0.2089 - test_loss: 0.093983
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.998843472680157
# City: Đà Nẵng  _algo:lstm  -RMSE: 28.73839196481255
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.757363033374943
# Epoch:  0/340 - train_loss: 0.8043 - test_loss: 0.760846
# Epoch: 85/340 - train_loss: 0.3177 - test_loss: 0.264201
# Epoch: 170/340 - train_loss: 0.2128 - test_loss: 0.113525
# Epoch: 255/340 - train_loss: 0.2066 - test_loss: 0.090903
# Epoch: 339/340 - train_loss: 0.2042 - test_loss: 0.091095
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.56447112421384
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.439146649940007
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.910259169804416
# Epoch:  0/340 - train_loss: 0.7820 - test_loss: 0.739084
# Epoch: 85/340 - train_loss: 0.3220 - test_loss: 0.265570
# Epoch: 170/340 - train_loss: 0.2183 - test_loss: 0.113815
# Epoch: 255/340 - train_loss: 0.2123 - test_loss: 0.090557
# Epoch: 339/340 - train_loss: 0.2043 - test_loss: 0.090269
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.8526636791942
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.803868342197532
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.33711209948446
# Epoch:  0/200 - train_loss: 0.8755 - test_loss: 0.648928
# Epoch: 50/200 - train_loss: 0.2100 - test_loss: 0.089303
# Epoch: 100/200 - train_loss: 0.2044 - test_loss: 0.091243
# Epoch: 150/200 - train_loss: 0.2024 - test_loss: 0.089372
# Epoch: 199/200 - train_loss: 0.2025 - test_loss: 0.091004
# City: Đà Nẵng  _algo:cnn  -RMSE: 20.214118972694806
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.205899186304542
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.841244560755918
# Epoch:  0/340 - train_loss: 0.7296 - test_loss: 0.701827
# Epoch: 85/340 - train_loss: 0.3246 - test_loss: 0.268592
# Epoch: 170/340 - train_loss: 0.2169 - test_loss: 0.115018
# Epoch: 255/340 - train_loss: 0.2056 - test_loss: 0.090396
# Epoch: 339/340 - train_loss: 0.2195 - test_loss: 0.088643
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.338044648179814
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.379816595561486
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.22549615912949
# Epoch:  0/340 - train_loss: 0.7200 - test_loss: 0.689817
# Epoch: 85/340 - train_loss: 0.3231 - test_loss: 0.269443
# Epoch: 170/340 - train_loss: 0.2112 - test_loss: 0.114704
# Epoch: 255/340 - train_loss: 0.2117 - test_loss: 0.090219
# Epoch: 339/340 - train_loss: 0.2116 - test_loss: 0.088831
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.74924898373795
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.92992644429114
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.33878288708544
# Epoch:  0/340 - train_loss: 0.7498 - test_loss: 0.712338
# Epoch: 85/340 - train_loss: 0.3216 - test_loss: 0.267474
# Epoch: 170/340 - train_loss: 0.2111 - test_loss: 0.114379
# Epoch: 255/340 - train_loss: 0.2108 - test_loss: 0.090139
# Epoch: 339/340 - train_loss: 0.2058 - test_loss: 0.088876
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.427220164595216
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.46234169816886
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.869122357464057
# Epoch:  0/340 - train_loss: 0.7271 - test_loss: 0.701216
# Epoch: 85/340 - train_loss: 0.3217 - test_loss: 0.268793
# Epoch: 170/340 - train_loss: 0.2118 - test_loss: 0.113703
# Epoch: 255/340 - train_loss: 0.2055 - test_loss: 0.090205
# Epoch: 339/340 - train_loss: 0.2092 - test_loss: 0.088374
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.203427033183196
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.70679970572208
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.3282503632509
# Epoch:  0/200 - train_loss: 0.8731 - test_loss: 0.666862
# Epoch: 50/200 - train_loss: 0.2040 - test_loss: 0.089075
# Epoch: 100/200 - train_loss: 0.2034 - test_loss: 0.088950
# Epoch: 150/200 - train_loss: 0.2034 - test_loss: 0.087305
# Epoch: 199/200 - train_loss: 0.2034 - test_loss: 0.088905
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.785606732628814
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.454768362235217
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.551860936219924
# Epoch:  0/340 - train_loss: 0.7571 - test_loss: 0.723791
# Epoch: 85/340 - train_loss: 0.3201 - test_loss: 0.266481
# Epoch: 170/340 - train_loss: 0.2143 - test_loss: 0.113305
# Epoch: 255/340 - train_loss: 0.2094 - test_loss: 0.090308
# Epoch: 339/340 - train_loss: 0.2062 - test_loss: 0.088493
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.090602255695153
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.092651575726105
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.95422122806065
# Epoch:  0/340 - train_loss: 0.7920 - test_loss: 0.761421
# Epoch: 85/340 - train_loss: 0.3187 - test_loss: 0.264712
# Epoch: 170/340 - train_loss: 0.2126 - test_loss: 0.112791
# Epoch: 255/340 - train_loss: 0.2053 - test_loss: 0.089909
# Epoch: 339/340 - train_loss: 0.2054 - test_loss: 0.088417
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.112648276425126
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.362276808897622
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.046809070377954
# Epoch:  0/340 - train_loss: 0.7533 - test_loss: 0.720969
# Epoch: 85/340 - train_loss: 0.3212 - test_loss: 0.267241
# Epoch: 170/340 - train_loss: 0.2123 - test_loss: 0.113058
# Epoch: 255/340 - train_loss: 0.2058 - test_loss: 0.089072
# Epoch: 339/340 - train_loss: 0.2058 - test_loss: 0.087671
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.70690987656754
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.510349686831493
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.784598070034477
# Epoch:  0/340 - train_loss: 0.8382 - test_loss: 0.802379
# Epoch: 85/340 - train_loss: 0.3176 - test_loss: 0.261153
# Epoch: 170/340 - train_loss: 0.2135 - test_loss: 0.111251
# Epoch: 255/340 - train_loss: 0.2080 - test_loss: 0.088864
# Epoch: 339/340 - train_loss: 0.2095 - test_loss: 0.087640
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.173230930454213
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.497485732818692
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.763257743731536
# Epoch:  0/200 - train_loss: 0.8331 - test_loss: 0.667928
# Epoch: 50/200 - train_loss: 0.2047 - test_loss: 0.086972
# Epoch: 100/200 - train_loss: 0.2042 - test_loss: 0.088682
# Epoch: 150/200 - train_loss: 0.2036 - test_loss: 0.089280
# Epoch: 199/200 - train_loss: 0.2041 - test_loss: 0.086752
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.276077804099
# City: Đà Nẵng  _algo:cnn  -RMSE: 27.576230858373577
# City: Đà Nẵng  _algo:cnn  -RMSE: 21.62983943337664
# Epoch:  0/340 - train_loss: 0.7992 - test_loss: 0.766990
# Epoch: 85/340 - train_loss: 0.3195 - test_loss: 0.263488
# Epoch: 170/340 - train_loss: 0.2108 - test_loss: 0.111608
# Epoch: 255/340 - train_loss: 0.2074 - test_loss: 0.089291
# Epoch: 339/340 - train_loss: 0.2061 - test_loss: 0.087201
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.016383462030387
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.745489478183053
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.396468169383
# Epoch:  0/340 - train_loss: 0.7332 - test_loss: 0.700090
# Epoch: 85/340 - train_loss: 0.3226 - test_loss: 0.268082
# Epoch: 170/340 - train_loss: 0.2109 - test_loss: 0.113096
# Epoch: 255/340 - train_loss: 0.2060 - test_loss: 0.089062
# Epoch: 339/340 - train_loss: 0.2093 - test_loss: 0.087147
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.650737616376563
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.56666318315985
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.536519771556005
# Epoch:  0/340 - train_loss: 0.7193 - test_loss: 0.692318
# Epoch: 85/340 - train_loss: 0.3217 - test_loss: 0.268804
# Epoch: 170/340 - train_loss: 0.2108 - test_loss: 0.112918
# Epoch: 255/340 - train_loss: 0.2051 - test_loss: 0.088125
# Epoch: 339/340 - train_loss: 0.2051 - test_loss: 0.086938
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.7964926423504
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.14993970654874
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.866783638030338
# Epoch:  0/340 - train_loss: 0.8013 - test_loss: 0.766543
# Epoch: 85/340 - train_loss: 0.3178 - test_loss: 0.264096
# Epoch: 170/340 - train_loss: 0.2104 - test_loss: 0.111071
# Epoch: 255/340 - train_loss: 0.2052 - test_loss: 0.088358
# Epoch: 339/340 - train_loss: 0.2052 - test_loss: 0.086965
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.85152159851042
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.948398354318645
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.39691496149732
# Epoch:  0/200 - train_loss: 0.8476 - test_loss: 0.727964
# Epoch: 50/200 - train_loss: 0.2048 - test_loss: 0.087921
# Epoch: 100/200 - train_loss: 0.2029 - test_loss: 0.088325
# Epoch: 150/200 - train_loss: 0.2042 - test_loss: 0.087422
# Epoch: 199/200 - train_loss: 0.2014 - test_loss: 0.088257
# City: Đà Nẵng  _algo:cnn  -RMSE: 32.991600478715284
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.14777707600232
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.488857778163123
# Epoch:  0/340 - train_loss: 0.8235 - test_loss: 0.784879
# Epoch: 85/340 - train_loss: 0.3147 - test_loss: 0.260275
# Epoch: 170/340 - train_loss: 0.2098 - test_loss: 0.110393
# Epoch: 255/340 - train_loss: 0.2053 - test_loss: 0.088089
# Epoch: 339/340 - train_loss: 0.2052 - test_loss: 0.086704
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.97585286407856
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.07163127186541
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.179500999342732
# Epoch:  0/340 - train_loss: 0.7499 - test_loss: 0.723103
# Epoch: 85/340 - train_loss: 0.3208 - test_loss: 0.266515
# Epoch: 170/340 - train_loss: 0.2107 - test_loss: 0.112993
# Epoch: 255/340 - train_loss: 0.2052 - test_loss: 0.088051
# Epoch: 339/340 - train_loss: 0.2054 - test_loss: 0.086325
# City: Đà Nẵng  _algo:lstm  -RMSE: 21.617351809254902
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.570635629386736
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.98270420130178
# Epoch:  0/340 - train_loss: 0.7156 - test_loss: 0.691652
# Epoch: 85/340 - train_loss: 0.2689 - test_loss: 0.216364
# Epoch: 170/340 - train_loss: 0.1896 - test_loss: 0.098880
# Epoch: 255/340 - train_loss: 0.1863 - test_loss: 0.090187
# Epoch: 339/340 - train_loss: 0.1849 - test_loss: 0.083273
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.16443452281952
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.03037699046295
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.708028194617224
# Epoch:  0/340 - train_loss: 0.7267 - test_loss: 0.698217
# Epoch: 85/340 - train_loss: 0.2704 - test_loss: 0.218490
# Epoch: 170/340 - train_loss: 0.1892 - test_loss: 0.098542
# Epoch: 255/340 - train_loss: 0.5325 - test_loss: 0.089057
# Epoch: 339/340 - train_loss: 0.1912 - test_loss: 0.089197
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.43847441935618
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.12362163172383
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.59995787618597
# Epoch:  0/200 - train_loss: 0.7474 - test_loss: 0.639694
# Epoch: 50/200 - train_loss: 0.1888 - test_loss: 0.078743
# Epoch: 100/200 - train_loss: 0.1847 - test_loss: 0.077783
# Epoch: 150/200 - train_loss: 0.1839 - test_loss: 0.077542
# Epoch: 199/200 - train_loss: 0.1843 - test_loss: 0.078952
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.25805609395244
# City: Đà Nẵng  _algo:cnn  -RMSE: 19.067062907532392
# City: Đà Nẵng  _algo:cnn  -RMSE: 20.077464010243933
# Epoch:  0/340 - train_loss: 0.7838 - test_loss: 0.748406
# Epoch: 85/340 - train_loss: 0.2686 - test_loss: 0.215427
# Epoch: 170/340 - train_loss: 0.1913 - test_loss: 0.100505
# Epoch: 255/340 - train_loss: 0.1853 - test_loss: 0.085008
# Epoch: 339/340 - train_loss: 0.1849 - test_loss: 0.083386
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.329004668068897
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.266019871750228
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.544056630982055
# Epoch:  0/340 - train_loss: 0.7598 - test_loss: 0.725993
# Epoch: 85/340 - train_loss: 0.2741 - test_loss: 0.221033
# Epoch: 170/340 - train_loss: 0.1907 - test_loss: 0.094238
# Epoch: 255/340 - train_loss: 0.1860 - test_loss: 0.089902
# Epoch: 339/340 - train_loss: 0.1854 - test_loss: 0.086833
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.66981852279928
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.899157324063815
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.96403423932774
# Epoch:  0/340 - train_loss: 0.7234 - test_loss: 0.695784
# Epoch: 85/340 - train_loss: 0.2699 - test_loss: 0.218527
# Epoch: 170/340 - train_loss: 0.2107 - test_loss: 0.094779
# Epoch: 255/340 - train_loss: 0.1851 - test_loss: 0.084552
# Epoch: 339/340 - train_loss: 0.3503 - test_loss: 0.085357
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.08387483750411
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.04328847744135
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.054982350740367
# Epoch:  0/340 - train_loss: 0.7493 - test_loss: 0.718845
# Epoch: 85/340 - train_loss: 0.2678 - test_loss: 0.215409
# Epoch: 170/340 - train_loss: 0.1878 - test_loss: 0.095175
# Epoch: 255/340 - train_loss: 0.1857 - test_loss: 0.086598
# Epoch: 339/340 - train_loss: 0.1864 - test_loss: 0.087151
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.167125203251505
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.53032499288996
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.528661717767324
# Epoch:  0/200 - train_loss: 0.8600 - test_loss: 0.648456
# Epoch: 50/200 - train_loss: 0.1871 - test_loss: 0.087271
# Epoch: 100/200 - train_loss: 0.1869 - test_loss: 0.083701
# Epoch: 150/200 - train_loss: 0.1889 - test_loss: 0.097087
# Epoch: 199/200 - train_loss: 0.1864 - test_loss: 0.079613
# City: Đà Nẵng  _algo:cnn  -RMSE: 18.92478678513547
# City: Đà Nẵng  _algo:cnn  -RMSE: 20.549193444066407
# City: Đà Nẵng  _algo:cnn  -RMSE: 20.462602286393835
# Epoch:  0/340 - train_loss: 0.7610 - test_loss: 0.732592
# Epoch: 85/340 - train_loss: 0.2704 - test_loss: 0.218284
# Epoch: 170/340 - train_loss: 0.2350 - test_loss: 0.105272
# Epoch: 255/340 - train_loss: 0.1864 - test_loss: 0.082398
# Epoch: 339/340 - train_loss: 0.1864 - test_loss: 0.079867
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.826532617358026
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.082056714832703
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.21340246739228
# Epoch:  0/340 - train_loss: 0.7784 - test_loss: 0.743520
# Epoch: 85/340 - train_loss: 0.2665 - test_loss: 0.213683
# Epoch: 170/340 - train_loss: 0.1883 - test_loss: 0.093245
# Epoch: 255/340 - train_loss: 0.1850 - test_loss: 0.083110
# Epoch: 339/340 - train_loss: 0.1847 - test_loss: 0.089810
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.36308107349719
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.716420396503896
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.88447678638917
# Epoch:  0/340 - train_loss: 0.7674 - test_loss: 0.723158
# Epoch: 85/340 - train_loss: 0.2687 - test_loss: 0.215882
# Epoch: 170/340 - train_loss: 0.1883 - test_loss: 0.095607
# Epoch: 255/340 - train_loss: 0.1870 - test_loss: 0.083496
# Epoch: 339/340 - train_loss: 0.1876 - test_loss: 0.085741
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.845646588759546
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.051980767465455
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.55320862191043
# Epoch:  0/340 - train_loss: 0.9846 - test_loss: 0.874029
# Epoch: 85/340 - train_loss: 0.2606 - test_loss: 0.206491
# Epoch: 170/340 - train_loss: 0.2200 - test_loss: 0.092088
# Epoch: 255/340 - train_loss: 0.2913 - test_loss: 0.082288
# Epoch: 339/340 - train_loss: 0.1866 - test_loss: 0.083693
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.800563048143882
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.763804861440043
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.054372802724817
# Epoch:  0/200 - train_loss: 0.7949 - test_loss: 0.644065
# Epoch: 50/200 - train_loss: 0.1861 - test_loss: 0.082318
# Epoch: 100/200 - train_loss: 0.1870 - test_loss: 0.086469
# Epoch: 150/200 - train_loss: 0.2188 - test_loss: 0.090239
# Epoch: 199/200 - train_loss: 0.2082 - test_loss: 0.080715
# City: Đà Nẵng  _algo:cnn  -RMSE: 16.095232088643957
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.245982822255794
# City: Đà Nẵng  _algo:cnn  -RMSE: 18.900645430438775
# Epoch:  0/340 - train_loss: 0.7891 - test_loss: 0.754753
# Epoch: 85/340 - train_loss: 0.2666 - test_loss: 0.214630
# Epoch: 170/340 - train_loss: 0.1872 - test_loss: 0.091766
# Epoch: 255/340 - train_loss: 0.1864 - test_loss: 0.083675
# Epoch: 339/340 - train_loss: 0.1865 - test_loss: 0.085374
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.197538962169393
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.17611221329022
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.48773906284582
# Epoch:  0/340 - train_loss: 0.7377 - test_loss: 0.709990
# Epoch: 85/340 - train_loss: 0.2695 - test_loss: 0.215823
# Epoch: 170/340 - train_loss: 0.1896 - test_loss: 0.097165
# Epoch: 255/340 - train_loss: 0.1871 - test_loss: 0.084618
# Epoch: 339/340 - train_loss: 0.1848 - test_loss: 0.082840
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.62392142255466
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.527695935731735
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.582845139033378
# Epoch:  0/340 - train_loss: 0.7803 - test_loss: 0.756153
# Epoch: 85/340 - train_loss: 0.2669 - test_loss: 0.212957
# Epoch: 170/340 - train_loss: 0.1888 - test_loss: 0.091937
# Epoch: 255/340 - train_loss: 0.1859 - test_loss: 0.084472
# Epoch: 339/340 - train_loss: 0.1963 - test_loss: 0.084504
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.87960126153471
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.340741210943538
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.93972771693331
# Epoch:  0/340 - train_loss: 0.7294 - test_loss: 0.701872
# Epoch: 85/340 - train_loss: 0.2695 - test_loss: 0.216547
# Epoch: 170/340 - train_loss: 0.2014 - test_loss: 0.094027
# Epoch: 255/340 - train_loss: 0.1858 - test_loss: 0.081628
# Epoch: 339/340 - train_loss: 0.1855 - test_loss: 0.079525
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.45964639626774
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.694842015518134
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.356162662423465
# Epoch:  0/200 - train_loss: 0.7916 - test_loss: 0.666713
# Epoch: 50/200 - train_loss: 0.1871 - test_loss: 0.084824
# Epoch: 100/200 - train_loss: 0.2584 - test_loss: 0.085322
# Epoch: 150/200 - train_loss: 0.1864 - test_loss: 0.080934
# Epoch: 199/200 - train_loss: 0.1851 - test_loss: 0.078051
# City: Đà Nẵng  _algo:cnn  -RMSE: 16.60839601966452
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.07830619379345
# City: Đà Nẵng  _algo:cnn  -RMSE: 19.039132541802623
# Epoch:  0/340 - train_loss: 0.7936 - test_loss: 0.763255
# Epoch: 85/340 - train_loss: 0.2668 - test_loss: 0.214093
# Epoch: 170/340 - train_loss: 0.1879 - test_loss: 0.095237
# Epoch: 255/340 - train_loss: 0.1858 - test_loss: 0.084412
# Epoch: 339/340 - train_loss: 0.1865 - test_loss: 0.086467
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.978578109070064
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.751149375906337
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.12699273204105
# Epoch:  0/340 - train_loss: 0.7407 - test_loss: 0.710794
# Epoch: 85/340 - train_loss: 0.2692 - test_loss: 0.216625
# Epoch: 170/340 - train_loss: 0.1877 - test_loss: 0.092087
# Epoch: 255/340 - train_loss: 0.1969 - test_loss: 0.083027
# Epoch: 339/340 - train_loss: 0.2209 - test_loss: 0.081936
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.07938808735436
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.826899687622507
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.79745410678295
# Epoch:  0/340 - train_loss: 0.7533 - test_loss: 0.727712
# Epoch: 85/340 - train_loss: 0.2687 - test_loss: 0.214585
# Epoch: 170/340 - train_loss: 0.1881 - test_loss: 0.093550
# Epoch: 255/340 - train_loss: 0.1868 - test_loss: 0.083440
# Epoch: 339/340 - train_loss: 0.1965 - test_loss: 0.086240
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.814774676679388
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.281786258577842
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.597436130314925
# Epoch:  0/340 - train_loss: 0.7934 - test_loss: 0.749505
# Epoch: 85/340 - train_loss: 0.2925 - test_loss: 0.213052
# Epoch: 170/340 - train_loss: 0.1880 - test_loss: 0.092642
# Epoch: 255/340 - train_loss: 0.1850 - test_loss: 0.080781
# Epoch: 339/340 - train_loss: 0.2035 - test_loss: 0.083679
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.682587427496088
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.974022472103186
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.308147989985663
# Epoch:  0/200 - train_loss: 0.7746 - test_loss: 0.680179
# Epoch: 50/200 - train_loss: 0.1855 - test_loss: 0.086540
# Epoch: 100/200 - train_loss: 0.1855 - test_loss: 0.077529
# Epoch: 150/200 - train_loss: 0.1850 - test_loss: 0.078695
# Epoch: 199/200 - train_loss: 0.2599 - test_loss: 0.078359
# City: Đà Nẵng  _algo:cnn  -RMSE: 14.477862328058892
# City: Đà Nẵng  _algo:cnn  -RMSE: 15.689734747568567
# City: Đà Nẵng  _algo:cnn  -RMSE: 18.18822664901234
# Epoch:  0/340 - train_loss: 0.7375 - test_loss: 0.711847
# Epoch: 85/340 - train_loss: 0.2687 - test_loss: 0.215805
# Epoch: 170/340 - train_loss: 0.1875 - test_loss: 0.094172
# Epoch: 255/340 - train_loss: 0.1859 - test_loss: 0.083084
# Epoch: 339/340 - train_loss: 0.2039 - test_loss: 0.081605
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.198561015248433
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.19909163108671
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.630023971953783
# Epoch:  0/340 - train_loss: 0.7599 - test_loss: 0.732192
# Epoch: 85/340 - train_loss: 0.2681 - test_loss: 0.214942
# Epoch: 170/340 - train_loss: 0.1973 - test_loss: 0.092343
# Epoch: 255/340 - train_loss: 0.2370 - test_loss: 0.086263
# Epoch: 339/340 - train_loss: 0.1866 - test_loss: 0.084546
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.964044778909287
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.2788895045178
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.67496886841478
# Epoch:  0/340 - train_loss: 0.7302 - test_loss: 0.701749
# Epoch: 85/340 - train_loss: 0.2886 - test_loss: 0.216007
# Epoch: 170/340 - train_loss: 0.2244 - test_loss: 0.093591
# Epoch: 255/340 - train_loss: 0.1858 - test_loss: 0.083021
# Epoch: 339/340 - train_loss: 0.1857 - test_loss: 0.083567
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.321726148214967
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.194070105381147
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.349900005321626
# Epoch:  0/340 - train_loss: 0.7334 - test_loss: 0.700672
# Epoch: 85/340 - train_loss: 0.2702 - test_loss: 0.217824
# Epoch: 170/340 - train_loss: 0.1882 - test_loss: 0.093101
# Epoch: 255/340 - train_loss: 0.1854 - test_loss: 0.081187
# Epoch: 339/340 - train_loss: 0.2320 - test_loss: 0.081349
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.628925763730642
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.975441050978436
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.889184216575078
# Epoch:  0/200 - train_loss: 0.8541 - test_loss: 0.636745
# Epoch: 50/200 - train_loss: 0.1981 - test_loss: 0.084224
# Epoch: 100/200 - train_loss: 0.1870 - test_loss: 0.077282
# Epoch: 150/200 - train_loss: 0.1863 - test_loss: 0.087285
# Epoch: 199/200 - train_loss: 0.1857 - test_loss: 0.082943
# City: Đà Nẵng  _algo:cnn  -RMSE: 17.767571157332927
# City: Đà Nẵng  _algo:cnn  -RMSE: 19.30333988097805
# City: Đà Nẵng  _algo:cnn  -RMSE: 16.172792722620848
# Epoch:  0/340 - train_loss: 0.7565 - test_loss: 0.728741
# Epoch: 85/340 - train_loss: 0.2678 - test_loss: 0.214088
# Epoch: 170/340 - train_loss: 0.1874 - test_loss: 0.091984
# Epoch: 255/340 - train_loss: 0.1871 - test_loss: 0.083772
# Epoch: 339/340 - train_loss: 0.2262 - test_loss: 0.083592
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.652870183955258
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.597096570811647
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.363656605017546
# Epoch:  0/340 - train_loss: 0.7660 - test_loss: 0.732651
# Epoch: 85/340 - train_loss: 0.2672 - test_loss: 0.213829
# Epoch: 170/340 - train_loss: 0.2062 - test_loss: 0.092364
# Epoch: 255/340 - train_loss: 0.1862 - test_loss: 0.084869
# Epoch: 339/340 - train_loss: 0.1984 - test_loss: 0.084273
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.279672196273175
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.73724879403676
# City: Đà Nẵng  _algo:lstm  -RMSE: 15.655756317924011
# Epoch:  0/340 - train_loss: 0.7510 - test_loss: 0.724013
# Epoch: 85/340 - train_loss: 0.2837 - test_loss: 0.214889
# Epoch: 170/340 - train_loss: 0.1879 - test_loss: 0.091405
# Epoch: 255/340 - train_loss: 0.1861 - test_loss: 0.083393
# Epoch: 339/340 - train_loss: 0.1860 - test_loss: 0.083596
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.087452731578253
# City: Đà Nẵng  _algo:lstm  -RMSE: 15.266656280564614
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.59259895900857
# Epoch:  0/340 - train_loss: 0.7831 - test_loss: 0.748707
# Epoch: 85/340 - train_loss: 0.2692 - test_loss: 0.213197
# Epoch: 170/340 - train_loss: 0.1880 - test_loss: 0.092061
# Epoch: 255/340 - train_loss: 0.1819 - test_loss: 0.085878
# Epoch: 339/340 - train_loss: 0.1827 - test_loss: 0.082838
# City: Đà Nẵng  _algo:lstm  -RMSE: 30.58990980499268
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.50384367746889
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.515663879688553
# Epoch:  0/200 - train_loss: 0.8270 - test_loss: 0.636452
# Epoch: 50/200 - train_loss: 0.1847 - test_loss: 0.084999
# Epoch: 100/200 - train_loss: 0.1996 - test_loss: 0.087672
# Epoch: 150/200 - train_loss: 0.1970 - test_loss: 0.082799
# Epoch: 199/200 - train_loss: 0.1860 - test_loss: 0.082263
# City: Đà Nẵng  _algo:cnn  -RMSE: 14.139804910098228
# City: Đà Nẵng  _algo:cnn  -RMSE: 14.207177219261892
# City: Đà Nẵng  _algo:cnn  -RMSE: 15.550311652917891
# Epoch:  0/340 - train_loss: 0.7146 - test_loss: 0.688552
# Epoch: 85/340 - train_loss: 0.2695 - test_loss: 0.216859
# Epoch: 170/340 - train_loss: 0.2161 - test_loss: 0.092014
# Epoch: 255/340 - train_loss: 0.1960 - test_loss: 0.084120
# Epoch: 339/340 - train_loss: 0.1853 - test_loss: 0.082949
# City: Đà Nẵng  _algo:lstm  -RMSE: 15.92313555416963
# City: Đà Nẵng  _algo:lstm  -RMSE: 19.007151927330867
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.704081088585617
# Epoch:  0/340 - train_loss: 0.8174 - test_loss: 0.781522
# Epoch: 85/340 - train_loss: 0.2695 - test_loss: 0.210866
# Epoch: 170/340 - train_loss: 0.1873 - test_loss: 0.090984
# Epoch: 255/340 - train_loss: 0.1853 - test_loss: 0.081921
# Epoch: 339/340 - train_loss: 0.1845 - test_loss: 0.080224
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.807820059259868
# City: Đà Nẵng  _algo:lstm  -RMSE: 15.625279677931264
# City: Đà Nẵng  _algo:lstm  -RMSE: 20.543255620847997
# Epoch:  0/340 - train_loss: 0.8282 - test_loss: 0.796202
# Epoch: 85/340 - train_loss: 0.2637 - test_loss: 0.210073
# Epoch: 170/340 - train_loss: 0.1873 - test_loss: 0.090981
# Epoch: 255/340 - train_loss: 0.2095 - test_loss: 0.081094
# Epoch: 339/340 - train_loss: 0.1857 - test_loss: 0.082194
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.55633463141582
# City: Đà Nẵng  _algo:lstm  -RMSE: 15.934940766521223
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.748397028614413
# Epoch:  0/340 - train_loss: 0.7632 - test_loss: 0.735573
# Epoch: 85/340 - train_loss: 0.2671 - test_loss: 0.213763
# Epoch: 170/340 - train_loss: 0.1948 - test_loss: 0.090564
# Epoch: 255/340 - train_loss: 0.1855 - test_loss: 0.080945
# Epoch: 339/340 - train_loss: 0.1858 - test_loss: 0.080544
# City: Đà Nẵng  _algo:lstm  -RMSE: 16.773783207171924
# City: Đà Nẵng  _algo:lstm  -RMSE: 18.134704093936676
# City: Đà Nẵng  _algo:lstm  -RMSE: 17.497865413514685
# Epoch:  0/200 - train_loss: 0.8281 - test_loss: 0.682939
# Epoch: 50/200 - train_loss: 0.1921 - test_loss: 0.077907
# Epoch: 100/200 - train_loss: 0.1871 - test_loss: 0.086123
# Epoch: 150/200 - train_loss: 0.2023 - test_loss: 0.082243
# Epoch: 199/200 - train_loss: 0.1890 - test_loss: 0.075519
# City: Đà Nẵng  _algo:cnn  -RMSE: 18.614520218736843
# ...
# Epoch: 170/340 - train_loss: 0.1838 - test_loss: 0.060081
# Epoch: 255/340 - train_loss: 0.1918 - test_loss: 0.058492
# Epoch: 339/340 - train_loss: 0.1302 - test_loss: 0.058968
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.59095025437084
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.51675337187662
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.809332836868094
# Epoch:  0/340 - train_loss: 0.7495 - test_loss: 0.719886
# Epoch: 85/340 - train_loss: 0.1376 - test_loss: 0.081616
# Epoch: 170/340 - train_loss: 0.1302 - test_loss: 0.059052
# Epoch: 255/340 - train_loss: 0.1307 - test_loss: 0.059243
# Epoch: 339/340 - train_loss: 0.1307 - test_loss: 0.060016
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.489945277348873
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.910738215757384
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.364456057276158
# Epoch:  0/340 - train_loss: 0.7498 - test_loss: 0.716684
# Epoch: 85/340 - train_loss: 0.1386 - test_loss: 0.081815
# Epoch: 170/340 - train_loss: 0.1305 - test_loss: 0.059293
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.061669
# Epoch: 339/340 - train_loss: 0.1287 - test_loss: 0.061625
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.483468645641242
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.65252968798474
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.985989024491943
# Epoch:  0/200 - train_loss: 0.7228 - test_loss: 0.586216
# Epoch: 50/200 - train_loss: 0.1308 - test_loss: 0.059058
# Epoch: 100/200 - train_loss: 0.1318 - test_loss: 0.057639
# Epoch: 150/200 - train_loss: 0.1306 - test_loss: 0.059774
# Epoch: 199/200 - train_loss: 0.1310 - test_loss: 0.056826
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.500799170051458
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.321859754217797
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.946968447647663
# Epoch:  0/340 - train_loss: 0.7104 - test_loss: 0.686285
# Epoch: 85/340 - train_loss: 0.1386 - test_loss: 0.083214
# Epoch: 170/340 - train_loss: 0.1301 - test_loss: 0.058422
# Epoch: 255/340 - train_loss: 0.1301 - test_loss: 0.060442
# Epoch: 339/340 - train_loss: 0.1305 - test_loss: 0.059323
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.72876743985128
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.269523201760144
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.755909501659
# Epoch:  0/340 - train_loss: 0.7397 - test_loss: 0.709327
# Epoch: 85/340 - train_loss: 0.1384 - test_loss: 0.082094
# Epoch: 170/340 - train_loss: 0.1317 - test_loss: 0.063425
# Epoch: 255/340 - train_loss: 0.1302 - test_loss: 0.060002
# Epoch: 339/340 - train_loss: 0.1360 - test_loss: 0.060407
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.523902391797066
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.197433925433042
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.165249154976475
# Epoch:  0/340 - train_loss: 0.7058 - test_loss: 0.686012
# Epoch: 85/340 - train_loss: 0.1390 - test_loss: 0.084231
# Epoch: 170/340 - train_loss: 0.1303 - test_loss: 0.058795
# Epoch: 255/340 - train_loss: 0.1597 - test_loss: 0.061279
# Epoch: 339/340 - train_loss: 0.1304 - test_loss: 0.060271
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.37615236632041
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.647114226700097
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.45900768302252
# Epoch:  0/340 - train_loss: 0.7393 - test_loss: 0.705966
# Epoch: 85/340 - train_loss: 0.1384 - test_loss: 0.082043
# Epoch: 170/340 - train_loss: 0.1306 - test_loss: 0.059672
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.058630
# Epoch: 339/340 - train_loss: 0.1307 - test_loss: 0.058529
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.91856093675868
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.496916678349802
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.201178542138383
# Epoch:  0/200 - train_loss: 0.7262 - test_loss: 0.589727
# Epoch: 50/200 - train_loss: 0.1313 - test_loss: 0.059251
# Epoch: 100/200 - train_loss: 0.1299 - test_loss: 0.057143
# Epoch: 150/200 - train_loss: 0.1306 - test_loss: 0.061227
# Epoch: 199/200 - train_loss: 0.1370 - test_loss: 0.056043
# City: Đà Nẵng  _algo:cnn  -RMSE: 27.994637059479345
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.168200702543
# City: Đà Nẵng  _algo:cnn  -RMSE: 27.50412107601569
# Epoch:  0/340 - train_loss: 0.7442 - test_loss: 0.722013
# Epoch: 85/340 - train_loss: 0.1388 - test_loss: 0.083207
# Epoch: 170/340 - train_loss: 0.1306 - test_loss: 0.058879
# Epoch: 255/340 - train_loss: 0.1304 - test_loss: 0.059003
# Epoch: 339/340 - train_loss: 0.1304 - test_loss: 0.059274
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.243344384926207
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.079295234715882
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.11996117571477
# Epoch:  0/340 - train_loss: 0.7045 - test_loss: 0.683550
# Epoch: 85/340 - train_loss: 0.1383 - test_loss: 0.083681
# Epoch: 170/340 - train_loss: 0.1308 - test_loss: 0.060960
# Epoch: 255/340 - train_loss: 0.1305 - test_loss: 0.058243
# Epoch: 339/340 - train_loss: 0.1601 - test_loss: 0.058469
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.911228199221668
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.553848595690056
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.10291111336567
# Epoch:  0/340 - train_loss: 0.7438 - test_loss: 0.717913
# Epoch: 85/340 - train_loss: 0.1380 - test_loss: 0.082100
# Epoch: 170/340 - train_loss: 0.1301 - test_loss: 0.059312
# Epoch: 255/340 - train_loss: 0.1530 - test_loss: 0.059282
# Epoch: 339/340 - train_loss: 0.1381 - test_loss: 0.059012
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.14310082321389
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.79499408181676
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.6884346751899
# Epoch:  0/340 - train_loss: 0.7983 - test_loss: 0.761752
# Epoch: 85/340 - train_loss: 0.1557 - test_loss: 0.081450
# Epoch: 170/340 - train_loss: 0.1536 - test_loss: 0.059056
# Epoch: 255/340 - train_loss: 0.1302 - test_loss: 0.059856
# Epoch: 339/340 - train_loss: 0.1311 - test_loss: 0.059155
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.981922874821084
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.286032168317632
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.785107123068034
# Epoch:  0/200 - train_loss: 0.7377 - test_loss: 0.580056
# Epoch: 50/200 - train_loss: 0.1350 - test_loss: 0.059897
# Epoch: 100/200 - train_loss: 0.1539 - test_loss: 0.058919
# Epoch: 150/200 - train_loss: 0.1306 - test_loss: 0.060780
# Epoch: 199/200 - train_loss: 0.1305 - test_loss: 0.058679
# City: Đà Nẵng  _algo:cnn  -RMSE: 28.631135312550672
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.243263674619012
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.649183539675402
# Epoch:  0/340 - train_loss: 0.7333 - test_loss: 0.701863
# Epoch: 85/340 - train_loss: 0.1586 - test_loss: 0.082290
# Epoch: 170/340 - train_loss: 0.1305 - test_loss: 0.059642
# Epoch: 255/340 - train_loss: 0.1304 - test_loss: 0.059967
# Epoch: 339/340 - train_loss: 0.1301 - test_loss: 0.059162
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.69864000329672
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.150715271769926
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.494784001635818
# Epoch:  0/340 - train_loss: 0.7412 - test_loss: 0.710634
# Epoch: 85/340 - train_loss: 0.1382 - test_loss: 0.082089
# Epoch: 170/340 - train_loss: 0.1537 - test_loss: 0.057892
# Epoch: 255/340 - train_loss: 0.1305 - test_loss: 0.058634
# Epoch: 339/340 - train_loss: 0.1307 - test_loss: 0.059330
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.38399186209801
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.547466045316884
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.10509371946461
# Epoch:  0/340 - train_loss: 0.7136 - test_loss: 0.691269
# Epoch: 85/340 - train_loss: 0.1383 - test_loss: 0.083036
# Epoch: 170/340 - train_loss: 0.1308 - test_loss: 0.060773
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.059688
# Epoch: 339/340 - train_loss: 0.1306 - test_loss: 0.060007
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.29976332627128
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.036785390813893
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.461296108274503
# Epoch:  0/340 - train_loss: 0.7219 - test_loss: 0.692203
# Epoch: 85/340 - train_loss: 0.1413 - test_loss: 0.081830
# Epoch: 170/340 - train_loss: 0.1511 - test_loss: 0.058303
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.059454
# Epoch: 339/340 - train_loss: 0.1482 - test_loss: 0.059644
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.937593955599876
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.13368854716115
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.090910522640282
# Epoch:  0/200 - train_loss: 0.7118 - test_loss: 0.581032
# Epoch: 50/200 - train_loss: 0.1343 - test_loss: 0.060961
# Epoch: 100/200 - train_loss: 0.1369 - test_loss: 0.057103
# Epoch: 150/200 - train_loss: 0.1309 - test_loss: 0.057307
# Epoch: 199/200 - train_loss: 0.1314 - test_loss: 0.060464
# City: Đà Nẵng  _algo:cnn  -RMSE: 28.22970822503592
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.32505694017513
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.1745609060044
# Epoch:  0/340 - train_loss: 0.7333 - test_loss: 0.707872
# Epoch: 85/340 - train_loss: 0.1383 - test_loss: 0.083699
# Epoch: 170/340 - train_loss: 0.1304 - test_loss: 0.059160
# Epoch: 255/340 - train_loss: 0.1308 - test_loss: 0.059027
# Epoch: 339/340 - train_loss: 0.1305 - test_loss: 0.058948
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.147829829856875
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.951536374141508
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.11945109593562
# Epoch:  0/340 - train_loss: 0.7102 - test_loss: 0.683727
# Epoch: 85/340 - train_loss: 0.1404 - test_loss: 0.083692
# Epoch: 170/340 - train_loss: 0.1310 - test_loss: 0.058526
# Epoch: 255/340 - train_loss: 0.1332 - test_loss: 0.058805
# Epoch: 339/340 - train_loss: 0.1482 - test_loss: 0.058084
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.935494983495694
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.834712210670315
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.718823146115987
# Epoch:  0/340 - train_loss: 0.7317 - test_loss: 0.704642
# Epoch: 85/340 - train_loss: 0.1382 - test_loss: 0.082953
# Epoch: 170/340 - train_loss: 0.1310 - test_loss: 0.057856
# Epoch: 255/340 - train_loss: 0.1306 - test_loss: 0.059742
# Epoch: 339/340 - train_loss: 0.1307 - test_loss: 0.059811
# City: Đà Nẵng  _algo:lstm  -RMSE: 23.603984925048664
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.338802093901712
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.29964650860399
# Epoch:  0/340 - train_loss: 0.7010 - test_loss: 0.681613
# Epoch: 85/340 - train_loss: 0.1383 - test_loss: 0.082831
# Epoch: 170/340 - train_loss: 0.1302 - test_loss: 0.059015
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.058259
# Epoch: 339/340 - train_loss: 0.1303 - test_loss: 0.058815
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.509573235829603
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.968595732740766
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.247862062113686
# Epoch:  0/200 - train_loss: 0.7496 - test_loss: 0.589143
# Epoch: 50/200 - train_loss: 0.1311 - test_loss: 0.062954
# Epoch: 100/200 - train_loss: 0.1373 - test_loss: 0.066387
# Epoch: 150/200 - train_loss: 0.1309 - test_loss: 0.058579
# Epoch: 199/200 - train_loss: 0.1309 - test_loss: 0.059610
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.826601427960174
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.360228121666854
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.351631038406023
# Epoch:  0/340 - train_loss: 0.7024 - test_loss: 0.683230
# Epoch: 85/340 - train_loss: 0.1388 - test_loss: 0.083784
# Epoch: 170/340 - train_loss: 0.1305 - test_loss: 0.059323
# Epoch: 255/340 - train_loss: 0.1302 - test_loss: 0.058243
# Epoch: 339/340 - train_loss: 0.1349 - test_loss: 0.058251
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.576949651606064
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.835664976149666
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.29404493371192
# Epoch:  0/340 - train_loss: 0.7138 - test_loss: 0.694982
# Epoch: 85/340 - train_loss: 0.1387 - test_loss: 0.083508
# Epoch: 170/340 - train_loss: 0.1468 - test_loss: 0.059025
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.059269
# Epoch: 339/340 - train_loss: 0.1442 - test_loss: 0.060100
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.746751621192775
# City: Đà Nẵng  _algo:lstm  -RMSE: 29.282440499476873
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.57785062312552
# Epoch:  0/340 - train_loss: 0.7534 - test_loss: 0.725155
# Epoch: 85/340 - train_loss: 0.1379 - test_loss: 0.082470
# Epoch: 170/340 - train_loss: 0.1305 - test_loss: 0.058708
# Epoch: 255/340 - train_loss: 0.1303 - test_loss: 0.059628
# Epoch: 339/340 - train_loss: 0.1304 - test_loss: 0.058925
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.883385036477648
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.95994107274813
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.12358695694101
# Epoch:  0/340 - train_loss: 0.7201 - test_loss: 0.699824
# Epoch: 85/340 - train_loss: 0.1398 - test_loss: 0.082862
# Epoch: 170/340 - train_loss: 0.1305 - test_loss: 0.058843
# Epoch: 255/340 - train_loss: 0.1304 - test_loss: 0.059371
# Epoch: 339/340 - train_loss: 0.1305 - test_loss: 0.059993
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.082064405109307
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.295242739264246
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.676107343814536
# Epoch:  0/200 - train_loss: 0.7372 - test_loss: 0.591591
# Epoch: 50/200 - train_loss: 0.1304 - test_loss: 0.058187
# Epoch: 100/200 - train_loss: 0.1417 - test_loss: 0.059815
# Epoch: 150/200 - train_loss: 0.1307 - test_loss: 0.058617
# Epoch: 199/200 - train_loss: 0.1311 - test_loss: 0.062109
# City: Đà Nẵng  _algo:cnn  -RMSE: 26.579609914568483
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.389371863350288
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.37813402664416
# Epoch:  0/340 - train_loss: 0.7484 - test_loss: 0.721770
# Epoch: 85/340 - train_loss: 0.1396 - test_loss: 0.082826
# Epoch: 170/340 - train_loss: 0.1307 - test_loss: 0.059958
# Epoch: 255/340 - train_loss: 0.1304 - test_loss: 0.058925
# Epoch: 339/340 - train_loss: 0.1303 - test_loss: 0.059109
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.637977852538278
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.216372378044788
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.40143205108751
# Epoch:  0/340 - train_loss: 0.7487 - test_loss: 0.716273
# Epoch: 85/340 - train_loss: 0.1410 - test_loss: 0.082148
# Epoch: 170/340 - train_loss: 0.1304 - test_loss: 0.058798
# Epoch: 255/340 - train_loss: 0.1304 - test_loss: 0.057828
# Epoch: 339/340 - train_loss: 0.1302 - test_loss: 0.058880
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.23694562283592
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.052792069190264
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.705681915352855
# Epoch:  0/340 - train_loss: 0.7428 - test_loss: 0.712062
# Epoch: 85/340 - train_loss: 0.1518 - test_loss: 0.080918
# Epoch: 170/340 - train_loss: 0.1306 - test_loss: 0.060024
# Epoch: 255/340 - train_loss: 0.1302 - test_loss: 0.058149
# Epoch: 339/340 - train_loss: 0.1284 - test_loss: 0.057947
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.57190543404394
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.252439854405
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.287954532296197
# Epoch:  0/340 - train_loss: 0.7074 - test_loss: 0.685947
# Epoch: 85/340 - train_loss: 0.1385 - test_loss: 0.082573
# Epoch: 170/340 - train_loss: 0.1304 - test_loss: 0.059571
# Epoch: 255/340 - train_loss: 0.1306 - test_loss: 0.058744
# Epoch: 339/340 - train_loss: 0.1304 - test_loss: 0.058637
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.095171818527376
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.99959188574996
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.54564534470336
# Epoch:  0/200 - train_loss: 0.7251 - test_loss: 0.585564
# Epoch: 50/200 - train_loss: 0.1481 - test_loss: 0.056179
# Epoch: 100/200 - train_loss: 0.1324 - test_loss: 0.056317
# Epoch: 150/200 - train_loss: 0.1391 - test_loss: 0.057872
# Epoch: 199/200 - train_loss: 0.1304 - test_loss: 0.057608
# City: Đà Nẵng  _algo:cnn  -RMSE: 31.06877851176292
# City: Đà Nẵng  _algo:cnn  -RMSE: 22.41128187992233
# City: Đà Nẵng  _algo:cnn  -RMSE: 23.375269889637078
# Epoch:  0/340 - train_loss: 0.7296 - test_loss: 0.711420
# Epoch: 85/340 - train_loss: 0.1383 - test_loss: 0.083261
# Epoch: 170/340 - train_loss: 0.1302 - test_loss: 0.059116
# Epoch: 255/340 - train_loss: 0.1317 - test_loss: 0.057891
# Epoch: 339/340 - train_loss: 0.1304 - test_loss: 0.058379
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.931488583497053
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.653662563051
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.82874772470432
# Epoch:  0/340 - train_loss: 0.7298 - test_loss: 0.703152
# Epoch: 85/340 - train_loss: 0.1382 - test_loss: 0.083173
# Epoch: 170/340 - train_loss: 0.1304 - test_loss: 0.058383
# Epoch: 255/340 - train_loss: 0.1417 - test_loss: 0.057390
# Epoch: 339/340 - train_loss: 0.1303 - test_loss: 0.059250
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.94929275769777
# City: Đà Nẵng  _algo:lstm  -RMSE: 27.67080561713815
# City: Đà Nẵng  _algo:lstm  -RMSE: 24.91301531328457
# kết thúc train trong: 275
# danh sách error city:
# {}

# %%
send_to_telegram("Server Chạy Xong ensemble weighted " )
# Out:
# {"ok":true,"result":{"message_id":234,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1675433564,"text":"Server Ch\u1ea1y Xong ensemble weighted"}}
