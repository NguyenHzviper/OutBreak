# %% [markdown]
# # Ensemble with Meta Model = LSTM, CNN, ATT, TF
# Create: 06/12/2022
# Description: Ensemble - Combination of Data and Staking Model by LSTM, CNN, ATT, TF. Data from 1997-2015. 44 validation
# Modification: 31/01/2023

# %%
# !nvidia-smi

# %%
# Install packages
# !pip install -U scikit-learn
# !pip install ftfy
# !pip install xlsxwriter 
# !pip install xlwt

# %% [markdown]
# # Imports

# %%
# Imports
import tensorflow as tf 
# from google.colab import drive
import os

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense

import traceback
import sys
import copy
import numpy as np
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
import random
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# lib for LSTM of Meta model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

from ftfy import fix_text
import warnings
warnings.simplefilter("ignore", UserWarning)

plt.rcParams['figure.figsize'] = [7, 3]
import math

# %% [markdown]
# # Global param and project path

# %%
# Attach Google Drive for reading and saving files
# drive.mount('/content/drive')
prj_path = '/home/mlworker/Quang/HealthCare/Source_14012023_v4/'

path_all_mix_data =             prj_path+ 'results/results_14022023/all_mix_data/'
path_all_mix_data_cnn =         prj_path+ 'results/results_14022023/all_mix_data/cnn/'
path_all_mix_data_lstm =        prj_path+ 'results/results_14022023/all_mix_data/lstm/'
path_all_mix_data_lstm_att =    prj_path+ 'results/results_14022023/all_mix_data/lstm_att/'
path_all_mix_data_tf =          prj_path+ 'results/results_14022023/all_mix_data/tf/'

prj_path_opt= prj_path+ 'optimize_hyperparam/opt_results/opt_results_1997_2015_mae/'

prj_path_result_ensemble = prj_path+ 'results/ensemble_15022023/'
com_path =      prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_15.xlsx'
com_path_2 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_25.xlsx'
com_path_3 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_35.xlsx'
com_path_4 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_45.xlsx'

com_path_metrics =      prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_metrics_15.xlsx'
com_path_metrics_2 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_metrics_25.xlsx'
com_path_metrics_3 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_metrics_35.xlsx'
com_path_metrics_4 =    prj_path+ 'results/ensemble_15022023/result/simple_combination/all_combinations_metrics_45.xlsx'



# os.chdir(prj_path)

# loockback_window for meta model. default = 3 months for alls
meta_lookback_window = 3
len_validation = 24 # validation or test depends on usecase

#Note: mỗi bộ all_mix_data sẽ có lenght = 251 (1997 -01/01/2018  và vì 1 dòng đầu bị bỏ đi do quá trình statitionary và remove NAN lúc train)
lenght_whole_data_city = 215

# %% [markdown]
# # Xây dựng Meta Data Set

# %%
##########################
# Xây Dựng Meta Data Set
meta_test_set_city = {}
meta_train_set_city = {}
meta_data_set_city = {}
cities = [
#         'An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
          
#         'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
          
#         'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
          
#         'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
          
        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
        'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên', 
        'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp'
         ]

# cities = ['Đà Nẵng']

for city in cities:  
  meta_test_set = pd.DataFrame()
  meta_train_set = pd.DataFrame() 
  
  
  ######################################
  # Xử lý data của CNN ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_cnn+'mix_train_test_data_'+city+'_cnn.xlsx')
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index() 
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-len_validation:-len_validation] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
  meta_test_cnn = result_test.reset_index(drop=True)  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-len_validation]
  meta_train_cnn = result_train.reset_index(drop=True)
  
  ######################################
  # Xử lý data của LSTM  ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm+'mix_train_test_data_'+city+'_lstm.xlsx')  
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-len_validation:-len_validation] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
  meta_test_lstm = result_test.reset_index(drop=True)
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-len_validation]
  meta_train_lstm = result_train.reset_index(drop=True)

  ###########################################
  # Xử lý data của LSTM ATT ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm_att+'mix_train_test_data_'+city+'_lstm_att.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window   
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-len_validation:-len_validation] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
  meta_test_lstm_att = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset  
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-len_validation]
  meta_train_lstm_att = result_train.reset_index(drop=True)

  # lấy observation
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-len_validation:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-len_validation]
  meta_train_observed = meta_train_observed.reset_index(drop=True)

  #############################################
  # # Xử lý data của Transformer ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_tf+'mix_train_test_data_'+city+'_tf.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-len_validation:-len_validation] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
  meta_test_tf = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-len_validation]
  meta_train_tf = result_train.reset_index(drop=True)

  
  meta_test_set['cnn_pred'] = meta_test_cnn
  meta_test_set['lstm_pred'] = meta_test_lstm
  meta_test_set['lstm_att_pred'] = meta_test_lstm_att
  meta_test_set['tf_pred'] = meta_test_tf
  meta_test_set['Observed'] = meta_test_observed
   
  meta_train_set['cnn_pred'] = meta_train_cnn
  meta_train_set['lstm_pred'] = meta_train_lstm
  meta_train_set['lstm_att_pred'] = meta_train_lstm_att 
  meta_train_set['tf_pred'] = meta_train_tf  
  meta_train_set['Observed'] = meta_train_observed

  meta_test_set_city[city] = meta_test_set # test set có chiều dài 39
  meta_train_set_city[city] = meta_train_set # train set có chiều dài 212 = 252 -36 (train) - 1 (station) - 3 (meta_lookback_window)

  # Đoạn này làm thêm. Nối dài meta_test_set_city và meta_train_set_city
  df = meta_train_set.append(meta_test_set[meta_lookback_window:])
  df.to_excel(prj_path_result_ensemble+'/meta_data/meta_data_'+city+'.xlsx')
# Out:
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])
# <ipython-input-5-988b42e80534>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:54: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:70: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation))
# <ipython-input-5-988b42e80534>:93: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(len_validation)) # Lấy 36 tháng cuối
# <ipython-input-5-988b42e80534>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[meta_lookback_window:])

# %%
# meta_train_set_city['An Giang']

# %%
# meta_test_set_city['An Giang']

# %% [markdown]
# # Danh sách các based Model và các Combination có thể của nó

# %%
# Danh sách các based Model và các Combination có thể của nó
list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

combs_features = list(combinations(list_based_model[0:], 2)) + list(combinations(list_based_model[0:], 3)) + list(combinations(list_based_model[0:], 4))


# list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

# combs_features = list(combinations(list_based_model[0:], 4)) 
combs_features
# Out:
# [('cnn_pred', 'lstm_att_pred'),
#  ('cnn_pred', 'lstm_pred'),
#  ('cnn_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred'),
#  ('lstm_att_pred', 'tf_pred'),
#  ('lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred', 'tf_pred')]

# %%
# combs_features = [('cnn_pred', 'lstm_att_pred')]

# %% [markdown]
# # Support Functions and Train class

# %%
def seed_everything(seed: int):
    import random, os    
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)



# Set hyperparameters as args using the Configuration class
class Configuration():
    def __init__(self):
      # lấy bộ test dài 36 tháng = 3 năm
        self.test_size = len_validation
        # là nhìn vào dữ liệu trước 3 tháng và dự phóng        
        self.look_back = 3
        # dự phóng 3 tháng
        self.n_predicted_month = 3
        self.n_features = 3
        self.seed = 42
        # mỗi phần tử x trong tập suppervise có độ lớn là 16 = 16 tháng
        self.batch_size = 16
        # self.device = torch.device("cuda")
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.epochs = 300
     

# Biến args lưu giá trị Global.
args = Configuration()


# Lưu ý sau khi stationnary thì dòng đầu tiên trừ cho dòng trước nữa là ko có cho nên về cơ bản sẽ thành NaN
# Cần remove dòng đầu tiên ra khỏi data để train và test. Cho nên cơ bản là data sau khi in ra sẽ thiếu 1 đơn vị đầu tiên
def convert_to_stationary(city_data):
    """Subtracts previous value for all cols except disease rates"""
    for col_name in city_data.columns:
        if col_name != 'Diarrhoea_rates':
            try:
                city_data[col_name] = city_data[col_name] - city_data[col_name].shift()
            except:
                print(col_name)
    return city_data

def impute_missing_value(city_data):
    """
    Cơ bản dữ liệu bị thiếu sót rất nhiều: Như Điện Biên 1997 -2003 là thiếu dữ liệu về bệnh
    Hàm này sẽ tự sinh ra dữ liệu bị thiếu. Nếu tháng nào không có số liệu thì tính như sau:
    12 tháng đầu không có số liệu thì gán = 0
    tháng 13-24 không có số liệu, sẽ lấy giá trị của tháng cùng kỳ năm trước
    tháng từ 24 trở đi sẽ lấy giá trị nhỏ nhất của 2 tháng cùng kỳ trong 2 năm gần nhất.
    Do Điện Biên bằng 0 nên sau khi xử lý từ 1997 -2003 là đều = 0.  
    """
    for col in city_data.columns:
        for index in range(len(city_data[col])):
            if np.isnan(city_data[col].iloc[index]):
                if index < 12:
                    city_data[col].iloc[index] = 0
                elif index >= 12 and index <= 24:
                    city_data[col].iloc[index] = city_data[col].iloc[index - 12]
                else:
                    city_data[col].iloc[index] = min(city_data[col].iloc[index - 12], city_data[col].iloc[index - 24])
    return city_data

def split_data(data, look_back ):
    """Splits data into train and test sets based on args (Configuration class)"""
    train = data[: -args.test_size]    
    test = data[-args.test_size - look_back: ]
    return train, test

def to_supervised(data, d_in=args.look_back, d_out=args.n_predicted_month, features_list=[]):
    """
    Frames time-series as supervised learning dataset.
    
    Args:
      d_in: lookback window
      d_out: number of predicted months
      features_list: list of all features **where last col is the disease incidence**

    Returns:
      Numpy arrays of disease incidence (y) and other predictors (X)
    """
    X, y = list(), list()
    for index, _ in enumerate(data):
        in_end = index + d_in
        out_end = in_end + d_out
        if out_end <= len(data):
            if len(features_list) == 0 :
                X.append(data[index: in_end, :])
            else:
                X.append(data[index: in_end, features_list])
            y.append(data[in_end: out_end, -1])
    return np.array(X), np.array(y)


def get_data(train_np, test_np, batch_size, list_selected_features, origin_city_meta_data):
    """
    Returns important feature list and data formatted for input into Pytorch 
    models
    """ 
    # origin_city_meta_data chứa data mẫu để lấy index 
    # important_features = arrary index nên ta phải truyền indexex của columns
    important_features = [origin_city_meta_data.columns.get_loc(c) for c in list_selected_features if c in origin_city_meta_data]  

    train_X, train_y = to_supervised(train_np, features_list=important_features)
    test_X, test_y = to_supervised(test_np, features_list=important_features)
    train_tensor = TensorDataset(torch.from_numpy(train_X), torch.from_numpy(train_y))
    test_tensor = (torch.from_numpy(test_X), torch.from_numpy(test_y))

    train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

    return important_features, train_loader, test_tensor

#Define Pytorch LSTM model
class MultiVariateLSTM(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = output[:, -1, :]
        y_predicted = self.linear(last_hidden_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            #return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

#Define Pytorch LSTM-ATT model
class MultiVariateLSTM_Attention(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.attention_linear = nn.Linear(hidden_size, hidden_size)
        # self.linear = nn.Linear(hidden_size*2, args.n_predicted_month)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = last_hidden[-1]
        remain_hidden_vector = output
        e_t = remain_hidden_vector.bmm(self.attention_linear(last_hidden_vector).unsqueeze(2)).squeeze(-1)
        alpha_t = F.softmax(e_t, dim=1)
        attenion_vector = remain_hidden_vector.transpose(2, 1).bmm(alpha_t.unsqueeze(2)).squeeze(-1)
        # combine_vector = torch.cat((last_hidden_vector, attenion_vector), dim=1)
        # combine_vector = last_hidden_vector + attenion_vector
        y_predicted = self.linear(attenion_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Define Pytorch CNN model
class MultivariateCNN(nn.Module):
    def __init__(self, num_filters=[100, 100, 100], dropout=0.01):
        super(MultivariateCNN, self).__init__()
        self.loss_fn = loss = nn.MSELoss()
        self.filter_sizes = [1, 2, 3]
        self.conv1d_list = nn.ModuleList([nn.Conv1d(args.n_features, num_filters[i], self.filter_sizes[i]) for i in range(len(self.filter_sizes))])
        self.linear = nn.Linear(np.sum(num_filters), args.n_predicted_month)
        self.dropout = nn.Dropout(dropout)
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))

    def forward(self, X_batch, y_batch=None):
        X_batch = X_batch.permute(0, 2, 1)  #(batch_size, n_features, n_look_back)
        X_conv_list = [F.relu(conv1d(X_batch)) for conv1d in self.conv1d_list]
        X_pool_list = [F.max_pool1d(x_conv, kernel_size=x_conv.shape[2]) for x_conv in X_conv_list]
        X_fc = torch.cat([x_pool.squeeze(dim=2) for x_pool in X_pool_list], dim=1)
        y_predicted = self.linear(self.dropout(X_fc))
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted

    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Transformer Model
# Transformer Model
class PositionalEncoder(nn.Module):
    def __init__(self, n_feature=3, dropout=0.1, max_length=24):
        super().__init__()
        
        self.hidden_dim = n_feature
        self.max_length = max_length
        self.dropout = nn.Dropout(dropout)
        
        pe = torch.zeros(max_length, self.hidden_dim)
        for pos in range(max_length):
            for i in range(0, self.hidden_dim, 2):
                pe[pos, i] = math.sin(pos/(10000**(2*i/self.hidden_dim)))
                if i + 1 < self.hidden_dim:
                    pe[pos, i+1] = math.cos(pos/(10000**((2*i+1)/self.hidden_dim)))
        pe = pe.unsqueeze(0)        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x*math.sqrt(self.hidden_dim)
        length = x.size(1)
        pe = Variable(self.pe[:, :length], requires_grad=False)
        if x.is_cuda:
            pe.cuda()
        x = x + pe
        x = self.dropout(x)
        
        return x

class TransformerModel(nn.Module):
    def __init__(self, d_input, n_look_back, hidden_size, n_layers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.hidden_size = hidden_size

        self.pe = PositionalEncoder(n_feature=args.n_features, dropout=dropout)

        encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dim_feedforward=hidden_size, dropout=dropout, activation='gelu')
        # encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)
        self.decoder = nn.Linear(d_input*n_look_back, args.n_predicted_month)

        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
        
        self.loss_fn = nn.MSELoss()
        
    
    def forward(self, X_batch, y_batch=None):
        X_batch = self.pe(X_batch)
        X_batch = self.transformer_encoder(X_batch)
        X_batch = X_batch.view(X_batch.size(0), -1)
        
        y_predicted = self.decoder(X_batch)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
        else:
            return y_predicted
        return X_batch
    
    def predict(self, X):
        with torch.no_grad():
            X = torch.tensor(X, device=args.device)
        return self.forward(X).squeeze()

# Create class to train and evaluate models
class Trainer():
    def __init__(self, city, model_type, learning_rate, important_features, train_loader, test_tensor, n_layers=2, hidden_size=128, num_filters=[100, 100, 100], dropout=0.01):
        """
        Initialise trainer, allowing input of LSTM, LSTM-ATT, or CNN 
        hyperparameters. Adam optimiser used for all models.
        """
        self.model_type = model_type    
        self.city = city    
        self.model = self.init_model(model_type, n_layers, hidden_size, num_filters, dropout, city)
        self.model.double().to(args.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.important_features, self.train_loader, self.test_tensor = important_features, train_loader, test_tensor
    
    def init_model(self, model_type, n_layers, hidden_size, num_filters, dropout, city):        
        #Get hyper param by name and set for n_layers, hidden_size, num_filters, dropout and overwrite the input param  
        # n_layers, hidden_size,num_filters, dropout= get_opt_param_by_name( algo = model_type, city = city)
    
        """Initialise a model based on whether LSTM, LSTM-ATT, or CNN is chosen."""
        if model_type.lower() == 'lstm':
            model = MultiVariateLSTM(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'lstm_attention':
            model = MultiVariateLSTM_Attention(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'cnn':
            model = MultivariateCNN(num_filters, dropout)
        elif model_type.lower() == 'transformers':
            model = TransformerModel(d_input=args.n_features, n_look_back=args.look_back, hidden_size=hidden_size, n_layers=n_layers, dropout=dropout)
        return model

    def step(self, batch):
        self.model.train()
        X_batch, y_batch = tuple(t.to(args.device) for t in batch)
        self.optimizer.zero_grad()
        y_pred, loss = self.model.forward(X_batch, y_batch)
        loss.backward()
        self.optimizer.step()
        return loss.mean().item()

    def validation(self):
        self.model.eval()
        eval_loss = 0.0

        result = {}

        y_true = np.array([])
        y_pred = np.array([])

        X_batch, y_batch = tuple(t.to(args.device) for t in self.test_tensor)
        with torch.no_grad():
            outputs, loss = self.model.forward(X_batch, y_batch)
            eval_loss = loss.mean().item()

        return eval_loss

    def train(self, epochs=20):
        # print('param of model')
        # print('hidensize',self.model.hidden_size)
        # print('nlayer',self.model.n_layers)  
        best_lost = float("inf")
        best_model = None
        for epoch in range(epochs):
            total_loss = 0.0
            for batch in self.train_loader:
                loss = self.step(batch)
                total_loss += loss
            train_loss = total_loss/len(self.train_loader)
            eval_loss = self.validation()
            if eval_loss < best_lost:
                best_lost = eval_loss
                best_model = copy.deepcopy(self.model)
            if (epoch + 1) == epochs or (epoch + 1) in [c + 1 for c in range(epochs) if c % int(epochs/4) == 0]:
                print(f"Epoch: {epoch:2}/{epochs:2} - train_loss: {train_loss:.4f} - test_loss: {eval_loss:4f}")
        self.model = best_model
        self.model.eval()
        return None



    # Lưu model vào trong thư mục models
    def save_model_to(self, path = '', city =''):       
        torch.save(self.model, path)

    def load_model_to(self, path = ''):       
        return torch.load(path)

    def evaluate_model(self, np_data=None, plot=True, scaled=True, city=None, k_steps=None, y_scaler =None):
        assert scaled, "data must be scaled"
        self.model.eval()
        tensor_data = torch.from_numpy(np_data)
        rmse_list = []
        mae_list = [] 
        mape_list = []

        y_predicted_list = []
        y_true_list = []

        for k_steps in range(1, args.n_predicted_month + 1):
            y_predicted = []
            y_true = []
            for index in range(tensor_data.size(0) - args.look_back):
                X = tensor_data[index: index + args.look_back, self.important_features]
                # yhat = self.model.predict(X.unsqueeze(0)).squeeze()

                yhat = self.model.predict(X.unsqueeze(0))
                yhat = yhat.squeeze()

                y_predicted.append(yhat.detach().cpu().numpy()[k_steps - 1])
                y_true.append(tensor_data[index + args.look_back, -1].detach().cpu().numpy())

            y_predicted = y_scaler.inverse_transform(np.array(y_predicted).reshape(-1, 1)).reshape(-1, )
            y_true = y_scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).reshape(-1, )

            

            rmse = mean_squared_error(y_true, y_predicted, squared=False)
            mae = mean_absolute_error(y_true, y_predicted)
            mape = mean_absolute_percentage_error(y_true, y_predicted)

            rmse_list.append(rmse)
            mae_list.append(mae)
            mape_list.append(mape)

            print('City: '+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))          
            if plot==True:
              plt.grid(True)
              plt.plot(y_predicted, label='predicted')
              plt.plot(y_true, label='actual')
              plt.title(f"k-steps = {k_steps} - city: "+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))
              plt.legend()
              plt.show()

              plt.show()
            y_predicted_list.append(y_predicted)
            y_true_list.append(y_true)

        return y_true_list, y_predicted_list, rmse_list, mae_list, mape_list

# %% [markdown]
# # Get optimized Hyper param

# %%
def convert_str_num_filter_array(str_filter = ''):  
  arr_filter = str_filter.split(',')  
  int_arr_filter= [int(x) for x in arr_filter]
  return int_arr_filter


opt_param_cnn = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_cnn.xlsx', index_col = 'City')
opt_param_lstm = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm.xlsx', index_col = 'City')
opt_param_lstm_att = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm_att.xlsx', index_col = 'City')
opt_param_transformer = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_transformer.xlsx', index_col = 'City')

def get_opt_param_by_name(algo = 'transformer', city = None):
  if algo == 'cnn':
    city_param = opt_param_cnn.loc[city]
    #load  param
    n_layers = ''
    hidden_size = ''
    num_filters = convert_str_num_filter_array(city_param['Num. filters'])
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm':
    city_param = opt_param_lstm.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm_attention':
    city_param = opt_param_lstm_att.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'transformers':
    city_param = opt_param_transformer.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hidden Size'])
    num_filters = ''
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  return n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window


# Manual Check param before train
n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window= get_opt_param_by_name(algo='lstm', city='Lào Cai')
lookback_window,epoch, hidden_size, n_layers,learning_rate, num_filters, dropout
# Out:
# (3, 210, 54, 5, 0.0005838118399695072, '', '')

# %%
# meta_test_set_city['Lào Cai']
# meta_test_set_city['Điện Biên']

# %%
import requests

def send_to_telegram(message):

    apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
    chatID = '@ptn_announcement'
    apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

    try:
        response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
        print(response.text)
    except Exception as e:
        print(e)

# %% [markdown]
# # Main Train and Predict Ensemble Meta Model

# %%
dt_started = datetime.now()


l_errCity = {} # có lỗi sẽ lưu vào đây, kiểm tra ngay cell sau

dict_comb_result = {}
df_all_combs_result_all = pd.DataFrame() # Lưu tất cả các loại combination
df_all_combs_2_result_all = pd.DataFrame()
df_all_combs_3_result_all = pd.DataFrame()
df_all_combs_4_result_all = pd.DataFrame()


dict_comb_metrics_result = {}
df_all_combs_metrics_result_all = pd.DataFrame() # Lưu tất cả các loại combination
df_all_combs_2_metrics_result_all = pd.DataFrame()
df_all_combs_3_metrics_result_all = pd.DataFrame()
df_all_combs_4_metrics_result_all = pd.DataFrame()

n_experiments = 2
# Loop n time and randome seed
for interation in range(n_experiments):
  seed_everything(np.int64(random.randint(1, 100)))
  for combination_features in combs_features:
    list_selected_features = [x for x in combination_features] +['Observed'] # Lấy danh sách tên các features + cột Observed 
    s_selected_features = '-'.join([str(elem) for elem in list_selected_features])
    args.n_features = len(list_selected_features) # Overwrite the global param để trả đúng n_features
    args.look_back = meta_lookback_window
    # global_epoch = 100 # no_need now

    for city in cities:
      
      try:
          # df_all_cities_result_per_com = pd.DataFrame()
          # df_all_cities_metrics_result_per_com = pd.DataFrame()

          df_one_city_result_all = pd.DataFrame()
          df_one_city_metrics_result_all = pd.DataFrame()

          origin_city_meta_test_set = meta_test_set_city[city]
          origin_city_meta_train_set = meta_train_set_city[city]     

          # Data train/test processing for all Meta model
          train = meta_train_set_city[city].astype(float)
          test = meta_test_set_city[city].astype(float)

          train = train.replace((np.inf, -np.inf, np.nan), 0)
          test = test.replace((np.inf, -np.inf, np.nan), 0) 
        
          # Đoạn này impute các trường hợp rỗng
          train = impute_missing_value(train)
          test = impute_missing_value(test)

          # Fit data scaler to training data
          full_scaler = MinMaxScaler().fit(train)
          y_scaler = MinMaxScaler().fit(train.values[:, -1].reshape(-1, 1))

          # Scale train and test data
          train = full_scaler.transform(train)
          test = full_scaler.transform(test)


          # Pre-process data        
          ########################################################
          # Generate CNN model and define province-specific params
          ########################################################
          # Get right optimize parame
          n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = 'cnn', city = city)

          # Get data to run model
          important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)    

          
          trainer = Trainer(
                              model_type='cnn',  
                              city = city,                    
                              learning_rate=learning_rate,
                              important_features=important_features,
                              train_loader=train_loader,
                              test_tensor=test_tensor,
                              num_filters= num_filters, 
                              dropout=dropout )

          # Train model with province-specific epochs
          trainer.train(epochs=epoch)           


          # Evaluate test set   
          y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
              
          cnn_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'CNN', 
                                    'Based_Models': s_selected_features,
                                    'Observed': y_true_test[0], 
                                    '1-month': y_pred_test[0], 
                                    '2-months': y_pred_test[1],
                                    '3-months': y_pred_test[2],
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': mape_list[2]})
          
          cnn_metric_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'CNN', 
                                    'Based_Models': s_selected_features,                                                      
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': [mape_list[2]]}) # do có 1 dòng nên pandas cần index = 0    

          
          # #############################################################
          # Generate LSTM model and define province-specific params
          n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = 'lstm', city = city)
          
          # Get data to run model
          important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set) 
          
          trainer = Trainer(model_type='lstm', 
                            city = city,
                            learning_rate=learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers=n_layers,
                            hidden_size=hidden_size)   
        
          # Train model with province-specific epochs
          trainer.train(epochs=epoch)

          # Evaluate test set   
          y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)

          lstm_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'LSTM', 
                                    'Based_Models': s_selected_features,                           
                                    'Observed': y_true_test[0], 
                                    '1-month': y_pred_test[0], 
                                    '2-months': y_pred_test[1],
                                    '3-months': y_pred_test[2],
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': mape_list[2]})
          
          lstm_metric_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'LSTM', 
                                    'Based_Models': s_selected_features,                                                      
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': [mape_list[2]]}) # do có 1 dòng nên pandas cần index = 0

          #############################################################
          # Generate LSTM-ATT model and define province-specific params
          #############################################################
          # Get right optimize parame
          n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = 'lstm_attention', city = city)       

          
          # Get data to run model
          important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   
        
          trainer = Trainer(model_type= 'lstm_attention',
                            city = city,
                            learning_rate= learning_rate,
                            important_features=important_features,
                            train_loader=train_loader,
                            test_tensor=test_tensor,
                            n_layers= n_layers,
                            hidden_size=hidden_size)

          # Train model with province-specific epochs
          trainer.train(epochs= epoch)
          
          # Evaluate test set   
          y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)   

          lstm_att_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'LSTM_ATT', 
                                    'Based_Models': s_selected_features,                           
                                    'Observed': y_true_test[0], 
                                    '1-month': y_pred_test[0], 
                                    '2-months': y_pred_test[1],
                                    '3-months': y_pred_test[2],
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': mape_list[2]})
          
          lstm_att_metric_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'LSTM_ATT', 
                                    'Based_Models': s_selected_features,                                                      
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': [mape_list[2]]}) # do có 1 dòng nên pandas cần index = 0      
          #############################################################
          # Generate Transformer model and define province-specific params
          #############################################################        
          # Get right optimize parame
          n_layers, hidden_size, _, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name(algo='transformers', city=city)
          
          # Get data to run model
          important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   
        
          # Overwrite parameters for province-specific diarrhoea prediction 
          trainer = Trainer(
                          model_type='transformers',
                          city = city, 
                          learning_rate=learning_rate,
                          important_features=important_features,
                          train_loader=train_loader,
                          test_tensor=test_tensor,
                          n_layers=n_layers,
                          hidden_size=hidden_size,
                          dropout=dropout)

          # Train model with province-specific epochs
          trainer.train(epochs=epoch)

          print("Evaluate on test set: ")
          y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)

          

          transformer_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'TF', 
                                    'Based_Models': s_selected_features,
                                    'Observed': y_true_test[0], 
                                    '1-month': y_pred_test[0], 
                                    '2-months': y_pred_test[1],
                                    '3-months': y_pred_test[2],
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': mape_list[2]})

          transformer_metrix_reslt = pd.DataFrame({
                                    'City': city,
                                    'Run Seq': interation,
                                    'Meta_Model_Name': 'TF', 
                                    'Based_Models': s_selected_features,                             
                                    'RMSE_1-month': rmse_list[0],
                                    'RMSE_2-month': rmse_list[1],
                                    'RMSE_3-month': rmse_list[2],
                                    'MAE_1-month': mae_list[0],
                                    'MAE_2-month': mae_list[1],
                                    'MAE_3-month': mae_list[2],
                                    'MAPE_1-month': mape_list[0],
                                    'MAPE_2-month': mape_list[1],
                                    'MAPE_3-month': [mape_list[2]]}) # do có 1 dòng nên pandas cần index = 0

          # Lưu kết quả  predict 36 months
          df_one_city_result_all = pd.concat([df_one_city_result_all, cnn_reslt,lstm_reslt,lstm_att_reslt,transformer_reslt], axis=0)
          # df_one_city_result_all = df_one_city_result_all.append(cnn_reslt)
          # df_one_city_result_all = df_one_city_result_all.append(lstm_reslt)
          # df_one_city_result_all = df_one_city_result_all.append(lstm_att_reslt)
          # df_one_city_result_all = df_one_city_result_all.append(transformer_reslt)

          # Lưu kết quả metrics
          df_one_city_metrics_result_all = pd.concat([df_one_city_metrics_result_all, cnn_metric_reslt,
                                      lstm_metric_reslt,lstm_att_metric_reslt,transformer_metrix_reslt], axis=0)
          # df_one_city_metrics_result_all = df_one_city_metrics_result_all.append(cnn_metric_reslt) 
          # df_one_city_metrics_result_all = df_one_city_metrics_result_all.append(lstm_metric_reslt)
          # df_one_city_metrics_result_all = df_one_city_metrics_result_all.append(lstm_att_metric_reslt)
          # df_one_city_metrics_result_all = df_one_city_metrics_result_all.append(transformer_metrix_reslt)

     
          # Lưu DF theo từng loại combination
          df_all_combs_result_all = pd.concat([df_all_combs_result_all, df_one_city_result_all], axis=0)
          df_all_combs_metrics_result_all = pd.concat([df_all_combs_metrics_result_all, df_one_city_metrics_result_all], axis=0)
          # df_all_combs_result_all = df_all_combs_result_all.append(df_one_city_result_all)
          # df_all_combs_metrics_result_all = df_all_combs_metrics_result_all.append(df_one_city_metrics_result_all)  

          if(len(combination_features) == 2):
            df_all_combs_2_result_all = pd.concat([df_all_combs_2_result_all, df_one_city_result_all], axis=0)
            df_all_combs_2_metrics_result_all = pd.concat([df_all_combs_2_metrics_result_all, df_one_city_metrics_result_all], axis=0)
            # df_all_combs_2_result_all = df_all_combs_2_result_all.append(df_one_city_result_all)
            # df_all_combs_2_metrics_result_all = df_all_combs_2_metrics_result_all.append(df_one_city_metrics_result_all)
          if(len(combination_features) == 3):
            df_all_combs_3_result_all = pd.concat([df_all_combs_3_result_all, df_one_city_result_all], axis=0)
            df_all_combs_3_metrics_result_all = pd.concat([df_all_combs_3_metrics_result_all, df_one_city_metrics_result_all], axis=0)
            # df_all_combs_3_result_all = df_all_combs_3_result_all.append(df_one_city_result_all)
            # df_all_combs_3_metrics_result_all = df_all_combs_3_metrics_result_all.append(df_one_city_metrics_result_all)
          if(len(combination_features) == 4):
            df_all_combs_4_result_all = pd.concat([df_all_combs_4_result_all, df_one_city_result_all], axis=0)
            df_all_combs_4_metrics_result_all = pd.concat([df_all_combs_4_metrics_result_all, df_one_city_metrics_result_all], axis=0)
            # df_all_combs_4_result_all = df_all_combs_4_result_all.append(df_one_city_result_all)
            # df_all_combs_4_metrics_result_all = df_all_combs_4_metrics_result_all.append(df_one_city_metrics_result_all)

          # lưu xuống nhiều lần, tránh mất dữ liệu khi train.
          df_all_combs_result_all.to_excel(com_path)
          df_all_combs_2_result_all.to_excel(com_path_2)
          df_all_combs_3_result_all.to_excel(com_path_3)
          df_all_combs_4_result_all.to_excel(com_path_4)

          df_all_combs_metrics_result_all.to_excel(com_path_metrics)
          df_all_combs_2_metrics_result_all.to_excel(com_path_metrics_2)
          df_all_combs_3_metrics_result_all.to_excel(com_path_metrics_3)
          df_all_combs_4_metrics_result_all.to_excel(com_path_metrics_4)

#           send_to_telegram("Server Chạy Xong validation Simple " + str(city))
          
        
      except Exception as e:
        l_errCity[city] = e
        break    
  

# dt_ended = datetime.now()
# run_time = round((dt_ended - dt_started).total_seconds()/60)
# print('kết thúc train trong:', run_time)
# print ('danh sách error city: ')
# print(l_errCity)

# send_to_telegram("Server Chạy Xong validation Simple")
# Out:
# <ipython-input-10-538c6d9183a6>:3: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   random.seed(seed)
# Epoch:  0/490 - train_loss: 0.7929 - test_loss: 0.621708
# Epoch: 122/490 - train_loss: 0.1676 - test_loss: 0.133520
# Epoch: 244/490 - train_loss: 0.1690 - test_loss: 0.131897
# Epoch: 366/490 - train_loss: 0.1711 - test_loss: 0.156918
# Epoch: 488/490 - train_loss: 0.1598 - test_loss: 0.140325
# Epoch: 489/490 - train_loss: 0.1619 - test_loss: 0.169599
# City: Thanh Hóa  _algo:cnn  -RMSE: 7.335919416336819
# City: Thanh Hóa  _algo:cnn  -RMSE: 7.230424317480148
# City: Thanh Hóa  _algo:cnn  -RMSE: 8.869876242741645
# Epoch:  0/500 - train_loss: 0.7669 - test_loss: 0.633909
# Epoch: 125/500 - train_loss: 0.1373 - test_loss: 0.141661
# Epoch: 250/500 - train_loss: 0.1045 - test_loss: 0.144941
# Epoch: 375/500 - train_loss: 0.0691 - test_loss: 0.192600
# Epoch: 499/500 - train_loss: 0.0456 - test_loss: 0.254031
# City: Thanh Hóa  _algo:lstm  -RMSE: 7.4850675851127075
# City: Thanh Hóa  _algo:lstm  -RMSE: 7.284536155104728
# City: Thanh Hóa  _algo:lstm  -RMSE: 9.41578954130382
# Epoch:  0/420 - train_loss: 0.7564 - test_loss: 0.669281
# Epoch: 105/420 - train_loss: 0.1727 - test_loss: 0.184805
# Epoch: 210/420 - train_loss: 0.1342 - test_loss: 0.160779
# Epoch: 315/420 - train_loss: 0.1111 - test_loss: 0.124184
# Epoch: 419/420 - train_loss: 0.0923 - test_loss: 0.117705
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 7.268139721665769
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 7.877243515742402
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 9.279246568958895
# Epoch:  0/130 - train_loss: 1.2404 - test_loss: 0.752485
# Epoch: 32/130 - train_loss: 0.3282 - test_loss: 0.298130
# Epoch: 64/130 - train_loss: 0.3297 - test_loss: 0.275459
# Epoch: 96/130 - train_loss: 0.3362 - test_loss: 0.269406
# Epoch: 128/130 - train_loss: 0.3315 - test_loss: 0.291226
# Epoch: 129/130 - train_loss: 0.3361 - test_loss: 0.274337
# Evaluate on test set:
# City: Thanh Hóa  _algo:transformers  -RMSE: 22.275664507188086
# City: Thanh Hóa  _algo:transformers  -RMSE: 20.196129153177118
# City: Thanh Hóa  _algo:transformers  -RMSE: 20.985130657596187
# {"ok":true,"result":{"message_id":498,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676433942,"text":"Server Ch\u1ea1y Xong validation Simple Thanh H\u00f3a"}}
# Epoch:  0/260 - train_loss: 0.8731 - test_loss: 0.682431
# Epoch: 65/260 - train_loss: 0.1762 - test_loss: 0.093190
# Epoch: 130/260 - train_loss: 0.1546 - test_loss: 0.069934
# Epoch: 195/260 - train_loss: 0.1398 - test_loss: 0.065461
# Epoch: 259/260 - train_loss: 0.1322 - test_loss: 0.063876
# City: Thái Bình  _algo:cnn  -RMSE: 20.83220845253378
# City: Thái Bình  _algo:cnn  -RMSE: 20.02195240406987
# City: Thái Bình  _algo:cnn  -RMSE: 20.226980095574984
# Epoch:  0/400 - train_loss: 0.8099 - test_loss: 0.713214
# Epoch: 100/400 - train_loss: 0.1519 - test_loss: 0.073122
# Epoch: 200/400 - train_loss: 0.1392 - test_loss: 0.078795
# Epoch: 300/400 - train_loss: 0.1427 - test_loss: 0.077497
# Epoch: 399/400 - train_loss: 0.1246 - test_loss: 0.083270
# City: Thái Bình  _algo:lstm  -RMSE: 19.94341380141908
# City: Thái Bình  _algo:lstm  -RMSE: 24.14043936140051
# City: Thái Bình  _algo:lstm  -RMSE: 19.53317999363151
# Epoch:  0/260 - train_loss: 1.7019 - test_loss: 0.702273
# Epoch: 65/260 - train_loss: 0.1827 - test_loss: 0.119642
# Epoch: 130/260 - train_loss: 0.1552 - test_loss: 0.074701
# Epoch: 195/260 - train_loss: 0.1527 - test_loss: 0.059212
# Epoch: 259/260 - train_loss: 0.1318 - test_loss: 0.067691
# City: Thái Bình  _algo:lstm_attention  -RMSE: 22.70954296279333
# City: Thái Bình  _algo:lstm_attention  -RMSE: 21.691767557291875
# City: Thái Bình  _algo:lstm_attention  -RMSE: 21.24857815238199
# Epoch:  0/330 - train_loss: 1.1170 - test_loss: 0.925959
# Epoch: 82/330 - train_loss: 0.2106 - test_loss: 0.102931
# Epoch: 164/330 - train_loss: 0.2124 - test_loss: 0.091164
# Epoch: 246/330 - train_loss: 0.2081 - test_loss: 0.092797
# Epoch: 328/330 - train_loss: 0.2182 - test_loss: 0.093715
# Epoch: 329/330 - train_loss: 0.2075 - test_loss: 0.092710
# Evaluate on test set:
# City: Thái Bình  _algo:transformers  -RMSE: 25.85648279804409
# City: Thái Bình  _algo:transformers  -RMSE: 24.904740385140915
# City: Thái Bình  _algo:transformers  -RMSE: 24.88190872214432
# {"ok":true,"result":{"message_id":503,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676434171,"text":"Server Ch\u1ea1y Xong validation Simple Th\u00e1i B\u00ecnh"}}
# Epoch:  0/330 - train_loss: 0.6694 - test_loss: 0.598865
# Epoch: 82/330 - train_loss: 0.1078 - test_loss: 0.231679
# Epoch: 164/330 - train_loss: 0.0874 - test_loss: 0.308763
# Epoch: 246/330 - train_loss: 0.0931 - test_loss: 0.279123
# Epoch: 328/330 - train_loss: 0.0944 - test_loss: 0.293879
# Epoch: 329/330 - train_loss: 0.0894 - test_loss: 0.289095
# City: Thái Nguyên  _algo:cnn  -RMSE: 35.0651821899357
# City: Thái Nguyên  _algo:cnn  -RMSE: 32.79887041301587
# City: Thái Nguyên  _algo:cnn  -RMSE: 36.345650871153566
# Epoch:  0/230 - train_loss: 0.6285 - test_loss: 0.549504
# Epoch: 57/230 - train_loss: 0.1504 - test_loss: 0.207230
# Epoch: 114/230 - train_loss: 0.1055 - test_loss: 0.193807
# Epoch: 171/230 - train_loss: 0.0814 - test_loss: 0.233998
# Epoch: 228/230 - train_loss: 0.1008 - test_loss: 0.203380
# Epoch: 229/230 - train_loss: 0.0915 - test_loss: 0.215712
# City: Thái Nguyên  _algo:lstm  -RMSE: 30.949698330551147
# City: Thái Nguyên  _algo:lstm  -RMSE: 33.34749331714317
# City: Thái Nguyên  _algo:lstm  -RMSE: 32.67932815541983
# Epoch:  0/230 - train_loss: 0.6298 - test_loss: 0.547801
# Epoch: 57/230 - train_loss: 0.1177 - test_loss: 0.203285
# Epoch: 114/230 - train_loss: 0.1088 - test_loss: 0.204648
# Epoch: 171/230 - train_loss: 0.1184 - test_loss: 0.205927
# Epoch: 228/230 - train_loss: 0.1239 - test_loss: 0.195921
# Epoch: 229/230 - train_loss: 0.1205 - test_loss: 0.202921
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 30.97425011111377
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 32.631920334767734
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 32.55189306146926
# Epoch:  0/230 - train_loss: 0.8985 - test_loss: 0.599018
# Epoch: 57/230 - train_loss: 0.1319 - test_loss: 0.201096
# Epoch: 114/230 - train_loss: 0.1317 - test_loss: 0.202866
# Epoch: 171/230 - train_loss: 0.1477 - test_loss: 0.200132
# Epoch: 228/230 - train_loss: 0.1335 - test_loss: 0.204744
# Epoch: 229/230 - train_loss: 0.1477 - test_loss: 0.197826
# Evaluate on test set:
# City: Thái Nguyên  _algo:transformers  -RMSE: 32.754685915538325
# City: Thái Nguyên  _algo:transformers  -RMSE: 34.335061574863595
# City: Thái Nguyên  _algo:transformers  -RMSE: 32.98550333239996
# {"ok":true,"result":{"message_id":507,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676434334,"text":"Server Ch\u1ea1y Xong validation Simple Th\u00e1i Nguy\u00ean"}}
# Epoch:  0/140 - train_loss: 0.8271 - test_loss: 0.711923
# Epoch: 35/140 - train_loss: 0.2076 - test_loss: 0.109860
# Epoch: 70/140 - train_loss: 0.2192 - test_loss: 0.099019
# Epoch: 105/140 - train_loss: 0.2028 - test_loss: 0.109193
# Epoch: 139/140 - train_loss: 0.1852 - test_loss: 0.102617
# City: Tiền Giang  _algo:cnn  -RMSE: 5.9604614239714975
# City: Tiền Giang  _algo:cnn  -RMSE: 6.672328816174615
# City: Tiền Giang  _algo:cnn  -RMSE: 8.782330342598405
# Epoch:  0/450 - train_loss: 1.0004 - test_loss: 0.707953
# Epoch: 112/450 - train_loss: 0.2872 - test_loss: 0.224870
# Epoch: 224/450 - train_loss: 0.2102 - test_loss: 0.125392
# Epoch: 336/450 - train_loss: 0.2098 - test_loss: 0.105175
# Epoch: 448/450 - train_loss: 0.2069 - test_loss: 0.122204
# Epoch: 449/450 - train_loss: 0.2039 - test_loss: 0.107169
# City: Tiền Giang  _algo:lstm  -RMSE: 5.470882775749801
# City: Tiền Giang  _algo:lstm  -RMSE: 7.527794353459118
# City: Tiền Giang  _algo:lstm  -RMSE: 7.065838573824159
# Epoch:  0/340 - train_loss: 1.0268 - test_loss: 0.665308
# Epoch: 85/340 - train_loss: 0.1916 - test_loss: 0.152848
# Epoch: 170/340 - train_loss: 0.1817 - test_loss: 0.108416
# Epoch: 255/340 - train_loss: 0.1620 - test_loss: 0.110148
# Epoch: 339/340 - train_loss: 0.1559 - test_loss: 0.129292
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 6.344341197217276
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 5.506433173128514
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 6.7264484636963155
# Epoch:  0/500 - train_loss: 1.1817 - test_loss: 0.774059
# Epoch: 125/500 - train_loss: 0.4301 - test_loss: 0.543572
# Epoch: 250/500 - train_loss: 0.4171 - test_loss: 0.534842
# Epoch: 375/500 - train_loss: 0.4156 - test_loss: 0.551240
# Epoch: 499/500 - train_loss: 0.4121 - test_loss: 0.541817
# Evaluate on test set:
# City: Tiền Giang  _algo:transformers  -RMSE: 53.04964661553655
# City: Tiền Giang  _algo:transformers  -RMSE: 44.630313978298624
# City: Tiền Giang  _algo:transformers  -RMSE: 50.23562313848977
# {"ok":true,"result":{"message_id":513,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676434606,"text":"Server Ch\u1ea1y Xong validation Simple Ti\u1ec1n Giang"}}
# Epoch:  0/200 - train_loss: 0.6774 - test_loss: 0.573688
# Epoch: 50/200 - train_loss: 0.1141 - test_loss: 0.072389
# Epoch: 100/200 - train_loss: 0.1036 - test_loss: 0.056980
# Epoch: 150/200 - train_loss: 0.1206 - test_loss: 0.051741
# Epoch: 199/200 - train_loss: 0.1091 - test_loss: 0.058143
# City: Trà Vinh  _algo:cnn  -RMSE: 11.888045760369485
# City: Trà Vinh  _algo:cnn  -RMSE: 7.87293728712342
# City: Trà Vinh  _algo:cnn  -RMSE: 13.151581518761471
# Epoch:  0/380 - train_loss: 0.7235 - test_loss: 0.649632
# Epoch: 95/380 - train_loss: 0.1062 - test_loss: 0.046758
# Epoch: 190/380 - train_loss: 0.0845 - test_loss: 0.055938
# Epoch: 285/380 - train_loss: 0.0769 - test_loss: 0.044571
# Epoch: 379/380 - train_loss: 0.0718 - test_loss: 0.040696
# City: Trà Vinh  _algo:lstm  -RMSE: 7.615030096644421
# City: Trà Vinh  _algo:lstm  -RMSE: 8.492690445416823
# City: Trà Vinh  _algo:lstm  -RMSE: 12.2260390676069
# Epoch:  0/370 - train_loss: 0.6583 - test_loss: 0.578647
# Epoch: 92/370 - train_loss: 0.0995 - test_loss: 0.064161
# Epoch: 184/370 - train_loss: 0.1458 - test_loss: 0.099274
# Epoch: 276/370 - train_loss: 0.1054 - test_loss: 0.055415
# Epoch: 368/370 - train_loss: 0.1080 - test_loss: 0.048625
# Epoch: 369/370 - train_loss: 0.1289 - test_loss: 0.057704
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 10.227300601809187
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 9.829195866109433
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 10.97827090963522
# Epoch:  0/160 - train_loss: 0.8702 - test_loss: 0.759427
# Epoch: 40/160 - train_loss: 0.1497 - test_loss: 0.086097
# Epoch: 80/160 - train_loss: 0.1495 - test_loss: 0.096829
# Epoch: 120/160 - train_loss: 0.1492 - test_loss: 0.094141
# Epoch: 159/160 - train_loss: 0.1492 - test_loss: 0.096850
# Evaluate on test set:
# City: Trà Vinh  _algo:transformers  -RMSE: 23.506785397182195
# City: Trà Vinh  _algo:transformers  -RMSE: 22.805409178633006
# City: Trà Vinh  _algo:transformers  -RMSE: 19.632372253686
# {"ok":true,"result":{"message_id":518,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676434758,"text":"Server Ch\u1ea1y Xong validation Simple Tr\u00e0 Vinh"}}
# Epoch:  0/460 - train_loss: 0.7157 - test_loss: 0.602726
# Epoch: 115/460 - train_loss: 0.1142 - test_loss: 0.056504
# Epoch: 230/460 - train_loss: 0.1219 - test_loss: 0.055846
# Epoch: 345/460 - train_loss: 0.1180 - test_loss: 0.064226
# Epoch: 459/460 - train_loss: 0.1082 - test_loss: 0.050289
# City: Tuyên Quang  _algo:cnn  -RMSE: 11.73793302633852
# City: Tuyên Quang  _algo:cnn  -RMSE: 11.426647358759892
# City: Tuyên Quang  _algo:cnn  -RMSE: 12.265039194903455
# Epoch:  0/450 - train_loss: 0.6954 - test_loss: 0.635014
# Epoch: 112/450 - train_loss: 0.0843 - test_loss: 0.042861
# Epoch: 224/450 - train_loss: 0.0802 - test_loss: 0.040538
# Epoch: 336/450 - train_loss: 0.0703 - test_loss: 0.048711
# Epoch: 448/450 - train_loss: 0.0716 - test_loss: 0.039826
# Epoch: 449/450 - train_loss: 0.0708 - test_loss: 0.044565
# City: Tuyên Quang  _algo:lstm  -RMSE: 12.409557109022952
# City: Tuyên Quang  _algo:lstm  -RMSE: 10.435453485976783
# City: Tuyên Quang  _algo:lstm  -RMSE: 9.943509385583218
# Epoch:  0/280 - train_loss: 0.6988 - test_loss: 0.650202
# Epoch: 70/280 - train_loss: 0.1030 - test_loss: 0.048334
# Epoch: 140/280 - train_loss: 0.0748 - test_loss: 0.038745
# Epoch: 210/280 - train_loss: 0.1074 - test_loss: 0.045286
# Epoch: 279/280 - train_loss: 0.0514 - test_loss: 0.042604
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 10.931833091523602
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 10.724996904599061
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 10.740449995338125
# Epoch:  0/120 - train_loss: 1.2505 - test_loss: 1.317198
# Epoch: 30/120 - train_loss: 0.7916 - test_loss: 0.740758
# Epoch: 60/120 - train_loss: 0.5593 - test_loss: 0.480209
# Epoch: 90/120 - train_loss: 0.4297 - test_loss: 0.373172
# Epoch: 119/120 - train_loss: 0.3559 - test_loss: 0.297659
# Evaluate on test set:
# City: Tuyên Quang  _algo:transformers  -RMSE: 13.281838205417337
# City: Tuyên Quang  _algo:transformers  -RMSE: 22.8566351988443
# City: Tuyên Quang  _algo:transformers  -RMSE: 16.286386415182907
# {"ok":true,"result":{"message_id":520,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676434934,"text":"Server Ch\u1ea1y Xong validation Simple Tuy\u00ean Quang"}}
# Epoch:  0/490 - train_loss: 0.7204 - test_loss: 0.588877
# Epoch: 122/490 - train_loss: 0.1748 - test_loss: 0.092382
# Epoch: 244/490 - train_loss: 0.1860 - test_loss: 0.088146
# Epoch: 366/490 - train_loss: 0.1852 - test_loss: 0.091468
# Epoch: 488/490 - train_loss: 0.1787 - test_loss: 0.083431
# Epoch: 489/490 - train_loss: 0.1914 - test_loss: 0.104500
# City: Tây Ninh  _algo:cnn  -RMSE: 4.148954550324996
# City: Tây Ninh  _algo:cnn  -RMSE: 3.745200938987374
# City: Tây Ninh  _algo:cnn  -RMSE: 3.5388048614760663
# Epoch:  0/400 - train_loss: 0.8150 - test_loss: 0.694395
# Epoch: 100/400 - train_loss: 0.4439 - test_loss: 0.417016
# Epoch: 200/400 - train_loss: 0.2676 - test_loss: 0.229249
# Epoch: 300/400 - train_loss: 0.1863 - test_loss: 0.120765
# Epoch: 399/400 - train_loss: 0.1701 - test_loss: 0.083465
# City: Tây Ninh  _algo:lstm  -RMSE: 3.274566859554842
# City: Tây Ninh  _algo:lstm  -RMSE: 2.697478043866892
# City: Tây Ninh  _algo:lstm  -RMSE: 3.299970024879304
# Epoch:  0/490 - train_loss: 0.7129 - test_loss: 0.637781
# Epoch: 122/490 - train_loss: 0.1693 - test_loss: 0.087480
# Epoch: 244/490 - train_loss: 0.1636 - test_loss: 0.105401
# Epoch: 366/490 - train_loss: 0.1571 - test_loss: 0.067874
# Epoch: 488/490 - train_loss: 0.1374 - test_loss: 0.072325
# Epoch: 489/490 - train_loss: 0.1408 - test_loss: 0.074417
# City: Tây Ninh  _algo:lstm_attention  -RMSE: 4.42270520197513
# City: Tây Ninh  _algo:lstm_attention  -RMSE: 4.675146592118917
# City: Tây Ninh  _algo:lstm_attention  -RMSE: 4.448826821974748
# Epoch:  0/200 - train_loss: 1.3046 - test_loss: 0.839019
# Epoch: 50/200 - train_loss: 0.3240 - test_loss: 0.282992
# Epoch: 100/200 - train_loss: 0.3281 - test_loss: 0.275296
# Epoch: 150/200 - train_loss: 0.3351 - test_loss: 0.265254
# Epoch: 199/200 - train_loss: 0.3249 - test_loss: 0.259316
# Evaluate on test set:
# City: Tây Ninh  _algo:transformers  -RMSE: 17.623380685304568
# City: Tây Ninh  _algo:transformers  -RMSE: 16.4241268120724
# City: Tây Ninh  _algo:transformers  -RMSE: 15.96727022029644
# {"ok":true,"result":{"message_id":527,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676435220,"text":"Server Ch\u1ea1y Xong validation Simple T\u00e2y Ninh"}}
# Epoch:  0/420 - train_loss: 0.6780 - test_loss: 0.564614
# Epoch: 105/420 - train_loss: 0.1089 - test_loss: 0.057702
# Epoch: 210/420 - train_loss: 0.1058 - test_loss: 0.061980
# Epoch: 315/420 - train_loss: 0.1027 - test_loss: 0.053933
# Epoch: 419/420 - train_loss: 0.1028 - test_loss: 0.053510
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 10.638898541236571
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 10.55805624261634
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 11.30996942805792
# Epoch:  0/390 - train_loss: 0.6548 - test_loss: 0.566809
# Epoch: 97/390 - train_loss: 0.1016 - test_loss: 0.049226
# Epoch: 194/390 - train_loss: 0.1472 - test_loss: 0.047693
# Epoch: 291/390 - train_loss: 0.1221 - test_loss: 0.055081
# Epoch: 388/390 - train_loss: 0.0978 - test_loss: 0.048717
# Epoch: 389/390 - train_loss: 0.1141 - test_loss: 0.056833
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 10.333753262464942
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 10.471630408550407
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 12.554963240857395
# Epoch:  0/200 - train_loss: 0.6526 - test_loss: 0.550899
# Epoch: 50/200 - train_loss: 0.1102 - test_loss: 0.059929
# Epoch: 100/200 - train_loss: 0.1031 - test_loss: 0.049699
# Epoch: 150/200 - train_loss: 0.1061 - test_loss: 0.046838
# Epoch: 199/200 - train_loss: 0.1078 - test_loss: 0.051677
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 10.698321089817904
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 10.411577713639161
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 10.69615437724623
# Epoch:  0/200 - train_loss: 0.8436 - test_loss: 0.637429
# Epoch: 50/200 - train_loss: 0.1338 - test_loss: 0.086100
# Epoch: 100/200 - train_loss: 0.1352 - test_loss: 0.083808
# Epoch: 150/200 - train_loss: 0.1365 - test_loss: 0.102063
# Epoch: 199/200 - train_loss: 0.1332 - test_loss: 0.082936
# Evaluate on test set:
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 21.705448414131453
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 10.98566546811749
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 12.764394819428494
# {"ok":true,"result":{"message_id":532,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676435395,"text":"Server Ch\u1ea1y Xong validation Simple V\u0129nh Ph\u00fac"}}
# Epoch:  0/390 - train_loss: 0.7707 - test_loss: 0.691509
# Epoch: 97/390 - train_loss: 0.1897 - test_loss: 0.101517
# Epoch: 194/390 - train_loss: 0.1678 - test_loss: 0.094777
# Epoch: 291/390 - train_loss: 0.1593 - test_loss: 0.096254
# Epoch: 388/390 - train_loss: 0.1572 - test_loss: 0.106401
# Epoch: 389/390 - train_loss: 0.1633 - test_loss: 0.124445
# City: Yên Bái  _algo:cnn  -RMSE: 8.09736528566991
# City: Yên Bái  _algo:cnn  -RMSE: 8.81103939091717
# City: Yên Bái  _algo:cnn  -RMSE: 10.405492021397583
# Epoch:  0/380 - train_loss: 0.7948 - test_loss: 0.806494
# Epoch: 95/380 - train_loss: 0.1683 - test_loss: 0.093075
# Epoch: 190/380 - train_loss: 0.1499 - test_loss: 0.083347
# Epoch: 285/380 - train_loss: 0.1354 - test_loss: 0.082100
# Epoch: 379/380 - train_loss: 0.0827 - test_loss: 0.135291
# City: Yên Bái  _algo:lstm  -RMSE: 14.101786770610286
# City: Yên Bái  _algo:lstm  -RMSE: 13.36633744517459
# City: Yên Bái  _algo:lstm  -RMSE: 14.839747480195031
# Epoch:  0/440 - train_loss: 1.0150 - test_loss: 0.834045
# Epoch: 110/440 - train_loss: 0.2289 - test_loss: 0.162162
# Epoch: 220/440 - train_loss: 0.1821 - test_loss: 0.106574
# Epoch: 330/440 - train_loss: 0.1813 - test_loss: 0.105866
# Epoch: 439/440 - train_loss: 0.1693 - test_loss: 0.100484
# City: Yên Bái  _algo:lstm_attention  -RMSE: 9.96657054288523
# City: Yên Bái  _algo:lstm_attention  -RMSE: 13.522580605378682
# City: Yên Bái  _algo:lstm_attention  -RMSE: 19.954374283597744
# Epoch:  0/430 - train_loss: 1.2370 - test_loss: 0.698945
# Epoch: 107/430 - train_loss: 0.2947 - test_loss: 0.385468
# Epoch: 214/430 - train_loss: 0.2952 - test_loss: 0.319415
# Epoch: 321/430 - train_loss: 0.3033 - test_loss: 0.330985
# Epoch: 428/430 - train_loss: 0.2928 - test_loss: 0.351230
# Epoch: 429/430 - train_loss: 0.2955 - test_loss: 0.266286
# Evaluate on test set:
# City: Yên Bái  _algo:transformers  -RMSE: 39.61525535381463
# City: Yên Bái  _algo:transformers  -RMSE: 45.27309739717028
# City: Yên Bái  _algo:transformers  -RMSE: 43.40165997500365
# {"ok":true,"result":{"message_id":537,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676435684,"text":"Server Ch\u1ea1y Xong validation Simple Y\u00ean B\u00e1i"}}
# Epoch:  0/320 - train_loss: 0.8392 - test_loss: 0.586051
# Epoch: 80/320 - train_loss: 0.2510 - test_loss: 0.174891
# Epoch: 160/320 - train_loss: 0.2571 - test_loss: 0.173321
# Epoch: 240/320 - train_loss: 0.2828 - test_loss: 0.182468
# Epoch: 319/320 - train_loss: 0.2517 - test_loss: 0.201932
# City: Điện Biên  _algo:cnn  -RMSE: 42.50647920086492
# City: Điện Biên  _algo:cnn  -RMSE: 46.655190826802404
# City: Điện Biên  _algo:cnn  -RMSE: 42.23297670549521
# Epoch:  0/390 - train_loss: 0.8141 - test_loss: 0.605160
# Epoch: 97/390 - train_loss: 0.2404 - test_loss: 0.399399
# Epoch: 194/390 - train_loss: 0.2281 - test_loss: 0.402330
# Epoch: 291/390 - train_loss: 0.2488 - test_loss: 0.387079
# Epoch: 388/390 - train_loss: 0.2293 - test_loss: 0.409059
# Epoch: 389/390 - train_loss: 0.2353 - test_loss: 0.391062
# City: Điện Biên  _algo:lstm  -RMSE: 51.842802874452865
# City: Điện Biên  _algo:lstm  -RMSE: 48.6636808259613
# City: Điện Biên  _algo:lstm  -RMSE: 52.47094083136635
# Epoch:  0/400 - train_loss: 1.1304 - test_loss: 0.991039
# Epoch: 100/400 - train_loss: 0.5718 - test_loss: 0.454197
# Epoch: 200/400 - train_loss: 0.4501 - test_loss: 0.296483
# Epoch: 300/400 - train_loss: 0.3454 - test_loss: 0.247491
# Epoch: 399/400 - train_loss: 0.2582 - test_loss: 0.231873
# City: Điện Biên  _algo:lstm_attention  -RMSE: 69.89436610922701
# City: Điện Biên  _algo:lstm_attention  -RMSE: 80.04569261975442
# City: Điện Biên  _algo:lstm_attention  -RMSE: 69.84609619104863
# Epoch:  0/260 - train_loss: 1.3004 - test_loss: 1.197150
# Epoch: 65/260 - train_loss: 0.4190 - test_loss: 0.192814
# Epoch: 130/260 - train_loss: 0.4157 - test_loss: 0.184248
# Epoch: 195/260 - train_loss: 0.4214 - test_loss: 0.185503
# Epoch: 259/260 - train_loss: 0.4243 - test_loss: 0.183563
# Evaluate on test set:
# City: Điện Biên  _algo:transformers  -RMSE: 41.84880349204672
# City: Điện Biên  _algo:transformers  -RMSE: 41.674851393558846
# City: Điện Biên  _algo:transformers  -RMSE: 41.62637250176518
# {"ok":true,"result":{"message_id":543,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676435876,"text":"Server Ch\u1ea1y Xong validation Simple \u0110i\u1ec7n Bi\u00ean"}}
# Epoch:  0/440 - train_loss: 0.7886 - test_loss: 0.579934
# Epoch: 110/440 - train_loss: 0.1258 - test_loss: 0.058290
# Epoch: 220/440 - train_loss: 0.1279 - test_loss: 0.064388
# Epoch: 330/440 - train_loss: 0.1247 - test_loss: 0.052862
# Epoch: 439/440 - train_loss: 0.1462 - test_loss: 0.058390
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.790891011543405
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.593691544969047
# City: Đà Nẵng  _algo:cnn  -RMSE: 24.73121084651641
# Epoch:  0/420 - train_loss: 0.6882 - test_loss: 0.630802
# Epoch: 105/420 - train_loss: 0.1244 - test_loss: 0.056264
# Epoch: 210/420 - train_loss: 0.1240 - test_loss: 0.061259
# Epoch: 315/420 - train_loss: 0.1260 - test_loss: 0.059338
# Epoch: 419/420 - train_loss: 0.1320 - test_loss: 0.055685
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.917051496608313
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.95082691701968
# City: Đà Nẵng  _algo:lstm  -RMSE: 22.494395638797926
# Epoch:  0/500 - train_loss: 0.6660 - test_loss: 0.555108
# Epoch: 125/500 - train_loss: 0.1258 - test_loss: 0.056997
# Epoch: 250/500 - train_loss: 0.1251 - test_loss: 0.052250
# Epoch: 375/500 - train_loss: 0.1470 - test_loss: 0.053992
# Epoch: 499/500 - train_loss: 0.1468 - test_loss: 0.055521
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 24.87399916098956
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 23.99648430737829
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 21.721526347544692
# Epoch:  0/370 - train_loss: 0.7610 - test_loss: 0.629226
# Epoch: 92/370 - train_loss: 0.1316 - test_loss: 0.056661
# Epoch: 184/370 - train_loss: 0.1476 - test_loss: 0.058681
# Epoch: 276/370 - train_loss: 0.1250 - test_loss: 0.055072
# Epoch: 368/370 - train_loss: 0.1246 - test_loss: 0.056940
# Epoch: 369/370 - train_loss: 0.1245 - test_loss: 0.056665
# Evaluate on test set:
# City: Đà Nẵng  _algo:transformers  -RMSE: 27.571034563654184
# City: Đà Nẵng  _algo:transformers  -RMSE: 23.110692998487078
# City: Đà Nẵng  _algo:transformers  -RMSE: 24.654249023349497
# {"ok":true,"result":{"message_id":550,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676436165,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u00e0 N\u1eb5ng"}}
# Epoch:  0/170 - train_loss: 0.8019 - test_loss: 0.701129
# Epoch: 42/170 - train_loss: 0.6740 - test_loss: 0.618336
# Epoch: 84/170 - train_loss: 0.5923 - test_loss: 0.546868
# Epoch: 126/170 - train_loss: 0.5216 - test_loss: 0.480058
# Epoch: 168/170 - train_loss: 0.4599 - test_loss: 0.418189
# Epoch: 169/170 - train_loss: 0.4539 - test_loss: 0.416870
# City: Đắk Nông  _algo:cnn  -RMSE: 9.11379855991361
# City: Đắk Nông  _algo:cnn  -RMSE: 9.254827512759977
# City: Đắk Nông  _algo:cnn  -RMSE: 9.882409843021254
# Epoch:  0/250 - train_loss: 0.8369 - test_loss: 0.726420
# Epoch: 62/250 - train_loss: 0.2874 - test_loss: 0.134939
# Epoch: 124/250 - train_loss: 0.2263 - test_loss: 0.111010
# Epoch: 186/250 - train_loss: 0.2251 - test_loss: 0.215648
# Epoch: 248/250 - train_loss: 0.2188 - test_loss: 0.207320
# Epoch: 249/250 - train_loss: 0.2194 - test_loss: 0.197123
# City: Đắk Nông  _algo:lstm  -RMSE: 14.084209317113249
# City: Đắk Nông  _algo:lstm  -RMSE: 12.640137078415306
# City: Đắk Nông  _algo:lstm  -RMSE: 12.98056713822917
# Epoch:  0/500 - train_loss: 0.6808 - test_loss: 0.585097
# Epoch: 125/500 - train_loss: 0.2944 - test_loss: 0.130374
# Epoch: 250/500 - train_loss: 0.3099 - test_loss: 0.127651
# Epoch: 375/500 - train_loss: 0.2885 - test_loss: 0.130836
# Epoch: 499/500 - train_loss: 0.2937 - test_loss: 0.138821
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 10.883577785898208
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 12.188044798205073
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 12.349669396577708
# Epoch:  0/410 - train_loss: 0.9436 - test_loss: 0.713438
# Epoch: 102/410 - train_loss: 0.3168 - test_loss: 0.215867
# Epoch: 204/410 - train_loss: 0.2196 - test_loss: 0.123776
# Epoch: 306/410 - train_loss: 0.2130 - test_loss: 0.112174
# Epoch: 408/410 - train_loss: 0.2163 - test_loss: 0.110744
# Epoch: 409/410 - train_loss: 0.2098 - test_loss: 0.110316
# Evaluate on test set:
# City: Đắk Nông  _algo:transformers  -RMSE: 8.568357014132339
# City: Đắk Nông  _algo:transformers  -RMSE: 8.554132012261402
# City: Đắk Nông  _algo:transformers  -RMSE: 8.364721046138667
# {"ok":true,"result":{"message_id":558,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676436497,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1eafk N\u00f4ng"}}
# Epoch:  0/150 - train_loss: 0.7265 - test_loss: 0.689101
# Epoch: 37/150 - train_loss: 0.3522 - test_loss: 0.329492
# Epoch: 74/150 - train_loss: 0.1748 - test_loss: 0.142246
# Epoch: 111/150 - train_loss: 0.1270 - test_loss: 0.076949
# Epoch: 148/150 - train_loss: 0.1349 - test_loss: 0.063797
# Epoch: 149/150 - train_loss: 0.1209 - test_loss: 0.063227
# City: Đắk Lắk  _algo:cnn  -RMSE: 13.12949288771103
# City: Đắk Lắk  _algo:cnn  -RMSE: 14.099667896008345
# City: Đắk Lắk  _algo:cnn  -RMSE: 13.562532189490557
# Epoch:  0/380 - train_loss: 0.6713 - test_loss: 0.577981
# Epoch: 95/380 - train_loss: 0.1229 - test_loss: 0.081616
# Epoch: 190/380 - train_loss: 0.1137 - test_loss: 0.073920
# Epoch: 285/380 - train_loss: 0.1025 - test_loss: 0.095278
# Epoch: 379/380 - train_loss: 0.0986 - test_loss: 0.144546
# City: Đắk Lắk  _algo:lstm  -RMSE: 11.912095428637556
# City: Đắk Lắk  _algo:lstm  -RMSE: 14.502539718682538
# City: Đắk Lắk  _algo:lstm  -RMSE: 13.878612237971868
# Epoch:  0/190 - train_loss: 0.7055 - test_loss: 0.623479
# Epoch: 47/190 - train_loss: 0.1366 - test_loss: 0.071624
# Epoch: 94/190 - train_loss: 0.1327 - test_loss: 0.081790
# Epoch: 141/190 - train_loss: 0.1227 - test_loss: 0.065472
# Epoch: 188/190 - train_loss: 0.1279 - test_loss: 0.062230
# Epoch: 189/190 - train_loss: 0.1241 - test_loss: 0.060878
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 11.669218287689409
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 13.434079476838363
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 13.184096898961911
# Epoch:  0/220 - train_loss: 1.0660 - test_loss: 1.166387
# Epoch: 55/220 - train_loss: 0.1619 - test_loss: 0.086478
# Epoch: 110/220 - train_loss: 0.1605 - test_loss: 0.091598
# Epoch: 165/220 - train_loss: 0.1601 - test_loss: 0.086284
# Epoch: 219/220 - train_loss: 0.1617 - test_loss: 0.088834
# Evaluate on test set:
# City: Đắk Lắk  _algo:transformers  -RMSE: 13.824735339101244
# City: Đắk Lắk  _algo:transformers  -RMSE: 13.381796677553048
# City: Đắk Lắk  _algo:transformers  -RMSE: 19.166482980738966
# {"ok":true,"result":{"message_id":562,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676436650,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1eafk L\u1eafk"}}
# Epoch:  0/110 - train_loss: 0.7883 - test_loss: 0.565645
# Epoch: 27/110 - train_loss: 0.2325 - test_loss: 0.245684
# Epoch: 54/110 - train_loss: 0.2502 - test_loss: 0.220629
# Epoch: 81/110 - train_loss: 0.2330 - test_loss: 0.254169
# Epoch: 108/110 - train_loss: 0.2380 - test_loss: 0.251148
# Epoch: 109/110 - train_loss: 0.2281 - test_loss: 0.288956
# City: Đồng Tháp  _algo:cnn  -RMSE: 22.386650400758406
# City: Đồng Tháp  _algo:cnn  -RMSE: 16.333316971954304
# City: Đồng Tháp  _algo:cnn  -RMSE: 18.098343370951845
# Epoch:  0/290 - train_loss: 0.9849 - test_loss: 0.720025
# Epoch: 72/290 - train_loss: 0.2286 - test_loss: 0.173891
# Epoch: 144/290 - train_loss: 0.2207 - test_loss: 0.138686
# Epoch: 216/290 - train_loss: 0.2208 - test_loss: 0.178065
# Epoch: 288/290 - train_loss: 0.2037 - test_loss: 0.208766
# Epoch: 289/290 - train_loss: 0.2037 - test_loss: 0.211059
# City: Đồng Tháp  _algo:lstm  -RMSE: 12.949504077840931
# City: Đồng Tháp  _algo:lstm  -RMSE: 13.001097795985054
# City: Đồng Tháp  _algo:lstm  -RMSE: 16.22380814847872
# Epoch:  0/100 - train_loss: 1.0273 - test_loss: 0.685060
# Epoch: 25/100 - train_loss: 0.2777 - test_loss: 0.181065
# Epoch: 50/100 - train_loss: 0.2433 - test_loss: 0.130633
# Epoch: 75/100 - train_loss: 0.2222 - test_loss: 0.124985
# Epoch: 99/100 - train_loss: 0.2228 - test_loss: 0.144138
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 13.777263340268755
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 11.187096915343586
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 11.463589723541261
# Epoch:  0/420 - train_loss: 1.2294 - test_loss: 0.830224
# Epoch: 105/420 - train_loss: 0.2938 - test_loss: 0.418914
# Epoch: 210/420 - train_loss: 0.2846 - test_loss: 0.376723
# Epoch: 315/420 - train_loss: 0.2832 - test_loss: 0.397643
# Epoch: 419/420 - train_loss: 0.2909 - test_loss: 0.387723
# Evaluate on test set:
# City: Đồng Tháp  _algo:transformers  -RMSE: 42.18360939925684
# City: Đồng Tháp  _algo:transformers  -RMSE: 45.311256611100085
# City: Đồng Tháp  _algo:transformers  -RMSE: 38.85149636096248
# {"ok":true,"result":{"message_id":564,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676436820,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1ed3ng Th\u00e1p"}}
# Epoch:  0/490 - train_loss: 0.8100 - test_loss: 0.604228
# Epoch: 122/490 - train_loss: 0.1678 - test_loss: 0.150298
# Epoch: 244/490 - train_loss: 0.1705 - test_loss: 0.139891
# Epoch: 366/490 - train_loss: 0.1755 - test_loss: 0.156947
# Epoch: 488/490 - train_loss: 0.1809 - test_loss: 0.178911
# Epoch: 489/490 - train_loss: 0.1633 - test_loss: 0.132530
# City: Thanh Hóa  _algo:cnn  -RMSE: 9.177765550686821
# City: Thanh Hóa  _algo:cnn  -RMSE: 9.515088411784044
# City: Thanh Hóa  _algo:cnn  -RMSE: 9.361764810213298
# Epoch:  0/500 - train_loss: 0.7671 - test_loss: 0.628905
# Epoch: 125/500 - train_loss: 0.1382 - test_loss: 0.147998
# Epoch: 250/500 - train_loss: 0.1218 - test_loss: 0.141113
# Epoch: 375/500 - train_loss: 0.0439 - test_loss: 0.183438
# Epoch: 499/500 - train_loss: 0.0134 - test_loss: 0.494577
# City: Thanh Hóa  _algo:lstm  -RMSE: 7.102030044362975
# City: Thanh Hóa  _algo:lstm  -RMSE: 8.057071121170683
# City: Thanh Hóa  _algo:lstm  -RMSE: 10.034221042195204
# Epoch:  0/420 - train_loss: 0.7607 - test_loss: 0.629058
# Epoch: 105/420 - train_loss: 0.1268 - test_loss: 0.108081
# Epoch: 210/420 - train_loss: 0.1195 - test_loss: 0.116545
# Epoch: 315/420 - train_loss: 0.1067 - test_loss: 0.114865
# Epoch: 419/420 - train_loss: 0.0723 - test_loss: 0.215129
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 9.108466530366607
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 9.00379855246443
# City: Thanh Hóa  _algo:lstm_attention  -RMSE: 9.637772836938652
# Epoch:  0/130 - train_loss: 1.5853 - test_loss: 0.808744
# Epoch: 32/130 - train_loss: 0.3422 - test_loss: 0.279344
# Epoch: 64/130 - train_loss: 0.3392 - test_loss: 0.274388
# Epoch: 96/130 - train_loss: 0.3354 - test_loss: 0.299158
# Epoch: 128/130 - train_loss: 0.3317 - test_loss: 0.292204
# Epoch: 129/130 - train_loss: 0.3244 - test_loss: 0.273957
# Evaluate on test set:
# City: Thanh Hóa  _algo:transformers  -RMSE: 23.26432388295516
# City: Thanh Hóa  _algo:transformers  -RMSE: 21.313445506587072
# City: Thanh Hóa  _algo:transformers  -RMSE: 21.29892703208986
# {"ok":true,"result":{"message_id":569,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676437070,"text":"Server Ch\u1ea1y Xong validation Simple Thanh H\u00f3a"}}
# Epoch:  0/260 - train_loss: 0.9323 - test_loss: 0.699155
# Epoch: 65/260 - train_loss: 0.1803 - test_loss: 0.095513
# Epoch: 130/260 - train_loss: 0.1591 - test_loss: 0.068612
# Epoch: 195/260 - train_loss: 0.1475 - test_loss: 0.066461
# Epoch: 259/260 - train_loss: 0.1434 - test_loss: 0.065418
# City: Thái Bình  _algo:cnn  -RMSE: 20.617454999868077
# City: Thái Bình  _algo:cnn  -RMSE: 19.210309725830445
# City: Thái Bình  _algo:cnn  -RMSE: 18.86291899036036
# Epoch:  0/400 - train_loss: 0.9277 - test_loss: 0.814318
# Epoch: 100/400 - train_loss: 0.1521 - test_loss: 0.068055
# Epoch: 200/400 - train_loss: 0.1442 - test_loss: 0.075302
# Epoch: 300/400 - train_loss: 0.1357 - test_loss: 0.061906
# Epoch: 399/400 - train_loss: 0.1298 - test_loss: 0.064336
# City: Thái Bình  _algo:lstm  -RMSE: 20.315328408507547
# City: Thái Bình  _algo:lstm  -RMSE: 17.23140798651904
# City: Thái Bình  _algo:lstm  -RMSE: 17.599632594420804
# Epoch:  0/260 - train_loss: 2.0943 - test_loss: 0.740207
# Epoch: 65/260 - train_loss: 0.1906 - test_loss: 0.078033
# Epoch: 130/260 - train_loss: 0.1873 - test_loss: 0.081059
# Epoch: 195/260 - train_loss: 0.1759 - test_loss: 0.086196
# Epoch: 259/260 - train_loss: 0.1806 - test_loss: 0.081080
# City: Thái Bình  _algo:lstm_attention  -RMSE: 28.538982939569998
# City: Thái Bình  _algo:lstm_attention  -RMSE: 28.728703054182922
# City: Thái Bình  _algo:lstm_attention  -RMSE: 24.30992040097419
# Epoch:  0/330 - train_loss: 1.3617 - test_loss: 1.029173
# Epoch: 82/330 - train_loss: 0.2097 - test_loss: 0.100454
# Epoch: 164/330 - train_loss: 0.2139 - test_loss: 0.092664
# Epoch: 246/330 - train_loss: 0.2136 - test_loss: 0.091644
# Epoch: 328/330 - train_loss: 0.2080 - test_loss: 0.094158
# Epoch: 329/330 - train_loss: 0.2158 - test_loss: 0.091673
# Evaluate on test set:
# City: Thái Bình  _algo:transformers  -RMSE: 24.606297310955448
# City: Thái Bình  _algo:transformers  -RMSE: 24.613940736766658
# City: Thái Bình  _algo:transformers  -RMSE: 24.67032251272969
# {"ok":true,"result":{"message_id":575,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676437338,"text":"Server Ch\u1ea1y Xong validation Simple Th\u00e1i B\u00ecnh"}}
# Epoch:  0/330 - train_loss: 0.6716 - test_loss: 0.598276
# Epoch: 82/330 - train_loss: 0.0824 - test_loss: 0.245721
# Epoch: 164/330 - train_loss: 0.0771 - test_loss: 0.303662
# Epoch: 246/330 - train_loss: 0.0714 - test_loss: 0.315240
# Epoch: 328/330 - train_loss: 0.0718 - test_loss: 0.339124
# Epoch: 329/330 - train_loss: 0.0714 - test_loss: 0.350278
# City: Thái Nguyên  _algo:cnn  -RMSE: 32.11844083931027
# City: Thái Nguyên  _algo:cnn  -RMSE: 34.599030924911055
# City: Thái Nguyên  _algo:cnn  -RMSE: 37.732281368299205
# Epoch:  0/230 - train_loss: 0.6283 - test_loss: 0.550367
# Epoch: 57/230 - train_loss: 0.1198 - test_loss: 0.199333
# Epoch: 114/230 - train_loss: 0.0829 - test_loss: 0.229420
# Epoch: 171/230 - train_loss: 0.1186 - test_loss: 0.192557
# Epoch: 228/230 - train_loss: 0.1210 - test_loss: 0.202730
# Epoch: 229/230 - train_loss: 0.1220 - test_loss: 0.191837
# City: Thái Nguyên  _algo:lstm  -RMSE: 31.905756152144942
# City: Thái Nguyên  _algo:lstm  -RMSE: 32.05265734840357
# City: Thái Nguyên  _algo:lstm  -RMSE: 32.52459851369085
# Epoch:  0/230 - train_loss: 0.6415 - test_loss: 0.551590
# Epoch: 57/230 - train_loss: 0.1130 - test_loss: 0.201425
# Epoch: 114/230 - train_loss: 0.1139 - test_loss: 0.200995
# Epoch: 171/230 - train_loss: 0.1140 - test_loss: 0.199456
# Epoch: 228/230 - train_loss: 0.1050 - test_loss: 0.201578
# Epoch: 229/230 - train_loss: 0.1124 - test_loss: 0.195869
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 31.358260477882435
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 31.261587840377207
# City: Thái Nguyên  _algo:lstm_attention  -RMSE: 32.28335276985466
# Epoch:  0/230 - train_loss: 0.9419 - test_loss: 0.583876
# Epoch: 57/230 - train_loss: 0.1319 - test_loss: 0.204362
# Epoch: 114/230 - train_loss: 0.1311 - test_loss: 0.200479
# Epoch: 171/230 - train_loss: 0.1309 - test_loss: 0.200201
# Epoch: 228/230 - train_loss: 0.1300 - test_loss: 0.193808
# Epoch: 229/230 - train_loss: 0.1301 - test_loss: 0.199973
# Evaluate on test set:
# City: Thái Nguyên  _algo:transformers  -RMSE: 32.31935054544395
# City: Thái Nguyên  _algo:transformers  -RMSE: 32.83140224158198
# City: Thái Nguyên  _algo:transformers  -RMSE: 32.631713776629596
# {"ok":true,"result":{"message_id":579,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676437471,"text":"Server Ch\u1ea1y Xong validation Simple Th\u00e1i Nguy\u00ean"}}
# Epoch:  0/140 - train_loss: 0.8077 - test_loss: 0.698430
# Epoch: 35/140 - train_loss: 0.2262 - test_loss: 0.105522
# Epoch: 70/140 - train_loss: 0.2159 - test_loss: 0.098417
# Epoch: 105/140 - train_loss: 0.1983 - test_loss: 0.089817
# Epoch: 139/140 - train_loss: 0.2079 - test_loss: 0.114461
# City: Tiền Giang  _algo:cnn  -RMSE: 3.9389640575227776
# City: Tiền Giang  _algo:cnn  -RMSE: 6.075932417582895
# City: Tiền Giang  _algo:cnn  -RMSE: 6.286437808168572
# Epoch:  0/450 - train_loss: 0.9106 - test_loss: 0.687750
# Epoch: 112/450 - train_loss: 0.2705 - test_loss: 0.209010
# Epoch: 224/450 - train_loss: 0.2034 - test_loss: 0.107824
# Epoch: 336/450 - train_loss: 0.1999 - test_loss: 0.110785
# Epoch: 448/450 - train_loss: 0.2079 - test_loss: 0.108969
# Epoch: 449/450 - train_loss: 0.2010 - test_loss: 0.110387
# City: Tiền Giang  _algo:lstm  -RMSE: 7.9427410653177875
# City: Tiền Giang  _algo:lstm  -RMSE: 9.441581923313898
# City: Tiền Giang  _algo:lstm  -RMSE: 10.73620129048598
# Epoch:  0/340 - train_loss: 1.0314 - test_loss: 0.641318
# Epoch: 85/340 - train_loss: 0.2063 - test_loss: 0.131168
# Epoch: 170/340 - train_loss: 0.1939 - test_loss: 0.124961
# Epoch: 255/340 - train_loss: 0.1906 - test_loss: 0.120261
# Epoch: 339/340 - train_loss: 0.1919 - test_loss: 0.186292
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 9.88883015172149
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 8.959735214330788
# City: Tiền Giang  _algo:lstm_attention  -RMSE: 10.109408291879925
# Epoch:  0/500 - train_loss: 0.8290 - test_loss: 0.665342
# Epoch: 125/500 - train_loss: 0.4190 - test_loss: 0.535461
# Epoch: 250/500 - train_loss: 0.4172 - test_loss: 0.578888
# Epoch: 375/500 - train_loss: 0.4159 - test_loss: 0.559353
# Epoch: 499/500 - train_loss: 0.4131 - test_loss: 0.565608
# Evaluate on test set:
# City: Tiền Giang  _algo:transformers  -RMSE: 50.783289128958366
# City: Tiền Giang  _algo:transformers  -RMSE: 56.94693694613153
# City: Tiền Giang  _algo:transformers  -RMSE: 50.14715551331964
# {"ok":true,"result":{"message_id":584,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676437790,"text":"Server Ch\u1ea1y Xong validation Simple Ti\u1ec1n Giang"}}
# Epoch:  0/200 - train_loss: 0.6774 - test_loss: 0.570347
# Epoch: 50/200 - train_loss: 0.1253 - test_loss: 0.059901
# Epoch: 100/200 - train_loss: 0.1320 - test_loss: 0.054099
# Epoch: 150/200 - train_loss: 0.1117 - test_loss: 0.057965
# Epoch: 199/200 - train_loss: 0.1263 - test_loss: 0.058643
# City: Trà Vinh  _algo:cnn  -RMSE: 9.144370884260756
# City: Trà Vinh  _algo:cnn  -RMSE: 9.161965513662457
# City: Trà Vinh  _algo:cnn  -RMSE: 11.619536096651276
# Epoch:  0/380 - train_loss: 0.7539 - test_loss: 0.681560
# Epoch: 95/380 - train_loss: 0.1151 - test_loss: 0.054426
# Epoch: 190/380 - train_loss: 0.0838 - test_loss: 0.042463
# Epoch: 285/380 - train_loss: 0.0789 - test_loss: 0.041168
# Epoch: 379/380 - train_loss: 0.0781 - test_loss: 0.037127
# City: Trà Vinh  _algo:lstm  -RMSE: 8.324388106805706
# City: Trà Vinh  _algo:lstm  -RMSE: 8.552961727363071
# City: Trà Vinh  _algo:lstm  -RMSE: 13.314483024788764
# Epoch:  0/370 - train_loss: 0.7081 - test_loss: 0.576629
# Epoch: 92/370 - train_loss: 0.1220 - test_loss: 0.059786
# Epoch: 184/370 - train_loss: 0.0810 - test_loss: 0.040407
# Epoch: 276/370 - train_loss: 0.1001 - test_loss: 0.047863
# Epoch: 368/370 - train_loss: 0.1126 - test_loss: 0.052803
# Epoch: 369/370 - train_loss: 0.1119 - test_loss: 0.053147
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 10.409430277840686
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 11.327646028462643
# City: Trà Vinh  _algo:lstm_attention  -RMSE: 11.712498199773028
# Epoch:  0/160 - train_loss: 1.1064 - test_loss: 0.742835
# Epoch: 40/160 - train_loss: 0.1705 - test_loss: 0.112892
# Epoch: 80/160 - train_loss: 0.1511 - test_loss: 0.085837
# Epoch: 120/160 - train_loss: 0.1491 - test_loss: 0.092815
# Epoch: 159/160 - train_loss: 0.1514 - test_loss: 0.105375
# Evaluate on test set:
# City: Trà Vinh  _algo:transformers  -RMSE: 24.940660506028877
# City: Trà Vinh  _algo:transformers  -RMSE: 17.937455123869498
# City: Trà Vinh  _algo:transformers  -RMSE: 25.08586995181406
# {"ok":true,"result":{"message_id":589,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676437938,"text":"Server Ch\u1ea1y Xong validation Simple Tr\u00e0 Vinh"}}
# Epoch:  0/460 - train_loss: 0.7107 - test_loss: 0.604578
# Epoch: 115/460 - train_loss: 0.1075 - test_loss: 0.053694
# Epoch: 230/460 - train_loss: 0.0998 - test_loss: 0.047343
# Epoch: 345/460 - train_loss: 0.1045 - test_loss: 0.049454
# Epoch: 459/460 - train_loss: 0.0886 - test_loss: 0.051693
# City: Tuyên Quang  _algo:cnn  -RMSE: 11.509718462763153
# City: Tuyên Quang  _algo:cnn  -RMSE: 9.88287437226042
# City: Tuyên Quang  _algo:cnn  -RMSE: 10.052961330969827
# Epoch:  0/450 - train_loss: 0.7047 - test_loss: 0.637497
# Epoch: 112/450 - train_loss: 0.0795 - test_loss: 0.043909
# Epoch: 224/450 - train_loss: 0.0700 - test_loss: 0.040035
# Epoch: 336/450 - train_loss: 0.0485 - test_loss: 0.040590
# Epoch: 448/450 - train_loss: 0.0602 - test_loss: 0.037438
# Epoch: 449/450 - train_loss: 0.0775 - test_loss: 0.040479
# City: Tuyên Quang  _algo:lstm  -RMSE: 13.852540999600343
# City: Tuyên Quang  _algo:lstm  -RMSE: 11.677060006672948
# City: Tuyên Quang  _algo:lstm  -RMSE: 12.235860585675708
# Epoch:  0/280 - train_loss: 0.7025 - test_loss: 0.650146
# Epoch: 70/280 - train_loss: 0.1052 - test_loss: 0.052646
# Epoch: 140/280 - train_loss: 0.0786 - test_loss: 0.040927
# Epoch: 210/280 - train_loss: 0.0859 - test_loss: 0.042256
# Epoch: 279/280 - train_loss: 0.0758 - test_loss: 0.042901
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 11.05277225114841
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 9.717822762879837
# City: Tuyên Quang  _algo:lstm_attention  -RMSE: 9.805633588344412
# Epoch:  0/120 - train_loss: 0.9944 - test_loss: 0.754740
# Epoch: 30/120 - train_loss: 0.6689 - test_loss: 0.583051
# Epoch: 60/120 - train_loss: 0.5448 - test_loss: 0.483715
# Epoch: 90/120 - train_loss: 0.4403 - test_loss: 0.396793
# Epoch: 119/120 - train_loss: 0.3865 - test_loss: 0.323920
# Evaluate on test set:
# City: Tuyên Quang  _algo:transformers  -RMSE: 14.03665834327007
# City: Tuyên Quang  _algo:transformers  -RMSE: 13.617995244339362
# City: Tuyên Quang  _algo:transformers  -RMSE: 10.60486592339493
# {"ok":true,"result":{"message_id":594,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676438101,"text":"Server Ch\u1ea1y Xong validation Simple Tuy\u00ean Quang"}}
# Epoch:  0/490 - train_loss: 0.7263 - test_loss: 0.593819
# Epoch: 122/490 - train_loss: 0.1691 - test_loss: 0.085650
# Epoch: 244/490 - train_loss: 0.1663 - test_loss: 0.073234
# Epoch: 366/490 - train_loss: 0.1750 - test_loss: 0.079818
# Epoch: 488/490 - train_loss: 0.1608 - test_loss: 0.106426
# Epoch: 489/490 - train_loss: 0.1773 - test_loss: 0.077022
# City: Tây Ninh  _algo:cnn  -RMSE: 4.50941639234529
# City: Tây Ninh  _algo:cnn  -RMSE: 3.8844231858355363
# City: Tây Ninh  _algo:cnn  -RMSE: 4.003682275971795
# Epoch:  0/400 - train_loss: 0.8275 - test_loss: 0.701989
# Epoch: 100/400 - train_loss: 0.4441 - test_loss: 0.413597
# Epoch: 200/400 - train_loss: 0.2635 - test_loss: 0.227796
# Epoch: 300/400 - train_loss: 0.1864 - test_loss: 0.125941
# Epoch: 399/400 - train_loss: 0.1585 - test_loss: 0.081007
# City: Tây Ninh  _algo:lstm  -RMSE: 3.2262769752090854
# City: Tây Ninh  _algo:lstm  -RMSE: 3.3711927230367746
# City: Tây Ninh  _algo:lstm  -RMSE: 3.833619189010447
# Epoch:  0/490 - train_loss: 0.7202 - test_loss: 0.610780
# Epoch: 122/490 - train_loss: 0.1732 - test_loss: 0.074557
# Epoch: 244/490 - train_loss: 0.1355 - test_loss: 0.070413
# Epoch: 366/490 - train_loss: 0.1347 - test_loss: 0.074551
# Epoch: 488/490 - train_loss: 0.1295 - test_loss: 0.069364
# Epoch: 489/490 - train_loss: 0.1386 - test_loss: 0.072432
# City: Tây Ninh  _algo:lstm_attention  -RMSE: 4.672823707996442
# ...
# Epoch: 419/420 - train_loss: 0.1055 - test_loss: 0.061791
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 18.893459538071067
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 14.926888655824015
# City: Vĩnh Phúc  _algo:cnn  -RMSE: 13.145607348355925
# Epoch:  0/390 - train_loss: 0.6606 - test_loss: 0.564561
# Epoch: 97/390 - train_loss: 0.1067 - test_loss: 0.057602
# Epoch: 194/390 - train_loss: 0.0932 - test_loss: 0.049318
# Epoch: 291/390 - train_loss: 0.1191 - test_loss: 0.074376
# Epoch: 388/390 - train_loss: 0.0958 - test_loss: 0.052182
# Epoch: 389/390 - train_loss: 0.1114 - test_loss: 0.051724
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 12.284413267189024
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 12.245279791082298
# City: Vĩnh Phúc  _algo:lstm  -RMSE: 12.94856185802841
# Epoch:  0/200 - train_loss: 0.6405 - test_loss: 0.544760
# Epoch: 50/200 - train_loss: 0.1010 - test_loss: 0.045409
# Epoch: 100/200 - train_loss: 0.1023 - test_loss: 0.053029
# Epoch: 150/200 - train_loss: 0.0989 - test_loss: 0.045722
# Epoch: 199/200 - train_loss: 0.1032 - test_loss: 0.048650
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 11.872255810453703
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 11.901155372293557
# City: Vĩnh Phúc  _algo:lstm_attention  -RMSE: 12.03451776132879
# Epoch:  0/200 - train_loss: 0.8219 - test_loss: 0.641181
# Epoch: 50/200 - train_loss: 0.1389 - test_loss: 0.085099
# Epoch: 100/200 - train_loss: 0.1335 - test_loss: 0.086250
# Epoch: 150/200 - train_loss: 0.1281 - test_loss: 0.078105
# Epoch: 199/200 - train_loss: 0.1255 - test_loss: 0.065827
# Evaluate on test set:
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 13.75102367868161
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 18.5722328837917
# City: Vĩnh Phúc  _algo:transformers  -RMSE: 18.47236394790435
# {"ok":true,"result":{"message_id":1094,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676465115,"text":"Server Ch\u1ea1y Xong validation Simple V\u0129nh Ph\u00fac"}}
# Epoch:  0/390 - train_loss: 0.8013 - test_loss: 0.707448
# Epoch: 97/390 - train_loss: 0.1871 - test_loss: 0.103009
# Epoch: 194/390 - train_loss: 0.1697 - test_loss: 0.097294
# Epoch: 291/390 - train_loss: 0.1646 - test_loss: 0.103267
# Epoch: 388/390 - train_loss: 0.1675 - test_loss: 0.095599
# Epoch: 389/390 - train_loss: 0.1512 - test_loss: 0.093077
# City: Yên Bái  _algo:cnn  -RMSE: 9.97066413189723
# City: Yên Bái  _algo:cnn  -RMSE: 11.625801761083203
# City: Yên Bái  _algo:cnn  -RMSE: 11.386584345546513
# Epoch:  0/380 - train_loss: 0.7950 - test_loss: 0.780105
# Epoch: 95/380 - train_loss: 0.1649 - test_loss: 0.100606
# Epoch: 190/380 - train_loss: 0.1501 - test_loss: 0.090035
# Epoch: 285/380 - train_loss: 0.1184 - test_loss: 0.095618
# Epoch: 379/380 - train_loss: 0.0505 - test_loss: 0.173167
# City: Yên Bái  _algo:lstm  -RMSE: 11.085177706053134
# City: Yên Bái  _algo:lstm  -RMSE: 12.279547540953216
# City: Yên Bái  _algo:lstm  -RMSE: 16.12588923451267
# Epoch:  0/440 - train_loss: 0.8623 - test_loss: 0.736522
# Epoch: 110/440 - train_loss: 0.2134 - test_loss: 0.137988
# Epoch: 220/440 - train_loss: 0.1819 - test_loss: 0.096269
# Epoch: 330/440 - train_loss: 0.1753 - test_loss: 0.098224
# Epoch: 439/440 - train_loss: 0.1833 - test_loss: 0.098753
# City: Yên Bái  _algo:lstm_attention  -RMSE: 7.232295309654033
# City: Yên Bái  _algo:lstm_attention  -RMSE: 11.229926592745244
# City: Yên Bái  _algo:lstm_attention  -RMSE: 15.388396063425128
# Epoch:  0/430 - train_loss: 1.0567 - test_loss: 0.838067
# Epoch: 107/430 - train_loss: 0.2939 - test_loss: 0.342459
# Epoch: 214/430 - train_loss: 0.3065 - test_loss: 0.337830
# Epoch: 321/430 - train_loss: 0.2955 - test_loss: 0.322298
# Epoch: 428/430 - train_loss: 0.3060 - test_loss: 0.322666
# Epoch: 429/430 - train_loss: 0.2925 - test_loss: 0.352593
# Evaluate on test set:
# City: Yên Bái  _algo:transformers  -RMSE: 37.24225659698325
# City: Yên Bái  _algo:transformers  -RMSE: 34.26689357223726
# City: Yên Bái  _algo:transformers  -RMSE: 32.584082770289925
# {"ok":true,"result":{"message_id":1095,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676465311,"text":"Server Ch\u1ea1y Xong validation Simple Y\u00ean B\u00e1i"}}
# Epoch:  0/320 - train_loss: 0.7976 - test_loss: 0.576499
# Epoch: 80/320 - train_loss: 0.2549 - test_loss: 0.158085
# Epoch: 160/320 - train_loss: 0.2851 - test_loss: 0.146900
# Epoch: 240/320 - train_loss: 0.2851 - test_loss: 0.170340
# Epoch: 319/320 - train_loss: 0.2848 - test_loss: 0.168138
# City: Điện Biên  _algo:cnn  -RMSE: 36.21646516759238
# City: Điện Biên  _algo:cnn  -RMSE: 43.67610408308102
# City: Điện Biên  _algo:cnn  -RMSE: 47.67319529955911
# Epoch:  0/390 - train_loss: 0.7669 - test_loss: 0.612808
# Epoch: 97/390 - train_loss: 0.2339 - test_loss: 0.414989
# Epoch: 194/390 - train_loss: 0.2354 - test_loss: 0.435034
# Epoch: 291/390 - train_loss: 0.2372 - test_loss: 0.419265
# Epoch: 388/390 - train_loss: 0.2282 - test_loss: 0.426148
# Epoch: 389/390 - train_loss: 0.2316 - test_loss: 0.430255
# City: Điện Biên  _algo:lstm  -RMSE: 54.36882920425432
# City: Điện Biên  _algo:lstm  -RMSE: 42.86504092032078
# City: Điện Biên  _algo:lstm  -RMSE: 40.811183443330144
# Epoch:  0/400 - train_loss: 0.8216 - test_loss: 0.770737
# Epoch: 100/400 - train_loss: 0.5868 - test_loss: 0.485834
# Epoch: 200/400 - train_loss: 0.4737 - test_loss: 0.328265
# Epoch: 300/400 - train_loss: 0.3248 - test_loss: 0.271008
# Epoch: 399/400 - train_loss: 0.2354 - test_loss: 0.383521
# City: Điện Biên  _algo:lstm_attention  -RMSE: 77.27570090205549
# City: Điện Biên  _algo:lstm_attention  -RMSE: 67.38073442256636
# City: Điện Biên  _algo:lstm_attention  -RMSE: 54.79235766171633
# Epoch:  0/260 - train_loss: 1.2179 - test_loss: 0.934888
# Epoch: 65/260 - train_loss: 0.4135 - test_loss: 0.204293
# Epoch: 130/260 - train_loss: 0.3992 - test_loss: 0.178583
# Epoch: 195/260 - train_loss: 0.3824 - test_loss: 0.172394
# Epoch: 259/260 - train_loss: 0.3593 - test_loss: 0.199556
# Evaluate on test set:
# City: Điện Biên  _algo:transformers  -RMSE: 46.11045170058679
# City: Điện Biên  _algo:transformers  -RMSE: 48.38425867347854
# City: Điện Biên  _algo:transformers  -RMSE: 43.55280523883805
# {"ok":true,"result":{"message_id":1096,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676465500,"text":"Server Ch\u1ea1y Xong validation Simple \u0110i\u1ec7n Bi\u00ean"}}
# Epoch:  0/440 - train_loss: 0.7372 - test_loss: 0.574442
# Epoch: 110/440 - train_loss: 0.1252 - test_loss: 0.057055
# Epoch: 220/440 - train_loss: 0.1505 - test_loss: 0.056145
# Epoch: 330/440 - train_loss: 0.1249 - test_loss: 0.057579
# Epoch: 439/440 - train_loss: 0.1244 - test_loss: 0.057592
# City: Đà Nẵng  _algo:cnn  -RMSE: 31.107058430427678
# City: Đà Nẵng  _algo:cnn  -RMSE: 29.48430010889906
# City: Đà Nẵng  _algo:cnn  -RMSE: 25.298714455381866
# Epoch:  0/420 - train_loss: 0.7383 - test_loss: 0.640334
# Epoch: 105/420 - train_loss: 0.1258 - test_loss: 0.059587
# Epoch: 210/420 - train_loss: 0.1252 - test_loss: 0.062112
# Epoch: 315/420 - train_loss: 0.1251 - test_loss: 0.058768
# Epoch: 419/420 - train_loss: 0.1456 - test_loss: 0.060136
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.187093615242883
# City: Đà Nẵng  _algo:lstm  -RMSE: 26.80903426393997
# City: Đà Nẵng  _algo:lstm  -RMSE: 25.339113582434095
# Epoch:  0/500 - train_loss: 0.6486 - test_loss: 0.556928
# Epoch: 125/500 - train_loss: 0.1261 - test_loss: 0.069994
# Epoch: 250/500 - train_loss: 0.1249 - test_loss: 0.055339
# Epoch: 375/500 - train_loss: 0.1248 - test_loss: 0.057664
# Epoch: 499/500 - train_loss: 0.1249 - test_loss: 0.058564
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 23.583626235432302
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 24.085227086232138
# City: Đà Nẵng  _algo:lstm_attention  -RMSE: 20.771684978921215
# Epoch:  0/370 - train_loss: 0.8149 - test_loss: 0.620108
# Epoch: 92/370 - train_loss: 0.1566 - test_loss: 0.056989
# Epoch: 184/370 - train_loss: 0.1251 - test_loss: 0.059757
# Epoch: 276/370 - train_loss: 0.1245 - test_loss: 0.058033
# Epoch: 368/370 - train_loss: 0.1464 - test_loss: 0.056584
# Epoch: 369/370 - train_loss: 0.1264 - test_loss: 0.063553
# Evaluate on test set:
# City: Đà Nẵng  _algo:transformers  -RMSE: 25.502715860830893
# City: Đà Nẵng  _algo:transformers  -RMSE: 31.354820951442694
# City: Đà Nẵng  _algo:transformers  -RMSE: 21.331684810697965
# {"ok":true,"result":{"message_id":1097,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676465782,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u00e0 N\u1eb5ng"}}
# Epoch:  0/170 - train_loss: 0.8536 - test_loss: 0.762653
# Epoch: 42/170 - train_loss: 0.6613 - test_loss: 0.617526
# Epoch: 84/170 - train_loss: 0.5843 - test_loss: 0.545389
# Epoch: 126/170 - train_loss: 0.5148 - test_loss: 0.478848
# Epoch: 168/170 - train_loss: 0.4554 - test_loss: 0.417330
# Epoch: 169/170 - train_loss: 0.4543 - test_loss: 0.415951
# City: Đắk Nông  _algo:cnn  -RMSE: 10.783976947746538
# City: Đắk Nông  _algo:cnn  -RMSE: 8.69131977472774
# City: Đắk Nông  _algo:cnn  -RMSE: 11.270864417598176
# Epoch:  0/250 - train_loss: 0.8158 - test_loss: 0.729755
# Epoch: 62/250 - train_loss: 0.2180 - test_loss: 0.121451
# Epoch: 124/250 - train_loss: 0.1930 - test_loss: 0.093791
# Epoch: 186/250 - train_loss: 0.1905 - test_loss: 0.086404
# Epoch: 248/250 - train_loss: 0.1803 - test_loss: 0.084955
# Epoch: 249/250 - train_loss: 0.1797 - test_loss: 0.093511
# City: Đắk Nông  _algo:lstm  -RMSE: 9.291841128857179
# City: Đắk Nông  _algo:lstm  -RMSE: 8.191911734859124
# City: Đắk Nông  _algo:lstm  -RMSE: 7.753660480312279
# Epoch:  0/500 - train_loss: 0.6747 - test_loss: 0.539479
# Epoch: 125/500 - train_loss: 0.2907 - test_loss: 0.133110
# Epoch: 250/500 - train_loss: 0.2872 - test_loss: 0.135544
# Epoch: 375/500 - train_loss: 0.2886 - test_loss: 0.135481
# Epoch: 499/500 - train_loss: 0.2881 - test_loss: 0.137382
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 12.4728285751361
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 12.32420716863301
# City: Đắk Nông  _algo:lstm_attention  -RMSE: 12.213916854365841
# Epoch:  0/410 - train_loss: 1.0433 - test_loss: 0.787615
# Epoch: 102/410 - train_loss: 0.2754 - test_loss: 0.203211
# Epoch: 204/410 - train_loss: 0.2051 - test_loss: 0.098920
# Epoch: 306/410 - train_loss: 0.1873 - test_loss: 0.092945
# Epoch: 408/410 - train_loss: 0.1821 - test_loss: 0.095187
# Epoch: 409/410 - train_loss: 0.1805 - test_loss: 0.094868
# Evaluate on test set:
# City: Đắk Nông  _algo:transformers  -RMSE: 11.857434441239938
# City: Đắk Nông  _algo:transformers  -RMSE: 10.198150538050342
# City: Đắk Nông  _algo:transformers  -RMSE: 9.662437963430085
# {"ok":true,"result":{"message_id":1098,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676466045,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1eafk N\u00f4ng"}}
# Epoch:  0/150 - train_loss: 0.7326 - test_loss: 0.697114
# Epoch: 37/150 - train_loss: 0.3535 - test_loss: 0.329686
# Epoch: 74/150 - train_loss: 0.1757 - test_loss: 0.141117
# Epoch: 111/150 - train_loss: 0.1402 - test_loss: 0.077199
# Epoch: 148/150 - train_loss: 0.1204 - test_loss: 0.061297
# Epoch: 149/150 - train_loss: 0.1181 - test_loss: 0.063079
# City: Đắk Lắk  _algo:cnn  -RMSE: 12.836064411556684
# City: Đắk Lắk  _algo:cnn  -RMSE: 13.604353849243717
# City: Đắk Lắk  _algo:cnn  -RMSE: 11.748653027023716
# Epoch:  0/380 - train_loss: 0.6601 - test_loss: 0.582297
# Epoch: 95/380 - train_loss: 0.1225 - test_loss: 0.066388
# Epoch: 190/380 - train_loss: 0.1224 - test_loss: 0.073063
# Epoch: 285/380 - train_loss: 0.1258 - test_loss: 0.074978
# Epoch: 379/380 - train_loss: 0.1034 - test_loss: 0.107839
# City: Đắk Lắk  _algo:lstm  -RMSE: 10.668366445073563
# City: Đắk Lắk  _algo:lstm  -RMSE: 14.893218009508763
# City: Đắk Lắk  _algo:lstm  -RMSE: 10.229547894252267
# Epoch:  0/190 - train_loss: 0.6913 - test_loss: 0.623118
# Epoch: 47/190 - train_loss: 0.1397 - test_loss: 0.072183
# Epoch: 94/190 - train_loss: 0.1282 - test_loss: 0.062608
# Epoch: 141/190 - train_loss: 0.1327 - test_loss: 0.072908
# Epoch: 188/190 - train_loss: 0.1206 - test_loss: 0.061802
# Epoch: 189/190 - train_loss: 0.1219 - test_loss: 0.064745
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 13.160798936115155
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 12.072940036754444
# City: Đắk Lắk  _algo:lstm_attention  -RMSE: 11.452663915432309
# Epoch:  0/220 - train_loss: 1.2516 - test_loss: 0.889999
# Epoch: 55/220 - train_loss: 0.1582 - test_loss: 0.091545
# Epoch: 110/220 - train_loss: 0.1612 - test_loss: 0.084923
# Epoch: 165/220 - train_loss: 0.1598 - test_loss: 0.088577
# Epoch: 219/220 - train_loss: 0.1610 - test_loss: 0.086285
# Evaluate on test set:
# City: Đắk Lắk  _algo:transformers  -RMSE: 11.069036262554604
# City: Đắk Lắk  _algo:transformers  -RMSE: 11.11905739542447
# City: Đắk Lắk  _algo:transformers  -RMSE: 13.681887074951417
# {"ok":true,"result":{"message_id":1099,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676466176,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1eafk L\u1eafk"}}
# Epoch:  0/110 - train_loss: 0.8853 - test_loss: 0.590489
# Epoch: 27/110 - train_loss: 0.2542 - test_loss: 0.246106
# Epoch: 54/110 - train_loss: 0.2550 - test_loss: 0.331362
# Epoch: 81/110 - train_loss: 0.2443 - test_loss: 0.315395
# Epoch: 108/110 - train_loss: 0.2485 - test_loss: 0.393416
# Epoch: 109/110 - train_loss: 0.2503 - test_loss: 0.348023
# City: Đồng Tháp  _algo:cnn  -RMSE: 20.29918706193153
# City: Đồng Tháp  _algo:cnn  -RMSE: 26.44574111557227
# City: Đồng Tháp  _algo:cnn  -RMSE: 20.746236045110148
# Epoch:  0/290 - train_loss: 1.0770 - test_loss: 0.744206
# Epoch: 72/290 - train_loss: 0.2374 - test_loss: 0.125369
# Epoch: 144/290 - train_loss: 0.2187 - test_loss: 0.134744
# Epoch: 216/290 - train_loss: 0.2129 - test_loss: 0.167514
# Epoch: 288/290 - train_loss: 0.2073 - test_loss: 0.201498
# Epoch: 289/290 - train_loss: 0.2091 - test_loss: 0.201188
# City: Đồng Tháp  _algo:lstm  -RMSE: 12.522153993886107
# City: Đồng Tháp  _algo:lstm  -RMSE: 12.11224497279355
# City: Đồng Tháp  _algo:lstm  -RMSE: 15.085030795787338
# Epoch:  0/100 - train_loss: 1.1107 - test_loss: 0.723009
# Epoch: 25/100 - train_loss: 0.2702 - test_loss: 0.213583
# Epoch: 50/100 - train_loss: 0.2405 - test_loss: 0.163690
# Epoch: 75/100 - train_loss: 0.2287 - test_loss: 0.112070
# Epoch: 99/100 - train_loss: 0.2220 - test_loss: 0.109434
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 12.278008415338249
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 9.834520761711913
# City: Đồng Tháp  _algo:lstm_attention  -RMSE: 11.66981818830889
# Epoch:  0/420 - train_loss: 0.8239 - test_loss: 0.592200
# Epoch: 105/420 - train_loss: 0.2837 - test_loss: 0.406052
# Epoch: 210/420 - train_loss: 0.2867 - test_loss: 0.354647
# Epoch: 315/420 - train_loss: 0.2841 - test_loss: 0.382593
# Epoch: 419/420 - train_loss: 0.2808 - test_loss: 0.358632
# Evaluate on test set:
# City: Đồng Tháp  _algo:transformers  -RMSE: 36.01628454684636
# City: Đồng Tháp  _algo:transformers  -RMSE: 42.696418846475396
# City: Đồng Tháp  _algo:transformers  -RMSE: 36.47485695033928
# {"ok":true,"result":{"message_id":1100,"sender_chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"chat":{"id":-1001712314864,"title":"PTN_Announcement","username":"ptn_announcement","type":"channel"},"date":1676466326,"text":"Server Ch\u1ea1y Xong validation Simple \u0110\u1ed3ng Th\u00e1p"}}

# %%
run_time = round((dt_ended - dt_started).total_seconds()/60)
print('kết thúc train trong:', run_time)
print ('danh sách error city: ')
print(l_errCity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 run_time = round((dt_ended - dt_started).total_seconds()/60)
#       2 print('kết thúc train trong:', run_time)
#       3 print ('danh sách error city: ')
#
# NameError: name 'dt_ended' is not defined

# %%
# import requests

# def send_to_telegram(message):

#     apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
#     chatID = '@ptn_announcement'
#     apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

#     try:
#         response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
#         print(response.text)
#     except Exception as e:
#         print(e)

# send_to_telegram("Server Chạy Xong\nList city:\n" + ',\n'.join(str(city) for city in cities) + "\nalgo: ensemble" )

# %% [markdown]
# # final result

# %% [markdown]
# # Đọc kết quả 1997-2015 của 44 combination.

# %%
prj_path = 'H:/Store/Research/UIT/PhD Research/Dev Environment/Tropical Diseases/running/'
path_simple_result_2015 =      prj_path+ 'results/ensemble/result/simple_combination_4_model_2015/all_combinations_metrics_1.xlsx'

df_result_simple_2015 = pd.read_excel(path_simple_result_2015)

# df_result_simple_2015 = df_result_simple_2015.loc[:,["City","Meta_Model_Name","Based_Models",'RMSE_1-month']
df_result_simple_2015 = df_result_simple_2015.loc[:,["City","Meta_Model_Name","Based_Models",'MAE_1-month']]

df_result_simple_2015['Model Name'] = df_result_simple_2015['Meta_Model_Name']+'*'+ df_result_simple_2015['Based_Models']
# df_result_simple_2015 = df_result_simple_2015.loc[:,["City","RMSE_1-month","Model Name"]]
df_result_simple_2015 = df_result_simple_2015.loc[:,["City","MAE_1-month","Model Name"]]
df_result_simple_2015

# %% [markdown]
# # Xếp hạng theo rank

# %%
pivot_simple = df_result_simple_2015.pivot(index='City', columns='Model Name', values='RMSE_1-month').reset_index(drop=True)
# pivot_simple = pivot_simple.reset_index()
ranked_pivot_simple = pivot_simple.rank(axis=1)
ranked_pivot_simple.head()
ranked_pivot_simple.to_excel('Ranked_44_2015.xlsx')

# %%
ranked_pivot_simple = pd.read_excel('Ranked_44_2015.xlsx')
ranked_pivot_simple = ranked_pivot_simple.drop(columns=['Unnamed: 0'])
ranked_pivot_simple

# %%
ranked_pivot_simple.mean(axis=0).sort_values()

# %%
tp_ranked_pivot_simple = ranked_pivot_simple.transpose()
# tp_ranked_pivot_simple.reset_index("Model Name", inplace = True)
tp_ranked_pivot_simple['Mean_Rank']= tp_ranked_pivot_simple.mean(axis=1)
rank_sort_simple = tp_ranked_pivot_simple.sort_values(by = 'Mean_Rank', ascending=True)
top_rank_simple = rank_sort_simple.head(5)
top_rank_simple

# %% [markdown]
# LSTM_ATT*cnn_pred-lstm_att_pred-lstm_pred-Observed            15.945455
# LSTM_ATT*lstm_pred-tf_pred-Observed                           16.127273
# LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed                  16.509091
# LSTM*cnn_pred-lstm_pred-Observed                              16.654545
# LSTM*lstm_att_pred-tf_pred-Observed                           16.854545

# %%
# Đoạn này dùng cho theo rank
top_n_of_simple_2015 = pd.DataFrame(data= ['LSTM_ATT*cnn_pred-lstm_att_pred-lstm_pred-Observed',
                                           'LSTM_ATT*lstm_pred-tf_pred-Observed',
                                           'LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed',                                           
                                            'LSTM*cnn_pred-lstm_pred-Observed',
                                            'LSTM*lstm_att_pred-tf_pred-Observed'], columns=['Model Name'])
top_n_of_simple_2015

# %% [markdown]
# # Xếp hạng 44 bộ kết hợp cho kết quả 1997-2015 theo rmse

# %%
# Get n_top theo rmse cố định cho tất cả thành phố
def get_n_top_in(df_combination ='', n_best =3):
    model_group_mean = df_combination.groupby(['Model Name'],as_index = False).mean()
    return model_group_mean.sort_values(by='RMSE_1-month',ascending=True).head(n_best).reset_index(drop=True)
top_n_of_simple_2015 = get_n_top_in (df_combination= df_result_simple_2015, n_best =5 )
top_n_of_simple_2015

# %% [markdown]
# # Theo MAE

# %%
# Get n_top theo rmse cố định cho tất cả thành phố
def get_n_top_in(df_combination ='', n_best =3):
    model_group_mean = df_combination.groupby(['Model Name'],as_index = False).mean()
    return model_group_mean.sort_values(by='MAE_1-month',ascending=True).head(n_best).reset_index(drop=True)
top_n_of_simple_2015 = get_n_top_in (df_combination= df_result_simple_2015, n_best =5 )
top_n_of_simple_2015

# %%
top_n_of_simple_2015.to_excel('list.xlsx')

# %%
# Get n_top theo rmse theo mỗi thành phố (linh động)
def get_n_top_each_city_in(df_combination ='', n_best =5):
    df = df_result_simple_2015.sort_values(by = ['RMSE_1-month'], ascending=True).groupby('City').head(n_best).reset_index()
    return df
top_n_of_simple_2015 = get_n_top_each_city_in (df_combination= df_result_simple_2015, n_best = 5 )
top_n_of_simple_2015

# %%
# Get n_top theo rmse theo mỗi thành phố (linh động)
def get_n_top_each_city_in(df_combination ='', n_best =5):
    df = df_result_simple_2015.sort_values(by = ['MAE_1-month'], ascending=True).groupby('City').head(n_best).reset_index()
    return df
top_n_of_simple_2015 = get_n_top_each_city_in (df_combination= df_result_simple_2015, n_best = 5 )
top_n_of_simple_2015

# %% [markdown]
# # Set cứng tính sau cho bộ rank này
# LSTM_ATT*cnn_pred-lstm_att_pred-lstm_pred-Observed
# LSTM_ATT*lstm_pred-tf_pred-Observed
# LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed
# LSTM*cnn_pred-lstm_pred-Observed
# LSTM*lstm_att_pred-tf_pred-Observed

# %% [markdown]
# CNN*lstm_att_pred-tf_pred-Observed

# %%
# Bộ này tự tạo
top_n_of_simple_2015 = pd.DataFrame(data= ['CNN*lstm_att_pred-tf_pred-Observed','CNN*cnn_pred-lstm_pred-Observed','CNN*lstm_pred-tf_pred-Observed'], columns=['Model Name'])
top_n_of_simple_2015

# %% [markdown]
# # Đọc kết quả Predict của 44 combination 1997-2018

# %%
prj_path_result_simple_ensemple_2018 = 'H:/Store/Research/UIT/PhD Research/Dev Environment/Tropical Diseases/running/eval_result/\simple_combination_14_12/'

df_simple_ensemble_2018 = pd.read_excel(prj_path_result_simple_ensemple_2018+'all_combinations_1.xlsx')
df_simple_ensemble_2018 = df_simple_ensemble_2018.loc[:,["City","Meta_Model_Name","Based_Models",'Observed','1-month','RMSE_1-month','MAE_1-month','MAE_1-month']]
# Không sort và lấy best result trong mỗi city. vì filter dùng df_result_simple_2015
df_simple_ensemble_2018['Model Name'] = df_simple_ensemble_2018['Meta_Model_Name']+'*'+ df_simple_ensemble_2018['Based_Models']
df_simple_ensemble_2018

# %% [markdown]
# # Convert kết quả 2015 thành 2018

# %%
# Convert Cứng n giải thuật cho cả kiểu rank và rmse
convert_simple_2015_to_2018 = df_simple_ensemble_2018.merge(top_n_of_simple_2015[['Model Name']], on=['Model Name'])
short_convert_simple_2015_to_2018 = convert_simple_2015_to_2018.loc[:,['City','Observed','1-month','Model Name']]
short_convert_simple_2015_to_2018.head()

# %%
# Conver linh động cho mỗi thành phố n giải thuật khác nhau
convert_simple_2015_to_2018 = df_simple_ensemble_2018.merge(top_n_of_simple_2015[['Model Name','City']], on=['Model Name','City'])
short_convert_simple_2015_to_2018 = convert_simple_2015_to_2018.loc[:,['City','Observed','1-month','Model Name']]
short_convert_simple_2015_to_2018.head()

# %%
# convert_simple_2015_to_2018.to_excel('convert_simple_2015_to_2018.xlsx')

# %%
# test = short_convert_simple_2015_to_2018.loc[(short_convert_simple_2015_to_2018['City']=='An Giang') & 
#                                             (short_convert_simple_2015_to_2018['Model Name']=='LSTM*cnn_pred-lstm_pred-Observed')]
# test.head()

# %%
# top_n_of_simple_2015['Model Name'].to_numpy()

# %%
# for model_name in top_n_of_simple_2015['Model Name'].to_numpy():
#         print(model_name)

# %% [markdown]
# # Tạo bộ kết quả trung bình cho mỗi thành phố. Cho dạng linh động mỗi thành phố N combine khác nhau

# %%
# Đoạn này hiện đang tính simple combination 5 bộ giải thuật khác nhau mỗi thành phố
cities = ['An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
        'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
        'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
        'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
        'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
        'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
        'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
        'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
        'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
         'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp']
dict_all_cities_simple = {}
df_mix_all = pd.DataFrame()
for city in cities:
        df_one_city = pd.DataFrame()        
        for model_name in top_n_of_simple_2015.loc[top_n_of_simple_2015['City']==city]['Model Name'].to_numpy():
                selected_result = short_convert_simple_2015_to_2018.loc[(short_convert_simple_2015_to_2018['City']==city) & 
                                            (short_convert_simple_2015_to_2018['Model Name']== model_name)]
                selected_result = selected_result.reset_index(drop=True)  
                selected_result = selected_result.rename(columns={"1-month": model_name})
                df_one_city = pd.concat([df_one_city,selected_result[model_name]], axis=1)
        
        df_one_city['Simple Average'] = df_one_city.mean(axis=1)
        df_one_city['Observed'] = selected_result['Observed']
        df_one_city['RMSE_Simple_Avg'] = mean_squared_error(df_one_city['Observed'], df_one_city['Simple Average'], squared=False)
        df_one_city['MAE_Simple_Avg'] = mean_absolute_error(df_one_city['Observed'], df_one_city['Simple Average'])
        df_one_city['City'] = city
        dict_all_cities_simple[city] = df_one_city
        df_mix_all = pd.concat([df_mix_all,df_one_city])

df_simple_mix_all_metrix= df_mix_all.groupby(['City']).head(1)
df_simple_mix_all_metrix = df_simple_mix_all_metrix.reset_index(drop=True)
df_simple_mix_all_metrix = df_simple_mix_all_metrix[['City','RMSE_Simple_Avg','MAE_Simple_Avg']]
df_simple_mix_all_metrix['Alg_name'] = 'Simple Ensemble'
df_simple_mix_all_metrix.head()

# %% [markdown]
# # Tạo ra Bộ kết quả Simple combination = trung bình của 5 combination
# Cho dạng cứng 5 combi giống nhau cho tất cả thành phố

# %%
# Đoạn này hiện đang tính simple combination cứng cho 5 bộ giải thuật
cities = ['An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
        'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
        'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
        'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
        'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
        'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
        'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
        'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
        'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
         'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp']
dict_all_cities_simple = {}
df_mix_all = pd.DataFrame()
for city in cities:
        df_one_city = pd.DataFrame()        
        for model_name in top_n_of_simple_2015['Model Name'].to_numpy():
                selected_result = short_convert_simple_2015_to_2018.loc[(short_convert_simple_2015_to_2018['City']==city) & 
                                            (short_convert_simple_2015_to_2018['Model Name']== model_name)]
                selected_result = selected_result.reset_index(drop=True)  
                selected_result = selected_result.rename(columns={"1-month": model_name})
                df_one_city = pd.concat([df_one_city,selected_result[model_name]], axis=1)
        df_one_city['Simple Average'] = df_one_city.mean(axis=1)
        df_one_city['Observed'] = selected_result['Observed']
        df_one_city['RMSE_Simple_Avg'] = mean_squared_error(df_one_city['Observed'], df_one_city['Simple Average'], squared=False)
        df_one_city['MAE_Simple_Avg'] = mean_absolute_error(df_one_city['Observed'], df_one_city['Simple Average'])
        df_one_city['City'] = city
        dict_all_cities_simple[city] = df_one_city
        df_mix_all = pd.concat([df_mix_all,df_one_city])

df_simple_mix_all_metrix= df_mix_all.groupby(['City']).head(1)
df_simple_mix_all_metrix = df_simple_mix_all_metrix.reset_index(drop=True)
df_simple_mix_all_metrix = df_simple_mix_all_metrix[['City','RMSE_Simple_Avg','MAE_Simple_Avg']]
df_simple_mix_all_metrix['Alg_name'] = 'Simple Ensemble'
df_simple_mix_all_metrix.head()

# %%
df_simple_mix_all_metrix.rename(columns = {'RMSE_Simple_Avg':'RMSE_1-month','MAE_Simple_Avg':'MAE_1-month'}, inplace = True)
df_simple_mix_all_metrix.to_excel('simple_ensemble_all_mae.xlsx')

# %% [markdown]
# # Đọc kết quả Deep Learning, Traditional... Và so sánh với simple

# %%
prj_path = 'H:/Store/Research/UIT/PhD Research/Dev Environment/Tropical Diseases/running'

result_path = 'H:/Store/Research/UIT/PhD Research/Dev Environment/Tropical Diseases/running/eval_result/MLJ 12_01/'
result_path_3algo = result_path + "cnn_lstm_lstm-att_30_11_2022/"
result_path_tf = result_path + "transformer_08_12_2022/"
result_path_sarima = result_path + "sarima_08_12_2022/"
result_path_sarimax = result_path + "sarimax_08_12_2022/"
result_path_poisson = result_path + "poisson_10_01_2023/"
result_path_xgboost = result_path + "xgboost_10_01_2023/"
result_path_svmrbf = result_path + "svmrbf_08_12_2022/"
result_path_ensemble = result_path + "ensemble_14_12_2022/result\weighted_combination/"
result_path_weighted_ensemble = result_path + "weighted_combination_14_12/"
result_path_dart = result_path + "dart_01_12/"
cities = ['An Giang', 'BR Vũng Tàu', 'Bình Phước', 'Bình Thuận', 'Bình Định',
        'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
        'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
        'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
        'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
        'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
        'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
        'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
        'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
         'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp']

# cities = ['Điện Biên', 'Thái Bình', 'Lào Cai', 'Kon Tum', 'Cao Bằng','Lâm Đồng']
z=55

# Lấy dạng Dataframe 3 kết quả metrix của tất cả thành phố theo eval_metrix
def get_df_best_metrix_results_by(eval_metrix='MAE_1-month', result_algo_path='', file_head='', file_tail='_0'):
    # Lọc ra theo min RMSE - của cả 3 giải thuật
    l_all_algo_cities = pd.DataFrame()
    for city in cities:
        city_result = pd.read_excel(
            result_algo_path + file_head + city + file_tail + '.xlsx')
        city_result = city_result[['City', 'Alg_name', 'RMSE_1-month','MAE_1-month']]
        # group by Alg_name, sort RMSE_1-month, select first row for each group
        selected_result = city_result.sort_values(
            by=[eval_metrix], ascending=True).groupby('Alg_name').head(1)
        selected_result = selected_result.sort_index(axis=0, ascending=True)

        # lấy kết quả theo giải thuật
        if len(l_all_algo_cities) == 0:
            l_all_algo_cities = selected_result
        else: 
            l_all_algo_cities = pd.concat([l_all_algo_cities, selected_result])
    return l_all_algo_cities

# Lọc ra theo từng giải thuật ứng với từng city
def extract_by_algo(algo='cnn', city_data=''):
    result = city_data.loc[city_data['Alg_name'] == algo]
    # result['Steps']= range(0,36)
    result.insert(0, 'Months', range(0, len(result)))
    # result = result.drop(['Steps'], axis=1)
    result = result.set_index('Months')
    return result
def get_dict_result(dict):
    lstm_att_result = {}
    cnn_result = {}
    lstm_result = {}
    tf_result = {}
    sarima_result = {}
    ensemble_result = {}
    sarimax_result = {}
    svm_result = {}
    xgboost_result = {}
    ps_result = {}
    for city in cities:
        one_city = dict[city]

        ps_one_city = extract_by_algo(algo='poisson', city_data=one_city)
        ps_result[city] = ps_one_city

        xgboost_one_city = extract_by_algo(algo='xgboost', city_data=one_city)
        xgboost_result[city] = xgboost_one_city

        svm_one_city = extract_by_algo(algo='SVM-BRF', city_data=one_city)
        svm_result[city] = svm_one_city

        sarima_one_city = extract_by_algo(algo='SARIMA', city_data=one_city)
        sarima_result[city] = sarima_one_city

        ensemble_one_city = extract_by_algo(
            algo='ensemble', city_data=one_city)
        ensemble_result[city] = ensemble_one_city

        sarimax_one_city = extract_by_algo(algo='SARIMAX', city_data=one_city)
        sarimax_result[city] = sarimax_one_city

        cnn_one_city = extract_by_algo(algo='cnn', city_data=one_city)
        cnn_result[city] = cnn_one_city

        lstm_one_city = extract_by_algo(algo='lstm', city_data=one_city)
        lstm_result[city] = lstm_one_city

        lstm_att_one_city = extract_by_algo(
            algo='lstm_attention', city_data=one_city)
        lstm_att_result[city] = lstm_att_one_city

        tf_one_city = extract_by_algo(algo='transformers', city_data=one_city)
        tf_result[city] = tf_one_city
    # return   svm_result , xgboost_result, ps_result , sarima_result, sarimax_result
    return lstm_att_result, cnn_result, lstm_result, tf_result, sarima_result, ensemble_result, svm_result, xgboost_result, ps_result, sarimax_result
def process_dart():
    dart_model_dict = {

    }
    model_list = ['BlockRNNModel', 'CatBoostModel', 'LightGBMModel', 'LinearRegressionModel',
                  'NHiTSModel', 'RandomForest', 'TCNModel', 'TFTModel', 'TransformerModel']
    BlockRNNModel = pd.DataFrame()

    for model in model_list:
        cities_result = pd.DataFrame()
        for city in cities:
            city_result = pd.read_excel(
                result_path_dart + model + "/" + "fb_" + city + ".xlsx")
            city_result['Alg_name'] = model
            city_result = city_result[['City', 'Alg_name', 'RMSE_1-month','MAE_1-month']]
            if len(cities_result) == 0:
                cities_result = city_result
            else:
                cities_result = pd.concat([cities_result, city_result])
        dart_model_dict[model] = cities_result
    return dart_model_dict

result_3algo = get_df_best_metrix_results_by(result_algo_path=result_path_3algo, file_head='diarrhoea_')
result_cnn= extract_by_algo(algo='cnn', city_data =result_3algo)
result_lstm = extract_by_algo(algo='lstm', city_data =result_3algo)
result_lstm_att = extract_by_algo(algo='lstm_attention', city_data =result_3algo)

# tf
result_tf = get_df_best_metrix_results_by(result_algo_path=result_path_tf, file_head="diarrhoea_transformer_")

# sarima
result_sarima = get_df_best_metrix_results_by(result_algo_path=result_path_sarima, file_head="diarrhoea_sarima_")

# sarimax
result_sarimax = get_df_best_metrix_results_by(result_algo_path=result_path_sarimax, file_head="diarrhoea_sarimax_")

# %%
simple_ensemble = df_simple_mix_all_metrix
simple_ensemble.to_excel('simple_ensemble_all_mae.xlsx')

# %% [markdown]
# # Đọc nhanh kết quả simple ensemble theo MAE của top 5

# %%
simple_ensemble = pd.read_excel('simple_ensemble_all_mae.xlsx')

# %%
simple_ensemble.head()

# %%
simple_ensemble

# %% [markdown]
# # Tạo DF So sánh Simple với Deep learning, plot chart

# %%
# simple_ensemble = df_simple_mix_all_metrix
simple_ensemble = simple_ensemble.rename(columns={"RMSE_Simple_Avg": 'RMSE_1-month',"MAE_Simple_Avg": 'MAE_1-month'})
simple_ensemble.head()
deep_and_simple = pd.concat([     
    result_cnn,
    result_lstm,
    result_tf,
    result_lstm_att,
    simple_ensemble
])
deep_and_simple

# %%
ax = sns.boxplot(y='Alg_name', x='MAE_1-month', data=deep_and_simple)
plt.ylabel('Model')
plt.xlabel('MAE 1-month')
plt.show()

# %% [markdown]
# # Rank và đếp số lần hạng 1,2,3 của từng bộ giải thuật

# %%
pivot_deep_and_simple = deep_and_simple.pivot(index='City', columns='Alg_name', values='MAE_1-month').reset_index(drop=True)
ranked_deep_and_simple = pivot_deep_and_simple.rank(axis=1)
ranked_deep_and_simple.mean(axis=0)

# %%
ranked_deep_and_simple.mean(axis=0).to_excel('rank_means_simple_vs_single.xlsx')

# %%
# tp_ranked_deep_and_simple = ranked_deep_and_simple.transpose()
# # tp_ranked_pivot_simple.reset_index("Model Name", inplace = True)
# tp_ranked_deep_and_simple['Mean_Rank']= tp_ranked_deep_and_simple.mean(axis=1)
# rank_sort_simple = tp_ranked_deep_and_simple.sort_values(by = 'Mean_Rank', ascending=True)
# top_rank_simple

# %%
# ranked_deep_and_simple.hist()
ax = ranked_deep_and_simple.plot.hist(bins=10, alpha=0.4)

# %%
sns.histplot(data=ranked_deep_and_simple)

# %%
melted_ranked_deep_and_simple = pd.melt(ranked_deep_and_simple)
melted_ranked_deep_and_simple
ax = sns.boxplot(x='Alg_name', y='value', data=melted_ranked_deep_and_simple)
# plt.setp(ax.get_xticklabels())
plt.xlabel('Model')
plt.ylabel('Rank')

# %%
df_simple = ranked_deep_and_simple['Simple Ensemble'].value_counts()
df_lstm_attention = ranked_deep_and_simple['lstm_attention'].value_counts()
df_lstm = ranked_deep_and_simple['lstm'].value_counts()
df_cnn = ranked_deep_and_simple['cnn'].value_counts()
df_tf = ranked_deep_and_simple['transformers'].value_counts()

arr_rank = []
for i in range(1,6):
    try:
        a = df_simple[i]
    except KeyError:
        a = 0
    
    try:
        b = df_lstm[i]
    except KeyError:
        b = 0
    
    try:
        c = df_lstm_attention[i]
    except KeyError:
        c = 0
    try:
        d = df_cnn[i]
    except KeyError:
        d = 0
    try:
        e = df_tf[i]
    except KeyError:
        e = 0
    arr_rank.append([a,b,c,d,e])
df_rank_table = pd.DataFrame(data=arr_rank, columns=['Simple Ensemble','LSTM','ATT','CNN', 'TF'])
df_rank_table

# %%
df_rank_table.to_excel('count_rank_simple.xlsx')

# %%
pivot_deep_and_simple = deep_and_simple.pivot(index='City', columns='Alg_name', values='RMSE_1-month').reset_index(drop=True)
ranked_deep_and_simple = pivot_deep_and_simple.rank(axis=1)
ranked_deep_and_simple.mean(axis=0)

# %%
melted_ranked_deep_and_simple = pd.melt(ranked_deep_and_simple)
melted_ranked_deep_and_simple
ax = sns.boxplot(x='Alg_name', y='value', data=melted_ranked_deep_and_simple)
# plt.setp(ax.get_xticklabels())
plt.xlabel('Model')
plt.ylabel('Rank')

# %%
df_simple = ranked_deep_and_simple['Simple Ensemble'].value_counts()
df_lstm_attention = ranked_deep_and_simple['lstm_attention'].value_counts()
df_lstm = ranked_deep_and_simple['lstm'].value_counts()
df_cnn = ranked_deep_and_simple['cnn'].value_counts()
df_tf = ranked_deep_and_simple['transformers'].value_counts()

arr_rank = []
for i in range(1,6):
    try:
        a = df_simple[i]
    except KeyError:
        a = 0
    
    try:
        b = df_lstm[i]
    except KeyError:
        b = 0
    
    try:
        c = df_lstm_attention[i]
    except KeyError:
        c = 0
    try:
        d = df_cnn[i]
    except KeyError:
        d = 0
    try:
        e = df_tf[i]
    except KeyError:
        e = 0
    arr_rank.append([a,b,c,d,e])
df_rank_table = pd.DataFrame(data=arr_rank, columns=['Simple Ensemble','LSTM','ATT','CNN', 'TF'])
# df_rank_table.to_excel('count_rank_simple.xlsx')
df_rank_table
