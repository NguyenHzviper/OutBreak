# %% [markdown]
# # Matrix of metrics of Cross validation  for 5 top Simple Combination
# Date: 09/12/2022
# Description: Create cross validation metrics
# Use 5 combinations only regarding to the ranking from simple combination result.
# This file creates cross validation metrics for next steps
# Modificaiton 02/01/2023
# Sử dụng 5 combination mới

# %%
# !nvidia-smi
# Out:
# Mon Feb  6 17:13:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.13    Driver Version: 525.60.13    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 6000     On   | 00000000:21:00.0 Off |                  Off |
# | 44%   67C    P2   121W / 260W |   5635MiB / 24576MiB |     96%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     27440      C   ..._diseases_py39/bin/python     1042MiB |
# |    0   N/A  N/A     33001      C   ..._diseases_py39/bin/python     2072MiB |
# |    0   N/A  N/A     33128      C   ..._diseases_py39/bin/python     2518MiB |
# +-----------------------------------------------------------------------------+

# %%
# Install packages
# !pip install -U scikit-learn
# !pip install ftfy
# !pip install xlsxwriter 
# !pip install xlwt
# Out:
# Requirement already satisfied: scikit-learn in /home/mlworker/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/mlworker/lib/python3.10/site-packages (from scikit-learn) (1.8.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ftfy in /home/mlworker/lib/python3.10/site-packages (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/mlworker/lib/python3.10/site-packages (from ftfy) (0.2.5)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
import tensorflow as tf 
# from google.colab import drive
import os

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense

import traceback
import sys
import copy
import numpy as np
from itertools import combinations
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# lib for LSTM of Meta model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

from ftfy import fix_text
import warnings
warnings.simplefilter("ignore", UserWarning)

plt.rcParams['figure.figsize'] = [7, 3]
import math

import optuna
from optuna.trial import TrialState

# %% [markdown]
# # Global param and project path
# All mix data 1997-2018

# %%
# Attach Google Drive for reading and saving files
# drive.mount('/content/drive')
prj_path = '/home/mlworker/Quang/HealthCare/Source_14012023_v4/'

path_all_mix_data =             prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/'
path_all_mix_data_cnn =         prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/cnn/'
path_all_mix_data_lstm =        prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/lstm/'
path_all_mix_data_lstm_att =    prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/lstm_att/'
path_all_mix_data_tf =          prj_path+ 'results/all_mix_data/all_mix_data_1997_2018/transformer/'

prj_path_opt= prj_path + '/optimize_hyperparam/opt_results/optimize_1997_2018/'

prj_path_result_ensemble =      prj_path+ 'results/ensemble/'
com_path_validation_metrics =   prj_path_result_ensemble+ 'result/weighted_combination/cv_metrics/'

com_eval_path_validation_metrics = 'eval_result/21_12_2022_weighted_combination-5-cities/'


# loockback_window for meta model
meta_lookback_window = 3

# %% [markdown]
# # Xây dựng Meta Data Set

# %%
##########################
# Xây Dựng Meta Data Set
meta_test_set_city = {}
meta_train_set_city = {}
meta_data_set_city = {}
cities = [
'Bình Phước', 'Bình Thuận', 'Bình Định',
#         'Bạc Liêu', 'Bắc Kạn', 'Bắc Giang', 'Cao Bằng', 'Cà Mau',
#         'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình',
#         'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Khánh Hòa', 'Kiên Giang',
#         'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng',
#         'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận',
#         'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi',
#         'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TT Huế',
#         'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Tiền Giang', 'Trà Vinh',
#         'Tuyên Quang', 'Tây Ninh', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên',
#          'Đà Nẵng', 'Đắk Nông', 'Đắk Lắk', 'Đồng Tháp'
]
# cities = ['An Giang','Lạng Sơn']

for city in cities:  
  meta_test_set = pd.DataFrame()
  meta_train_set = pd.DataFrame() 
  #Note: mỗi bộ all_mix_data sẽ có lenght = 251 (10997 -01/01/2018  và vì 1 dòng đầu bị bỏ đi do quá trình statitionary và remove NAN lúc train)
  lenght_whole_data_city = 251
  ######################################
  # Xử lý data của CNN ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_cnn+'mix_train_test_data_'+city+'_cnn.xlsx')
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index() 
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_cnn = result_test.reset_index(drop=True)  
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_cnn = result_train.reset_index(drop=True)
  
  ######################################
  # Xử lý data của LSTM  ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm+'mix_train_test_data_'+city+'_lstm.xlsx')  
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm = result_test.reset_index(drop=True)
  # Tạo meta trainset
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm = result_train.reset_index(drop=True)

  ###########################################
  # Xử lý data của LSTM ATT ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_lstm_att+'mix_train_test_data_'+city+'_lstm_att.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36))
  meta_test_lstm_att = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36]
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_lstm_att = result_train.reset_index(drop=True)


  #############################################
  # Xử lý data của Transformer ứng với mỗi city
  df = pd.read_excel(path_all_mix_data_tf+'mix_train_test_data_'+city+'_tf.xlsx') 
  selected_result = df.sort_values(by = 'rmse', ascending=True) # Sắp xếp theo rmse nhỏ nhất
  selected_result = selected_result.head(lenght_whole_data_city) # lấy 251 phần tử đầu tiên
  selected_result= selected_result.sort_index()   
  
  # Tạo meta testset
  # Meta testset sẽ có lenght = 36 + lookback_window 
  meta_test_observed = selected_result['Observed'].iloc[-meta_lookback_window-36:]
  meta_test_observed = meta_test_observed.reset_index(drop=True) 

  result_test = selected_result['Train Prediction'].iloc[-meta_lookback_window-36:-36] # Lấy buffer cho phần lookback_window
  result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
  meta_test_tf = result_test.reset_index(drop=True)  
  
  # Tạo meta trainset
  meta_train_observed = selected_result['Observed'].iloc[meta_lookback_window:-36] # Lấy từ meta_lookback_window cho đến -36 (3 năm cuối)
  meta_train_observed = meta_train_observed.reset_index(drop=True)
  result_train = selected_result['Train Prediction'].iloc[meta_lookback_window:-36]
  meta_train_tf = result_train.reset_index(drop=True)

  
  meta_test_set['cnn_pred'] = meta_test_cnn
  meta_test_set['lstm_pred'] = meta_test_lstm
  meta_test_set['lstm_att_pred'] = meta_test_lstm_att
  meta_test_set['tf_pred'] = meta_test_tf
  meta_test_set['Observed'] = meta_test_observed
   
  meta_train_set['cnn_pred'] = meta_train_cnn
  meta_train_set['lstm_pred'] = meta_train_lstm
  meta_train_set['lstm_att_pred'] = meta_train_lstm_att 
  meta_train_set['tf_pred'] = meta_train_tf  
  meta_train_set['Observed'] = meta_train_observed

  meta_test_set_city[city] = meta_test_set # test set có chiều dài 39
  meta_train_set_city[city] = meta_train_set # train set có chiều dài 212 = 252 -36 (train) - 1 (station) - 3 (meta_lookback_window)

  # Đoạn này làm thêm. Nối dài meta_test_set_city và meta_train_set_city
  # lưu ý đoạn này sẽ tạo ra data có chiều dài = 252 - 1 (bỏ đi 1 tháng đầu do xử lý stationary) - meta_lookback_window
  df = meta_train_set.append(meta_test_set[3:])
  df = df.reset_index(drop=True)
  # range date từ 1 + lookback_window tháng đầu tiên
  df['year_month'] = pd.Series(pd.date_range("1997-05-01", periods=248, freq="M"))  
  meta_data_set_city[city] = df
  df.to_excel(prj_path_result_ensemble+'/meta_data/meta_data_'+city+'.xlsx')
# Out:
# <ipython-input-5-54d36daf2e14>:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:49: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:68: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:91: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-54d36daf2e14>:118: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-5-54d36daf2e14>:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:49: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:68: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:91: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-54d36daf2e14>:118: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-5-54d36daf2e14>:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:49: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:68: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:91: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-54d36daf2e14>:118: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-5-54d36daf2e14>:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:49: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:68: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:91: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-54d36daf2e14>:118: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])
# <ipython-input-5-54d36daf2e14>:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:49: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:68: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36))
# <ipython-input-5-54d36daf2e14>:91: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_test = result_test.append(selected_result['Test Prediction'].tail(36)) # Lấy 36 tháng cuối
# <ipython-input-5-54d36daf2e14>:118: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = meta_train_set.append(meta_test_set[3:])

# %%
# meta_train_set_city['Lạng Sơn'].shape

# %% [markdown]
# # Danh sách các based Model và các Combination có thể của nó

# %%
# Danh sách các based Model và các Combination có thể của nó
list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

combs_features = list(combinations(list_based_model[0:], 2)) + list(combinations(list_based_model[0:], 3)) + list(combinations(list_based_model[0:], 4))

# list_based_model = ['cnn_pred','lstm_att_pred','lstm_pred','tf_pred']

# combs_features = list(combinations(list_based_model[0:], 3)) 
combs_features
# Out:
# [('cnn_pred', 'lstm_att_pred'),
#  ('cnn_pred', 'lstm_pred'),
#  ('cnn_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred'),
#  ('lstm_att_pred', 'tf_pred'),
#  ('lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_pred', 'tf_pred'),
#  ('lstm_att_pred', 'lstm_pred', 'tf_pred'),
#  ('cnn_pred', 'lstm_att_pred', 'lstm_pred', 'tf_pred')]

# %% [markdown]
# # Selected 5 Combination

# %%
# # Bộ này theo top 7 ( rmse va mae)
selected_combs = ['LSTM*cnn_pred-tf_pred-Observed',
                  'LSTM*lstm_att_pred-lstm_pred-Observed',    

                  'LSTM*cnn_pred-lstm_att_pred-tf_pred-Observed',
                  'CNN*lstm_att_pred-lstm_pred-Observed', 
                  'LSTM*cnn_pred-lstm_pred-Observed',

                  'LSTM*lstm_att_pred-lstm_pred-tf_pred-Observed',                    
                  'CNN*lstm_att_pred-tf_pred-Observed'      
                 ]

def is_in_Selected_combination(comb_string = ''):
    return any(comb_string in x for x in selected_combs)

# %% [markdown]
# # Support Functions and Train class

# %%
import requests

def send_to_telegram(message):

    apiToken = '5908735099:AAGVSLrW62aXPBP-GrMvxoVgMsuJxXJpP1Q'
    chatID = '@ptn_announcement'
    apiURL = f'https://api.telegram.org/bot{apiToken}/sendMessage'

    try:
        response = requests.post(apiURL, json={'chat_id': chatID, 'text': message})
        print(response.text)
    except Exception as e:
        print(e)


def seed_everything(seed: int):
    import random, os    
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything(42)

# Set hyperparameters as args using the Configuration class
class Configuration():
    def __init__(self):
      # lấy bộ test dài 36 tháng = 3 năm
        self.test_size = 36
        # là nhìn vào dữ liệu trước 3 tháng và dự phóng        
        self.look_back = 3
        # dự phóng 3 tháng
        self.n_predicted_month = 3
        self.n_features = 3
        self.seed = 42
        # mỗi phần tử x trong tập suppervise có độ lớn là 16 = 16 tháng
        self.batch_size = 16
        # self.device = torch.device("cuda")
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.epochs = 300
     

# Biến args lưu giá trị Global.
args = Configuration()


# Lưu ý sau khi stationnary thì dòng đầu tiên trừ cho dòng trước nữa là ko có cho nên về cơ bản sẽ thành NaN
# Cần remove dòng đầu tiên ra khỏi data để train và test. Cho nên cơ bản là data sau khi in ra sẽ thiếu 1 đơn vị đầu tiên
def convert_to_stationary(city_data):
    """Subtracts previous value for all cols except disease rates"""
    for col_name in city_data.columns:
        if col_name != 'Diarrhoea_rates':
            try:
                city_data[col_name] = city_data[col_name] - city_data[col_name].shift()
            except:
                print(col_name)
    return city_data

def impute_missing_value(city_data):
    """
    Cơ bản dữ liệu bị thiếu sót rất nhiều: Như Điện Biên 1997 -2003 là thiếu dữ liệu về bệnh
    Hàm này sẽ tự sinh ra dữ liệu bị thiếu. Nếu tháng nào không có số liệu thì tính như sau:
    12 tháng đầu không có số liệu thì gán = 0
    tháng 13-24 không có số liệu, sẽ lấy giá trị của tháng cùng kỳ năm trước
    tháng từ 24 trở đi sẽ lấy giá trị nhỏ nhất của 2 tháng cùng kỳ trong 2 năm gần nhất.
    Do Điện Biên bằng 0 nên sau khi xử lý từ 1997 -2003 là đều = 0.  
    """
    for col in city_data.columns:
        for index in range(len(city_data[col])):
            if np.isnan(city_data[col].iloc[index]):
                if index < 12:
                    city_data[col].iloc[index] = 0
                elif index >= 12 and index <= 24:
                    city_data[col].iloc[index] = city_data[col].iloc[index - 12]
                else:
                    city_data[col].iloc[index] = min(city_data[col].iloc[index - 12], city_data[col].iloc[index - 24])
    return city_data

def split_data(data, look_back ):
    """Splits data into train and test sets based on args (Configuration class)"""
    train = data[: -args.test_size]    
    test = data[-args.test_size - look_back: ]
    return train, test

def to_supervised(data, d_in=args.look_back, d_out=args.n_predicted_month, features_list=[]):
    """
    Frames time-series as supervised learning dataset.
    
    Args:
      d_in: lookback window
      d_out: number of predicted months
      features_list: list of all features **where last col is the disease incidence**

    Returns:
      Numpy arrays of disease incidence (y) and other predictors (X)
    """
    X, y = list(), list()
    for index, _ in enumerate(data):
        in_end = index + d_in
        out_end = in_end + d_out
        if out_end <= len(data):
            if len(features_list) == 0 :
                X.append(data[index: in_end, :])
            else:
                X.append(data[index: in_end, features_list])
            y.append(data[in_end: out_end, -1])
    return np.array(X), np.array(y)


def get_data(train_np, test_np, batch_size, list_selected_features, origin_city_meta_data):
    """
    Returns important feature list and data formatted for input into Pytorch 
    models
    """ 
    # origin_city_meta_data chứa data mẫu để lấy index 
    # important_features = arrary index nên ta phải truyền indexex của columns
    important_features = [origin_city_meta_data.columns.get_loc(c) for c in list_selected_features if c in origin_city_meta_data]  

    train_X, train_y = to_supervised(train_np, features_list=important_features)
    test_X, test_y = to_supervised(test_np, features_list=important_features)
    train_tensor = TensorDataset(torch.from_numpy(train_X), torch.from_numpy(train_y))
    test_tensor = (torch.from_numpy(test_X), torch.from_numpy(test_y))

    train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

    return important_features, train_loader, test_tensor

#Define Pytorch LSTM model
class MultiVariateLSTM(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = output[:, -1, :]
        y_predicted = self.linear(last_hidden_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            #return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

#Define Pytorch LSTM-ATT model
class MultiVariateLSTM_Attention(nn.Module):
    def __init__(self, n_feature=3, n_layers=2, hidden_size=50):
        super(MultiVariateLSTM_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size=n_feature, hidden_size=hidden_size, num_layers=n_layers, batch_first=True)
        self.attention_linear = nn.Linear(hidden_size, hidden_size)
        # self.linear = nn.Linear(hidden_size*2, args.n_predicted_month)
        self.linear = nn.Linear(hidden_size, args.n_predicted_month)
        self.loss_fn = nn.MSELoss()
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
    
    def forward(self, X_batch, y_batch=None):
        output, (last_hidden, _) = self.lstm(X_batch)
        last_hidden_vector = last_hidden[-1]
        remain_hidden_vector = output
        e_t = remain_hidden_vector.bmm(self.attention_linear(last_hidden_vector).unsqueeze(2)).squeeze(-1)
        alpha_t = F.softmax(e_t, dim=1)
        attenion_vector = remain_hidden_vector.transpose(2, 1).bmm(alpha_t.unsqueeze(2)).squeeze(-1)
        # combine_vector = torch.cat((last_hidden_vector, attenion_vector), dim=1)
        # combine_vector = last_hidden_vector + attenion_vector
        y_predicted = self.linear(attenion_vector)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted
    
    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Define Pytorch CNN model
class MultivariateCNN(nn.Module):
    def __init__(self, num_filters=[100, 100, 100], dropout=0.01):
        super(MultivariateCNN, self).__init__()
        self.loss_fn = loss = nn.MSELoss()
        self.filter_sizes = [1, 2, 3]
        self.conv1d_list = nn.ModuleList([nn.Conv1d(args.n_features, num_filters[i], self.filter_sizes[i]) for i in range(len(self.filter_sizes))])
        self.linear = nn.Linear(np.sum(num_filters), args.n_predicted_month)
        self.dropout = nn.Dropout(dropout)
        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))

    def forward(self, X_batch, y_batch=None):
        X_batch = X_batch.permute(0, 2, 1)  #(batch_size, n_features, n_look_back)
        X_conv_list = [F.relu(conv1d(X_batch)) for conv1d in self.conv1d_list]
        X_pool_list = [F.max_pool1d(x_conv, kernel_size=x_conv.shape[2]) for x_conv in X_conv_list]
        X_fc = torch.cat([x_pool.squeeze(dim=2) for x_pool in X_pool_list], dim=1)
        y_predicted = self.linear(self.dropout(X_fc))
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
            # return y_predicted, self.loss_fn(y_predicted, y_batch)
        else:
            return y_predicted

    def predict(self, X):
        X = torch.tensor(X, device=args.device)
        return self.forward(X)

# Transformer Model
# Transformer Model
class PositionalEncoder(nn.Module):
    def __init__(self, n_feature=3, dropout=0.1, max_length=24):
        super().__init__()
        
        self.hidden_dim = n_feature
        self.max_length = max_length
        self.dropout = nn.Dropout(dropout)
        
        pe = torch.zeros(max_length, self.hidden_dim)
        for pos in range(max_length):
            for i in range(0, self.hidden_dim, 2):
                pe[pos, i] = math.sin(pos/(10000**(2*i/self.hidden_dim)))
                if i + 1 < self.hidden_dim:
                    pe[pos, i+1] = math.cos(pos/(10000**((2*i+1)/self.hidden_dim)))
        pe = pe.unsqueeze(0)        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x*math.sqrt(self.hidden_dim)
        length = x.size(1)
        pe = Variable(self.pe[:, :length], requires_grad=False)
        if x.is_cuda:
            pe.cuda()
        x = x + pe
        x = self.dropout(x)
        
        return x

class TransformerModel(nn.Module):
    def __init__(self, d_input, n_look_back, hidden_size, n_layers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.hidden_size = hidden_size

        self.pe = PositionalEncoder(n_feature=args.n_features, dropout=dropout)

        encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dim_feedforward=hidden_size, dropout=dropout, activation='gelu')
        # encoder_layers = nn.TransformerEncoderLayer(d_model=d_input, nhead=d_input, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)
        self.decoder = nn.Linear(d_input*n_look_back, args.n_predicted_month)

        self.sigma = nn.Parameter(torch.ones(args.n_predicted_month))
        
        self.loss_fn = nn.MSELoss()
        
    
    def forward(self, X_batch, y_batch=None):
        X_batch = self.pe(X_batch)
        X_batch = self.transformer_encoder(X_batch)
        X_batch = X_batch.view(X_batch.size(0), -1)
        
        y_predicted = self.decoder(X_batch)
        if y_batch != None:
            assert y_predicted.size() == y_batch.size()
            loss = self.loss_fn(y_predicted, y_batch)
            loss = 0.5 * loss / self.sigma**2
            loss = loss.sum() + torch.log(1 + self.sigma.prod())
            return y_predicted, loss
        else:
            return y_predicted
        return X_batch
    
    def predict(self, X):
        with torch.no_grad():
            X = torch.tensor(X, device=args.device)
        return self.forward(X).squeeze()

# Create class to train and evaluate models
class Trainer():
    def __init__(self, city, model_type, learning_rate, important_features, train_loader, test_tensor, n_layers=2, hidden_size=128, num_filters=[100, 100, 100], dropout=0.01):
        """
        Initialise trainer, allowing input of LSTM, LSTM-ATT, or CNN 
        hyperparameters. Adam optimiser used for all models.
        """
        self.model_type = model_type    
        self.city = city    
        self.model = self.init_model(model_type, n_layers, hidden_size, num_filters, dropout, city)
        self.model.double().to(args.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.important_features, self.train_loader, self.test_tensor = important_features, train_loader, test_tensor
    
    def init_model(self, model_type, n_layers, hidden_size, num_filters, dropout, city):        
        #Get hyper param by name and set for n_layers, hidden_size, num_filters, dropout and overwrite the input param  
        # n_layers, hidden_size,num_filters, dropout= get_opt_param_by_name( algo = model_type, city = city)
    
        """Initialise a model based on whether LSTM, LSTM-ATT, or CNN is chosen."""
        if model_type.lower() == 'lstm':
            model = MultiVariateLSTM(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'lstm_attention':
            model = MultiVariateLSTM_Attention(args.n_features, n_layers, hidden_size)
        elif model_type.lower() == 'cnn':
            model = MultivariateCNN(num_filters, dropout)
        elif model_type.lower() == 'transformers':
            model = TransformerModel(d_input=args.n_features, n_look_back=args.look_back, hidden_size=hidden_size, n_layers=n_layers, dropout=dropout)
        return model

    def step(self, batch):
        self.model.train()
        X_batch, y_batch = tuple(t.to(args.device) for t in batch)
        self.optimizer.zero_grad()
        y_pred, loss = self.model.forward(X_batch, y_batch)
        loss.backward()
        self.optimizer.step()
        return loss.mean().item()

    def validation(self):
        self.model.eval()
        eval_loss = 0.0

        result = {}

        y_true = np.array([])
        y_pred = np.array([])

        X_batch, y_batch = tuple(t.to(args.device) for t in self.test_tensor)
        with torch.no_grad():
            outputs, loss = self.model.forward(X_batch, y_batch)
            eval_loss = loss.mean().item()

        return eval_loss

    def train(self, epochs=20):
        # print('param of model')
        # print('hidensize',self.model.hidden_size)
        # print('nlayer',self.model.n_layers)  
        best_lost = float("inf")
        best_model = None
        for epoch in range(epochs):
            total_loss = 0.0
            for batch in self.train_loader:
                loss = self.step(batch)
                total_loss += loss
            train_loss = total_loss/len(self.train_loader)
            eval_loss = self.validation()
            if eval_loss < best_lost:
                best_lost = eval_loss
                best_model = copy.deepcopy(self.model)
            if (epoch + 1) == epochs or (epoch + 1) in [c + 1 for c in range(epochs) if c % int(epochs/4) == 0]:
                print(f"Epoch: {epoch:2}/{epochs:2} - train_loss: {train_loss:.4f} - test_loss: {eval_loss:4f}")
        self.model = best_model
        self.model.eval()
        return None



    # Lưu model vào trong thư mục models
    def save_model_to(self, path = '', city =''):       
        torch.save(self.model, path)

    def load_model_to(self, path = ''):       
        return torch.load(path)

    def evaluate_model(self, np_data=None, plot=True, scaled=True, city=None, k_steps=None, y_scaler =None):
        assert scaled, "data must be scaled"
        self.model.eval()
        tensor_data = torch.from_numpy(np_data)
        rmse_list = []
        mae_list = [] 
        mape_list = []

        y_predicted_list = []
        y_true_list = []

        for k_steps in range(1, args.n_predicted_month + 1):
            y_predicted = []
            y_true = []
            for index in range(tensor_data.size(0) - args.look_back):
                X = tensor_data[index: index + args.look_back, self.important_features]
                # yhat = self.model.predict(X.unsqueeze(0)).squeeze()

                yhat = self.model.predict(X.unsqueeze(0))
                yhat = yhat.squeeze()

                y_predicted.append(yhat.detach().cpu().numpy()[k_steps - 1])
                y_true.append(tensor_data[index + args.look_back, -1].detach().cpu().numpy())

            y_predicted = y_scaler.inverse_transform(np.array(y_predicted).reshape(-1, 1)).reshape(-1, )
            y_true = y_scaler.inverse_transform(np.array(y_true).reshape(-1, 1)).reshape(-1, )

            

            rmse = mean_squared_error(y_true, y_predicted, squared=False)
            mae = mean_absolute_error(y_true, y_predicted)
            mape = mean_absolute_percentage_error(y_true, y_predicted)

            rmse_list.append(rmse)
            mae_list.append(mae)
            mape_list.append(mape)

            print('City: '+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))          
            if plot==True:
              plt.grid(True)
              plt.plot(y_predicted, label='predicted')
              plt.plot(y_true, label='actual')
              plt.title(f"k-steps = {k_steps} - city: "+self.city+'  _algo:'+self.model_type+'  -RMSE: '+str(rmse))
              plt.legend()
              plt.show()

              plt.show()
            y_predicted_list.append(y_predicted)
            y_true_list.append(y_true)

        return y_true_list, y_predicted_list, rmse_list, mae_list, mape_list

# %% [markdown]
# # Get optimized Hyper param

# %%
def convert_str_num_filter_array(str_filter = ''):  
  arr_filter = str_filter.split(',')  
  int_arr_filter= [int(x) for x in arr_filter]
  return int_arr_filter

def concate_2_filter_str(listfilter = ''):
  string_filter = ','.join(str(e) for e in listfilter)
  return string_filter

opt_param_cnn = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_cnn.xlsx', index_col = 'City')
opt_param_lstm = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm.xlsx', index_col = 'City')
opt_param_lstm_att = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_lstm_att.xlsx', index_col = 'City')
opt_param_transformer = pd.read_excel(prj_path_opt+'diarrhoea_opt_hyperparam_transformer.xlsx', index_col = 'City')

def get_opt_param_by_name(algo = 'transformers', city = None):
  if algo == 'cnn':
    city_param = opt_param_cnn.loc[city]
    #load  param
    n_layers = ''
    hidden_size = ''
    num_filters = convert_str_num_filter_array(city_param['Num. filters'])
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm':
    city_param = opt_param_lstm.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'lstm_attention':
    city_param = opt_param_lstm_att.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hiden Size'])
    num_filters = ''
    dropout = ''
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  elif algo == 'transformers':
    city_param = opt_param_transformer.loc[city]
    #load  param
    n_layers = int(city_param['n Layers'])
    hidden_size = int(city_param['Hidden Size'])
    num_filters = ''
    dropout = float(city_param['Dropout rate'])
    learning_rate = float(city_param['Learning rate'])
    epoch = int(city_param['Epochs'])
    lookback_window = int(city_param['Lookback Window'])
  return n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window


# Manual Check param before train
n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window= get_opt_param_by_name(algo='transformers', city='Cao Bằng')
lookback_window,epoch, hidden_size, n_layers,learning_rate, num_filters, dropout
# Out:
# (3, 270, 36, 6, 0.001205121044593835, '', 0.4761287407623291)

# %% [markdown]
# # Đoạn này nhái Cross validation Train/Test set. Tạo 1 bộ validation duy nhất để chạy optimize

# %%
# Cross validation chỉ trên chiều dài của bộ train = 212
# tạo l_train_indices\l_test_indices
data = list(range(212))
min_train_size = 176 # Chiều dài ban đầu train size = 6 năm = 72
test_size = 36 # chiều dài test size 36 tháng
l_train_indices= []
l_test_indices = []
for i in range(min_train_size, len(data)-test_size+1):
    train = np.array(data[0:i])
    test = np.array(data[i:i+test_size])    
    l_train_indices.append(train)
    l_test_indices.append(test)

len(l_test_indices)
# Out:
# 1

# %% [markdown]
# # Function Tạo và Predict. Important (epoch = 1 for test)

# %%
# def do_train_predict(city ='', algo = '', list_selected_features = '', origin_city_meta_test_set= '', y_scaler = '', s_selected_features= '', train ='', test ='', sample_idx ='', combination_idx= ''):
    
#     metric_reslt = pd.DataFrame()
#     n_layers, hidden_size, num_filters, dropout, learning_rate, epoch, lookback_window = get_opt_param_by_name( algo = algo, city = city)
#     # Get data to run model
#     important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   

#     epoch = 1 # comment when do experiment
    
#     if( algo =='cnn'): 
#         algo = 'CNN'    # upper case only
#         trainer = Trainer(
#                             model_type='cnn',  
#                             city = city,                    
#                             learning_rate=learning_rate,
#                             important_features=important_features,
#                             train_loader=train_loader,
#                             test_tensor=test_tensor,
#                             num_filters= num_filters, 
#                             dropout=dropout )

#     if( algo =='lstm'):
#         algo = 'LSTM'    # upper case only        
#         trainer = Trainer(
#                             model_type='lstm', 
#                             city = city,
#                             learning_rate=learning_rate,
#                             important_features=important_features,
#                             train_loader=train_loader,
#                             test_tensor=test_tensor,
#                             n_layers=n_layers,
#                             hidden_size=hidden_size)

#     if( algo =='lstm_attention'): 
#         algo = 'LSTM ATT'    # upper case only       
#         trainer = Trainer(
#                             model_type= 'lstm_attention',
#                             city = city,
#                             learning_rate= learning_rate,
#                             important_features=important_features,
#                             train_loader=train_loader,
#                             test_tensor=test_tensor,
#                             n_layers= n_layers,
#                             hidden_size=hidden_size )

#     if( algo =='transformers'): 
#         algo = 'TF'    # upper case only       
#         trainer = Trainer(
#                             model_type='transformers',
#                             city = city, 
#                             learning_rate=learning_rate,
#                             important_features=important_features,
#                             train_loader=train_loader,
#                             test_tensor=test_tensor,
#                             n_layers=n_layers,
#                             hidden_size=hidden_size,
#                             dropout=dropout)

    
#     # Train model with province-specific epochs
#     trainer.train(epochs=epoch)  
#     # Evaluate test set   
#     y_true_test, y_pred_test, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler= y_scaler)
        
#     metric_reslt = pd.DataFrame({
#                                 'City': city,
#                                 'Meta_Model_Name': algo, 
#                                 'sample_index':sample_idx,
#                                 'Based_Models': s_selected_features,                                                      
#                                 # algo+'_'+str(combination_idx)+'_rmse': rmse_list[0],
#                                 # algo+'_'+str(combination_idx)+'_mae': mae_list[0]
#                                 algo+'*'+s_selected_features+'_rmse': rmse_list[0],
#                                 algo+'*'+s_selected_features+'_mae': mae_list[0]
#                                 }, index=[0]) # do có 1 dòng nên pandas cần index = 0    
  

        
#     return metric_reslt

# %%
def objective_CNN(trial, city, important_features,train_loader,test_tensor,test, y_scaler):
    # Define search parameters   
    args.epochs = trial.suggest_int('Epochs', 100, 500, step=10)
    learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
    num_filters = trial.suggest_categorical('Num. filters', [[64, 64, 64], [100, 100, 100], [128, 128, 128], [16, 32, 64], [32, 64, 128]])
    dropout = trial.suggest_uniform('Dropout rate', 0.01, 0.80)

    trainer = Trainer(  model_type='cnn',  
                        city = city,                    
                        learning_rate=learning_rate,
                        important_features=important_features,
                        train_loader=train_loader,
                        test_tensor=test_tensor,
                        num_filters= num_filters, 
                        dropout=dropout )
    # Train model
    # trainer.train(epochs=args.epochs, trial=trial)
    trainer.train(epochs=args.epochs)
    
    # Evaluate model
    y_true, y_pred, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler = y_scaler)
    # _, _, rmse, mae, = trainer.evaluate_model(np_data=test, plot=False, scaled=True, city=city, y_scaler=y_scaler)

    return rmse_list[0]

# %%
def objective_LSTM(trial, city, important_features,train_loader,test_tensor,test, y_scaler):
    # Define search parameters   
    # args.epochs = trial.suggest_int('Epochs', 100, 500, step=10)
    # learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
    # num_filters = trial.suggest_categorical('Num. filters', [[64, 64, 64], [100, 100, 100], [128, 128, 128], [16, 32, 64], [32, 64, 128]])
    # dropout = trial.suggest_uniform('Dropout rate', 0.01, 0.80)    
    
    args.epochs = trial.suggest_int('Epochs', 100, 500, step=10)
    hidden_size = trial.suggest_int('Hidden size', 5, 256, log=True)
    n_layers = trial.suggest_int('n layers', 3, 10)
    learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)

    # # LSTM model
    trainer = Trainer(model_type='lstm',
                        city = city,     
                        learning_rate=learning_rate,
                        important_features=important_features,
                        train_loader=train_loader,
                        test_tensor=test_tensor,
                        n_layers=n_layers,
                        hidden_size=hidden_size )
    # Train model
    # trainer.train(epochs=args.epochs, trial=trial)
    trainer.train(epochs=args.epochs)
    
    # Evaluate model
    y_true, y_pred, rmse_list, mae_list, mape_list = trainer.evaluate_model(np_data=test, plot= False, scaled=True, city=city, y_scaler = y_scaler)
    # _, _, rmse, mae, = trainer.evaluate_model(np_data=test, plot=False, scaled=True, city=city, y_scaler=y_scaler)

    return rmse_list[0]

# %%
def do_optimize(city ='', algo = '', list_selected_features = '', origin_city_meta_test_set= '', y_scaler = '', 
                s_selected_features= '', train ='', test ='', sample_idx ='', combination_idx= ''):
    # Get data to run model
    important_features, train_loader, test_tensor = get_data(train, test, args.batch_size, list_selected_features, origin_city_meta_test_set)   
    
    ntry = 30
    njob = -1
    l_errCity ={}
    result = pd.DataFrame 
    if( algo =='cnn'):         
        algo = 'CNN'    # upper case only
        sampler = optuna.samplers.TPESampler()
        study = optuna.create_study(sampler=sampler, direction='minimize')

        # truyền multiple param vào trong biến trial
        obj_func = lambda trial: objective_CNN(trial, city, important_features,train_loader,test_tensor,test,y_scaler)

        try:
            # Optimise over 100 trials
            study.optimize(obj_func, n_trials=ntry, n_jobs=njob)

            # Print results
            print("Study statistics for : ")
            print("  Number of finished trials: ", len(study.trials))
        
            
            print("Best trial of city: ",city)
            best_trial = study.best_trial
            print("  Value: ", best_trial.value)   

            # lưu best param vào trong biến toàn cục
            one_city_param = pd.DataFrame({                     
                                    'City': city,
                                    'Alg_name': 'cnn',
                                    'Best_value': best_trial.value,
                                    'n_try_opt': ntry,
                                    'n Feature': 3, # dùng chung cho tất cả các model và algorithm
                                    'Batch Size': 16, # dùng chung cho tất cả các model và algorithm
                                    'Lookback Window': 3, # dùng chung cho tất cả các tỉnh của CNN
                                    'Epochs': best_trial.params['Epochs'],
                                    'Hiden Size': '', # CNN không quan tâm
                                    'n Layers': '', # CNN không quan tâm
                                    'Learning rate': best_trial.params['Learning rate'], 
                                    'Num. filters': concate_2_filter_str(best_trial.params['Num. filters']), # đoạn này ép kiểu không sẽ thành x 3 do cấu trúc [] 
                                    'Dropout rate': best_trial.params['Dropout rate']}, index=[0])
            
            # one_city_param.to_excel(city+'_opt_hyperparam_cnn_'+s_selected_features+'.xlsx') 
            result =  one_city_param          
        except Exception as e:
          print(e)
    if( algo =='lstm'):         
        algo = 'LSTM'    # upper case only
        sampler = optuna.samplers.TPESampler()
        study = optuna.create_study(sampler=sampler, direction='minimize')

        # truyền multiple param vào trong biến trial
        obj_func = lambda trial: objective_LSTM(trial, city, important_features,train_loader,test_tensor,test,y_scaler)

        try:
            # Optimise over 100 trials
            study.optimize(obj_func, n_trials=ntry, n_jobs=njob)

            # Print results
            print("Study statistics for : ")
            print("  Number of finished trials: ", len(study.trials))
        
            
            print("Best trial of city: ",city)
            best_trial = study.best_trial
            print("  Value: ", best_trial.value)   

            # lưu best param vào trong biến toàn cục
            # lưu best param vào trong biến toàn cục
            one_city_param = pd.DataFrame({                     
                                    'City': city,
                                    'Alg_name': 'lstm',
                                    'Best_value': best_trial.value,
                                    'n_try_opt': ntry,
                                    'n Feature': 3, # dùng chung cho tất cả các model và algorithm
                                    'Batch Size': 16, # dùng chung cho tất cả các model và algorithm
                                    'Lookback Window': 3, 
                                    'Epochs': best_trial.params['Epochs'],
                                    'Hiden Size': best_trial.params['Hidden size'], 
                                    'n Layers': best_trial.params['n layers'],
                                    'Learning rate': best_trial.params['Learning rate'], 
                                    'Num. filters': '', # đoạn này ép kiểu không sẽ thành x 3 do cấu trúc [] 
                                    'Dropout rate': ''}, index=[0])
            
            # one_city_param.to_excel(city+'_opt_hyperparam_cnn_'+s_selected_features+'.xlsx') 
            result =  one_city_param          
        except Exception as e:
          print(e)
    
    return result

# %% [markdown]
# # Main Optimization
# Tạo ra 1 bộ validation. Xuất ra Metrics (RMSE và MAE) cho 5 bộ giải thuật chọn lựa. (10 cột cho 1 dòng validation )

# %%
dt_started = datetime.now()

l_errCity = {} # có lỗi sẽ lưu vào đây, kiểm tra ngay cell sau

# city_list = ['An Giang']
# Với mỗi thành phố, loop qua từng bộ tr/validation, cho train/predict N tổ hợp models
for city in cities:
  pd_all_rows_new_meta_data = pd.DataFrame()

  for sample_index in  range(0,len(l_train_indices)):

    pd_one_row_new_meta_data = pd.DataFrame()
    combination_idx = 0
    for combination_features in combs_features:            
      list_selected_features = [x for x in combination_features] +['Observed'] # Lấy danh sách tên các features + cột Observed 
      s_selected_features = '-'.join([str(elem) for elem in list_selected_features])      

      # Có trong danh sách chọn lựa thì thực hiện optimize
      if((is_in_Selected_combination('CNN*'+s_selected_features)==True) or (is_in_Selected_combination('LSTM*'+s_selected_features) == True)):        
        args.n_features = len(list_selected_features) 
        args.look_back = meta_lookback_window  
        cnn_metrics = pd.DataFrame()
        lstm_metrics = pd.DataFrame()

        try:
          # Lấy data từ train set và chia ra theo valiation
          origin_city_meta_train_set = meta_train_set_city[city]
          origin_city_meta_test_set = meta_test_set_city[city]
          
          train = origin_city_meta_train_set.iloc[l_train_indices[sample_index]]
          test = origin_city_meta_train_set.iloc[l_test_indices[sample_index]]        

          # Data train/test processing for all Meta model
          train = train.astype(float)
          test = test.astype(float)

          train = train.replace((np.inf, -np.inf, np.nan), 0)
          test = test.replace((np.inf, -np.inf, np.nan), 0) 
        
          # Đoạn này impute các trường hợp rỗng
          train = impute_missing_value(train)
          test = impute_missing_value(test)

          # Fit data scaler to training data
          full_scaler = MinMaxScaler().fit(train)
          y_scaler = MinMaxScaler().fit(train.values[:, -1].reshape(-1, 1))

          # Scale train and test data
          train = full_scaler.transform(train)
          test = full_scaler.transform(test)

          if(is_in_Selected_combination('CNN*'+s_selected_features)==True):
            ########################################
            ########## làm optimize cho CNN 
            ########################################

            one_cnn_opt_result = do_optimize(city =city, algo='cnn', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)
            one_cnn_opt_result.to_excel(prj_path_opt+'opt_combination/'+city+'_opt_CNN_with_'+s_selected_features+'.xlsx') 

          if(is_in_Selected_combination('LSTM*'+s_selected_features)==True):
            ########################################
            ########## LSTM 
            ########################################
            one_lstm_opt_result = do_optimize(city =city, algo='lstm', list_selected_features = list_selected_features,
                                                origin_city_meta_test_set= origin_city_meta_test_set, y_scaler = y_scaler, 
                                                s_selected_features= s_selected_features, train = train, test = test, 
                                                sample_idx = sample_index,combination_idx= combination_idx)
            one_lstm_opt_result.to_excel(prj_path_opt+'opt_combination/'+city+'_opt_hyperparam_LSTM_with_'+s_selected_features+'.xlsx')           

        except Exception as e:
          l_errCity[city] = e
          break    
    send_to_telegram(city)
print(l_errCity)
# Telegram vào
# Out:
# [I 2023-02-06 17:13:53,196] A new study created in memory with name: no-name-dbcaaa31-7e4b-4c48-a45b-c6116ec60e2e
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/100 - train_loss: 0.7818 - test_loss: 0.787109
# Epoch:  0/100 - train_loss: 0.7631 - test_loss: 0.691982
# Epoch:  0/100 - train_loss: 0.7461 - test_loss: 0.697801
# Epoch:  0/100 - train_loss: 0.7047 - test_loss: 0.656172
# Epoch:  0/100 - train_loss: 0.7947 - test_loss: 0.695424
# Epoch:  0/100 - train_loss: 0.7548 - test_loss: 0.694340
# Epoch:  0/100 - train_loss: 0.7291 - test_loss: 0.662682
# Epoch: 25/100 - train_loss: 0.6752 - test_loss: 0.675648
# Epoch: 25/100 - train_loss: 0.6719 - test_loss: 0.658845
# Epoch: 25/100 - train_loss: 0.3342 - test_loss: 0.280682
# Epoch: 25/100 - train_loss: 0.2257 - test_loss: 0.140660
# Epoch: 50/100 - train_loss: 0.5977 - test_loss: 0.588098
# Epoch: 50/100 - train_loss: 0.6073 - test_loss: 0.585086
# Epoch:  0/100 - train_loss: 1.0017 - test_loss: 0.864723
# Epoch: 25/100 - train_loss: 0.6339 - test_loss: 0.609321
# Epoch: 50/100 - train_loss: 0.2306 - test_loss: 0.151865
# Epoch: 50/100 - train_loss: 0.1883 - test_loss: 0.159039
# Epoch: 75/100 - train_loss: 0.5311 - test_loss: 0.517515
# Epoch: 75/100 - train_loss: 0.5526 - test_loss: 0.520240
# Epoch: 25/100 - train_loss: 0.6782 - test_loss: 0.663826
# Epoch: 75/100 - train_loss: 0.2224 - test_loss: 0.130050
# Epoch: 99/100 - train_loss: 0.4774 - test_loss: 0.460731
# City: An Giang  _algo:lstm  -RMSE: 78.0491194833066
# City: An Giang  _algo:lstm  -RMSE: 77.78269774515455
# [I 2023-02-06 17:14:39,430] Trial 0 finished with value: 78.0491194833066 and parameters: {'Epochs': 470, 'Hidden size': 5, 'n layers': 3, 'Learning rate': 0.00018922997584684722}. Best is trial 0 with value: 78.0491194833066.
# City: An Giang  _algo:lstm  -RMSE: 80.61578445656762
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/460 - train_loss: 0.7813 - test_loss: 0.685711
# Epoch: 99/100 - train_loss: 0.5035 - test_loss: 0.467873
# City: An Giang  _algo:lstm  -RMSE: 28.49852424720947
# City: An Giang  _algo:lstm  -RMSE: 36.55694531973297
# [I 2023-02-06 17:14:41,668] Trial 12 finished with value: 28.49852424720947 and parameters: {'Epochs': 220, 'Hidden size': 34, 'n layers': 3, 'Learning rate': 0.00015399648248735367}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 39.05318753914323
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/490 - train_loss: 0.7665 - test_loss: 0.691335
# Epoch: 75/100 - train_loss: 0.1634 - test_loss: 0.111075
# Epoch: 50/100 - train_loss: 0.5423 - test_loss: 0.513511
# Epoch: 99/100 - train_loss: 0.2189 - test_loss: 0.140594
# City: An Giang  _algo:lstm  -RMSE: 29.533109401469503
# City: An Giang  _algo:lstm  -RMSE: 30.99642029448098
# [I 2023-02-06 17:14:55,656] Trial 18 finished with value: 29.533109401469503 and parameters: {'Epochs': 410, 'Hidden size': 12, 'n layers': 4, 'Learning rate': 0.0012561758398647112}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 36.15910901221502
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/140 - train_loss: 0.7648 - test_loss: 0.689437
# Epoch: 99/100 - train_loss: 0.1546 - test_loss: 0.102671
# City: An Giang  _algo:lstm  -RMSE: 29.371305118221027
# City: An Giang  _algo:lstm  -RMSE: 26.7506959669015
# [I 2023-02-06 17:15:02,489] Trial 6 finished with value: 29.371305118221027 and parameters: {'Epochs': 170, 'Hidden size': 121, 'n layers': 4, 'Learning rate': 0.005006263247377702}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 27.686116548503133
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/300 - train_loss: 0.7089 - test_loss: 0.620890
# Epoch: 50/100 - train_loss: 0.6161 - test_loss: 0.590378
# Epoch: 75/100 - train_loss: 0.4656 - test_loss: 0.431507
# Epoch:  0/100 - train_loss: 0.7560 - test_loss: 0.698738
# Epoch: 35/140 - train_loss: 0.5536 - test_loss: 0.538814
# Epoch: 99/100 - train_loss: 0.3982 - test_loss: 0.362665
# City: An Giang  _algo:lstm  -RMSE: 35.92950162923929
# City: An Giang  _algo:lstm  -RMSE: 35.25952295437456
# [I 2023-02-06 17:15:42,797] Trial 2 finished with value: 35.92950162923929 and parameters: {'Epochs': 460, 'Hidden size': 138, 'n layers': 8, 'Learning rate': 0.00024110963152632666}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 36.51056628691538
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/400 - train_loss: 0.7892 - test_loss: 0.689529
# Epoch: 75/100 - train_loss: 0.5624 - test_loss: 0.534966
# Epoch: 25/100 - train_loss: 0.2240 - test_loss: 0.142813
# Epoch: 70/140 - train_loss: 0.3999 - test_loss: 0.358474
# Epoch: 122/490 - train_loss: 0.4247 - test_loss: 0.389117
# Epoch: 75/300 - train_loss: 0.2155 - test_loss: 0.130705
# Epoch: 99/100 - train_loss: 0.5147 - test_loss: 0.485920
# City: An Giang  _algo:lstm  -RMSE: 39.819683906231724
# City: An Giang  _algo:lstm  -RMSE: 39.77046389998286
# [I 2023-02-06 17:16:22,308] Trial 9 finished with value: 39.819683906231724 and parameters: {'Epochs': 190, 'Hidden size': 186, 'n layers': 10, 'Learning rate': 0.00014219918929783107}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 42.160573280725195
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/190 - train_loss: 0.7215 - test_loss: 0.645140
# Epoch: 115/460 - train_loss: 0.2362 - test_loss: 0.145057
# Epoch: 105/140 - train_loss: 0.2963 - test_loss: 0.246239
# Epoch: 100/400 - train_loss: 0.3715 - test_loss: 0.322227
# Epoch: 139/140 - train_loss: 0.2292 - test_loss: 0.174857
# Epoch: 50/100 - train_loss: 0.2081 - test_loss: 0.126634
# City: An Giang  _algo:lstm  -RMSE: 32.86628768928822
# City: An Giang  _algo:lstm  -RMSE: 37.818253566162234
# [I 2023-02-06 17:17:13,082] Trial 22 finished with value: 32.86628768928822 and parameters: {'Epochs': 140, 'Hidden size': 86, 'n layers': 10, 'Learning rate': 0.00035685689953171193}. Best is trial 12 with value: 28.49852424720947.
# City: An Giang  _algo:lstm  -RMSE: 36.21729313458341
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/310 - train_loss: 0.7858 - test_loss: 0.689539
# Epoch: 47/190 - train_loss: 0.2219 - test_loss: 0.123427
# Epoch: 150/300 - train_loss: 0.1960 - test_loss: 0.127877
# Epoch: 244/490 - train_loss: 0.2571 - test_loss: 0.206827
# Epoch: 77/310 - train_loss: 0.2916 - test_loss: 0.218169
# Epoch: 94/190 - train_loss: 0.1876 - test_loss: 0.155791
# Epoch: 200/400 - train_loss: 0.2158 - test_loss: 0.146587
# Epoch: 75/100 - train_loss: 0.1911 - test_loss: 0.116045
# Epoch: 230/460 - train_loss: 0.2080 - test_loss: 0.122814
# Epoch: 154/310 - train_loss: 0.1961 - test_loss: 0.117744
# Epoch: 225/300 - train_loss: 0.1872 - test_loss: 0.120707
# Epoch: 366/490 - train_loss: 0.2099 - test_loss: 0.136319
# Epoch: 141/190 - train_loss: 0.2278 - test_loss: 0.082480
# Epoch: 231/310 - train_loss: 0.1697 - test_loss: 0.107774
# Epoch: 300/400 - train_loss: 0.1686 - test_loss: 0.134806
# Epoch: 99/100 - train_loss: 0.1852 - test_loss: 0.120026
# City: An Giang  _algo:lstm  -RMSE: 19.70696027038095
# City: An Giang  _algo:lstm  -RMSE: 30.28065700369687
# [I 2023-02-06 17:19:33,996] Trial 14 finished with value: 19.70696027038095 and parameters: {'Epochs': 150, 'Hidden size': 225, 'n layers': 7, 'Learning rate': 0.0027350293746797507}. Best is trial 14 with value: 19.70696027038095.
# City: An Giang  _algo:lstm  -RMSE: 23.154291080806285
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/200 - train_loss: 0.7286 - test_loss: 0.684867
# Epoch: 299/300 - train_loss: 0.1711 - test_loss: 0.117072
# City: An Giang  _algo:lstm  -RMSE: 29.762733448873526
# City: An Giang  _algo:lstm  -RMSE: 35.595180347286515
# Epoch: 308/310 - train_loss: 0.1541 - test_loss: 0.130921
# [I 2023-02-06 17:19:39,913] Trial 23 finished with value: 29.762733448873526 and parameters: {'Epochs': 300, 'Hidden size': 51, 'n layers': 8, 'Learning rate': 0.005546890998502461}. Best is trial 14 with value: 19.70696027038095.
# City: An Giang  _algo:lstm  -RMSE: 38.59827064640221
# Epoch: 309/310 - train_loss: 0.1539 - test_loss: 0.137021
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# City: An Giang  _algo:lstm  -RMSE: 26.324192068093392
# City: An Giang  _algo:lstm  -RMSE: 33.93878981254315
# Epoch:  0/300 - train_loss: 0.7590 - test_loss: 0.654236
# [I 2023-02-06 17:19:41,068] Trial 26 finished with value: 26.324192068093392 and parameters: {'Epochs': 310, 'Hidden size': 75, 'n layers': 3, 'Learning rate': 0.0005147229358307342}. Best is trial 14 with value: 19.70696027038095.
# City: An Giang  _algo:lstm  -RMSE: 34.1493354236455
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/110 - train_loss: 0.7292 - test_loss: 0.681984
# Epoch: 188/190 - train_loss: 0.1866 - test_loss: 0.140187
# Epoch: 189/190 - train_loss: 0.1830 - test_loss: 0.140756
# City: An Giang  _algo:lstm  -RMSE: 16.20989842965794
# City: An Giang  _algo:lstm  -RMSE: 14.169142959592385
# [I 2023-02-06 17:19:57,644] Trial 25 finished with value: 16.20989842965794 and parameters: {'Epochs': 190, 'Hidden size': 105, 'n layers': 6, 'Learning rate': 0.0039848511409974864}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 27.68460643610124
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/100 - train_loss: 0.7410 - test_loss: 0.663937
# Epoch: 27/110 - train_loss: 0.2379 - test_loss: 0.164371
# Epoch: 488/490 - train_loss: 0.1863 - test_loss: 0.163856
# Epoch: 489/490 - train_loss: 0.1879 - test_loss: 0.173975
# City: An Giang  _algo:lstm  -RMSE: 34.93448741678069
# City: An Giang  _algo:lstm  -RMSE: 42.833130166925606
# [I 2023-02-06 17:20:11,313] Trial 21 finished with value: 34.93448741678069 and parameters: {'Epochs': 490, 'Hidden size': 121, 'n layers': 6, 'Learning rate': 0.00017650002585752213}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 44.19291168320764
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch: 345/460 - train_loss: 0.2146 - test_loss: 0.124659
# Epoch:  0/120 - train_loss: 0.7305 - test_loss: 0.672576
# Epoch: 25/100 - train_loss: 0.6664 - test_loss: 0.631169
# Epoch: 399/400 - train_loss: 0.1639 - test_loss: 0.161816
# City: An Giang  _algo:lstm  -RMSE: 34.15131724461337
# City: An Giang  _algo:lstm  -RMSE: 46.3277603192522
# [I 2023-02-06 17:20:23,020] Trial 24 finished with value: 34.15131724461337 and parameters: {'Epochs': 400, 'Hidden size': 169, 'n layers': 3, 'Learning rate': 0.0002720957524390271}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 47.98402367029862
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/120 - train_loss: 0.7328 - test_loss: 0.676872
# Epoch: 54/110 - train_loss: 0.1999 - test_loss: 0.131895
# Epoch: 25/100 - train_loss: 0.2508 - test_loss: 0.190602
# Epoch: 30/120 - train_loss: 0.2408 - test_loss: 0.151114
# Epoch:  0/100 - train_loss: 0.8158 - test_loss: 0.771894
# Epoch: 81/110 - train_loss: 0.1656 - test_loss: 0.126047
# Epoch: 30/120 - train_loss: 0.2289 - test_loss: 0.151613
# Epoch: 75/300 - train_loss: 0.2083 - test_loss: 0.169312
# Epoch: 60/120 - train_loss: 0.1827 - test_loss: 0.171679
# Epoch: 108/110 - train_loss: 0.1872 - test_loss: 0.114719
# Epoch: 109/110 - train_loss: 0.1861 - test_loss: 0.112305
# City: An Giang  _algo:lstm  -RMSE: 19.127047579813524
# City: An Giang  _algo:lstm  -RMSE: 37.47909340368689
# [I 2023-02-06 17:21:15,975] Trial 29 finished with value: 19.127047579813524 and parameters: {'Epochs': 110, 'Hidden size': 244, 'n layers': 6, 'Learning rate': 0.001981610317419962}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 31.164938903089148
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/100 - train_loss: 0.7584 - test_loss: 0.683421
# Epoch: 50/100 - train_loss: 0.2248 - test_loss: 0.105884
# Epoch: 60/120 - train_loss: 0.1809 - test_loss: 0.116322
# Epoch: 90/120 - train_loss: 0.1680 - test_loss: 0.144340
# Epoch: 25/100 - train_loss: 0.2559 - test_loss: 0.188068
# Epoch: 90/120 - train_loss: 0.1671 - test_loss: 0.101166
# Epoch: 50/100 - train_loss: 0.2180 - test_loss: 0.124472
# Epoch: 75/100 - train_loss: 0.1855 - test_loss: 0.108966
# Epoch: 119/120 - train_loss: 0.1633 - test_loss: 0.128909
# City: An Giang  _algo:lstm  -RMSE: 17.678536113308887
# City: An Giang  _algo:lstm  -RMSE: 35.89350330708073
# [I 2023-02-06 17:21:59,276] Trial 31 finished with value: 17.678536113308887 and parameters: {'Epochs': 120, 'Hidden size': 230, 'n layers': 6, 'Learning rate': 0.0019395688503798633}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 31.051091834812006
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/240 - train_loss: 0.6917 - test_loss: 0.600112
# Epoch: 150/300 - train_loss: 0.1599 - test_loss: 0.177333
# Epoch: 119/120 - train_loss: 0.1742 - test_loss: 0.097514
# City: An Giang  _algo:lstm  -RMSE: 24.09085396967859
# City: An Giang  _algo:lstm  -RMSE: 23.84892268164442
# [I 2023-02-06 17:22:13,554] Trial 32 finished with value: 24.09085396967859 and parameters: {'Epochs': 120, 'Hidden size': 239, 'n layers': 6, 'Learning rate': 0.002115944866729401}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 31.52516503754729
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/260 - train_loss: 0.7042 - test_loss: 0.587485
# Epoch: 75/100 - train_loss: 0.2128 - test_loss: 0.121806
# Epoch: 50/200 - train_loss: 0.1834 - test_loss: 0.141093
# Epoch: 99/100 - train_loss: 0.1669 - test_loss: 0.117568
# City: An Giang  _algo:lstm  -RMSE: 24.191231303255954
# City: An Giang  _algo:lstm  -RMSE: 28.414398730623578
# [I 2023-02-06 17:22:28,461] Trial 30 finished with value: 24.191231303255954 and parameters: {'Epochs': 100, 'Hidden size': 251, 'n layers': 6, 'Learning rate': 0.002016821349373872}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 32.904974349702115
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/260 - train_loss: 0.6846 - test_loss: 0.606208
# Epoch: 99/100 - train_loss: 0.2032 - test_loss: 0.130628
# City: An Giang  _algo:lstm  -RMSE: 22.96997493048141
# City: An Giang  _algo:lstm  -RMSE: 29.979282156207425
# [I 2023-02-06 17:22:32,110] Trial 33 finished with value: 22.96997493048141 and parameters: {'Epochs': 100, 'Hidden size': 19, 'n layers': 6, 'Learning rate': 0.001898477718725731}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 29.495579492390213
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/240 - train_loss: 0.6813 - test_loss: 0.600283
# Epoch: 60/240 - train_loss: 0.2053 - test_loss: 0.172668
# Epoch: 459/460 - train_loss: 0.2007 - test_loss: 0.121177
# City: An Giang  _algo:lstm  -RMSE: 21.51957568888283
# City: An Giang  _algo:lstm  -RMSE: 36.62493150510937
# [I 2023-02-06 17:22:46,563] Trial 20 finished with value: 21.51957568888283 and parameters: {'Epochs': 460, 'Hidden size': 16, 'n layers': 10, 'Learning rate': 0.0014360893059187222}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 35.778687326080885
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/240 - train_loss: 0.8260 - test_loss: 0.688127
# Epoch: 225/300 - train_loss: 0.1214 - test_loss: 0.488462
# Epoch: 65/260 - train_loss: 0.1735 - test_loss: 0.158599
# Epoch: 60/240 - train_loss: 0.2290 - test_loss: 0.190095
# Epoch: 120/240 - train_loss: 0.1668 - test_loss: 0.221723
# Epoch: 60/240 - train_loss: 0.2638 - test_loss: 0.210136
# Epoch: 130/260 - train_loss: 0.1553 - test_loss: 0.169037
# Epoch: 299/300 - train_loss: 0.0972 - test_loss: 1.094192
# City: An Giang  _algo:lstm  -RMSE: 22.645362454761884
# City: An Giang  _algo:lstm  -RMSE: 20.958721256589453
# [I 2023-02-06 17:23:32,868] Trial 28 finished with value: 22.645362454761884 and parameters: {'Epochs': 300, 'Hidden size': 14, 'n layers': 4, 'Learning rate': 0.003818494170251276}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 35.26147749987048
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/240 - train_loss: 0.7244 - test_loss: 0.553947
# Epoch: 120/240 - train_loss: 0.1389 - test_loss: 0.343468
# Epoch: 180/240 - train_loss: 0.1113 - test_loss: 0.172512
# Epoch: 65/260 - train_loss: 0.1928 - test_loss: 0.117850
# Epoch: 195/260 - train_loss: 0.1306 - test_loss: 0.547437
# Epoch: 180/240 - train_loss: 0.1903 - test_loss: 0.360135
# Epoch: 120/240 - train_loss: 0.2016 - test_loss: 0.190525
# Epoch: 60/240 - train_loss: 0.1797 - test_loss: 0.107571
# Epoch: 239/240 - train_loss: 0.1165 - test_loss: 0.249594
# City: An Giang  _algo:lstm  -RMSE: 22.44797188794048
# City: An Giang  _algo:lstm  -RMSE: 26.158997508250554
# [I 2023-02-06 17:24:15,386] Trial 34 finished with value: 22.44797188794048 and parameters: {'Epochs': 240, 'Hidden size': 15, 'n layers': 5, 'Learning rate': 0.009807595295486938}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 30.607920752291804
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/200 - train_loss: 0.7728 - test_loss: 0.688010
# Epoch: 239/240 - train_loss: 0.1353 - test_loss: 0.101256
# City: An Giang  _algo:lstm  -RMSE: 24.142933033549525
# City: An Giang  _algo:lstm  -RMSE: 26.626495616798557
# [I 2023-02-06 17:24:38,759] Trial 37 finished with value: 24.142933033549525 and parameters: {'Epochs': 240, 'Hidden size': 68, 'n layers': 5, 'Learning rate': 0.008819353380280616}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 26.627327897021505
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/190 - train_loss: 0.7516 - test_loss: 0.706946
# Epoch: 259/260 - train_loss: 0.0879 - test_loss: 1.026637
# City: An Giang  _algo:lstm  -RMSE: 20.017993987419768
# City: An Giang  _algo:lstm  -RMSE: 24.900695468629426
# [I 2023-02-06 17:24:43,671] Trial 35 finished with value: 20.017993987419768 and parameters: {'Epochs': 260, 'Hidden size': 18, 'n layers': 5, 'Learning rate': 0.009646729824102775}. Best is trial 25 with value: 16.20989842965794.
# City: An Giang  _algo:lstm  -RMSE: 29.06567121873346
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/180 - train_loss: 0.7625 - test_loss: 0.690324
# Epoch: 120/240 - train_loss: 0.1530 - test_loss: 0.161922
# Epoch: 180/240 - train_loss: 0.1808 - test_loss: 0.177713
# Epoch: 50/200 - train_loss: 0.2540 - test_loss: 0.182132
# Epoch: 130/260 - train_loss: 0.1524 - test_loss: 0.120146
# Epoch: 47/190 - train_loss: 0.2913 - test_loss: 0.229635
# Epoch: 45/180 - train_loss: 0.2967 - test_loss: 0.245497
# Epoch: 100/200 - train_loss: 0.1786 - test_loss: 0.118718
# Epoch: 180/240 - train_loss: 0.1521 - test_loss: 0.113148
# Epoch: 239/240 - train_loss: 0.1377 - test_loss: 0.292504
# City: An Giang  _algo:lstm  -RMSE: 10.630129153328149
# City: An Giang  _algo:lstm  -RMSE: 15.86954199833524
# [I 2023-02-06 17:25:30,650] Trial 38 finished with value: 10.630129153328149 and parameters: {'Epochs': 240, 'Hidden size': 68, 'n layers': 5, 'Learning rate': 0.0007316382133561643}. Best is trial 38 with value: 10.630129153328149.
# City: An Giang  _algo:lstm  -RMSE: 32.04788019368821
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/200 - train_loss: 0.7283 - test_loss: 0.710962
# Epoch: 100/200 - train_loss: 0.1573 - test_loss: 0.123614
# Epoch: 94/190 - train_loss: 0.1829 - test_loss: 0.126033
# Epoch: 90/180 - train_loss: 0.1929 - test_loss: 0.125539
# Epoch: 150/200 - train_loss: 0.1597 - test_loss: 0.104224
# Epoch: 239/240 - train_loss: 0.1447 - test_loss: 0.123751
# City: An Giang  _algo:lstm  -RMSE: 20.0568959527966
# City: An Giang  _algo:lstm  -RMSE: 27.544612230463954
# [I 2023-02-06 17:26:05,360] Trial 39 finished with value: 20.0568959527966 and parameters: {'Epochs': 240, 'Hidden size': 71, 'n layers': 5, 'Learning rate': 0.008897425698656264}. Best is trial 38 with value: 10.630129153328149.
# City: An Giang  _algo:lstm  -RMSE: 34.14219349867826
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/200 - train_loss: 0.7575 - test_loss: 0.688580
# Epoch: 50/200 - train_loss: 0.2575 - test_loss: 0.195349
# Epoch: 141/190 - train_loss: 0.1628 - test_loss: 0.097541
# Epoch: 135/180 - train_loss: 0.1605 - test_loss: 0.105860
# Epoch: 195/260 - train_loss: 0.1553 - test_loss: 0.118259
# Epoch: 199/200 - train_loss: 0.1509 - test_loss: 0.134317
# City: An Giang  _algo:lstm  -RMSE: 29.22231493010025
# City: An Giang  _algo:lstm  -RMSE: 29.95720952408267
# [I 2023-02-06 17:26:29,771] Trial 40 finished with value: 29.22231493010025 and parameters: {'Epochs': 200, 'Hidden size': 91, 'n layers': 7, 'Learning rate': 0.0009485957676199531}. Best is trial 38 with value: 10.630129153328149.
# City: An Giang  _algo:lstm  -RMSE: 26.495436632942038
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/180 - train_loss: 0.7775 - test_loss: 0.683875
# Epoch: 50/200 - train_loss: 0.3022 - test_loss: 0.252040
# Epoch: 50/100 - train_loss: 0.5451 - test_loss: 0.527328
# Epoch: 188/190 - train_loss: 0.1600 - test_loss: 0.114057
# Epoch: 189/190 - train_loss: 0.1557 - test_loss: 0.100904
# City: An Giang  _algo:lstm  -RMSE: 10.06746791655871
# City: An Giang  _algo:lstm  -RMSE: 29.11066051567949
# [I 2023-02-06 17:26:46,069] Trial 41 finished with value: 10.06746791655871 and parameters: {'Epochs': 190, 'Hidden size': 102, 'n layers': 7, 'Learning rate': 0.000804287560758315}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 27.692319669480412
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/270 - train_loss: 0.7894 - test_loss: 0.691075
# Epoch: 179/180 - train_loss: 0.1551 - test_loss: 0.111615
# City: An Giang  _algo:lstm  -RMSE: 21.854138029625084
# City: An Giang  _algo:lstm  -RMSE: 21.787986500143926
# [I 2023-02-06 17:26:48,799] Trial 42 finished with value: 21.854138029625084 and parameters: {'Epochs': 180, 'Hidden size': 101, 'n layers': 7, 'Learning rate': 0.0008250274659696576}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 34.28937973092237
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/340 - train_loss: 0.7987 - test_loss: 0.690339
# Epoch: 100/200 - train_loss: 0.1988 - test_loss: 0.134368
# Epoch: 45/180 - train_loss: 0.3309 - test_loss: 0.288685
# Epoch: 100/200 - train_loss: 0.2104 - test_loss: 0.125708
# Epoch: 150/200 - train_loss: 0.1690 - test_loss: 0.116736
# Epoch: 90/180 - train_loss: 0.2205 - test_loss: 0.137288
# Epoch: 67/270 - train_loss: 0.2519 - test_loss: 0.187546
# Epoch: 259/260 - train_loss: 0.1484 - test_loss: 0.198765
# City: An Giang  _algo:lstm  -RMSE: 19.614941501613416
# City: An Giang  _algo:lstm  -RMSE: 20.991100836014418
# [I 2023-02-06 17:27:47,540] Trial 36 finished with value: 19.614941501613416 and parameters: {'Epochs': 260, 'Hidden size': 18, 'n layers': 5, 'Learning rate': 0.008351643638790299}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 22.699109451855836
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/360 - train_loss: 0.7468 - test_loss: 0.696625
# Epoch: 85/340 - train_loss: 0.2413 - test_loss: 0.183045
# Epoch: 150/200 - train_loss: 0.2189 - test_loss: 0.123104
# Epoch: 135/180 - train_loss: 0.2058 - test_loss: 0.123568
# Epoch: 199/200 - train_loss: 0.1764 - test_loss: 0.132793
# City: An Giang  _algo:lstm  -RMSE: 31.140071029905073
# City: An Giang  _algo:lstm  -RMSE: 32.753234213347
# [I 2023-02-06 17:28:12,747] Trial 43 finished with value: 31.140071029905073 and parameters: {'Epochs': 200, 'Hidden size': 40, 'n layers': 7, 'Learning rate': 0.0009008299568153161}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 36.85740479949729
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/340 - train_loss: 0.8057 - test_loss: 0.689759
# Epoch: 134/270 - train_loss: 0.1880 - test_loss: 0.120866
# Epoch: 199/200 - train_loss: 0.1869 - test_loss: 0.113196
# City: An Giang  _algo:lstm  -RMSE: 16.771972270511487
# City: An Giang  _algo:lstm  -RMSE: 27.034863398436954
# [I 2023-02-06 17:28:37,550] Trial 44 finished with value: 16.771972270511487 and parameters: {'Epochs': 200, 'Hidden size': 45, 'n layers': 7, 'Learning rate': 0.0007310904720065779}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 17.40480239722772
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch: 179/180 - train_loss: 0.1959 - test_loss: 0.119077
# Epoch:  0/160 - train_loss: 0.7985 - test_loss: 0.691919
# City: An Giang  _algo:lstm  -RMSE: 24.945040147352298
# City: An Giang  _algo:lstm  -RMSE: 25.46583983056175
# [I 2023-02-06 17:28:39,911] Trial 45 finished with value: 24.945040147352298 and parameters: {'Epochs': 180, 'Hidden size': 45, 'n layers': 7, 'Learning rate': 0.0007174496564724087}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 26.57783138413857
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/150 - train_loss: 0.7889 - test_loss: 0.692341
# Epoch: 170/340 - train_loss: 0.2103 - test_loss: 0.116908
# Epoch: 150/200 - train_loss: 0.1232 - test_loss: 0.405304
# Epoch: 37/150 - train_loss: 0.4357 - test_loss: 0.397443
# Epoch: 40/160 - train_loss: 0.4080 - test_loss: 0.365726
# Epoch: 201/270 - train_loss: 0.1545 - test_loss: 0.110335
# Epoch: 85/340 - train_loss: 0.2521 - test_loss: 0.191696
# Epoch: 74/150 - train_loss: 0.2733 - test_loss: 0.217143
# Epoch: 80/160 - train_loss: 0.2533 - test_loss: 0.193099
# Epoch: 90/360 - train_loss: 0.2244 - test_loss: 0.158635
# Epoch: 111/150 - train_loss: 0.2183 - test_loss: 0.144653
# Epoch: 268/270 - train_loss: 0.1480 - test_loss: 0.103748
# Epoch: 269/270 - train_loss: 0.1481 - test_loss: 0.099086
# Epoch: 255/340 - train_loss: 0.2013 - test_loss: 0.117439
# City: An Giang  _algo:lstm  -RMSE: 28.648280977771698
# City: An Giang  _algo:lstm  -RMSE: 29.760794072315953
# [I 2023-02-06 17:30:08,842] Trial 46 finished with value: 28.648280977771698 and parameters: {'Epochs': 270, 'Hidden size': 46, 'n layers': 8, 'Learning rate': 0.0007062401069348494}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 31.399790621595862
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/150 - train_loss: 0.8366 - test_loss: 0.707149
# Epoch: 120/160 - train_loss: 0.2147 - test_loss: 0.131111
# Epoch: 148/150 - train_loss: 0.2059 - test_loss: 0.121903
# Epoch: 149/150 - train_loss: 0.2010 - test_loss: 0.124066
# City: An Giang  _algo:lstm  -RMSE: 20.16714753221412
# City: An Giang  _algo:lstm  -RMSE: 32.77852811653617
# [I 2023-02-06 17:30:37,440] Trial 51 finished with value: 20.16714753221412 and parameters: {'Epochs': 150, 'Hidden size': 56, 'n layers': 8, 'Learning rate': 0.0005611614851412033}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 25.11839833120094
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/320 - train_loss: 0.7772 - test_loss: 0.688516
# Epoch: 37/150 - train_loss: 0.5543 - test_loss: 0.535444
# Epoch: 170/340 - train_loss: 0.2160 - test_loss: 0.110312
# Epoch: 159/160 - train_loss: 0.2025 - test_loss: 0.133953
# City: An Giang  _algo:lstm  -RMSE: 30.4282446769436
# City: An Giang  _algo:lstm  -RMSE: 30.07925470613663
# [I 2023-02-06 17:30:55,976] Trial 50 finished with value: 30.4282446769436 and parameters: {'Epochs': 160, 'Hidden size': 51, 'n layers': 8, 'Learning rate': 0.0005865605536091507}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 31.091284986023712
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/330 - train_loss: 0.8224 - test_loss: 0.728935
# Epoch: 74/150 - train_loss: 0.3953 - test_loss: 0.360244
# Epoch: 339/340 - train_loss: 0.1904 - test_loss: 0.116100
# City: An Giang  _algo:lstm  -RMSE: 18.402617935949056
# City: An Giang  _algo:lstm  -RMSE: 21.631138038294882
# [I 2023-02-06 17:31:23,274] Trial 47 finished with value: 18.402617935949056 and parameters: {'Epochs': 340, 'Hidden size': 39, 'n layers': 8, 'Learning rate': 0.0006160623474380537}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 22.17971536313658
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.8421 - test_loss: 0.683417
# Epoch: 111/150 - train_loss: 0.3033 - test_loss: 0.249283
# Epoch: 80/320 - train_loss: 0.2928 - test_loss: 0.235148
# Epoch: 180/360 - train_loss: 0.1854 - test_loss: 0.100726
# Epoch: 82/330 - train_loss: 0.3404 - test_loss: 0.294667
# Epoch: 55/220 - train_loss: 0.2254 - test_loss: 0.144398
# Epoch: 255/340 - train_loss: 0.2042 - test_loss: 0.113562
# Epoch: 148/150 - train_loss: 0.2503 - test_loss: 0.185151
# Epoch: 149/150 - train_loss: 0.2464 - test_loss: 0.182831
# City: An Giang  _algo:lstm  -RMSE: 39.53783765328859
# City: An Giang  _algo:lstm  -RMSE: 40.599141079563886
# [I 2023-02-06 17:32:25,714] Trial 52 finished with value: 39.53783765328859 and parameters: {'Epochs': 150, 'Hidden size': 24, 'n layers': 9, 'Learning rate': 0.000329643282152537}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 41.29202696651499
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7401 - test_loss: 0.728506
# Epoch: 160/320 - train_loss: 0.1827 - test_loss: 0.122068
# Epoch: 110/220 - train_loss: 0.2043 - test_loss: 0.129142
# Epoch: 199/200 - train_loss: 0.1111 - test_loss: 0.270710
# City: An Giang  _algo:lstm  -RMSE: 17.301049670479543
# City: An Giang  _algo:lstm  -RMSE: 32.11580279330103
# [I 2023-02-06 17:33:16,171] Trial 27 finished with value: 17.301049670479543 and parameters: {'Epochs': 200, 'Hidden size': 201, 'n layers': 4, 'Learning rate': 0.0020118043431953474}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 47.85950349690914
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7474 - test_loss: 0.737051
# Epoch: 55/220 - train_loss: 0.2311 - test_loss: 0.157568
# Epoch: 164/330 - train_loss: 0.2231 - test_loss: 0.142343
# Epoch: 339/340 - train_loss: 0.1685 - test_loss: 0.132952
# City: An Giang  _algo:lstm  -RMSE: 21.483545919168634
# City: An Giang  _algo:lstm  -RMSE: 28.704626521781027
# [I 2023-02-06 17:33:55,236] Trial 49 finished with value: 21.483545919168634 and parameters: {'Epochs': 340, 'Hidden size': 54, 'n layers': 8, 'Learning rate': 0.0005645233165995722}. Best is trial 41 with value: 10.06746791655871.
# Epoch: 75/100 - train_loss: 0.4713 - test_loss: 0.446267
# City: An Giang  _algo:lstm  -RMSE: 27.38474347738001
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 1.0595 - test_loss: 0.842193
# Epoch: 165/220 - train_loss: 0.1932 - test_loss: 0.113253
# Epoch: 110/220 - train_loss: 0.2044 - test_loss: 0.123402
# Epoch: 240/320 - train_loss: 0.1675 - test_loss: 0.103824
# Epoch: 270/360 - train_loss: 0.1435 - test_loss: 0.106586
# Epoch: 55/220 - train_loss: 0.2782 - test_loss: 0.242179
# Epoch: 246/330 - train_loss: 0.2117 - test_loss: 0.171293
# Epoch: 219/220 - train_loss: 0.1885 - test_loss: 0.136278
# City: An Giang  _algo:lstm  -RMSE: 30.528667633692965
# City: An Giang  _algo:lstm  -RMSE: 36.39123944747306
# [I 2023-02-06 17:35:09,290] Trial 55 finished with value: 30.528667633692965 and parameters: {'Epochs': 220, 'Hidden size': 30, 'n layers': 9, 'Learning rate': 0.0012666984356904424}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 35.22242548891375
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7903 - test_loss: 0.745474
# Epoch: 165/220 - train_loss: 0.1897 - test_loss: 0.098576
# Epoch: 319/320 - train_loss: 0.1643 - test_loss: 0.106299
# City: An Giang  _algo:lstm  -RMSE: 21.768333774648177
# City: An Giang  _algo:lstm  -RMSE: 31.683387973351444
# [I 2023-02-06 17:35:55,992] Trial 53 finished with value: 21.768333774648177 and parameters: {'Epochs': 320, 'Hidden size': 153, 'n layers': 9, 'Learning rate': 0.0004690511445289824}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 30.28371911859803
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/210 - train_loss: 0.7794 - test_loss: 0.695646
# Epoch: 55/220 - train_loss: 0.4309 - test_loss: 0.411531
# Epoch: 219/220 - train_loss: 0.1938 - test_loss: 0.121997
# City: An Giang  _algo:lstm  -RMSE: 15.899853747162743
# Epoch: 110/220 - train_loss: 0.2147 - test_loss: 0.127220
# City: An Giang  _algo:lstm  -RMSE: 18.060405416473234
# [I 2023-02-06 17:36:07,692] Trial 56 finished with value: 15.899853747162743 and parameters: {'Epochs': 220, 'Hidden size': 142, 'n layers': 9, 'Learning rate': 0.0012407072019799687}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 25.732580199622806
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7439 - test_loss: 0.730343
# Epoch: 328/330 - train_loss: 0.2070 - test_loss: 0.177037
# Epoch: 329/330 - train_loss: 0.2059 - test_loss: 0.174378
# City: An Giang  _algo:lstm  -RMSE: 35.308230010319775
# City: An Giang  _algo:lstm  -RMSE: 34.26536009615346
# [I 2023-02-06 17:36:23,901] Trial 54 finished with value: 35.308230010319775 and parameters: {'Epochs': 330, 'Hidden size': 24, 'n layers': 7, 'Learning rate': 0.00037588954849101163}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 32.39952506717937
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7334 - test_loss: 0.730559
# Epoch: 52/210 - train_loss: 0.6313 - test_loss: 0.604066
# Epoch: 110/220 - train_loss: 0.3002 - test_loss: 0.268925
# Epoch: 104/210 - train_loss: 0.5478 - test_loss: 0.511622
# Epoch: 55/220 - train_loss: 0.2290 - test_loss: 0.155466
# Epoch: 359/360 - train_loss: 0.1391 - test_loss: 0.103471
# City: An Giang  _algo:lstm  -RMSE: 28.952294775324013
# City: An Giang  _algo:lstm  -RMSE: 34.142646704859196
# [I 2023-02-06 17:37:01,440] Trial 48 finished with value: 28.952294775324013 and parameters: {'Epochs': 360, 'Hidden size': 48, 'n layers': 8, 'Learning rate': 0.0006071744799632842}. Best is trial 41 with value: 10.06746791655871.
# Epoch: 165/220 - train_loss: 0.2083 - test_loss: 0.207160
# City: An Giang  _algo:lstm  -RMSE: 35.773840638417504
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/220 - train_loss: 0.7498 - test_loss: 0.738421
# Epoch: 55/220 - train_loss: 0.2406 - test_loss: 0.180402
# Epoch: 156/210 - train_loss: 0.4691 - test_loss: 0.427213
# Epoch: 165/220 - train_loss: 0.2318 - test_loss: 0.155702
# Epoch: 55/220 - train_loss: 0.2334 - test_loss: 0.163093
# Epoch: 110/220 - train_loss: 0.2049 - test_loss: 0.135604
# Epoch: 208/210 - train_loss: 0.4020 - test_loss: 0.355355
# Epoch: 209/210 - train_loss: 0.3998 - test_loss: 0.354019
# City: An Giang  _algo:lstm  -RMSE: 17.41643871310767
# City: An Giang  _algo:lstm  -RMSE: 21.060424730991198
# [I 2023-02-06 17:37:52,291] Trial 60 finished with value: 17.41643871310767 and parameters: {'Epochs': 210, 'Hidden size': 107, 'n layers': 4, 'Learning rate': 0.00011501162560282668}. Best is trial 41 with value: 10.06746791655871.
# City: An Giang  _algo:lstm  -RMSE: 27.017175917800206
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/280 - train_loss: 0.7330 - test_loss: 0.655467
# Epoch: 219/220 - train_loss: 0.2131 - test_loss: 0.226000
# City: An Giang  _algo:lstm  -RMSE: 34.05237748161569
# City: An Giang  _algo:lstm  -RMSE: 36.26794893666566
# [I 2023-02-06 17:37:58,792] Trial 58 finished with value: 34.05237748161569 and parameters: {'Epochs': 220, 'Hidden size': 5, 'n layers': 9, 'Learning rate': 0.0011201899462959489}. Best is trial 41 with value: 10.06746791655871.
# ...
# [I 2023-02-07 00:22:24,713] Trial 76 finished with value: 27.03058394022558 and parameters: {'Epochs': 470, 'Hidden size': 56, 'n layers': 5, 'Learning rate': 0.00042873395251229835}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 31.88665332297356
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7246 - test_loss: 0.696284
# Epoch: 479/480 - train_loss: 0.1794 - test_loss: 0.072337
# City: An Giang  _algo:lstm  -RMSE: 18.89876329034837
# Epoch: 134/270 - train_loss: 0.1659 - test_loss: 0.111895
# City: An Giang  _algo:lstm  -RMSE: 13.012842491020775
# [I 2023-02-07 00:22:29,131] Trial 77 finished with value: 18.89876329034837 and parameters: {'Epochs': 480, 'Hidden size': 37, 'n layers': 5, 'Learning rate': 0.0010333830335114093}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 20.13611287457496
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7037 - test_loss: 0.655762
# Epoch: 201/270 - train_loss: 0.1572 - test_loss: 0.112570
# Epoch: 375/500 - train_loss: 0.1506 - test_loss: 0.105757
# Epoch: 122/490 - train_loss: 0.1920 - test_loss: 0.117144
# Epoch: 125/500 - train_loss: 0.2161 - test_loss: 0.125558
# Epoch: 125/500 - train_loss: 0.2046 - test_loss: 0.115337
# Epoch: 268/270 - train_loss: 0.1478 - test_loss: 0.117873
# Epoch: 134/270 - train_loss: 0.2002 - test_loss: 0.112377
# Epoch: 269/270 - train_loss: 0.1546 - test_loss: 0.103198
# City: An Giang  _algo:lstm  -RMSE: 16.078836762653502
# City: An Giang  _algo:lstm  -RMSE: 28.962160175528396
# [I 2023-02-07 00:24:20,106] Trial 79 finished with value: 16.078836762653502 and parameters: {'Epochs': 270, 'Hidden size': 39, 'n layers': 8, 'Learning rate': 0.001112924913480521}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 26.24830208533555
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/440 - train_loss: 0.7201 - test_loss: 0.694205
# Epoch: 499/500 - train_loss: 0.1390 - test_loss: 0.099834
# City: An Giang  _algo:lstm  -RMSE: 13.785967031806958
# City: An Giang  _algo:lstm  -RMSE: 18.266273343898884
# [I 2023-02-07 00:25:06,991] Trial 78 finished with value: 13.785967031806958 and parameters: {'Epochs': 500, 'Hidden size': 73, 'n layers': 8, 'Learning rate': 0.0010470994746577754}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 25.86173746390322
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7018 - test_loss: 0.644075
# Epoch: 244/490 - train_loss: 0.2117 - test_loss: 0.131341
# Epoch: 250/500 - train_loss: 0.1704 - test_loss: 0.114115
# Epoch: 250/500 - train_loss: 0.2050 - test_loss: 0.115918
# Epoch: 110/440 - train_loss: 0.2172 - test_loss: 0.132400
# Epoch: 201/270 - train_loss: 0.2373 - test_loss: 0.112126
# Epoch: 125/500 - train_loss: 0.2856 - test_loss: 0.232485
# Epoch: 375/500 - train_loss: 0.1782 - test_loss: 1.308476
# Epoch: 375/500 - train_loss: 0.2062 - test_loss: 0.194408
# Epoch: 366/490 - train_loss: 0.2193 - test_loss: 0.130782
# Epoch: 220/440 - train_loss: 0.1972 - test_loss: 0.118299
# Epoch: 268/270 - train_loss: 0.2433 - test_loss: 0.136711
# Epoch: 269/270 - train_loss: 0.2291 - test_loss: 0.141668
# City: An Giang  _algo:lstm  -RMSE: 20.46340426939879
# City: An Giang  _algo:lstm  -RMSE: 22.966465809494718
# [I 2023-02-07 00:27:56,590] Trial 80 finished with value: 20.46340426939879 and parameters: {'Epochs': 270, 'Hidden size': 56, 'n layers': 8, 'Learning rate': 0.00490807455442163}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 28.381858669707597
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/490 - train_loss: 0.7556 - test_loss: 0.725863
# Epoch: 250/500 - train_loss: 0.2804 - test_loss: 0.240364
# Epoch: 499/500 - train_loss: 0.1814 - test_loss: 0.707438
# City: An Giang  _algo:lstm  -RMSE: 15.280585589432752
# City: An Giang  _algo:lstm  -RMSE: 25.27689427388199
# [I 2023-02-07 00:28:45,222] Trial 83 finished with value: 15.280585589432752 and parameters: {'Epochs': 500, 'Hidden size': 42, 'n layers': 8, 'Learning rate': 0.004731393521304973}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 23.505350810732267
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7753 - test_loss: 0.678811
# Epoch: 499/500 - train_loss: 0.2091 - test_loss: 0.150006
# City: An Giang  _algo:lstm  -RMSE: 11.830665713960812
# City: An Giang  _algo:lstm  -RMSE: 19.382441810108627
# [I 2023-02-07 00:29:07,542] Trial 82 finished with value: 11.830665713960812 and parameters: {'Epochs': 500, 'Hidden size': 43, 'n layers': 8, 'Learning rate': 0.00281852083997544}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 16.8319272970313
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.6956 - test_loss: 0.612854
# Epoch: 330/440 - train_loss: 0.2072 - test_loss: 0.129334
# Epoch: 488/490 - train_loss: 0.1624 - test_loss: 0.107346
# Epoch: 489/490 - train_loss: 0.1617 - test_loss: 0.116281
# City: An Giang  _algo:lstm  -RMSE: 28.822862150105696
# City: An Giang  _algo:lstm  -RMSE: 36.189599039997354
# [I 2023-02-07 00:29:27,462] Trial 81 finished with value: 28.822862150105696 and parameters: {'Epochs': 490, 'Hidden size': 41, 'n layers': 8, 'Learning rate': 0.002826339069246353}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 35.854110263619674
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7741 - test_loss: 0.682483
# Epoch: 375/500 - train_loss: 0.2844 - test_loss: 0.251038
# Epoch: 125/500 - train_loss: 0.2117 - test_loss: 0.126849
# Epoch: 439/440 - train_loss: 0.1818 - test_loss: 0.422201
# City: An Giang  _algo:lstm  -RMSE: 15.6366049394914
# City: An Giang  _algo:lstm  -RMSE: 15.883176027115892
# [I 2023-02-07 00:30:52,724] Trial 84 finished with value: 15.6366049394914 and parameters: {'Epochs': 440, 'Hidden size': 44, 'n layers': 9, 'Learning rate': 0.002853661770794281}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 14.225823188159511
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/500 - train_loss: 0.7783 - test_loss: 0.686109
# Epoch: 125/500 - train_loss: 0.2848 - test_loss: 0.239049
# Epoch: 125/500 - train_loss: 0.1879 - test_loss: 0.132802
# Epoch: 122/490 - train_loss: 0.2091 - test_loss: 0.115378
# Epoch: 499/500 - train_loss: 0.2810 - test_loss: 0.233167
# City: An Giang  _algo:lstm  -RMSE: 41.97445828205659
# City: An Giang  _algo:lstm  -RMSE: 39.38816975779984
# [I 2023-02-07 00:32:05,731] Trial 85 finished with value: 41.97445828205659 and parameters: {'Epochs': 500, 'Hidden size': 75, 'n layers': 9, 'Learning rate': 0.005023386955406848}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 50.9089806823801
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/480 - train_loss: 0.6982 - test_loss: 0.618884
# Epoch: 250/500 - train_loss: 0.1951 - test_loss: 0.118298
# Epoch: 250/500 - train_loss: 0.2799 - test_loss: 0.246068
# Epoch: 125/500 - train_loss: 0.2010 - test_loss: 0.127281
# Epoch: 250/500 - train_loss: 0.1471 - test_loss: 0.282721
# Epoch: 120/480 - train_loss: 0.2187 - test_loss: 0.134332
# Epoch: 375/500 - train_loss: 0.2255 - test_loss: 0.119666
# Epoch: 375/500 - train_loss: 0.2816 - test_loss: 0.237764
# Epoch: 250/500 - train_loss: 0.1454 - test_loss: 0.193531
# Epoch: 419/420 - train_loss: 0.1394 - test_loss: 0.570620
# City: An Giang  _algo:lstm  -RMSE: 23.264366646282262
# City: An Giang  _algo:lstm  -RMSE: 30.343028614793223
# [I 2023-02-07 00:34:49,437] Trial 55 finished with value: 23.264366646282262 and parameters: {'Epochs': 420, 'Hidden size': 78, 'n layers': 5, 'Learning rate': 0.0006613591912704536}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 29.21428432787898
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/480 - train_loss: 0.7536 - test_loss: 0.685315
# Epoch: 244/490 - train_loss: 0.1904 - test_loss: 0.108486
# Epoch: 240/480 - train_loss: 0.2830 - test_loss: 0.216514
# Epoch: 499/500 - train_loss: 0.1900 - test_loss: 0.128129
# City: An Giang  _algo:lstm  -RMSE: 28.280285226436625
# City: An Giang  _algo:lstm  -RMSE: 32.30820428652571
# [I 2023-02-07 00:35:45,430] Trial 87 finished with value: 28.280285226436625 and parameters: {'Epochs': 500, 'Hidden size': 31, 'n layers': 9, 'Learning rate': 0.0020373911904542573}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 33.59159416191453
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/480 - train_loss: 0.7120 - test_loss: 0.594246
# Epoch: 375/500 - train_loss: 0.1406 - test_loss: 0.163447
# Epoch: 499/500 - train_loss: 0.2802 - test_loss: 0.228579
# City: An Giang  _algo:lstm  -RMSE: 65.75596690594531
# City: An Giang  _algo:lstm  -RMSE: 72.94937722370351
# [I 2023-02-07 00:36:29,588] Trial 88 finished with value: 65.75596690594531 and parameters: {'Epochs': 500, 'Hidden size': 31, 'n layers': 9, 'Learning rate': 0.007602080651131901}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 62.7830449747551
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/480 - train_loss: 0.7849 - test_loss: 0.687724
# Epoch: 375/500 - train_loss: 0.1522 - test_loss: 0.314275
# Epoch: 360/480 - train_loss: 0.2808 - test_loss: 0.258126
# Epoch: 120/480 - train_loss: 0.2052 - test_loss: 0.133659
# Epoch: 499/500 - train_loss: 0.1168 - test_loss: 0.082083
# City: An Giang  _algo:lstm  -RMSE: 22.23899803347203
# City: An Giang  _algo:lstm  -RMSE: 19.226664188917972
# [I 2023-02-07 00:38:04,988] Trial 89 finished with value: 22.23899803347203 and parameters: {'Epochs': 500, 'Hidden size': 75, 'n layers': 9, 'Learning rate': 0.0008350165707406053}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 24.62988481104956
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/480 - train_loss: 0.7319 - test_loss: 0.734059
# Epoch: 120/480 - train_loss: 0.2048 - test_loss: 0.125450
# Epoch: 366/490 - train_loss: 0.1536 - test_loss: 0.252785
# Epoch: 499/500 - train_loss: 0.1478 - test_loss: 0.105256
# City: An Giang  _algo:lstm  -RMSE: 20.515423791654975
# City: An Giang  _algo:lstm  -RMSE: 32.16389875544765
# [I 2023-02-07 00:38:43,079] Trial 90 finished with value: 20.515423791654975 and parameters: {'Epochs': 500, 'Hidden size': 32, 'n layers': 9, 'Learning rate': 0.0008500703913969331}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 22.71954889040963
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch:  0/100 - train_loss: 0.7099 - test_loss: 0.597240
# Epoch: 240/480 - train_loss: 0.1867 - test_loss: 0.132153
# Epoch: 479/480 - train_loss: 0.2849 - test_loss: 0.236501
# City: An Giang  _algo:lstm  -RMSE: 18.872271487194286
# City: An Giang  _algo:lstm  -RMSE: 29.00783488140367
# [I 2023-02-07 00:39:07,399] Trial 91 finished with value: 18.872271487194286 and parameters: {'Epochs': 480, 'Hidden size': 31, 'n layers': 9, 'Learning rate': 0.006953215305347023}. Best is trial 44 with value: 8.21942785619018.
# City: An Giang  _algo:lstm  -RMSE: 32.31462490770071
# <ipython-input-14-8244d6fc4512>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform('Learning rate', 1e-4, 1e-2)
# Epoch: 25/100 - train_loss: 0.2274 - test_loss: 0.128652
# Epoch:  0/350 - train_loss: 0.7452 - test_loss: 0.728271
# Epoch: 50/100 - train_loss: 0.2293 - test_loss: 0.138343
# Epoch: 75/100 - train_loss: 0.2123 - test_loss: 0.121378
# Epoch: 240/480 - train_loss: 0.1699 - test_loss: 1.066656
# Epoch: 120/480 - train_loss: 0.1759 - test_loss: 0.125432
